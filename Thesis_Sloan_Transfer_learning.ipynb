# %% [markdown]
# <a href="https://colab.research.google.com/github/sabeesh90/Multimodal-Architectures-Deep_Learning/blob/main/Thesis_Sloan_Transfer_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### <p style = "text-align:center"><font color  = 'blue'> Thesis Dissertation - Masters

# %% [markdown]
# #### Importing libraries

# %%
from PIL import Image
import requests
from io import BytesIO
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os
from skimage import io
import pathlib
import glob
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import Model
from tensorflow.keras.layers import *
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization,GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import optimizers
from sklearn.metrics import classification_report, confusion_matrix
# !pip install -q -U keras-tuner
import kerastuner as kt
# %load_ext tensorboard
warnings.filterwarnings("ignore")
# Out:
#      |████████████████████████████████| 71kB 5.9MB/s
#   Building wheel for keras-tuner (setup.py) ... done
#   Building wheel for terminaltables (setup.py) ... done

# %% [markdown]
# ### <font color = "blue"> Custom Deep Learning model

# %% [markdown]
# #### **Tensorflow conventional loading dataset from directory**

# %%
pip install Ipython
# Out:
# Requirement already satisfied: Ipython in /usr/local/lib/python3.7/dist-packages (5.5.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from Ipython) (4.4.2)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from Ipython) (1.0.18)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from Ipython) (0.7.5)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from Ipython) (0.8.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from Ipython) (57.2.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from Ipython) (4.8.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from Ipython) (5.0.5)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from Ipython) (2.6.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->Ipython) (0.2.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->Ipython) (1.15.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.7/dist-packages (from traitlets>=4.2->Ipython) (0.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->Ipython) (0.7.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     582         """
# --> 583         parts = [self.recv(flags, copy=copy, track=track)]
#     584         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-d5df0069828e> in <module>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, use_metadata_server)
#     258       with _output.use_tags('dfs-auth-dance'):
#     259         with open(fifo, 'w') as fifo_file:
# --> 260           fifo_file.write(get_code(auth_prompt) + '\n')
#     261       wrote_to_fifo = True
#     262     elif case == 5:
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %%
# %cd drive/MyDrive/Colab Notebooks

# %%
classes = ['GALAXY', 'QSO', 'STAR']

# %% [markdown]
# #### **Image augmentation code and testing using conventional tensorflow libraries**

# %% [markdown]
# ##### Non rigid transformation  - Image augmentation

# %%
data_augmentation  = tf.keras.Sequential(
    [layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"), # these are rigid transformation techniques  - flipping, rotation 
     layers.experimental.preprocessing.RandomRotation(0.2)])

data_cropping  = tf.keras.Sequential([layers.experimental.preprocessing.CenterCrop(1000,1000)])

# %%
def generate_image(c = 0, n = 0, aug = False):
    dataset_path = 'Images'
    ast_class_path  = os.path.join(dataset_path, classes[c], '*')
    print(ast_class_path)
    # n = np.random.randint(0, len(ast_class_path))
    ast_image_path = glob.glob(ast_class_path)
    # print(ast_image_path[n])
    image = io.imread(ast_image_path[n])
        
    if aug == False:
        print(image.shape)
        plt.imshow(image)
        plt.show()
    else:
        plt.figure(figsize = (15,5))  
        print(image.shape)    
        image_expanded = tf.expand_dims(image,0)
        print(image.shape)  
        augmented_image = data_augmentation(image_expanded)
        cropped_image = data_cropping(image_expanded)
        plt.figure(figsize = (15,5))
        plt.subplot(1,3,1)
        plt.title('original_image')
        plt.imshow(image)
        plt.subplot(1,3,2)
        plt.title('augmented_image')
        plt.imshow(augmented_image[0])

        plt.subplot(1,3,3)
        plt.title('cropped_image')
        plt.imshow(cropped_image[0])

# %%
generate_image(0,4, aug = True)
# Out:
# Images/GALAXY/*
# (2048, 2048, 3)
# (2048, 2048, 3)

# %% [markdown]
# #### **Defining functions for code shortening**

# %%
def generate_graph(model_training):
    plt.figure(figsize= (15,5))
    plt.subplot(1,2,1)
    plt.plot(model_training.history.history['accuracy'])
    plt.plot(model_training.history.history['val_accuracy'])
    plt.title('Training vs TestAccuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend(('Training', 'Validation'), loc = 'best')
    plt.subplot(1,2,2)
    plt.plot(model_training.history.history['loss'])
    plt.plot(model_training.history.history['val_loss'])
    plt.title('Training loss vs Test Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(('Training', 'Validation'), loc = 'best')
    plt.show()

class Metrics:
    # from sklearn
    def __init__(self, model, val_ds):
        self.val_ds = val_ds
        self.model = model
        self.prediction_classes = np.array([])
        self.true_classes = np.array([])
        
    def calculate_scores(self):     
        print('calculating score.....')   
        
        for x, y in self.val_ds:
            self.prediction_classes = np.concatenate([self.prediction_classes,np.argmax(self.model.predict(x), axis = -1)])
            self.true_classes = np.concatenate([self.true_classes, np.argmax(y.numpy(), axis=-1)])
        
        class_report = classification_report(self.true_classes, self.prediction_classes)
        conf_matrix = confusion_matrix(self.true_classes, self.prediction_classes)
        print(conf_matrix)
        print('------------------------------------')
        print(class_report)

model_name_resnet = 'sloan_resnet' +'/'    
if not os.path.exists(model_name_resnet):
    os.mkdir(model_name_resnet)        
filepath_resnet = model_name_resnet + 'model-{epoch:05d}-{loss:.5f}-{accuracy:.5f}-{val_loss:.5f}-{val_accuracy:.5f}.h5'
model_checkpoint_callback_resnet = tf.keras.callbacks.ModelCheckpoint(
    filepath=filepath_resnet,
    monitor='val_accuracy',
    mode='auto',
    save_best_only=False,
    verbose = 1
    )
callbacks_resnet = [model_checkpoint_callback_resnet]


model_name_vgg = 'sloan_vgg' +'/'    
if not os.path.exists(model_name_vgg):
    os.mkdir(model_name_vgg)        
filepath_vgg = model_name_vgg + 'model-{epoch:05d}-{loss:.5f}-{accuracy:.5f}-{val_loss:.5f}-{val_accuracy:.5f}.h5'
model_checkpoint_callback_vgg = tf.keras.callbacks.ModelCheckpoint(
    filepath=filepath_vgg,
    monitor='val_accuracy',
    mode='auto',
    save_best_only=False,
    verbose = 1
    )
callbacks_vgg = [model_checkpoint_callback_vgg]

model_name_xception = 'sloan_xception' +'/'    
if not os.path.exists(model_name_xception):
    os.mkdir(model_name_xception)        
filepath_xception = model_name_xception + 'model-{epoch:05d}-{loss:.5f}-{accuracy:.5f}-{val_loss:.5f}-{val_accuracy:.5f}.h5'
model_checkpoint_callback_xception = tf.keras.callbacks.ModelCheckpoint(
    filepath=filepath_xception,
    monitor='val_accuracy',
    mode='auto',
    save_best_only=False,
    verbose = 1
    )
callbacks_xception = [model_checkpoint_callback_xception]

model_name_efficient = 'sloan_efficient' +'/'    
if not os.path.exists(model_name_efficient):
    os.mkdir(model_name_efficient)        
filepath_efficient = model_name_efficient + 'model-{epoch:05d}-{loss:.2f}-{accuracy:.4f}-{val_loss:.2f}-{val_accuracy:.4f}.h5'
model_checkpoint_callback_efficient = tf.keras.callbacks.ModelCheckpoint(
    filepath=filepath_efficient,
    monitor='val_accuracy',
    mode='auto',
    save_best_only=False,
    verbose = 1
    )
callbacks_efficient = [model_checkpoint_callback_efficient]

model_name_dense = 'sloan_dense' +'/'    
if not os.path.exists(model_name_dense):
    os.mkdir(model_name_dense)        
filepath_dense = model_name_dense + 'model-{epoch:05d}-{loss:.2f}-{accuracy:.4f}-{val_loss:.2f}-{val_accuracy:.4f}.h5'
model_checkpoint_callback_dense = tf.keras.callbacks.ModelCheckpoint(
    filepath=filepath_dense,
    monitor='val_accuracy',
    mode='auto',
    save_best_only=False,
    verbose = 1
    )
callbacks_dense = [model_checkpoint_callback_dense]

# %% [markdown]
# #### Resnet 50

# %% [markdown]
# ##### Data preparation

# %%
# Preprocessing the data
dataset_path = 'Images'
img_width = 512
img_height = 512
channels = 3
num_classes = 3
batch_size = 8


img_width_crop = 1024
img_height_crop = 1024

rescale = tf.keras.Sequential([layers.experimental.preprocessing.Rescaling(1./255)])


# augmenting the data
# cropless flip and rotate

data_aug_flip = tf.keras.Sequential([layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
                                # layers.experimental.preprocessing.RandomRotation(0.2)])
])

data_aug_flip_rotate = tf.keras.Sequential([layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
                                layers.experimental.preprocessing.RandomRotation(0.2)])


# crop flip and rotate
data_aug_crop_flip_rotate = tf.keras.Sequential([layers.experimental.preprocessing.CenterCrop(512,512),
                                                 layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
                                                 layers.experimental.preprocessing.RandomRotation(0.2)])

data_aug_crop_flip = tf.keras.Sequential([layers.experimental.preprocessing.CenterCrop(512,512),
                                          layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical")])

normal_crop = tf.keras.Sequential([layers.experimental.preprocessing.CenterCrop(512,512)],)
batch_size =32 
autotune = tf.data.AUTOTUNE

# Preparing the normal dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(dataset_path, validation_split = 0.2,subset = 'training',seed = 123, image_size = (img_width, img_height), 
                                                                  batch_size = batch_size, label_mode = 'categorical',)
val_ds = tf.keras.preprocessing.image_dataset_from_directory(dataset_path, validation_split = 0.2,subset = 'validation',seed = 123, image_size = (img_width, img_height),
                                                                batch_size = batch_size, label_mode = 'categorical')

train_ds_cropped = tf.keras.preprocessing.image_dataset_from_directory(dataset_path, validation_split = 0.2,subset = 'training',seed = 123, image_size = (img_width_crop, img_height_crop), 
                                                                  batch_size = batch_size, label_mode = 'categorical',)
val_ds_cropped = tf.keras.preprocessing.image_dataset_from_directory(dataset_path, validation_split = 0.2,subset = 'validation',seed = 123, image_size = (img_width_crop, img_height_crop),
                                                                batch_size = batch_size, label_mode = 'categorical')


# preparing the scalred dataset
train_ds_scaled = train_ds.map(lambda x,y: (rescale(x, training = True), y), num_parallel_calls=autotune)
val_ds_scaled = val_ds.map(lambda x,y: (rescale(x, training = False), y), num_parallel_calls=autotune)
train_ds.prefetch(buffer_size=autotune)
val_ds.prefetch(buffer_size=autotune)

train_ds_scaled_cropped = train_ds_scaled.map(lambda x,y: (rescale(x, training = True), y), num_parallel_calls=autotune)
val_ds_scaled_cropped = val_ds_scaled.map(lambda x,y: (rescale(x, training = False), y), num_parallel_calls=autotune)

# augment function 
def prepare_dataset(ds, flip = False, flip_rotate = False):
    if flip == True:
        ds = ds.map(lambda x, y : (data_aug_flip(x, training = True), y), num_parallel_calls = autotune)
    elif flip_rotate == True:
        ds = ds.map(lambda x, y : (data_aug_flip_rotate(x, training = True), y), num_parallel_calls = autotune)
    
    return ds.prefetch(buffer_size =autotune)

def prepare_dataset_crop(ds, crop_flip = False, crop_flip_rotate = False):
    if crop_flip_rotate == True:
        ds = ds.map(lambda x, y : (data_aug_crop_flip_rotate(x, training = True), y), num_parallel_calls = autotune)
    elif crop_flip == True:
        ds = ds.map(lambda x, y : (data_aug_crop_flip(x, training = True), y), num_parallel_calls = autotune)
    
    return ds.prefetch(buffer_size =autotune)
    
def prepare_dataset_normal_crop(ds, training = True):
    ds = ds.map(lambda x, y : (normal_crop(x, training = training), y), num_parallel_calls = autotune)
    return ds.prefetch(buffer_size =autotune)
# 25 batches of 32 each and 7 batches of 32 each
# Out:
# Found 1000 files belonging to 3 classes.
# Using 800 files for training.
# Found 1000 files belonging to 3 classes.
# Using 200 files for validation.
# Found 1000 files belonging to 3 classes.
# Using 800 files for training.
# Found 1000 files belonging to 3 classes.
# Using 200 files for validation.

# %%
train_ds.class_names
# Out:
# ['GALAXY', 'QSO', 'STAR']

# %% [markdown]
# ##### Data Analysis

# %%
# analysing the tensor
image = next(iter(train_ds))

# checking the shape of the tensor
print(image[0][0].numpy().shape)

# Taking the 5th image  from the batch
print(image[0][5].numpy())

# outputting the image from the batch
plt.imshow(image[0][5].numpy())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-daac13f84601> in <module>()
#       1 # analysing the tensor
# ----> 2 image = next(iter(train_ds))
#       3
#       4 # checking the shape of the tensor
#       5 print(image[0][0].numpy().shape)
#
# NameError: name 'train_ds' is not defined

# %% [markdown]
# ##### Resnet model building

# %%
from tensorflow.keras.applications import  ResNet50
# loading the model
base_model = ResNet50(include_top=False, weights='imagenet', input_shape = (img_height, img_width, 3),classes = num_classes, pooling = 'avg',)
# base_model = ResNet50(include_top=False, weights='imagenet', input_shape = (img_height_crop, img_width_crop, 3),classes = num_classes, pooling = 'avg',)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 3s 0us/step

# %%
layer_count  = len(base_model.layers)
print(f'There are a total of {layer_count} in the resnet layer')
# making the base layers non trainable or freezing
break_point  = 150
for layer in base_model.layers[0:break_point]:
    layer.trainable = False
for layer in base_model.layers[break_point:]:
    layer.trainable = True

# please note higher the break point ; lesser the trainable layers lesser is the over fitting -> high breakpoint -> less over fitting
# Out:
# There are a total of 176 in the resnet layer

# %%
print(base_model.inputs)
input_layer = base_model.inputs

# Building a functional model
output = base_model.output
x = Dense(512, activation  = 'relu')(output)
x = Dense(num_classes, activation  = 'softmax')(x)
resnet_model = Model(inputs = input_layer, outputs = x)
# Out:
# [<KerasTensor: shape=(None, 512, 512, 3) dtype=float32 (created by layer 'input_1')>]

# %%
resnet_model.summary()
resnet_model.compile(optimizer = optimizers.Adam(lr=1e-4), loss = 'categorical_crossentropy', metrics = ['accuracy'])
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 512, 512, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 518, 518, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 256, 256, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 256, 256, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 256, 256, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 258, 258, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 128, 128, 64) 0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 128, 128, 64) 4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 128, 128, 64) 256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 128, 128, 64) 0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 128, 128, 64) 36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 128, 128, 64) 256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 128, 128, 64) 0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 128, 128, 256 16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 128, 128, 256 16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 128, 128, 256 1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 128, 128, 256 1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 128, 128, 256 0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 128, 128, 256 0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 128, 128, 64) 16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 128, 128, 64) 256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 128, 128, 64) 0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 128, 128, 64) 36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 128, 128, 64) 256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 128, 128, 64) 0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 128, 128, 256 16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 128, 128, 256 1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 128, 128, 256 0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 128, 128, 256 0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 128, 128, 64) 16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 128, 128, 64) 256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 128, 128, 64) 0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 128, 128, 64) 36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 128, 128, 64) 256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 128, 128, 64) 0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 128, 128, 256 16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 128, 128, 256 1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 128, 128, 256 0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 128, 128, 256 0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 64, 64, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 64, 64, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 64, 64, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 64, 64, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 64, 64, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 64, 64, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 64, 64, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 64, 64, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 64, 64, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 64, 64, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 64, 64, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 64, 64, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 64, 64, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 64, 64, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 64, 64, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 64, 64, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 64, 64, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 64, 64, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 64, 64, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 64, 64, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 64, 64, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 64, 64, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 64, 64, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 64, 64, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 64, 64, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 64, 64, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 64, 64, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 64, 64, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 64, 64, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 64, 64, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 64, 64, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 64, 64, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 64, 64, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 64, 64, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 64, 64, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 64, 64, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 64, 64, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 64, 64, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 64, 64, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 64, 64, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 64, 64, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 64, 64, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 32, 32, 256)  131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 32, 32, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 32, 32, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 32, 32, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 32, 32, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 32, 32, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 32, 32, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 32, 32, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 32, 32, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 32, 32, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 32, 32, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 32, 32, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 32, 32, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 32, 32, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 32, 32, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 32, 32, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 32, 32, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 32, 32, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 32, 32, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 32, 32, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 32, 32, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 32, 32, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 32, 32, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 32, 32, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 32, 32, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 32, 32, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 32, 32, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 32, 32, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 32, 32, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 32, 32, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 32, 32, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 32, 32, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 32, 32, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 32, 32, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 32, 32, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 32, 32, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 32, 32, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 32, 32, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 32, 32, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 32, 32, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 32, 32, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 32, 32, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 32, 32, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 32, 32, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 32, 32, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 32, 32, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 32, 32, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 32, 32, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 32, 32, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 32, 32, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 32, 32, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 32, 32, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 32, 32, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 32, 32, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 32, 32, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 32, 32, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 32, 32, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 32, 32, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 32, 32, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 32, 32, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 32, 32, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 32, 32, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 16, 16, 512)  524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 16, 16, 512)  2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 16, 16, 512)  0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 16, 16, 512)  2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 16, 16, 512)  2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 16, 16, 512)  0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 16, 16, 2048) 2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 16, 16, 2048) 1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 16, 16, 2048) 8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 16, 16, 2048) 8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 16, 16, 2048) 0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 16, 16, 2048) 0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 16, 16, 512)  1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 16, 16, 512)  2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 16, 16, 512)  0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 16, 16, 512)  2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 16, 16, 512)  2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 16, 16, 512)  0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 16, 16, 2048) 1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 16, 16, 2048) 8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 16, 16, 2048) 0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 16, 16, 2048) 0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 16, 16, 512)  1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 16, 16, 512)  2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 16, 16, 512)  0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 16, 16, 512)  2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 16, 16, 512)  2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 16, 16, 512)  0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 16, 16, 2048) 1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 16, 16, 2048) 8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 16, 16, 2048) 0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 16, 16, 2048) 0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          1049088     avg_pool[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 3)            1539        dense[0][0]
# ==================================================================================================
# Total params: 24,638,339
# Trainable params: 11,040,771
# Non-trainable params: 13,597,568
# __________________________________________________________________________________________________

# %% [markdown]
# ##### Resnet model with normalization of  image pixels

# %%
resnet_model.fit(train_ds_scaled,validation_data=val_ds_scaled,epochs = 60, verbose = 1, workers = 3, class_weight = {0:1.13, 1:8.03, 2:1}, callbacks = callbacks_resnet)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/60
# 25/25 [==============================] - 19s 446ms/step - loss: 1.7691 - accuracy: 0.3300 - val_loss: 1.3620 - val_accuracy: 0.0850
#
# Epoch 00001: val_accuracy improved from -inf to 0.08500, saving model to sloan_resnet/model-00001-1.76905-0.33000-1.36195-0.08500.h5
# Epoch 2/60
# 25/25 [==============================] - 12s 418ms/step - loss: 1.4245 - accuracy: 0.5587 - val_loss: 1.3010 - val_accuracy: 0.0850
#
# Epoch 00002: val_accuracy did not improve from 0.08500
# Epoch 3/60
# 25/25 [==============================] - 12s 409ms/step - loss: 1.0230 - accuracy: 0.7412 - val_loss: 1.4084 - val_accuracy: 0.0850
#
# Epoch 00003: val_accuracy did not improve from 0.08500
# Epoch 4/60
# 25/25 [==============================] - 12s 408ms/step - loss: 0.8655 - accuracy: 0.7675 - val_loss: 1.7018 - val_accuracy: 0.4350
#
# Epoch 00004: val_accuracy improved from 0.08500 to 0.43500, saving model to sloan_resnet/model-00004-0.86550-0.76750-1.70185-0.43500.h5
# Epoch 5/60
# 25/25 [==============================] - 12s 413ms/step - loss: 0.6720 - accuracy: 0.8338 - val_loss: 2.6276 - val_accuracy: 0.0850
#
# Epoch 00005: val_accuracy did not improve from 0.43500
# Epoch 6/60
# 25/25 [==============================] - 12s 413ms/step - loss: 0.6398 - accuracy: 0.8512 - val_loss: 3.5946 - val_accuracy: 0.0850
#
# Epoch 00006: val_accuracy did not improve from 0.43500
# Epoch 7/60
# 25/25 [==============================] - 12s 410ms/step - loss: 0.5654 - accuracy: 0.8637 - val_loss: 1.1965 - val_accuracy: 0.1000
#
# Epoch 00007: val_accuracy did not improve from 0.43500
# Epoch 8/60
# 25/25 [==============================] - 12s 408ms/step - loss: 0.5738 - accuracy: 0.8637 - val_loss: 1.2883 - val_accuracy: 0.5600
#
# Epoch 00008: val_accuracy improved from 0.43500 to 0.56000, saving model to sloan_resnet/model-00008-0.57384-0.86375-1.28830-0.56000.h5
# Epoch 9/60
# 25/25 [==============================] - 12s 416ms/step - loss: 0.5925 - accuracy: 0.8475 - val_loss: 9.2259 - val_accuracy: 0.0850
#
# Epoch 00009: val_accuracy did not improve from 0.56000
# Epoch 10/60
# 25/25 [==============================] - 12s 410ms/step - loss: 0.5137 - accuracy: 0.9075 - val_loss: 5.4938 - val_accuracy: 0.0850
#
# Epoch 00010: val_accuracy did not improve from 0.56000
# Epoch 11/60
# 25/25 [==============================] - 12s 411ms/step - loss: 0.4847 - accuracy: 0.8813 - val_loss: 4.0233 - val_accuracy: 0.1050
#
# Epoch 00011: val_accuracy did not improve from 0.56000
# Epoch 12/60
# 25/25 [==============================] - 12s 413ms/step - loss: 0.6829 - accuracy: 0.8475 - val_loss: 3.6725 - val_accuracy: 0.4800
#
# Epoch 00012: val_accuracy did not improve from 0.56000
# Epoch 13/60
# 25/25 [==============================] - 12s 408ms/step - loss: 0.5249 - accuracy: 0.8625 - val_loss: 3.4123 - val_accuracy: 0.4800
#
# Epoch 00013: val_accuracy did not improve from 0.56000
# Epoch 14/60
# 25/25 [==============================] - 12s 411ms/step - loss: 0.4576 - accuracy: 0.9038 - val_loss: 3.1843 - val_accuracy: 0.4800
#
# Epoch 00014: val_accuracy did not improve from 0.56000
# Epoch 15/60
# 25/25 [==============================] - 12s 407ms/step - loss: 0.4674 - accuracy: 0.8863 - val_loss: 2.1867 - val_accuracy: 0.4800
#
# Epoch 00015: val_accuracy did not improve from 0.56000
# Epoch 16/60
# 25/25 [==============================] - 12s 410ms/step - loss: 0.4786 - accuracy: 0.8963 - val_loss: 2.9216 - val_accuracy: 0.4800
#
# Epoch 00016: val_accuracy did not improve from 0.56000
# Epoch 17/60
# 25/25 [==============================] - 12s 408ms/step - loss: 0.4806 - accuracy: 0.8925 - val_loss: 4.8269 - val_accuracy: 0.4800
#
# Epoch 00017: val_accuracy did not improve from 0.56000
# Epoch 18/60
# 25/25 [==============================] - 12s 409ms/step - loss: 0.5025 - accuracy: 0.8737 - val_loss: 3.3837 - val_accuracy: 0.4800
#
# Epoch 00018: val_accuracy did not improve from 0.56000
# Epoch 19/60
# 25/25 [==============================] - 12s 406ms/step - loss: 0.4555 - accuracy: 0.8888 - val_loss: 5.2124 - val_accuracy: 0.0850
#
# Epoch 00019: val_accuracy did not improve from 0.56000
# Epoch 20/60
# 25/25 [==============================] - 12s 408ms/step - loss: 0.4809 - accuracy: 0.8838 - val_loss: 1.9748 - val_accuracy: 0.0850
#
# Epoch 00020: val_accuracy did not improve from 0.56000
# Epoch 21/60
# 25/25 [==============================] - 12s 408ms/step - loss: 0.5065 - accuracy: 0.8612 - val_loss: 6.3819 - val_accuracy: 0.4800
#
# Epoch 00021: val_accuracy did not improve from 0.56000
# Epoch 22/60
# 25/25 [==============================] - 12s 416ms/step - loss: 0.4202 - accuracy: 0.9175 - val_loss: 4.1943 - val_accuracy: 0.0850
#
# Epoch 00022: val_accuracy did not improve from 0.56000
# Epoch 23/60
# 25/25 [==============================] - 12s 406ms/step - loss: 0.4560 - accuracy: 0.9062 - val_loss: 10.0817 - val_accuracy: 0.0850
#
# Epoch 00023: val_accuracy did not improve from 0.56000
# Epoch 24/60
# 25/25 [==============================] - 12s 409ms/step - loss: 0.5078 - accuracy: 0.8662 - val_loss: 1.8979 - val_accuracy: 0.1350
#
# Epoch 00024: val_accuracy did not improve from 0.56000
# Epoch 25/60
# 25/25 [==============================] - 12s 409ms/step - loss: 0.4677 - accuracy: 0.8775 - val_loss: 0.8326 - val_accuracy: 0.5550
#
# Epoch 00025: val_accuracy did not improve from 0.56000
# Epoch 26/60
# 25/25 [==============================] - 12s 410ms/step - loss: 0.3894 - accuracy: 0.9125 - val_loss: 3.6850 - val_accuracy: 0.0850
#
# Epoch 00026: val_accuracy did not improve from 0.56000
# Epoch 27/60
# 25/25 [==============================] - 12s 410ms/step - loss: 0.4386 - accuracy: 0.8988 - val_loss: 12.9353 - val_accuracy: 0.4350
#
# Epoch 00027: val_accuracy did not improve from 0.56000
# Epoch 28/60
# 25/25 [==============================] - 12s 408ms/step - loss: 0.5754 - accuracy: 0.8875 - val_loss: 2.2570 - val_accuracy: 0.4350
#
# Epoch 00028: val_accuracy did not improve from 0.56000
# Epoch 29/60
# 25/25 [==============================] - 12s 412ms/step - loss: 0.4806 - accuracy: 0.8800 - val_loss: 6.6955 - val_accuracy: 0.0850
#
# Epoch 00029: val_accuracy did not improve from 0.56000
# Epoch 30/60
# 25/25 [==============================] - 12s 407ms/step - loss: 0.4538 - accuracy: 0.8888 - val_loss: 3.9918 - val_accuracy: 0.2900
#
# Epoch 00030: val_accuracy did not improve from 0.56000
# Epoch 31/60
# 25/25 [==============================] - 12s 407ms/step - loss: 0.4469 - accuracy: 0.8913 - val_loss: 19.5304 - val_accuracy: 0.0850
#
# Epoch 00031: val_accuracy did not improve from 0.56000
# Epoch 32/60
# 25/25 [==============================] - 12s 409ms/step - loss: 0.4153 - accuracy: 0.9150 - val_loss: 11.7496 - val_accuracy: 0.0850
#
# Epoch 00032: val_accuracy did not improve from 0.56000
# Epoch 33/60
# 25/25 [==============================] - 12s 408ms/step - loss: 0.4261 - accuracy: 0.9013 - val_loss: 18.5654 - val_accuracy: 0.0850
#
# Epoch 00033: val_accuracy did not improve from 0.56000
# Epoch 34/60
# 25/25 [==============================] - 12s 410ms/step - loss: 0.3861 - accuracy: 0.9162 - val_loss: 2.3958 - val_accuracy: 0.5400
#
# Epoch 00034: val_accuracy did not improve from 0.56000
# Epoch 35/60
# 25/25 [==============================] - 12s 411ms/step - loss: 0.4268 - accuracy: 0.9000 - val_loss: 11.8574 - val_accuracy: 0.0850
#
# Epoch 00035: val_accuracy did not improve from 0.56000
# Epoch 36/60
# 25/25 [==============================] - 12s 415ms/step - loss: 0.4313 - accuracy: 0.9050 - val_loss: 3.1099 - val_accuracy: 0.2450
#
# Epoch 00036: val_accuracy did not improve from 0.56000
# Epoch 37/60
# 25/25 [==============================] - 12s 408ms/step - loss: 0.4285 - accuracy: 0.9087 - val_loss: 6.1795 - val_accuracy: 0.4350
#
# Epoch 00037: val_accuracy did not improve from 0.56000
# Epoch 38/60
# 25/25 [==============================] - 12s 408ms/step - loss: 0.3939 - accuracy: 0.9112 - val_loss: 2.9875 - val_accuracy: 0.4800
#
# Epoch 00038: val_accuracy did not improve from 0.56000
# Epoch 39/60
# 25/25 [==============================] - 12s 411ms/step - loss: 0.3777 - accuracy: 0.9212 - val_loss: 15.1715 - val_accuracy: 0.4350
#
# Epoch 00039: val_accuracy did not improve from 0.56000
# Epoch 40/60
# 25/25 [==============================] - 12s 412ms/step - loss: 0.3297 - accuracy: 0.9300 - val_loss: 6.4304 - val_accuracy: 0.4350
#
# Epoch 00040: val_accuracy did not improve from 0.56000
# Epoch 41/60
# 25/25 [==============================] - 12s 410ms/step - loss: 0.5061 - accuracy: 0.8763 - val_loss: 25.0576 - val_accuracy: 0.4350
#
# Epoch 00041: val_accuracy did not improve from 0.56000
# Epoch 42/60
# 25/25 [==============================] - 12s 408ms/step - loss: 0.4224 - accuracy: 0.9062 - val_loss: 8.1782 - val_accuracy: 0.4350
#
# Epoch 00042: val_accuracy did not improve from 0.56000
# Epoch 43/60
# 25/25 [==============================] - 12s 413ms/step - loss: 0.4178 - accuracy: 0.8988 - val_loss: 6.1319 - val_accuracy: 0.4350
#
# Epoch 00043: val_accuracy did not improve from 0.56000
# Epoch 44/60
# 25/25 [==============================] - 12s 410ms/step - loss: 0.5171 - accuracy: 0.8900 - val_loss: 51.6387 - val_accuracy: 0.4350
#
# Epoch 00044: val_accuracy did not improve from 0.56000
# Epoch 45/60
# 25/25 [==============================] - 12s 410ms/step - loss: 0.4277 - accuracy: 0.9025 - val_loss: 18.5273 - val_accuracy: 0.4350
#
# Epoch 00045: val_accuracy did not improve from 0.56000
# Epoch 46/60
# 25/25 [==============================] - 12s 411ms/step - loss: 0.4017 - accuracy: 0.9112 - val_loss: 7.3638 - val_accuracy: 0.4350
#
# Epoch 00046: val_accuracy did not improve from 0.56000
# Epoch 47/60
# 25/25 [==============================] - 12s 409ms/step - loss: 0.4597 - accuracy: 0.8963 - val_loss: 8.1892 - val_accuracy: 0.1150
#
# Epoch 00047: val_accuracy did not improve from 0.56000
# Epoch 48/60
# 25/25 [==============================] - 12s 408ms/step - loss: 0.4635 - accuracy: 0.9000 - val_loss: 13.4232 - val_accuracy: 0.0850
#
# Epoch 00048: val_accuracy did not improve from 0.56000
# Epoch 49/60
# 25/25 [==============================] - 12s 413ms/step - loss: 0.3732 - accuracy: 0.9112 - val_loss: 4.2035 - val_accuracy: 0.0850
#
# Epoch 00049: val_accuracy did not improve from 0.56000
# Epoch 50/60
# 25/25 [==============================] - 12s 410ms/step - loss: 0.4423 - accuracy: 0.8938 - val_loss: 3.9131 - val_accuracy: 0.0850
#
# Epoch 00050: val_accuracy did not improve from 0.56000
# Epoch 51/60
# 25/25 [==============================] - 12s 407ms/step - loss: 0.4015 - accuracy: 0.9237 - val_loss: 1.7174 - val_accuracy: 0.2950
#
# Epoch 00051: val_accuracy did not improve from 0.56000
# Epoch 52/60
# 25/25 [==============================] - 12s 407ms/step - loss: 0.4043 - accuracy: 0.8925 - val_loss: 8.4831 - val_accuracy: 0.4800
#
# Epoch 00052: val_accuracy did not improve from 0.56000
# Epoch 53/60
# 25/25 [==============================] - 12s 415ms/step - loss: 0.3660 - accuracy: 0.9312 - val_loss: 0.8172 - val_accuracy: 0.8100
#
# Epoch 00053: val_accuracy improved from 0.56000 to 0.81000, saving model to sloan_resnet/model-00053-0.36601-0.93125-0.81719-0.81000.h5
# Epoch 54/60
# 25/25 [==============================] - 12s 412ms/step - loss: 0.2996 - accuracy: 0.9425 - val_loss: 2.7036 - val_accuracy: 0.0900
#
# Epoch 00054: val_accuracy did not improve from 0.81000
# Epoch 55/60
# 25/25 [==============================] - 12s 409ms/step - loss: 0.3407 - accuracy: 0.9175 - val_loss: 0.8385 - val_accuracy: 0.6600
#
# Epoch 00055: val_accuracy did not improve from 0.81000
# Epoch 56/60
# 25/25 [==============================] - 12s 413ms/step - loss: 0.3091 - accuracy: 0.9375 - val_loss: 6.8202 - val_accuracy: 0.4350
#
# Epoch 00056: val_accuracy did not improve from 0.81000
# Epoch 57/60
# 25/25 [==============================] - 12s 407ms/step - loss: 0.3348 - accuracy: 0.9287 - val_loss: 7.6971 - val_accuracy: 0.4600
#
# Epoch 00057: val_accuracy did not improve from 0.81000
# Epoch 58/60
# 25/25 [==============================] - 12s 409ms/step - loss: 0.3279 - accuracy: 0.9250 - val_loss: 7.6423 - val_accuracy: 0.1200
#
# Epoch 00058: val_accuracy did not improve from 0.81000
# Epoch 59/60
# 25/25 [==============================] - 12s 410ms/step - loss: 0.3380 - accuracy: 0.9287 - val_loss: 25.6750 - val_accuracy: 0.4350
#
# Epoch 00059: val_accuracy did not improve from 0.81000
# Epoch 60/60
# 25/25 [==============================] - 12s 408ms/step - loss: 0.3223 - accuracy: 0.9312 - val_loss: 10.0078 - val_accuracy: 0.4350
#
# Epoch 00060: val_accuracy did not improve from 0.81000

# %% [markdown]
# ##### Resnet model without scaling of images

# %%
resnet_model.fit(train_ds,validation_data=val_ds, epochs = 10, verbose = 1, workers = 3, class_weight = {0:1.13, 1:8.03, 2:1}, callbacks = callbacks_resnet)
# Out:
# Epoch 1/10
# 25/25 [==============================] - 13s 460ms/step - loss: 0.6505 - accuracy: 0.8737 - val_loss: 0.3098 - val_accuracy: 0.8650
#
# Epoch 00001: val_accuracy improved from 0.81000 to 0.86500, saving model to sloan_resnet/model-00001-0.65051-0.87375-0.30978-0.86500.h5
# Epoch 2/10
# 25/25 [==============================] - 12s 417ms/step - loss: 0.2463 - accuracy: 0.9388 - val_loss: 0.3468 - val_accuracy: 0.9000
#
# Epoch 00002: val_accuracy improved from 0.86500 to 0.90000, saving model to sloan_resnet/model-00002-0.24633-0.93875-0.34678-0.90000.h5
# Epoch 3/10
# 25/25 [==============================] - 12s 418ms/step - loss: 0.0992 - accuracy: 0.9775 - val_loss: 0.4575 - val_accuracy: 0.8950
#
# Epoch 00003: val_accuracy did not improve from 0.90000
# Epoch 4/10
# 25/25 [==============================] - 12s 413ms/step - loss: 0.0299 - accuracy: 0.9950 - val_loss: 0.2832 - val_accuracy: 0.9100
#
# Epoch 00004: val_accuracy improved from 0.90000 to 0.91000, saving model to sloan_resnet/model-00004-0.02992-0.99500-0.28320-0.91000.h5
# Epoch 5/10
# 25/25 [==============================] - 12s 419ms/step - loss: 0.0171 - accuracy: 0.9987 - val_loss: 0.4379 - val_accuracy: 0.8950
#
# Epoch 00005: val_accuracy did not improve from 0.91000
# Epoch 6/10
# 25/25 [==============================] - 12s 415ms/step - loss: 0.0101 - accuracy: 0.9962 - val_loss: 0.3594 - val_accuracy: 0.9100
#
# Epoch 00006: val_accuracy did not improve from 0.91000
# Epoch 7/10
# 25/25 [==============================] - 12s 409ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.2843 - val_accuracy: 0.9100
#
# Epoch 00007: val_accuracy did not improve from 0.91000
# Epoch 8/10
# 25/25 [==============================] - 12s 411ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.3081 - val_accuracy: 0.9100
#
# Epoch 00008: val_accuracy did not improve from 0.91000
# Epoch 9/10
# 25/25 [==============================] - 12s 410ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.3374 - val_accuracy: 0.9200
#
# Epoch 00009: val_accuracy improved from 0.91000 to 0.92000, saving model to sloan_resnet/model-00009-0.00201-1.00000-0.33735-0.92000.h5
# Epoch 10/10
# 25/25 [==============================] - 12s 420ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.3153 - val_accuracy: 0.9150
#
# Epoch 00010: val_accuracy did not improve from 0.92000

# %% [markdown]
# ##### Augmentation Experiments

# %%
train_ds_flip = prepare_dataset(train_ds, flip= True)
train_ds_flip_rotate = prepare_dataset(train_ds, flip_rotate = True)
train_ds_crop_flip = prepare_dataset_crop(train_ds_cropped, crop_flip = True)
train_ds_crop_flip_rotate = prepare_dataset_crop(train_ds_cropped, crop_flip_rotate = True)

resnet_non_scaled_flip = load_model('./sloan_resnet/resenet_non_normalized_93_90.h5')
resnet_non_scaled_flip_rotate = load_model('./sloan_resnet/resenet_non_normalized_93_90.h5')
resnet_non_scaled_crop_flip = load_model('./sloan_resnet/resenet_non_normalized_93_90.h5')
resnet_non_scaled_crop_flip_rotate = load_model('./sloan_resnet/resenet_non_normalized_93_90.h5')

# %% [markdown]
# ##### resnet_non_scaled_flip_model

# %%
resnet_non_scaled_flip.fit(train_ds_flip,validation_data=val_ds, epochs = 10, verbose = 1, workers = 3, class_weight = {0:1.13, 1:8.03, 2:1}, callbacks = callbacks_resnet)
# Out:
# Epoch 1/10
# 25/25 [==============================] - 16s 468ms/step - loss: 0.2681 - accuracy: 0.9388 - val_loss: 0.3596 - val_accuracy: 0.8850
#
# Epoch 00001: val_accuracy did not improve from 0.92000
# Epoch 2/10
# 25/25 [==============================] - 13s 438ms/step - loss: 0.2421 - accuracy: 0.9650 - val_loss: 0.2513 - val_accuracy: 0.9350
#
# Epoch 00002: val_accuracy improved from 0.92000 to 0.93500, saving model to sloan_resnet/model-00002-0.24208-0.96500-0.25134-0.93500.h5
# Epoch 3/10
# 25/25 [==============================] - 13s 439ms/step - loss: 0.1492 - accuracy: 0.9688 - val_loss: 0.3441 - val_accuracy: 0.8800
#
# Epoch 00003: val_accuracy did not improve from 0.93500
# Epoch 4/10
# 25/25 [==============================] - 13s 432ms/step - loss: 0.2225 - accuracy: 0.9650 - val_loss: 0.4190 - val_accuracy: 0.9050
#
# Epoch 00004: val_accuracy did not improve from 0.93500
# Epoch 5/10
# 25/25 [==============================] - 13s 431ms/step - loss: 0.1894 - accuracy: 0.9575 - val_loss: 0.2439 - val_accuracy: 0.9400
#
# Epoch 00005: val_accuracy improved from 0.93500 to 0.94000, saving model to sloan_resnet/model-00005-0.18939-0.95750-0.24390-0.94000.h5
# Epoch 6/10
# 25/25 [==============================] - 13s 442ms/step - loss: 0.0953 - accuracy: 0.9762 - val_loss: 0.1986 - val_accuracy: 0.9300
#
# Epoch 00006: val_accuracy did not improve from 0.94000
# Epoch 7/10
# 25/25 [==============================] - 13s 432ms/step - loss: 0.0605 - accuracy: 0.9900 - val_loss: 0.1927 - val_accuracy: 0.9450
#
# Epoch 00007: val_accuracy improved from 0.94000 to 0.94500, saving model to sloan_resnet/model-00007-0.06046-0.99000-0.19267-0.94500.h5
# Epoch 8/10
# 25/25 [==============================] - 13s 442ms/step - loss: 0.0692 - accuracy: 0.9850 - val_loss: 0.2387 - val_accuracy: 0.9200
#
# Epoch 00008: val_accuracy did not improve from 0.94500
# Epoch 9/10
# 25/25 [==============================] - 13s 434ms/step - loss: 0.0459 - accuracy: 0.9900 - val_loss: 0.1961 - val_accuracy: 0.9350
#
# Epoch 00009: val_accuracy did not improve from 0.94500
# Epoch 10/10
# 25/25 [==============================] - 13s 434ms/step - loss: 0.0246 - accuracy: 0.9962 - val_loss: 0.2494 - val_accuracy: 0.9200
#
# Epoch 00010: val_accuracy did not improve from 0.94500

# %%
##### resnet_non_scaled_flip_rotate_model

# %% [markdown]
# ##### resnet_non_scaled_flip_rotate_model

# %%
resnet_non_scaled_flip_rotate.fit(train_ds_flip_rotate,validation_data=val_ds, epochs = 10, verbose = 1, workers = 3, class_weight = {0:1.13, 1:8.03, 2:1}, callbacks = callbacks_resnet)
# Out:
# Epoch 1/10
# 25/25 [==============================] - 22s 669ms/step - loss: 0.3623 - accuracy: 0.9162 - val_loss: 0.3759 - val_accuracy: 0.8700
#
# Epoch 00001: saving model to sloan_resnet/model-00001-0.36227-0.91625-0.37592-0.87000.h5
# Epoch 2/10
# 25/25 [==============================] - 19s 651ms/step - loss: 0.3864 - accuracy: 0.9150 - val_loss: 0.4069 - val_accuracy: 0.8800
#
# Epoch 00002: saving model to sloan_resnet/model-00002-0.38636-0.91500-0.40685-0.88000.h5
# Epoch 3/10
# 25/25 [==============================] - 19s 656ms/step - loss: 0.4448 - accuracy: 0.9200 - val_loss: 0.9938 - val_accuracy: 0.8050
#
# Epoch 00003: saving model to sloan_resnet/model-00003-0.44485-0.92000-0.99381-0.80500.h5
# Epoch 4/10
# 25/25 [==============================] - 19s 652ms/step - loss: 0.2627 - accuracy: 0.9475 - val_loss: 0.2465 - val_accuracy: 0.9400
#
# Epoch 00004: saving model to sloan_resnet/model-00004-0.26267-0.94750-0.24654-0.94000.h5
# Epoch 5/10
# 25/25 [==============================] - 19s 637ms/step - loss: 0.2648 - accuracy: 0.9488 - val_loss: 0.3649 - val_accuracy: 0.8850
#
# Epoch 00005: saving model to sloan_resnet/model-00005-0.26482-0.94875-0.36488-0.88500.h5
# Epoch 6/10
# 25/25 [==============================] - 19s 647ms/step - loss: 0.3546 - accuracy: 0.9237 - val_loss: 0.2884 - val_accuracy: 0.9250
#
# Epoch 00006: saving model to sloan_resnet/model-00006-0.35461-0.92375-0.28842-0.92500.h5
# Epoch 7/10
# 25/25 [==============================] - 19s 668ms/step - loss: 0.1763 - accuracy: 0.9625 - val_loss: 0.3671 - val_accuracy: 0.9250
#
# Epoch 00007: saving model to sloan_resnet/model-00007-0.17633-0.96250-0.36714-0.92500.h5
# Epoch 8/10
# 25/25 [==============================] - 19s 653ms/step - loss: 0.1090 - accuracy: 0.9837 - val_loss: 0.2501 - val_accuracy: 0.9450
#
# Epoch 00008: saving model to sloan_resnet/model-00008-0.10895-0.98375-0.25007-0.94500.h5
# Epoch 9/10
# 25/25 [==============================] - 19s 665ms/step - loss: 0.1714 - accuracy: 0.9625 - val_loss: 0.3522 - val_accuracy: 0.9250
#
# Epoch 00009: saving model to sloan_resnet/model-00009-0.17141-0.96250-0.35222-0.92500.h5
# Epoch 10/10
# 25/25 [==============================] - 19s 656ms/step - loss: 0.0888 - accuracy: 0.9800 - val_loss: 0.3357 - val_accuracy: 0.9350
#
# Epoch 00010: saving model to sloan_resnet/model-00010-0.08881-0.98000-0.33568-0.93500.h5

# %%
generate_graph(resnet_non_scaled_flip_rotate)

# %%
##### Resnet non scaled crop flip

# %% [markdown]
# ##### Resnet non scaled crop flip

# %%
resnet_non_scaled_crop_flip.fit(train_ds_crop_flip,validation_data=val_ds, epochs = 10, verbose = 1, workers = 3, class_weight = {0:1.13, 1:8.03, 2:1}, callbacks = callbacks_resnet)
# Out:
# Epoch 1/10
# 25/25 [==============================] - 21s 633ms/step - loss: 0.6519 - accuracy: 0.8763 - val_loss: 2.0037 - val_accuracy: 0.5300
#
# Epoch 00001: saving model to sloan_resnet/model-00001-0.65191-0.87625-2.00372-0.53000.h5
# Epoch 2/10
# 25/25 [==============================] - 18s 594ms/step - loss: 0.3132 - accuracy: 0.9413 - val_loss: 1.8513 - val_accuracy: 0.6000
#
# Epoch 00002: saving model to sloan_resnet/model-00002-0.31316-0.94125-1.85134-0.60000.h5
# Epoch 3/10
# 25/25 [==============================] - 18s 594ms/step - loss: 0.1990 - accuracy: 0.9588 - val_loss: 2.7986 - val_accuracy: 0.4350
#
# Epoch 00003: saving model to sloan_resnet/model-00003-0.19897-0.95875-2.79857-0.43500.h5
# Epoch 4/10
# 25/25 [==============================] - 18s 595ms/step - loss: 0.1870 - accuracy: 0.9688 - val_loss: 2.1475 - val_accuracy: 0.4600
#
# Epoch 00004: saving model to sloan_resnet/model-00004-0.18705-0.96875-2.14752-0.46000.h5
# Epoch 5/10
# 25/25 [==============================] - 18s 578ms/step - loss: 0.1953 - accuracy: 0.9588 - val_loss: 5.1180 - val_accuracy: 0.2900
#
# Epoch 00005: saving model to sloan_resnet/model-00005-0.19535-0.95875-5.11804-0.29000.h5
# Epoch 6/10
# 25/25 [==============================] - 18s 591ms/step - loss: 0.0879 - accuracy: 0.9775 - val_loss: 3.0374 - val_accuracy: 0.3900
#
# Epoch 00006: saving model to sloan_resnet/model-00006-0.08791-0.97750-3.03742-0.39000.h5
# Epoch 7/10
# 25/25 [==============================] - 18s 602ms/step - loss: 0.0771 - accuracy: 0.9837 - val_loss: 4.3213 - val_accuracy: 0.3050
#
# Epoch 00007: saving model to sloan_resnet/model-00007-0.07714-0.98375-4.32134-0.30500.h5
# Epoch 8/10
# 25/25 [==============================] - 18s 605ms/step - loss: 0.0887 - accuracy: 0.9812 - val_loss: 2.1874 - val_accuracy: 0.5150
#
# Epoch 00008: saving model to sloan_resnet/model-00008-0.08868-0.98125-2.18737-0.51500.h5
# Epoch 9/10
# 25/25 [==============================] - 18s 606ms/step - loss: 0.0273 - accuracy: 0.9962 - val_loss: 3.4870 - val_accuracy: 0.4000
#
# Epoch 00009: saving model to sloan_resnet/model-00009-0.02733-0.99625-3.48698-0.40000.h5
# Epoch 10/10
# 25/25 [==============================] - 18s 588ms/step - loss: 0.1208 - accuracy: 0.9787 - val_loss: 2.3537 - val_accuracy: 0.5100
#
# Epoch 00010: saving model to sloan_resnet/model-00010-0.12076-0.97875-2.35374-0.51000.h5

# %%
generate_graph(resnet_non_scaled_crop_flip)

# %% [markdown]
# ##### Resnet non normalized crop flip and rotate

# %%
resnet_non_scaled_crop_flip_rotate.fit(train_ds_crop_flip_rotate,validation_data=val_ds, epochs = 10, verbose = 1, workers = 3, class_weight = {0:1.13, 1:8.03, 2:1}, callbacks = callbacks_resnet)
# Out:
# Epoch 1/10
# 25/25 [==============================] - 26s 809ms/step - loss: 0.6087 - accuracy: 0.8875 - val_loss: 2.2722 - val_accuracy: 0.4750
#
# Epoch 00001: saving model to sloan_resnet/model-00001-0.60873-0.88750-2.27223-0.47500.h5
# Epoch 2/10
# 25/25 [==============================] - 23s 773ms/step - loss: 0.4571 - accuracy: 0.8975 - val_loss: 2.7879 - val_accuracy: 0.4600
#
# Epoch 00002: saving model to sloan_resnet/model-00002-0.45712-0.89750-2.78795-0.46000.h5
# Epoch 3/10
# 25/25 [==============================] - 23s 742ms/step - loss: 0.3124 - accuracy: 0.9425 - val_loss: 2.9061 - val_accuracy: 0.4250
#
# Epoch 00003: saving model to sloan_resnet/model-00003-0.31242-0.94250-2.90613-0.42500.h5
# Epoch 4/10
# 25/25 [==============================] - 23s 762ms/step - loss: 0.2712 - accuracy: 0.9500 - val_loss: 3.4955 - val_accuracy: 0.4250
#
# Epoch 00004: saving model to sloan_resnet/model-00004-0.27124-0.95000-3.49550-0.42500.h5
# Epoch 5/10
# 25/25 [==============================] - 23s 770ms/step - loss: 0.2810 - accuracy: 0.9337 - val_loss: 3.8157 - val_accuracy: 0.3400
#
# Epoch 00005: saving model to sloan_resnet/model-00005-0.28102-0.93375-3.81568-0.34000.h5
# Epoch 6/10
# 25/25 [==============================] - 23s 775ms/step - loss: 0.2400 - accuracy: 0.9488 - val_loss: 2.4563 - val_accuracy: 0.4200
#
# Epoch 00006: saving model to sloan_resnet/model-00006-0.24001-0.94875-2.45633-0.42000.h5
# Epoch 7/10
# 25/25 [==============================] - 23s 781ms/step - loss: 0.3144 - accuracy: 0.9425 - val_loss: 5.9452 - val_accuracy: 0.2900
#
# Epoch 00007: saving model to sloan_resnet/model-00007-0.31443-0.94250-5.94519-0.29000.h5
# Epoch 8/10
# 25/25 [==============================] - 23s 767ms/step - loss: 0.2494 - accuracy: 0.9350 - val_loss: 4.6355 - val_accuracy: 0.4050
#
# Epoch 00008: saving model to sloan_resnet/model-00008-0.24939-0.93500-4.63546-0.40500.h5
# Epoch 9/10
# 25/25 [==============================] - 23s 760ms/step - loss: 0.1754 - accuracy: 0.9463 - val_loss: 3.0925 - val_accuracy: 0.3750
#
# Epoch 00009: saving model to sloan_resnet/model-00009-0.17544-0.94625-3.09247-0.37500.h5
# Epoch 10/10
# 25/25 [==============================] - 23s 769ms/step - loss: 0.1360 - accuracy: 0.9712 - val_loss: 3.1707 - val_accuracy: 0.3400
#
# Epoch 00010: saving model to sloan_resnet/model-00010-0.13596-0.97125-3.17065-0.34000.h5

# %% [markdown]
# ##### Resnet  - Preprocessing cropped as dataset not augmentation

# %%
train_ds_normal_crop = prepare_dataset_normal_crop(train_ds_cropped) 
val_ds_normal_crop = prepare_dataset_normal_crop(val_ds_cropped, training = False)
resnet_model.fit(train_ds_normal_crop, validation_data = val_ds_normal_crop, epochs = 10, verbose = 1, workers = 3, class_weight = {0:1.13, 1:8.03, 2:1}, callbacks = callbacks_resnet)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/10
# 25/25 [==============================] - 116s 3s/step - loss: 0.8338 - accuracy: 0.8138 - val_loss: 0.3512 - val_accuracy: 0.8750
#
# Epoch 00001: saving model to sloan_resnet/model-00001-0.83378-0.81375-0.35125-0.87500.h5
# Epoch 2/10
# 25/25 [==============================] - 14s 453ms/step - loss: 0.1558 - accuracy: 0.9712 - val_loss: 0.3413 - val_accuracy: 0.8750
#
# Epoch 00002: saving model to sloan_resnet/model-00002-0.15582-0.97125-0.34129-0.87500.h5
# Epoch 3/10
# 25/25 [==============================] - 14s 454ms/step - loss: 0.1049 - accuracy: 0.9787 - val_loss: 0.5441 - val_accuracy: 0.7950
#
# Epoch 00003: saving model to sloan_resnet/model-00003-0.10486-0.97875-0.54411-0.79500.h5
# Epoch 4/10
# 25/25 [==============================] - 14s 455ms/step - loss: 0.0301 - accuracy: 0.9937 - val_loss: 0.3461 - val_accuracy: 0.9100
#
# Epoch 00004: saving model to sloan_resnet/model-00004-0.03014-0.99375-0.34610-0.91000.h5
# Epoch 5/10
# 25/25 [==============================] - 14s 453ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.2663 - val_accuracy: 0.9200
#
# Epoch 00005: saving model to sloan_resnet/model-00005-0.01100-1.00000-0.26630-0.92000.h5
# Epoch 6/10
# 25/25 [==============================] - 14s 453ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.2005 - val_accuracy: 0.9400
#
# Epoch 00006: saving model to sloan_resnet/model-00006-0.00548-1.00000-0.20046-0.94000.h5
# Epoch 7/10
# 25/25 [==============================] - 14s 455ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.2210 - val_accuracy: 0.9450
#
# Epoch 00007: saving model to sloan_resnet/model-00007-0.00404-1.00000-0.22095-0.94500.h5
# Epoch 8/10
# 25/25 [==============================] - 14s 457ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.2194 - val_accuracy: 0.9600
#
# Epoch 00008: saving model to sloan_resnet/model-00008-0.00176-1.00000-0.21938-0.96000.h5
# Epoch 9/10
# 25/25 [==============================] - 14s 452ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2073 - val_accuracy: 0.9500
#
# Epoch 00009: saving model to sloan_resnet/model-00009-0.00218-1.00000-0.20732-0.95000.h5
# Epoch 10/10
# 25/25 [==============================] - 14s 458ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2038 - val_accuracy: 0.9450
#
# Epoch 00010: saving model to sloan_resnet/model-00010-0.00122-1.00000-0.20381-0.94500.h5

# %%
generate_graph(resnet_model)

# %% [markdown]
# ##### Model Evaluation

# %%
resnet_normalized_43 = load_model('./sloan_resnet/resnet_normalized_43.h5')
resenet_non_normalized_93_90 = load_model('./sloan_resnet/resenet_non_normalized_93_90.h5')
resnet_non_normalized_flip_957_94 = load_model('./sloan_resnet/resnet_non_normalized_flip_95.7_94.h5')
resnet_non_normalized_flip_rotate_9475_94 = load_model('./sloan_resnet/resnet_non_normalized_flip_rotate_94.75_94.h5')
resnet_non_normalized_crop_flip_94_60 = load_model('./sloan_resnet/resnet_non_normalized_crop_flip_94_60.h5')
resnet_non_normalized_flip_crop_rotate_88_47 = load_model('./sloan_resnet/resnet_non_normalized_flip_crop_rotate_88_47.h5')
resnet_preprocessing_crop = load_model('./sloan_resnet/Resnet_normal_crop_non_aug-0.011-0.9975-0.24-0.93.h5')

# %%
metrics = Metrics(resnet_normalized_93_81,val_ds)
print(metrics.calculate_scores())
print('---------------------------------------------------------------------------------------------------------------------')
metrics = Metrics(resenet_non_normalized_93_90,val_ds)
print(metrics.calculate_scores())
print('---------------------------------------------------------------------------------------------------------------------')
metrics = Metrics(resnet_non_normalized_flip_957_94,val_ds)
print(metrics.calculate_scores())
print('---------------------------------------------------------------------------------------------------------------------')
metrics = Metrics(resnet_non_normalized_flip_rotate_9475_94,val_ds)
print(metrics.calculate_scores())
print('---------------------------------------------------------------------------------------------------------------------')
metrics = Metrics(resnet_non_normalized_crop_flip_94_60,val_ds)
print(metrics.calculate_scores())
print('---------------------------------------------------------------------------------------------------------------------')
metrics = Metrics(resnet_non_normalized_flip_crop_rotate_88_47,val_ds)
print(metrics.calculate_scores())
print('---------------------------------------------------------------------------------------------------------------------')
# Out:
# calculating score.....
# [[ 0  0 96]
#  [ 0  0 17]
#  [ 0  0 87]]
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        96
#          1.0       0.00      0.00      0.00        17
#          2.0       0.43      1.00      0.61        87
#
#     accuracy                           0.43       200
#    macro avg       0.14      0.33      0.20       200
# weighted avg       0.19      0.43      0.26       200
#
# None
# ---------------------------------------------------------------------------------------------------------------------
# calculating score.....
# [[93  0  3]
#  [ 0  3 14]
#  [ 1  2 84]]
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.97      0.98        96
#          1.0       0.60      0.18      0.27        17
#          2.0       0.83      0.97      0.89        87
#
#     accuracy                           0.90       200
#    macro avg       0.81      0.70      0.72       200
# weighted avg       0.89      0.90      0.88       200
#
# None
# ---------------------------------------------------------------------------------------------------------------------
# calculating score.....
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f2e14b237a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [[93  0  3]
#  [ 0 13  4]
#  [ 0  5 82]]
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.97      0.98        96
#          1.0       0.72      0.76      0.74        17
#          2.0       0.92      0.94      0.93        87
#
#     accuracy                           0.94       200
#    macro avg       0.88      0.89      0.89       200
# weighted avg       0.94      0.94      0.94       200
#
# None
# ---------------------------------------------------------------------------------------------------------------------
# calculating score.....
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f2e122ae7a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [[92  0  4]
#  [ 0 13  4]
#  [ 0  4 83]]
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.96      0.98        96
#          1.0       0.76      0.76      0.76        17
#          2.0       0.91      0.95      0.93        87
#
#     accuracy                           0.94       200
#    macro avg       0.89      0.89      0.89       200
# weighted avg       0.94      0.94      0.94       200
#
# None
# ---------------------------------------------------------------------------------------------------------------------
# calculating score.....
# [[47  2 47]
#  [ 0 14  3]
#  [ 0 28 59]]
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.49      0.66        96
#          1.0       0.32      0.82      0.46        17
#          2.0       0.54      0.68      0.60        87
#
#     accuracy                           0.60       200
#    macro avg       0.62      0.66      0.57       200
# weighted avg       0.74      0.60      0.62       200
#
# None
# ---------------------------------------------------------------------------------------------------------------------
# calculating score.....
# [[19  3 74]
#  [ 0 16  1]
#  [ 0 27 60]]
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.20      0.33        96
#          1.0       0.35      0.94      0.51        17
#          2.0       0.44      0.69      0.54        87
#
#     accuracy                           0.48       200
#    macro avg       0.60      0.61      0.46       200
# weighted avg       0.70      0.47      0.44       200
#
# None
# ---------------------------------------------------------------------------------------------------------------------

# %%
metrics = Metrics(resnet_preprocessing_crop,val_ds_normal_crop)
print(metrics.calculate_scores())
print('---------------------------------------------------------------------------------------------------------------------')
# Out:
# calculating score.....
# [[96  0  0]
#  [ 2  8  7]
#  [ 2  3 82]]
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.96      1.00      0.98        96
#          1.0       0.73      0.47      0.57        17
#          2.0       0.92      0.94      0.93        87
#
#     accuracy                           0.93       200
#    macro avg       0.87      0.80      0.83       200
# weighted avg       0.92      0.93      0.92       200
#
# None
# ---------------------------------------------------------------------------------------------------------------------

# %%
import time
a = time.time()
print(1+1)
b = time.time()
print(b-a)
# Out:
# 2
# 0.0007543563842773438

# %%
print(a)
# Out:
# 1628330657.4058182

# %% [markdown]
# #### VGG 16

# %% [markdown]
# ##### VGG model building

# %%
base_model_vgg = tf.keras.applications.VGG16(
    include_top=False,
    weights="imagenet",    
    input_shape=(img_height, img_width, channels),
    pooling='max',
    classes=3,
)
layer_count  = len(base_model_vgg.layers)
print(f'There are a total of {layer_count} layers in the VGG 16 network')
# making the base layers non trainable or freezing
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# There are a total of 20 layers in the VGG 16 network

# %%
break_point  = 16
for layer in base_model_vgg.layers[0:break_point]:
    layer.trainable = False
for layer in base_model_vgg.layers[break_point:]:
    layer.trainable = True

# please note higher the break point ; lesser the trainable layers lesser is the over fitting -> high breakpoint -> less over fitting 
base_model_vgg.inputs
input_layer = base_model_vgg.inputs
# Building a functional model

output = base_model_vgg.output
output
# Out:
# <KerasTensor: shape=(None, 512) dtype=float32 (created by layer 'global_max_pooling2d')>

# %%
# x = Dense(1024, activation  = 'relu')(output)
x = Dense(num_classes, activation  = 'softmax')(output)

vgg_model = Model(inputs = input_layer, outputs = x)
vgg_model.summary()
vgg_model.compile(optimizer = optimizers.Adam(lr=1e-4), loss = 'categorical_crossentropy', metrics = ['accuracy'])
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 512, 512, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 512, 512, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 512, 512, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 256, 256, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 256, 256, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 256, 256, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 128, 128, 128)     0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 128, 128, 256)     295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 128, 128, 256)     590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 128, 128, 256)     590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 64, 64, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 64, 64, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 64, 64, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 64, 64, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 32, 32, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 16, 16, 512)       0
# _________________________________________________________________
# global_max_pooling2d (Global (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 14,716,227
# Trainable params: 4,721,155
# Non-trainable params: 9,995,072
# _________________________________________________________________

# %% [markdown]
# ##### VGG-16 scaled model

# %%
vgg_model.fit(train_ds_scaled,validation_data=val_ds_scaled,epochs = 40, verbose = 1, workers = 3, class_weight = {0:1.13, 1:8.03, 2:1}, callbacks = callbacks_vgg)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/40
# 25/25 [==============================] - 87s 2s/step - loss: 1.4359 - accuracy: 0.6388 - val_loss: 0.6811 - val_accuracy: 0.7850
#
# Epoch 00001: saving model to sloan_resnet/model-00001-1.43590-0.63875-0.68114-0.78500.h5
# Epoch 2/40
# 25/25 [==============================] - 12s 442ms/step - loss: 0.9198 - accuracy: 0.7713 - val_loss: 0.6016 - val_accuracy: 0.8100
#
# Epoch 00002: saving model to sloan_resnet/model-00002-0.91983-0.77125-0.60156-0.81000.h5
# Epoch 3/40
# 25/25 [==============================] - 12s 443ms/step - loss: 0.7846 - accuracy: 0.7925 - val_loss: 0.6329 - val_accuracy: 0.7200
#
# Epoch 00003: saving model to sloan_resnet/model-00003-0.78463-0.79250-0.63287-0.72000.h5
# Epoch 4/40
# 25/25 [==============================] - 12s 441ms/step - loss: 0.6860 - accuracy: 0.8275 - val_loss: 0.5185 - val_accuracy: 0.7950
#
# Epoch 00004: saving model to sloan_resnet/model-00004-0.68603-0.82750-0.51849-0.79500.h5
# Epoch 5/40
# 25/25 [==============================] - 12s 438ms/step - loss: 0.5326 - accuracy: 0.8550 - val_loss: 0.4528 - val_accuracy: 0.8300
#
# Epoch 00005: saving model to sloan_resnet/model-00005-0.53258-0.85500-0.45284-0.83000.h5
# Epoch 6/40
# 25/25 [==============================] - 12s 439ms/step - loss: 0.5220 - accuracy: 0.8813 - val_loss: 0.3822 - val_accuracy: 0.8550
#
# Epoch 00006: saving model to sloan_resnet/model-00006-0.52195-0.88125-0.38223-0.85500.h5
# Epoch 7/40
# 25/25 [==============================] - 12s 442ms/step - loss: 0.4160 - accuracy: 0.9013 - val_loss: 0.4057 - val_accuracy: 0.8650
#
# Epoch 00007: saving model to sloan_resnet/model-00007-0.41603-0.90125-0.40570-0.86500.h5
# Epoch 8/40
# 25/25 [==============================] - 12s 443ms/step - loss: 0.3618 - accuracy: 0.9225 - val_loss: 0.3205 - val_accuracy: 0.8900
#
# Epoch 00008: saving model to sloan_resnet/model-00008-0.36180-0.92250-0.32050-0.89000.h5
# Epoch 9/40
# 25/25 [==============================] - 12s 444ms/step - loss: 0.3146 - accuracy: 0.9413 - val_loss: 0.3920 - val_accuracy: 0.8450
#
# Epoch 00009: saving model to sloan_resnet/model-00009-0.31456-0.94125-0.39204-0.84500.h5
# Epoch 10/40
# 25/25 [==============================] - 12s 443ms/step - loss: 0.2821 - accuracy: 0.9388 - val_loss: 0.3724 - val_accuracy: 0.8550
#
# Epoch 00010: saving model to sloan_resnet/model-00010-0.28205-0.93875-0.37243-0.85500.h5
# Epoch 11/40
# 25/25 [==============================] - 12s 443ms/step - loss: 0.3051 - accuracy: 0.9488 - val_loss: 0.3068 - val_accuracy: 0.9050
#
# Epoch 00011: saving model to sloan_resnet/model-00011-0.30509-0.94875-0.30683-0.90500.h5
# Epoch 12/40
# 25/25 [==============================] - 12s 440ms/step - loss: 0.2257 - accuracy: 0.9600 - val_loss: 0.3442 - val_accuracy: 0.8700
#
# Epoch 00012: saving model to sloan_resnet/model-00012-0.22568-0.96000-0.34418-0.87000.h5
# Epoch 13/40
# 25/25 [==============================] - 12s 445ms/step - loss: 0.2028 - accuracy: 0.9563 - val_loss: 0.3711 - val_accuracy: 0.8700
#
# Epoch 00013: saving model to sloan_resnet/model-00013-0.20280-0.95625-0.37115-0.87000.h5
# Epoch 14/40
# 25/25 [==============================] - 13s 447ms/step - loss: 0.2049 - accuracy: 0.9600 - val_loss: 0.3319 - val_accuracy: 0.8900
#
# Epoch 00014: saving model to sloan_resnet/model-00014-0.20486-0.96000-0.33195-0.89000.h5
# Epoch 15/40
# 25/25 [==============================] - 12s 443ms/step - loss: 0.1619 - accuracy: 0.9725 - val_loss: 0.4001 - val_accuracy: 0.8650
#
# Epoch 00015: saving model to sloan_resnet/model-00015-0.16187-0.97250-0.40012-0.86500.h5
# Epoch 16/40
# 25/25 [==============================] - 12s 443ms/step - loss: 0.1530 - accuracy: 0.9700 - val_loss: 0.3763 - val_accuracy: 0.8750
#
# Epoch 00016: saving model to sloan_resnet/model-00016-0.15298-0.97000-0.37631-0.87500.h5
# Epoch 17/40
# 25/25 [==============================] - 13s 446ms/step - loss: 0.1365 - accuracy: 0.9800 - val_loss: 0.3082 - val_accuracy: 0.9100
#
# Epoch 00017: saving model to sloan_resnet/model-00017-0.13646-0.98000-0.30819-0.91000.h5
# Epoch 18/40
# 25/25 [==============================] - 12s 443ms/step - loss: 0.1301 - accuracy: 0.9750 - val_loss: 0.3596 - val_accuracy: 0.9000
#
# Epoch 00018: saving model to sloan_resnet/model-00018-0.13012-0.97500-0.35963-0.90000.h5
# Epoch 19/40
# 25/25 [==============================] - 12s 439ms/step - loss: 0.1253 - accuracy: 0.9750 - val_loss: 0.3424 - val_accuracy: 0.8950
#
# Epoch 00019: saving model to sloan_resnet/model-00019-0.12526-0.97500-0.34238-0.89500.h5
# Epoch 20/40
# 25/25 [==============================] - 12s 441ms/step - loss: 0.1560 - accuracy: 0.9638 - val_loss: 0.3844 - val_accuracy: 0.8750
#
# Epoch 00020: saving model to sloan_resnet/model-00020-0.15597-0.96375-0.38437-0.87500.h5
# Epoch 21/40
# 25/25 [==============================] - 12s 441ms/step - loss: 0.0965 - accuracy: 0.9850 - val_loss: 0.3687 - val_accuracy: 0.9100
#
# Epoch 00021: saving model to sloan_resnet/model-00021-0.09648-0.98500-0.36867-0.91000.h5
# Epoch 22/40
# 25/25 [==============================] - 12s 445ms/step - loss: 0.0883 - accuracy: 0.9800 - val_loss: 0.3088 - val_accuracy: 0.9150
#
# Epoch 00022: saving model to sloan_resnet/model-00022-0.08829-0.98000-0.30880-0.91500.h5
# Epoch 23/40
# 25/25 [==============================] - 12s 443ms/step - loss: 0.0800 - accuracy: 0.9850 - val_loss: 0.3542 - val_accuracy: 0.9100
#
# Epoch 00023: saving model to sloan_resnet/model-00023-0.08003-0.98500-0.35421-0.91000.h5
# Epoch 24/40
# 25/25 [==============================] - 12s 439ms/step - loss: 0.0969 - accuracy: 0.9787 - val_loss: 0.3755 - val_accuracy: 0.8750
#
# Epoch 00024: saving model to sloan_resnet/model-00024-0.09689-0.97875-0.37546-0.87500.h5
# Epoch 25/40
# 25/25 [==============================] - 12s 443ms/step - loss: 0.1089 - accuracy: 0.9750 - val_loss: 0.3683 - val_accuracy: 0.8650
#
# Epoch 00025: saving model to sloan_resnet/model-00025-0.10890-0.97500-0.36832-0.86500.h5
# Epoch 26/40
# 25/25 [==============================] - 12s 446ms/step - loss: 0.0688 - accuracy: 0.9925 - val_loss: 0.3614 - val_accuracy: 0.8850
#
# Epoch 00026: saving model to sloan_resnet/model-00026-0.06882-0.99250-0.36143-0.88500.h5
# Epoch 27/40
# 25/25 [==============================] - 12s 445ms/step - loss: 0.0681 - accuracy: 0.9887 - val_loss: 0.3268 - val_accuracy: 0.9000
#
# Epoch 00027: saving model to sloan_resnet/model-00027-0.06814-0.98875-0.32683-0.90000.h5
# Epoch 28/40
# 25/25 [==============================] - 12s 446ms/step - loss: 0.0668 - accuracy: 0.9912 - val_loss: 0.5159 - val_accuracy: 0.8850
#
# Epoch 00028: saving model to sloan_resnet/model-00028-0.06679-0.99125-0.51594-0.88500.h5
# Epoch 29/40
# 25/25 [==============================] - 12s 443ms/step - loss: 0.0883 - accuracy: 0.9787 - val_loss: 0.3554 - val_accuracy: 0.9150
#
# Epoch 00029: saving model to sloan_resnet/model-00029-0.08834-0.97875-0.35540-0.91500.h5
# Epoch 30/40
# 25/25 [==============================] - 13s 447ms/step - loss: 0.0420 - accuracy: 0.9937 - val_loss: 0.3350 - val_accuracy: 0.8900
#
# Epoch 00030: saving model to sloan_resnet/model-00030-0.04199-0.99375-0.33500-0.89000.h5
# Epoch 31/40
# 25/25 [==============================] - 12s 446ms/step - loss: 0.0426 - accuracy: 0.9962 - val_loss: 0.3556 - val_accuracy: 0.9050
#
# Epoch 00031: saving model to sloan_resnet/model-00031-0.04265-0.99625-0.35556-0.90500.h5
# Epoch 32/40
# 25/25 [==============================] - 12s 440ms/step - loss: 0.0350 - accuracy: 0.9962 - val_loss: 0.3530 - val_accuracy: 0.9100
#
# Epoch 00032: saving model to sloan_resnet/model-00032-0.03501-0.99625-0.35301-0.91000.h5
# Epoch 33/40
# 25/25 [==============================] - 13s 446ms/step - loss: 0.0424 - accuracy: 0.9962 - val_loss: 0.4403 - val_accuracy: 0.8550
#
# Epoch 00033: saving model to sloan_resnet/model-00033-0.04236-0.99625-0.44026-0.85500.h5
# Epoch 34/40
# 25/25 [==============================] - 13s 445ms/step - loss: 0.0489 - accuracy: 0.9887 - val_loss: 0.3485 - val_accuracy: 0.9000
#
# Epoch 00034: saving model to sloan_resnet/model-00034-0.04888-0.98875-0.34849-0.90000.h5
# Epoch 35/40
# 25/25 [==============================] - 12s 445ms/step - loss: 0.0319 - accuracy: 0.9987 - val_loss: 0.3346 - val_accuracy: 0.9150
#
# Epoch 00035: saving model to sloan_resnet/model-00035-0.03191-0.99875-0.33462-0.91500.h5
# Epoch 36/40
# 25/25 [==============================] - 12s 440ms/step - loss: 0.0294 - accuracy: 0.9975 - val_loss: 0.3420 - val_accuracy: 0.8950
#
# Epoch 00036: saving model to sloan_resnet/model-00036-0.02941-0.99750-0.34205-0.89500.h5
# Epoch 37/40
# 25/25 [==============================] - 12s 442ms/step - loss: 0.0245 - accuracy: 1.0000 - val_loss: 0.3592 - val_accuracy: 0.9050
#
# Epoch 00037: saving model to sloan_resnet/model-00037-0.02447-1.00000-0.35919-0.90500.h5
# Epoch 38/40
# 25/25 [==============================] - 12s 444ms/step - loss: 0.0186 - accuracy: 1.0000 - val_loss: 0.3419 - val_accuracy: 0.9000
#
# Epoch 00038: saving model to sloan_resnet/model-00038-0.01863-1.00000-0.34193-0.90000.h5
# Epoch 39/40
# 25/25 [==============================] - 12s 440ms/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.3454 - val_accuracy: 0.9050
#
# Epoch 00039: saving model to sloan_resnet/model-00039-0.01435-1.00000-0.34537-0.90500.h5
# Epoch 40/40
# 25/25 [==============================] - 12s 445ms/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.3472 - val_accuracy: 0.9000
#
# Epoch 00040: saving model to sloan_resnet/model-00040-0.01280-1.00000-0.34725-0.90000.h5

# %%
generate_graph(vgg_model)

# %% [markdown]
# ##### VGG 16 uscaled model

# %%
vgg_model.fit(train_ds,validation_data=val_ds,epochs = 35, verbose = 1, workers = 3, class_weight = {0:1.13, 1:8.03, 2:1}, callbacks = callbacks_vgg)
# Out:
# Epoch 1/35
# 25/25 [==============================] - 13s 449ms/step - loss: 1.2786 - accuracy: 0.8163 - val_loss: 0.9811 - val_accuracy: 0.7600
#
# Epoch 00001: saving model to sloan_vgg/model-00001-1.27861-0.81625-0.98112-0.76000.h5
# Epoch 2/35
# 25/25 [==============================] - 12s 444ms/step - loss: 0.2587 - accuracy: 0.9413 - val_loss: 0.7749 - val_accuracy: 0.8400
#
# Epoch 00002: saving model to sloan_vgg/model-00002-0.25872-0.94125-0.77488-0.84000.h5
# Epoch 3/35
# 25/25 [==============================] - 12s 445ms/step - loss: 0.0951 - accuracy: 0.9850 - val_loss: 0.8963 - val_accuracy: 0.8150
#
# Epoch 00003: saving model to sloan_vgg/model-00003-0.09515-0.98500-0.89633-0.81500.h5
# Epoch 4/35
# 25/25 [==============================] - 12s 446ms/step - loss: 0.0450 - accuracy: 0.9862 - val_loss: 0.7415 - val_accuracy: 0.8650
#
# Epoch 00004: saving model to sloan_vgg/model-00004-0.04498-0.98625-0.74148-0.86500.h5
# Epoch 5/35
# 25/25 [==============================] - 13s 448ms/step - loss: 0.0159 - accuracy: 0.9975 - val_loss: 0.6487 - val_accuracy: 0.8650
#
# Epoch 00005: saving model to sloan_vgg/model-00005-0.01594-0.99750-0.64867-0.86500.h5
# Epoch 6/35
# 25/25 [==============================] - 13s 450ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.6188 - val_accuracy: 0.8600
#
# Epoch 00006: saving model to sloan_vgg/model-00006-0.00353-1.00000-0.61885-0.86000.h5
# Epoch 7/35
# 25/25 [==============================] - 13s 446ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.6279 - val_accuracy: 0.8700
#
# Epoch 00007: saving model to sloan_vgg/model-00007-0.00253-1.00000-0.62789-0.87000.h5
# Epoch 8/35
# 25/25 [==============================] - 12s 446ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.6272 - val_accuracy: 0.8750
#
# Epoch 00008: saving model to sloan_vgg/model-00008-0.00139-1.00000-0.62717-0.87500.h5
# Epoch 9/35
# 25/25 [==============================] - 12s 446ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.6290 - val_accuracy: 0.8750
#
# Epoch 00009: saving model to sloan_vgg/model-00009-0.00106-1.00000-0.62905-0.87500.h5
# Epoch 10/35
# 25/25 [==============================] - 13s 449ms/step - loss: 9.1547e-04 - accuracy: 1.0000 - val_loss: 0.6320 - val_accuracy: 0.8750
#
# Epoch 00010: saving model to sloan_vgg/model-00010-0.00092-1.00000-0.63197-0.87500.h5
# Epoch 11/35
# 25/25 [==============================] - 13s 449ms/step - loss: 8.0945e-04 - accuracy: 1.0000 - val_loss: 0.6361 - val_accuracy: 0.8750
#
# Epoch 00011: saving model to sloan_vgg/model-00011-0.00081-1.00000-0.63608-0.87500.h5
# Epoch 12/35
# 25/25 [==============================] - 13s 448ms/step - loss: 7.2015e-04 - accuracy: 1.0000 - val_loss: 0.6387 - val_accuracy: 0.8750
#
# Epoch 00012: saving model to sloan_vgg/model-00012-0.00072-1.00000-0.63872-0.87500.h5
# Epoch 13/35
# 25/25 [==============================] - 12s 446ms/step - loss: 6.5232e-04 - accuracy: 1.0000 - val_loss: 0.6389 - val_accuracy: 0.8750
#
# Epoch 00013: saving model to sloan_vgg/model-00013-0.00065-1.00000-0.63890-0.87500.h5
# Epoch 14/35
# 25/25 [==============================] - 13s 449ms/step - loss: 5.9852e-04 - accuracy: 1.0000 - val_loss: 0.6437 - val_accuracy: 0.8750
#
# Epoch 00014: saving model to sloan_vgg/model-00014-0.00060-1.00000-0.64366-0.87500.h5
# Epoch 15/35
# 25/25 [==============================] - 12s 444ms/step - loss: 5.4528e-04 - accuracy: 1.0000 - val_loss: 0.6441 - val_accuracy: 0.8750
#
# Epoch 00015: saving model to sloan_vgg/model-00015-0.00055-1.00000-0.64414-0.87500.h5
# Epoch 16/35
# 25/25 [==============================] - 13s 447ms/step - loss: 5.0034e-04 - accuracy: 1.0000 - val_loss: 0.6475 - val_accuracy: 0.8750
#
# Epoch 00016: saving model to sloan_vgg/model-00016-0.00050-1.00000-0.64746-0.87500.h5
# Epoch 17/35
# 25/25 [==============================] - 13s 447ms/step - loss: 4.6575e-04 - accuracy: 1.0000 - val_loss: 0.6487 - val_accuracy: 0.8750
#
# Epoch 00017: saving model to sloan_vgg/model-00017-0.00047-1.00000-0.64874-0.87500.h5
# Epoch 18/35
# 25/25 [==============================] - 13s 448ms/step - loss: 4.3073e-04 - accuracy: 1.0000 - val_loss: 0.6508 - val_accuracy: 0.8750
#
# Epoch 00018: saving model to sloan_vgg/model-00018-0.00043-1.00000-0.65083-0.87500.h5
# Epoch 19/35
# 25/25 [==============================] - 13s 449ms/step - loss: 4.0090e-04 - accuracy: 1.0000 - val_loss: 0.6547 - val_accuracy: 0.8750
#
# Epoch 00019: saving model to sloan_vgg/model-00019-0.00040-1.00000-0.65467-0.87500.h5
# Epoch 20/35
# 25/25 [==============================] - 12s 446ms/step - loss: 3.7474e-04 - accuracy: 1.0000 - val_loss: 0.6543 - val_accuracy: 0.8750
#
# Epoch 00020: saving model to sloan_vgg/model-00020-0.00037-1.00000-0.65428-0.87500.h5
# Epoch 21/35
# 25/25 [==============================] - 12s 446ms/step - loss: 3.5199e-04 - accuracy: 1.0000 - val_loss: 0.6588 - val_accuracy: 0.8750
#
# Epoch 00021: saving model to sloan_vgg/model-00021-0.00035-1.00000-0.65884-0.87500.h5
# Epoch 22/35
# 25/25 [==============================] - 13s 451ms/step - loss: 3.2946e-04 - accuracy: 1.0000 - val_loss: 0.6582 - val_accuracy: 0.8750
#
# Epoch 00022: saving model to sloan_vgg/model-00022-0.00033-1.00000-0.65821-0.87500.h5
# Epoch 23/35
# 25/25 [==============================] - 13s 448ms/step - loss: 3.1087e-04 - accuracy: 1.0000 - val_loss: 0.6626 - val_accuracy: 0.8750
#
# Epoch 00023: saving model to sloan_vgg/model-00023-0.00031-1.00000-0.66259-0.87500.h5
# Epoch 24/35
# 25/25 [==============================] - 13s 448ms/step - loss: 2.9188e-04 - accuracy: 1.0000 - val_loss: 0.6630 - val_accuracy: 0.8750
#
# Epoch 00024: saving model to sloan_vgg/model-00024-0.00029-1.00000-0.66295-0.87500.h5
# Epoch 25/35
# 25/25 [==============================] - 13s 447ms/step - loss: 2.7679e-04 - accuracy: 1.0000 - val_loss: 0.6649 - val_accuracy: 0.8750
#
# Epoch 00025: saving model to sloan_vgg/model-00025-0.00028-1.00000-0.66492-0.87500.h5
# Epoch 26/35
# 25/25 [==============================] - 13s 452ms/step - loss: 2.6187e-04 - accuracy: 1.0000 - val_loss: 0.6677 - val_accuracy: 0.8750
#
# Epoch 00026: saving model to sloan_vgg/model-00026-0.00026-1.00000-0.66769-0.87500.h5
# Epoch 27/35
# 25/25 [==============================] - 13s 445ms/step - loss: 2.4832e-04 - accuracy: 1.0000 - val_loss: 0.6677 - val_accuracy: 0.8750
#
# Epoch 00027: saving model to sloan_vgg/model-00027-0.00025-1.00000-0.66774-0.87500.h5
# Epoch 28/35
# 25/25 [==============================] - 12s 444ms/step - loss: 2.3660e-04 - accuracy: 1.0000 - val_loss: 0.6692 - val_accuracy: 0.8750
#
# Epoch 00028: saving model to sloan_vgg/model-00028-0.00024-1.00000-0.66922-0.87500.h5
# Epoch 29/35
# 25/25 [==============================] - 13s 450ms/step - loss: 2.2421e-04 - accuracy: 1.0000 - val_loss: 0.6713 - val_accuracy: 0.8750
#
# Epoch 00029: saving model to sloan_vgg/model-00029-0.00022-1.00000-0.67131-0.87500.h5
# Epoch 30/35
# 25/25 [==============================] - 13s 448ms/step - loss: 2.1355e-04 - accuracy: 1.0000 - val_loss: 0.6714 - val_accuracy: 0.8750
#
# Epoch 00030: saving model to sloan_vgg/model-00030-0.00021-1.00000-0.67136-0.87500.h5
# Epoch 31/35
# 25/25 [==============================] - 13s 450ms/step - loss: 2.0372e-04 - accuracy: 1.0000 - val_loss: 0.6740 - val_accuracy: 0.8750
#
# Epoch 00031: saving model to sloan_vgg/model-00031-0.00020-1.00000-0.67396-0.87500.h5
# Epoch 32/35
# 25/25 [==============================] - 13s 448ms/step - loss: 1.9338e-04 - accuracy: 1.0000 - val_loss: 0.6758 - val_accuracy: 0.8750
#
# Epoch 00032: saving model to sloan_vgg/model-00032-0.00019-1.00000-0.67579-0.87500.h5
# Epoch 33/35
# 25/25 [==============================] - 12s 446ms/step - loss: 1.8445e-04 - accuracy: 1.0000 - val_loss: 0.6762 - val_accuracy: 0.8750
#
# Epoch 00033: saving model to sloan_vgg/model-00033-0.00018-1.00000-0.67618-0.87500.h5
# Epoch 34/35
# 25/25 [==============================] - 12s 447ms/step - loss: 1.7648e-04 - accuracy: 1.0000 - val_loss: 0.6760 - val_accuracy: 0.8750
#
# Epoch 00034: saving model to sloan_vgg/model-00034-0.00018-1.00000-0.67600-0.87500.h5
# Epoch 35/35
# 25/25 [==============================] - 12s 444ms/step - loss: 1.6881e-04 - accuracy: 1.0000 - val_loss: 0.6800 - val_accuracy: 0.8750
#
# Epoch 00035: saving model to sloan_vgg/model-00035-0.00017-1.00000-0.68000-0.87500.h5

# %%
generate_graph(vgg_model)

# %% [markdown]
# ##### Augmentation experiments

# %%
train_ds_flip = prepare_dataset(train_ds_scaled, flip= True)
train_ds_flip_rotate = prepare_dataset(train_ds_scaled, flip_rotate = True)
train_ds_crop_flip = prepare_dataset_crop(train_ds_scaled_cropped, crop_flip = True)
train_ds_crop_flip_rotate = prepare_dataset_crop(train_ds_scaled_cropped, crop_flip_rotate = True)

vgg_scaled_flip = load_model('./sloan_vgg/vgg16-scaled_0.36-92.25_0.32-089.h5')
vgg_scaled_flip_rotate = load_model('./sloan_vgg/vgg16-scaled_0.36-92.25_0.32-089.h5')
# this model is trained on the 
vgg_scaled_crop_flip = load_model('./sloan_vgg/vgg16-scaled_0.36-92.25_0.32-089.h5')
vgg_scaled_crop_flip_rotate = load_model('./sloan_vgg/vgg16-scaled_0.36-92.25_0.32-089.h5')

# %% [markdown]
# ##### VGG scaled flip

# %%
vgg_scaled_flip.fit(train_ds_flip,validation_data=val_ds_scaled,epochs = 40, verbose = 1, workers = 3, class_weight = {0:1.13, 1:8.03, 2:1},callbacks = callbacks_vgg)
# Out:
# Epoch 1/40
# 25/25 [==============================] - 13s 452ms/step - loss: 0.5809 - accuracy: 0.8763 - val_loss: 0.4137 - val_accuracy: 0.8600
#
# Epoch 00001: saving model to sloan_vgg/model-00001-0.58092-0.87625-0.41365-0.86000.h5
# Epoch 2/40
# 25/25 [==============================] - 13s 454ms/step - loss: 0.4376 - accuracy: 0.8913 - val_loss: 0.3183 - val_accuracy: 0.8800
#
# Epoch 00002: saving model to sloan_vgg/model-00002-0.43763-0.89125-0.31833-0.88000.h5
# Epoch 3/40
# 25/25 [==============================] - 13s 451ms/step - loss: 0.4332 - accuracy: 0.9137 - val_loss: 0.3345 - val_accuracy: 0.8600
#
# Epoch 00003: saving model to sloan_vgg/model-00003-0.43316-0.91375-0.33454-0.86000.h5
# Epoch 4/40
# 25/25 [==============================] - 13s 458ms/step - loss: 0.3711 - accuracy: 0.9200 - val_loss: 0.3278 - val_accuracy: 0.8850
#
# Epoch 00004: saving model to sloan_vgg/model-00004-0.37113-0.92000-0.32777-0.88500.h5
# Epoch 5/40
# 25/25 [==============================] - 13s 453ms/step - loss: 0.3701 - accuracy: 0.9212 - val_loss: 0.3694 - val_accuracy: 0.8600
#
# Epoch 00005: saving model to sloan_vgg/model-00005-0.37010-0.92125-0.36937-0.86000.h5
# Epoch 6/40
# 25/25 [==============================] - 13s 449ms/step - loss: 0.3516 - accuracy: 0.9212 - val_loss: 0.3075 - val_accuracy: 0.8850
#
# Epoch 00006: saving model to sloan_vgg/model-00006-0.35164-0.92125-0.30745-0.88500.h5
# Epoch 7/40
# 25/25 [==============================] - 13s 452ms/step - loss: 0.2778 - accuracy: 0.9550 - val_loss: 0.3470 - val_accuracy: 0.8850
#
# Epoch 00007: saving model to sloan_vgg/model-00007-0.27783-0.95500-0.34700-0.88500.h5
# Epoch 8/40
# 25/25 [==============================] - 13s 454ms/step - loss: 0.2647 - accuracy: 0.9488 - val_loss: 0.3045 - val_accuracy: 0.8950
#
# Epoch 00008: saving model to sloan_vgg/model-00008-0.26470-0.94875-0.30451-0.89500.h5
# Epoch 9/40
# 25/25 [==============================] - 13s 453ms/step - loss: 0.2728 - accuracy: 0.9600 - val_loss: 0.4298 - val_accuracy: 0.8200
#
# Epoch 00009: saving model to sloan_vgg/model-00009-0.27282-0.96000-0.42982-0.82000.h5
# Epoch 10/40
# 25/25 [==============================] - 13s 455ms/step - loss: 0.2839 - accuracy: 0.9450 - val_loss: 0.3493 - val_accuracy: 0.8950
#
# Epoch 00010: saving model to sloan_vgg/model-00010-0.28388-0.94500-0.34933-0.89500.h5
# Epoch 11/40
# 25/25 [==============================] - 13s 453ms/step - loss: 0.2912 - accuracy: 0.9463 - val_loss: 0.2721 - val_accuracy: 0.9050
#
# Epoch 00011: saving model to sloan_vgg/model-00011-0.29122-0.94625-0.27214-0.90500.h5
# Epoch 12/40
# 25/25 [==============================] - 13s 454ms/step - loss: 0.2128 - accuracy: 0.9638 - val_loss: 0.3067 - val_accuracy: 0.8750
#
# Epoch 00012: saving model to sloan_vgg/model-00012-0.21279-0.96375-0.30672-0.87500.h5
# Epoch 13/40
# 25/25 [==============================] - 13s 454ms/step - loss: 0.2542 - accuracy: 0.9488 - val_loss: 0.4569 - val_accuracy: 0.8300
#
# Epoch 00013: saving model to sloan_vgg/model-00013-0.25419-0.94875-0.45691-0.83000.h5
# Epoch 14/40
# 25/25 [==============================] - 13s 454ms/step - loss: 0.2639 - accuracy: 0.9438 - val_loss: 0.3775 - val_accuracy: 0.8750
#
# Epoch 00014: saving model to sloan_vgg/model-00014-0.26386-0.94375-0.37753-0.87500.h5
# Epoch 15/40
# 25/25 [==============================] - 13s 456ms/step - loss: 0.2096 - accuracy: 0.9663 - val_loss: 0.3795 - val_accuracy: 0.8650
#
# Epoch 00015: saving model to sloan_vgg/model-00015-0.20956-0.96625-0.37954-0.86500.h5
# Epoch 16/40
# 25/25 [==============================] - 13s 456ms/step - loss: 0.2072 - accuracy: 0.9550 - val_loss: 0.2985 - val_accuracy: 0.8800
#
# Epoch 00016: saving model to sloan_vgg/model-00016-0.20724-0.95500-0.29854-0.88000.h5
# Epoch 17/40
# 25/25 [==============================] - 13s 450ms/step - loss: 0.1680 - accuracy: 0.9787 - val_loss: 0.2908 - val_accuracy: 0.9150
#
# Epoch 00017: saving model to sloan_vgg/model-00017-0.16802-0.97875-0.29081-0.91500.h5
# Epoch 18/40
# 25/25 [==============================] - 13s 455ms/step - loss: 0.1862 - accuracy: 0.9650 - val_loss: 0.3003 - val_accuracy: 0.9100
#
# Epoch 00018: saving model to sloan_vgg/model-00018-0.18617-0.96500-0.30034-0.91000.h5
# Epoch 19/40
# 25/25 [==============================] - 13s 450ms/step - loss: 0.1529 - accuracy: 0.9712 - val_loss: 0.2967 - val_accuracy: 0.9200
#
# Epoch 00019: saving model to sloan_vgg/model-00019-0.15291-0.97125-0.29670-0.92000.h5
# Epoch 20/40
# 25/25 [==============================] - 13s 452ms/step - loss: 0.2290 - accuracy: 0.9513 - val_loss: 0.4889 - val_accuracy: 0.8600
#
# Epoch 00020: saving model to sloan_vgg/model-00020-0.22902-0.95125-0.48895-0.86000.h5
# Epoch 21/40
# 25/25 [==============================] - 13s 455ms/step - loss: 0.2072 - accuracy: 0.9550 - val_loss: 0.3120 - val_accuracy: 0.9100
#
# Epoch 00021: saving model to sloan_vgg/model-00021-0.20718-0.95500-0.31198-0.91000.h5
# Epoch 22/40
# 25/25 [==============================] - 13s 452ms/step - loss: 0.2301 - accuracy: 0.9513 - val_loss: 0.3434 - val_accuracy: 0.8800
#
# Epoch 00022: saving model to sloan_vgg/model-00022-0.23011-0.95125-0.34338-0.88000.h5
# Epoch 23/40
# 25/25 [==============================] - 13s 452ms/step - loss: 0.1692 - accuracy: 0.9663 - val_loss: 0.3198 - val_accuracy: 0.9250
#
# Epoch 00023: saving model to sloan_vgg/model-00023-0.16917-0.96625-0.31984-0.92500.h5
# Epoch 24/40
# 25/25 [==============================] - 13s 455ms/step - loss: 0.1924 - accuracy: 0.9525 - val_loss: 0.3283 - val_accuracy: 0.8700
#
# Epoch 00024: saving model to sloan_vgg/model-00024-0.19239-0.95250-0.32827-0.87000.h5
# Epoch 25/40
# 25/25 [==============================] - 13s 455ms/step - loss: 0.1720 - accuracy: 0.9675 - val_loss: 0.3756 - val_accuracy: 0.8550
#
# Epoch 00025: saving model to sloan_vgg/model-00025-0.17199-0.96750-0.37564-0.85500.h5
# Epoch 26/40
# 25/25 [==============================] - 13s 452ms/step - loss: 0.1508 - accuracy: 0.9800 - val_loss: 0.4523 - val_accuracy: 0.8450
#
# Epoch 00026: saving model to sloan_vgg/model-00026-0.15081-0.98000-0.45227-0.84500.h5
# Epoch 27/40
# 25/25 [==============================] - 13s 453ms/step - loss: 0.1576 - accuracy: 0.9725 - val_loss: 0.3754 - val_accuracy: 0.8700
#
# Epoch 00027: saving model to sloan_vgg/model-00027-0.15759-0.97250-0.37539-0.87000.h5
# Epoch 28/40
# 25/25 [==============================] - 13s 451ms/step - loss: 0.1206 - accuracy: 0.9800 - val_loss: 0.3969 - val_accuracy: 0.8650
#
# Epoch 00028: saving model to sloan_vgg/model-00028-0.12064-0.98000-0.39692-0.86500.h5
# Epoch 29/40
# 25/25 [==============================] - 13s 454ms/step - loss: 0.1344 - accuracy: 0.9688 - val_loss: 0.3344 - val_accuracy: 0.8850
#
# Epoch 00029: saving model to sloan_vgg/model-00029-0.13441-0.96875-0.33440-0.88500.h5
# Epoch 30/40
# 25/25 [==============================] - 13s 453ms/step - loss: 0.1027 - accuracy: 0.9825 - val_loss: 0.3638 - val_accuracy: 0.8950
#
# Epoch 00030: saving model to sloan_vgg/model-00030-0.10265-0.98250-0.36376-0.89500.h5
# Epoch 31/40
# 25/25 [==============================] - 13s 454ms/step - loss: 0.1091 - accuracy: 0.9825 - val_loss: 0.4008 - val_accuracy: 0.8650
#
# Epoch 00031: saving model to sloan_vgg/model-00031-0.10912-0.98250-0.40075-0.86500.h5
# Epoch 32/40
# 25/25 [==============================] - 13s 455ms/step - loss: 0.1277 - accuracy: 0.9825 - val_loss: 0.3775 - val_accuracy: 0.9050
#
# Epoch 00032: saving model to sloan_vgg/model-00032-0.12770-0.98250-0.37752-0.90500.h5
# Epoch 33/40
# 25/25 [==============================] - 13s 455ms/step - loss: 0.1878 - accuracy: 0.9625 - val_loss: 0.7660 - val_accuracy: 0.8050
#
# Epoch 00033: saving model to sloan_vgg/model-00033-0.18778-0.96250-0.76597-0.80500.h5
# Epoch 34/40
# 25/25 [==============================] - 13s 453ms/step - loss: 0.3290 - accuracy: 0.9425 - val_loss: 0.3459 - val_accuracy: 0.9050
#
# Epoch 00034: saving model to sloan_vgg/model-00034-0.32898-0.94250-0.34588-0.90500.h5
# Epoch 35/40
# 25/25 [==============================] - 13s 454ms/step - loss: 0.2515 - accuracy: 0.9563 - val_loss: 0.6412 - val_accuracy: 0.8200
#
# Epoch 00035: saving model to sloan_vgg/model-00035-0.25147-0.95625-0.64124-0.82000.h5
# Epoch 36/40
# 25/25 [==============================] - 13s 454ms/step - loss: 0.2049 - accuracy: 0.9513 - val_loss: 0.3433 - val_accuracy: 0.9150
#
# Epoch 00036: saving model to sloan_vgg/model-00036-0.20487-0.95125-0.34329-0.91500.h5
# Epoch 37/40
# 25/25 [==============================] - 13s 453ms/step - loss: 0.1336 - accuracy: 0.9762 - val_loss: 0.3360 - val_accuracy: 0.9100
#
# Epoch 00037: saving model to sloan_vgg/model-00037-0.13356-0.97625-0.33596-0.91000.h5
# Epoch 38/40
# 25/25 [==============================] - 13s 453ms/step - loss: 0.1453 - accuracy: 0.9725 - val_loss: 0.4579 - val_accuracy: 0.8500
#
# Epoch 00038: saving model to sloan_vgg/model-00038-0.14534-0.97250-0.45792-0.85000.h5
# Epoch 39/40
# 25/25 [==============================] - 13s 456ms/step - loss: 0.1362 - accuracy: 0.9787 - val_loss: 0.4344 - val_accuracy: 0.8600
#
# Epoch 00039: saving model to sloan_vgg/model-00039-0.13616-0.97875-0.43443-0.86000.h5
# Epoch 40/40
# 25/25 [==============================] - 13s 452ms/step - loss: 0.1293 - accuracy: 0.9775 - val_loss: 0.3507 - val_accuracy: 0.9050
#
# Epoch 00040: saving model to sloan_vgg/model-00040-0.12927-0.97750-0.35072-0.90500.h5

# %%
generate_graph(vgg_scaled_flip)

# %% [markdown]
# ##### VGG scaled flip rotate

# %%
vgg_scaled_flip_rotate.fit(train_ds_flip_rotate,validation_data=val_ds_scaled,epochs = 40, verbose = 1, workers = 3, class_weight = {0:1.13, 1:8.03, 2:1},callbacks = callbacks_vgg)
# Out:
# Epoch 1/40
# 25/25 [==============================] - 19s 629ms/step - loss: 0.5575 - accuracy: 0.8675 - val_loss: 0.3667 - val_accuracy: 0.8600
#
# Epoch 00001: saving model to sloan_vgg/model-00001-0.55748-0.86750-0.36666-0.86000.h5
# Epoch 2/40
# 25/25 [==============================] - 19s 648ms/step - loss: 0.4819 - accuracy: 0.8838 - val_loss: 0.5301 - val_accuracy: 0.7950
#
# Epoch 00002: saving model to sloan_vgg/model-00002-0.48191-0.88375-0.53011-0.79500.h5
# Epoch 3/40
# 25/25 [==============================] - 18s 628ms/step - loss: 0.6089 - accuracy: 0.8500 - val_loss: 0.5684 - val_accuracy: 0.7850
#
# Epoch 00003: saving model to sloan_vgg/model-00003-0.60889-0.85000-0.56844-0.78500.h5
# Epoch 4/40
# 25/25 [==============================] - 18s 619ms/step - loss: 0.5080 - accuracy: 0.8813 - val_loss: 0.4461 - val_accuracy: 0.8200
#
# Epoch 00004: saving model to sloan_vgg/model-00004-0.50805-0.88125-0.44609-0.82000.h5
# Epoch 5/40
# 25/25 [==============================] - 18s 606ms/step - loss: 0.4629 - accuracy: 0.9000 - val_loss: 0.3753 - val_accuracy: 0.8550
#
# Epoch 00005: saving model to sloan_vgg/model-00005-0.46294-0.90000-0.37530-0.85500.h5
# Epoch 6/40
# 25/25 [==============================] - 18s 638ms/step - loss: 0.4244 - accuracy: 0.9062 - val_loss: 0.4571 - val_accuracy: 0.8450
#
# Epoch 00006: saving model to sloan_vgg/model-00006-0.42440-0.90625-0.45709-0.84500.h5
# Epoch 7/40
# 25/25 [==============================] - 18s 646ms/step - loss: 0.3874 - accuracy: 0.9262 - val_loss: 0.3555 - val_accuracy: 0.8750
#
# Epoch 00007: saving model to sloan_vgg/model-00007-0.38740-0.92625-0.35547-0.87500.h5
# Epoch 8/40
# 25/25 [==============================] - 18s 616ms/step - loss: 0.3687 - accuracy: 0.9200 - val_loss: 0.3533 - val_accuracy: 0.8700
#
# Epoch 00008: saving model to sloan_vgg/model-00008-0.36871-0.92000-0.35332-0.87000.h5
# Epoch 9/40
# 25/25 [==============================] - 18s 622ms/step - loss: 0.4217 - accuracy: 0.8963 - val_loss: 0.3218 - val_accuracy: 0.8800
#
# Epoch 00009: saving model to sloan_vgg/model-00009-0.42171-0.89625-0.32184-0.88000.h5
# Epoch 10/40
# 25/25 [==============================] - 18s 629ms/step - loss: 0.3529 - accuracy: 0.9275 - val_loss: 0.2808 - val_accuracy: 0.9100
#
# Epoch 00010: saving model to sloan_vgg/model-00010-0.35287-0.92750-0.28085-0.91000.h5
# Epoch 11/40
# 25/25 [==============================] - 18s 632ms/step - loss: 0.3518 - accuracy: 0.9300 - val_loss: 0.4655 - val_accuracy: 0.8250
#
# Epoch 00011: saving model to sloan_vgg/model-00011-0.35185-0.93000-0.46552-0.82500.h5
# Epoch 12/40
# 25/25 [==============================] - 18s 634ms/step - loss: 0.3295 - accuracy: 0.9300 - val_loss: 0.3400 - val_accuracy: 0.8650
#
# Epoch 00012: saving model to sloan_vgg/model-00012-0.32953-0.93000-0.33997-0.86500.h5
# Epoch 13/40
# 25/25 [==============================] - 18s 622ms/step - loss: 0.3217 - accuracy: 0.9425 - val_loss: 0.4873 - val_accuracy: 0.8250
#
# Epoch 00013: saving model to sloan_vgg/model-00013-0.32173-0.94250-0.48727-0.82500.h5
# Epoch 14/40
# 25/25 [==============================] - 18s 629ms/step - loss: 0.3174 - accuracy: 0.9300 - val_loss: 0.2733 - val_accuracy: 0.9200
#
# Epoch 00014: saving model to sloan_vgg/model-00014-0.31737-0.93000-0.27327-0.92000.h5
# Epoch 15/40
# 25/25 [==============================] - 18s 628ms/step - loss: 0.2601 - accuracy: 0.9575 - val_loss: 0.2659 - val_accuracy: 0.9150
#
# Epoch 00015: saving model to sloan_vgg/model-00015-0.26006-0.95750-0.26591-0.91500.h5
# Epoch 16/40
# 25/25 [==============================] - 18s 639ms/step - loss: 0.3311 - accuracy: 0.9438 - val_loss: 0.5016 - val_accuracy: 0.7950
#
# Epoch 00016: saving model to sloan_vgg/model-00016-0.33107-0.94375-0.50159-0.79500.h5
# Epoch 17/40
# 25/25 [==============================] - 18s 622ms/step - loss: 0.3871 - accuracy: 0.9250 - val_loss: 0.3266 - val_accuracy: 0.8800
#
# Epoch 00017: saving model to sloan_vgg/model-00017-0.38713-0.92500-0.32656-0.88000.h5
# Epoch 18/40
# 25/25 [==============================] - 18s 632ms/step - loss: 0.3358 - accuracy: 0.9287 - val_loss: 0.3501 - val_accuracy: 0.8650
#
# Epoch 00018: saving model to sloan_vgg/model-00018-0.33581-0.92875-0.35006-0.86500.h5
# Epoch 19/40
# 25/25 [==============================] - 18s 626ms/step - loss: 0.2801 - accuracy: 0.9337 - val_loss: 0.5065 - val_accuracy: 0.8300
#
# Epoch 00019: saving model to sloan_vgg/model-00019-0.28008-0.93375-0.50654-0.83000.h5
# Epoch 20/40
# 25/25 [==============================] - 18s 637ms/step - loss: 0.2945 - accuracy: 0.9337 - val_loss: 0.3274 - val_accuracy: 0.8900
#
# Epoch 00020: saving model to sloan_vgg/model-00020-0.29449-0.93375-0.32743-0.89000.h5
# Epoch 21/40
# 25/25 [==============================] - 18s 638ms/step - loss: 0.3111 - accuracy: 0.9287 - val_loss: 0.2942 - val_accuracy: 0.8900
#
# Epoch 00021: saving model to sloan_vgg/model-00021-0.31113-0.92875-0.29415-0.89000.h5
# Epoch 22/40
# 25/25 [==============================] - 18s 632ms/step - loss: 0.3404 - accuracy: 0.9337 - val_loss: 0.3846 - val_accuracy: 0.8900
#
# Epoch 00022: saving model to sloan_vgg/model-00022-0.34037-0.93375-0.38458-0.89000.h5
# Epoch 23/40
# 25/25 [==============================] - 18s 630ms/step - loss: 0.2652 - accuracy: 0.9488 - val_loss: 0.3169 - val_accuracy: 0.8750
#
# Epoch 00023: saving model to sloan_vgg/model-00023-0.26519-0.94875-0.31686-0.87500.h5
# Epoch 24/40
# 25/25 [==============================] - 18s 626ms/step - loss: 0.2510 - accuracy: 0.9500 - val_loss: 0.3614 - val_accuracy: 0.8900
#
# Epoch 00024: saving model to sloan_vgg/model-00024-0.25100-0.95000-0.36137-0.89000.h5
# Epoch 25/40
# 25/25 [==============================] - 18s 618ms/step - loss: 0.2476 - accuracy: 0.9500 - val_loss: 0.2871 - val_accuracy: 0.9150
#
# Epoch 00025: saving model to sloan_vgg/model-00025-0.24763-0.95000-0.28709-0.91500.h5
# Epoch 26/40
# 25/25 [==============================] - 18s 635ms/step - loss: 0.2501 - accuracy: 0.9525 - val_loss: 0.3640 - val_accuracy: 0.8850
#
# Epoch 00026: saving model to sloan_vgg/model-00026-0.25009-0.95250-0.36402-0.88500.h5
# Epoch 27/40
# 25/25 [==============================] - 18s 633ms/step - loss: 0.2494 - accuracy: 0.9475 - val_loss: 0.2900 - val_accuracy: 0.9200
#
# Epoch 00027: saving model to sloan_vgg/model-00027-0.24938-0.94750-0.29004-0.92000.h5
# Epoch 28/40
# 25/25 [==============================] - 18s 638ms/step - loss: 0.2115 - accuracy: 0.9675 - val_loss: 0.3523 - val_accuracy: 0.8900
#
# Epoch 00028: saving model to sloan_vgg/model-00028-0.21146-0.96750-0.35235-0.89000.h5
# Epoch 29/40
# 25/25 [==============================] - 18s 631ms/step - loss: 0.2242 - accuracy: 0.9588 - val_loss: 0.3104 - val_accuracy: 0.9100
#
# Epoch 00029: saving model to sloan_vgg/model-00029-0.22418-0.95875-0.31041-0.91000.h5
# Epoch 30/40
# 25/25 [==============================] - 18s 646ms/step - loss: 0.2148 - accuracy: 0.9550 - val_loss: 0.3053 - val_accuracy: 0.9050
#
# Epoch 00030: saving model to sloan_vgg/model-00030-0.21477-0.95500-0.30529-0.90500.h5
# Epoch 31/40
# 25/25 [==============================] - 18s 639ms/step - loss: 0.2371 - accuracy: 0.9625 - val_loss: 0.3162 - val_accuracy: 0.9050
#
# Epoch 00031: saving model to sloan_vgg/model-00031-0.23706-0.96250-0.31617-0.90500.h5
# Epoch 32/40
# 25/25 [==============================] - 18s 628ms/step - loss: 0.2061 - accuracy: 0.9675 - val_loss: 0.2559 - val_accuracy: 0.9400
#
# Epoch 00032: saving model to sloan_vgg/model-00032-0.20614-0.96750-0.25595-0.94000.h5
# Epoch 33/40
# 25/25 [==============================] - 18s 634ms/step - loss: 0.2216 - accuracy: 0.9575 - val_loss: 0.3708 - val_accuracy: 0.9000
#
# Epoch 00033: saving model to sloan_vgg/model-00033-0.22160-0.95750-0.37076-0.90000.h5
# Epoch 34/40
# 25/25 [==============================] - 18s 627ms/step - loss: 0.1803 - accuracy: 0.9712 - val_loss: 0.2763 - val_accuracy: 0.9000
#
# Epoch 00034: saving model to sloan_vgg/model-00034-0.18034-0.97125-0.27626-0.90000.h5
# Epoch 35/40
# 25/25 [==============================] - 18s 634ms/step - loss: 0.1613 - accuracy: 0.9737 - val_loss: 0.2745 - val_accuracy: 0.9350
#
# Epoch 00035: saving model to sloan_vgg/model-00035-0.16128-0.97375-0.27454-0.93500.h5
# Epoch 36/40
# 25/25 [==============================] - 18s 641ms/step - loss: 0.1838 - accuracy: 0.9712 - val_loss: 0.2883 - val_accuracy: 0.9250
#
# Epoch 00036: saving model to sloan_vgg/model-00036-0.18384-0.97125-0.28834-0.92500.h5
# Epoch 37/40
# 25/25 [==============================] - 18s 634ms/step - loss: 0.1852 - accuracy: 0.9725 - val_loss: 0.3315 - val_accuracy: 0.9000
#
# Epoch 00037: saving model to sloan_vgg/model-00037-0.18523-0.97250-0.33148-0.90000.h5
# Epoch 38/40
# 25/25 [==============================] - 18s 635ms/step - loss: 0.1913 - accuracy: 0.9625 - val_loss: 0.3829 - val_accuracy: 0.8750
#
# Epoch 00038: saving model to sloan_vgg/model-00038-0.19130-0.96250-0.38288-0.87500.h5
# Epoch 39/40
# 25/25 [==============================] - 18s 625ms/step - loss: 0.2028 - accuracy: 0.9550 - val_loss: 0.2722 - val_accuracy: 0.9250
#
# Epoch 00039: saving model to sloan_vgg/model-00039-0.20284-0.95500-0.27215-0.92500.h5
# Epoch 40/40
# 25/25 [==============================] - 18s 629ms/step - loss: 0.1794 - accuracy: 0.9650 - val_loss: 0.2855 - val_accuracy: 0.9300
#
# Epoch 00040: saving model to sloan_vgg/model-00040-0.17938-0.96500-0.28545-0.93000.h5

# %%
generate_graph(vgg_scaled_flip_rotate)

# %% [markdown]
# ##### VGG crop flip

# %%
vgg_scaled_crop_flip.fit(train_ds_crop_flip,validation_data=val_ds_scaled_cropped,epochs = 40, verbose = 1, workers = 3, class_weight = {0:1.13, 1:8.03, 2:1}, callbacks = callbacks_vgg)
# Out:
# Epoch 1/40
# 25/25 [==============================] - 13s 459ms/step - loss: 1.9000 - accuracy: 0.3713 - val_loss: 1.0387 - val_accuracy: 0.4800
#
# Epoch 00001: saving model to sloan_vgg/model-00001-1.90001-0.37125-1.03868-0.48000.h5
# Epoch 2/40
# 25/25 [==============================] - 13s 447ms/step - loss: 1.6070 - accuracy: 0.3388 - val_loss: 1.0856 - val_accuracy: 0.4350
#
# Epoch 00002: saving model to sloan_vgg/model-00002-1.60702-0.33875-1.08561-0.43500.h5
# Epoch 3/40
# 25/25 [==============================] - 13s 451ms/step - loss: 1.6047 - accuracy: 0.4588 - val_loss: 1.0837 - val_accuracy: 0.4350
#
# Epoch 00003: saving model to sloan_vgg/model-00003-1.60470-0.45875-1.08370-0.43500.h5
# Epoch 4/40
# 25/25 [==============================] - 13s 456ms/step - loss: 1.5988 - accuracy: 0.4525 - val_loss: 1.0798 - val_accuracy: 0.4350
#
# Epoch 00004: saving model to sloan_vgg/model-00004-1.59878-0.45250-1.07979-0.43500.h5
# Epoch 5/40
# 25/25 [==============================] - 13s 445ms/step - loss: 1.6039 - accuracy: 0.4762 - val_loss: 1.1045 - val_accuracy: 0.4350
#
# Epoch 00005: saving model to sloan_vgg/model-00005-1.60392-0.47625-1.10451-0.43500.h5
# Epoch 6/40
# 25/25 [==============================] - 13s 453ms/step - loss: 1.5997 - accuracy: 0.4500 - val_loss: 1.1047 - val_accuracy: 0.4350
#
# Epoch 00006: saving model to sloan_vgg/model-00006-1.59973-0.45000-1.10470-0.43500.h5
# Epoch 7/40
# 25/25 [==============================] - 13s 452ms/step - loss: 1.6020 - accuracy: 0.5138 - val_loss: 1.0769 - val_accuracy: 0.4350
#
# Epoch 00007: saving model to sloan_vgg/model-00007-1.60202-0.51375-1.07693-0.43500.h5
# Epoch 8/40
# 25/25 [==============================] - 13s 453ms/step - loss: 1.6000 - accuracy: 0.3000 - val_loss: 1.0832 - val_accuracy: 0.4350
#
# Epoch 00008: saving model to sloan_vgg/model-00008-1.60000-0.30000-1.08325-0.43500.h5
# Epoch 9/40
# 25/25 [==============================] - 13s 445ms/step - loss: 1.6094 - accuracy: 0.4762 - val_loss: 1.0720 - val_accuracy: 0.4350
#
# Epoch 00009: saving model to sloan_vgg/model-00009-1.60936-0.47625-1.07202-0.43500.h5
# Epoch 10/40
# 25/25 [==============================] - 13s 449ms/step - loss: 1.6080 - accuracy: 0.3587 - val_loss: 1.1133 - val_accuracy: 0.4350
#
# Epoch 00010: saving model to sloan_vgg/model-00010-1.60796-0.35875-1.11328-0.43500.h5
# Epoch 11/40
# 25/25 [==============================] - 15s 525ms/step - loss: 1.6015 - accuracy: 0.4525 - val_loss: 1.0835 - val_accuracy: 0.4350
#
# Epoch 00011: saving model to sloan_vgg/model-00011-1.60146-0.45250-1.08353-0.43500.h5
# Epoch 12/40
# 25/25 [==============================] - 15s 528ms/step - loss: 1.5999 - accuracy: 0.5138 - val_loss: 1.0863 - val_accuracy: 0.4350
#
# Epoch 00012: saving model to sloan_vgg/model-00012-1.59991-0.51375-1.08630-0.43500.h5
# Epoch 13/40
# 25/25 [==============================] - 15s 521ms/step - loss: 1.6002 - accuracy: 0.4663 - val_loss: 1.0898 - val_accuracy: 0.4350
#
# Epoch 00013: saving model to sloan_vgg/model-00013-1.60015-0.46625-1.08981-0.43500.h5
# Epoch 14/40
# 25/25 [==============================] - 15s 524ms/step - loss: 1.5991 - accuracy: 0.5138 - val_loss: 1.0869 - val_accuracy: 0.4350
#
# Epoch 00014: saving model to sloan_vgg/model-00014-1.59912-0.51375-1.08693-0.43500.h5
# Epoch 15/40
# 25/25 [==============================] - 15s 527ms/step - loss: 1.5975 - accuracy: 0.4487 - val_loss: 1.0826 - val_accuracy: 0.4350
#
# Epoch 00015: saving model to sloan_vgg/model-00015-1.59746-0.44875-1.08262-0.43500.h5
# Epoch 16/40
# 25/25 [==============================] - 15s 521ms/step - loss: 1.5966 - accuracy: 0.5138 - val_loss: 1.0677 - val_accuracy: 0.4350
#
# Epoch 00016: saving model to sloan_vgg/model-00016-1.59656-0.51375-1.06774-0.43500.h5
# Epoch 17/40
# 25/25 [==============================] - 15s 525ms/step - loss: 1.5982 - accuracy: 0.4775 - val_loss: 1.0893 - val_accuracy: 0.4350
#
# Epoch 00017: saving model to sloan_vgg/model-00017-1.59817-0.47750-1.08931-0.43500.h5
# Epoch 18/40
# 25/25 [==============================] - 15s 529ms/step - loss: 1.5998 - accuracy: 0.4638 - val_loss: 1.0851 - val_accuracy: 0.4350
#
# Epoch 00018: saving model to sloan_vgg/model-00018-1.59985-0.46375-1.08508-0.43500.h5
# Epoch 19/40
# 25/25 [==============================] - 15s 523ms/step - loss: 1.6001 - accuracy: 0.4475 - val_loss: 1.0913 - val_accuracy: 0.4350
#
# Epoch 00019: saving model to sloan_vgg/model-00019-1.60011-0.44750-1.09125-0.43500.h5
# Epoch 20/40
# 25/25 [==============================] - 15s 527ms/step - loss: 1.5967 - accuracy: 0.5138 - val_loss: 1.0846 - val_accuracy: 0.4350
#
# Epoch 00020: saving model to sloan_vgg/model-00020-1.59673-0.51375-1.08455-0.43500.h5
# Epoch 21/40
# 25/25 [==============================] - 15s 528ms/step - loss: 1.5958 - accuracy: 0.4675 - val_loss: 1.0776 - val_accuracy: 0.4350
#
# Epoch 00021: saving model to sloan_vgg/model-00021-1.59585-0.46750-1.07762-0.43500.h5
# Epoch 22/40
# 25/25 [==============================] - 15s 525ms/step - loss: 1.6003 - accuracy: 0.3500 - val_loss: 1.0774 - val_accuracy: 0.4350
#
# Epoch 00022: saving model to sloan_vgg/model-00022-1.60032-0.35000-1.07736-0.43500.h5
# Epoch 23/40
# 25/25 [==============================] - 15s 528ms/step - loss: 1.5977 - accuracy: 0.4737 - val_loss: 1.0802 - val_accuracy: 0.4350
#
# Epoch 00023: saving model to sloan_vgg/model-00023-1.59775-0.47375-1.08017-0.43500.h5
# Epoch 24/40
# 25/25 [==============================] - 15s 532ms/step - loss: 1.5957 - accuracy: 0.4787 - val_loss: 1.0877 - val_accuracy: 0.4350
#
# Epoch 00024: saving model to sloan_vgg/model-00024-1.59571-0.47875-1.08767-0.43500.h5
# Epoch 25/40
# 25/25 [==============================] - 15s 528ms/step - loss: 1.5971 - accuracy: 0.4625 - val_loss: 1.0752 - val_accuracy: 0.4350
#
# Epoch 00025: saving model to sloan_vgg/model-00025-1.59713-0.46250-1.07517-0.43500.h5
# Epoch 26/40
# 25/25 [==============================] - 15s 524ms/step - loss: 1.6013 - accuracy: 0.4437 - val_loss: 1.0640 - val_accuracy: 0.4350
#
# Epoch 00026: saving model to sloan_vgg/model-00026-1.60129-0.44375-1.06404-0.43500.h5
# Epoch 27/40
# 25/25 [==============================] - 15s 525ms/step - loss: 1.6024 - accuracy: 0.2800 - val_loss: 1.1071 - val_accuracy: 0.0850
#
# Epoch 00027: saving model to sloan_vgg/model-00027-1.60244-0.28000-1.10709-0.08500.h5
# Epoch 28/40
# 25/25 [==============================] - 15s 528ms/step - loss: 1.5982 - accuracy: 0.4963 - val_loss: 1.0631 - val_accuracy: 0.4350
#
# Epoch 00028: saving model to sloan_vgg/model-00028-1.59825-0.49625-1.06315-0.43500.h5
# Epoch 29/40
# 25/25 [==============================] - 15s 522ms/step - loss: 1.6097 - accuracy: 0.2500 - val_loss: 1.0750 - val_accuracy: 0.4350
#
# Epoch 00029: saving model to sloan_vgg/model-00029-1.60967-0.25000-1.07505-0.43500.h5
# Epoch 30/40
# 25/25 [==============================] - 15s 530ms/step - loss: 1.5967 - accuracy: 0.5138 - val_loss: 1.0700 - val_accuracy: 0.4350
#
# Epoch 00030: saving model to sloan_vgg/model-00030-1.59673-0.51375-1.06997-0.43500.h5
# Epoch 31/40
# 25/25 [==============================] - 15s 532ms/step - loss: 1.5964 - accuracy: 0.4875 - val_loss: 1.0721 - val_accuracy: 0.4350
#
# Epoch 00031: saving model to sloan_vgg/model-00031-1.59642-0.48750-1.07214-0.43500.h5
# Epoch 32/40
# 25/25 [==============================] - 15s 517ms/step - loss: 1.5965 - accuracy: 0.4688 - val_loss: 1.0684 - val_accuracy: 0.4350
#
# Epoch 00032: saving model to sloan_vgg/model-00032-1.59646-0.46875-1.06840-0.43500.h5
# Epoch 33/40
# 25/25 [==============================] - 15s 539ms/step - loss: 1.5965 - accuracy: 0.5138 - val_loss: 1.0689 - val_accuracy: 0.4350
#
# Epoch 00033: saving model to sloan_vgg/model-00033-1.59645-0.51375-1.06886-0.43500.h5
# Epoch 34/40
# 25/25 [==============================] - 13s 450ms/step - loss: 1.5958 - accuracy: 0.4363 - val_loss: 1.0822 - val_accuracy: 0.4350
#
# Epoch 00034: saving model to sloan_vgg/model-00034-1.59575-0.43625-1.08220-0.43500.h5
# Epoch 35/40
# 25/25 [==============================] - 13s 452ms/step - loss: 1.5956 - accuracy: 0.5138 - val_loss: 1.0801 - val_accuracy: 0.4350
#
# Epoch 00035: saving model to sloan_vgg/model-00035-1.59564-0.51375-1.08009-0.43500.h5
# Epoch 36/40
# 25/25 [==============================] - 13s 451ms/step - loss: 1.5960 - accuracy: 0.4650 - val_loss: 1.0874 - val_accuracy: 0.4350
#
# Epoch 00036: saving model to sloan_vgg/model-00036-1.59605-0.46500-1.08739-0.43500.h5
# Epoch 37/40
# 25/25 [==============================] - 13s 448ms/step - loss: 1.5989 - accuracy: 0.5138 - val_loss: 1.0809 - val_accuracy: 0.4350
#
# Epoch 00037: saving model to sloan_vgg/model-00037-1.59890-0.51375-1.08088-0.43500.h5
# Epoch 38/40
# 25/25 [==============================] - 13s 445ms/step - loss: 1.6005 - accuracy: 0.4425 - val_loss: 1.0792 - val_accuracy: 0.4350
#
# Epoch 00038: saving model to sloan_vgg/model-00038-1.60047-0.44250-1.07922-0.43500.h5
# Epoch 39/40
# 25/25 [==============================] - 15s 526ms/step - loss: 1.5973 - accuracy: 0.4538 - val_loss: 1.0765 - val_accuracy: 0.4350
#
# Epoch 00039: saving model to sloan_vgg/model-00039-1.59733-0.45375-1.07646-0.43500.h5
# Epoch 40/40
# 25/25 [==============================] - 15s 529ms/step - loss: 1.6038 - accuracy: 0.4475 - val_loss: 1.0703 - val_accuracy: 0.4350
#
# Epoch 00040: saving model to sloan_vgg/model-00040-1.60381-0.44750-1.07025-0.43500.h5

# %%
generate_graph(vgg_scaled_crop_flip)

# %% [markdown]
# ##### vgg crop flip rotate

# %%
vgg_scaled_crop_flip_rotate.fit(train_ds_crop_flip_rotate,validation_data=val_ds_scaled_cropped,epochs = 40, verbose = 1, workers = 3, class_weight = {0:1.13, 1:8.03, 2:1},callbacks = callbacks_vgg)
# Out:
# Epoch 1/40
# 25/25 [==============================] - 27s 989ms/step - loss: 1.8818 - accuracy: 0.3487 - val_loss: 1.1389 - val_accuracy: 0.0850
#
# Epoch 00001: saving model to sloan_vgg/model-00001-1.88177-0.34875-1.13890-0.08500.h5
# Epoch 2/40
# 25/25 [==============================] - 27s 980ms/step - loss: 1.6099 - accuracy: 0.4363 - val_loss: 1.1225 - val_accuracy: 0.4350
#
# Epoch 00002: saving model to sloan_vgg/model-00002-1.60987-0.43625-1.12248-0.43500.h5
# Epoch 3/40
# 25/25 [==============================] - 27s 988ms/step - loss: 1.6055 - accuracy: 0.4125 - val_loss: 1.1103 - val_accuracy: 0.4350
#
# Epoch 00003: saving model to sloan_vgg/model-00003-1.60545-0.41250-1.11033-0.43500.h5
# Epoch 4/40
# 25/25 [==============================] - 27s 1s/step - loss: 1.6036 - accuracy: 0.3750 - val_loss: 1.0562 - val_accuracy: 0.4350
#
# Epoch 00004: saving model to sloan_vgg/model-00004-1.60356-0.37500-1.05620-0.43500.h5
# Epoch 5/40
# 25/25 [==============================] - 27s 976ms/step - loss: 1.5986 - accuracy: 0.4725 - val_loss: 1.1076 - val_accuracy: 0.4350
#
# Epoch 00005: saving model to sloan_vgg/model-00005-1.59860-0.47250-1.10765-0.43500.h5
# Epoch 6/40
# 25/25 [==============================] - 27s 1s/step - loss: 1.6148 - accuracy: 0.4325 - val_loss: 1.1066 - val_accuracy: 0.4350
#
# Epoch 00006: saving model to sloan_vgg/model-00006-1.61480-0.43250-1.10656-0.43500.h5
# Epoch 7/40
# 25/25 [==============================] - 27s 1s/step - loss: 1.6072 - accuracy: 0.5138 - val_loss: 1.0512 - val_accuracy: 0.4350
#
# Epoch 00007: saving model to sloan_vgg/model-00007-1.60724-0.51375-1.05116-0.43500.h5
# Epoch 8/40
# 25/25 [==============================] - 27s 995ms/step - loss: 1.5980 - accuracy: 0.2975 - val_loss: 1.1368 - val_accuracy: 0.4350
#
# Epoch 00008: saving model to sloan_vgg/model-00008-1.59801-0.29750-1.13680-0.43500.h5
# Epoch 9/40
# 25/25 [==============================] - 27s 983ms/step - loss: 1.6087 - accuracy: 0.4238 - val_loss: 1.0981 - val_accuracy: 0.4350
#
# Epoch 00009: saving model to sloan_vgg/model-00009-1.60875-0.42375-1.09809-0.43500.h5
# Epoch 10/40
# 25/25 [==============================] - 26s 973ms/step - loss: 1.6021 - accuracy: 0.4525 - val_loss: 1.0704 - val_accuracy: 0.4350
#
# Epoch 00010: saving model to sloan_vgg/model-00010-1.60206-0.45250-1.07043-0.43500.h5
# Epoch 11/40
# 25/25 [==============================] - 27s 1s/step - loss: 1.5962 - accuracy: 0.5138 - val_loss: 1.0875 - val_accuracy: 0.4350
#
# Epoch 00011: saving model to sloan_vgg/model-00011-1.59622-0.51375-1.08747-0.43500.h5
# Epoch 12/40
# 25/25 [==============================] - 18s 635ms/step - loss: 1.5964 - accuracy: 0.5138 - val_loss: 1.0736 - val_accuracy: 0.4350
#
# Epoch 00012: saving model to sloan_vgg/model-00012-1.59637-0.51375-1.07357-0.43500.h5
# Epoch 13/40
# 25/25 [==============================] - 18s 629ms/step - loss: 1.5976 - accuracy: 0.4700 - val_loss: 1.0716 - val_accuracy: 0.4350
#
# Epoch 00013: saving model to sloan_vgg/model-00013-1.59755-0.47000-1.07161-0.43500.h5
# Epoch 14/40
# 25/25 [==============================] - 18s 635ms/step - loss: 1.5993 - accuracy: 0.4750 - val_loss: 1.1008 - val_accuracy: 0.4350
#
# Epoch 00014: saving model to sloan_vgg/model-00014-1.59932-0.47500-1.10075-0.43500.h5
# Epoch 15/40
# 25/25 [==============================] - 18s 640ms/step - loss: 1.6057 - accuracy: 0.3200 - val_loss: 1.0584 - val_accuracy: 0.4350
#
# Epoch 00015: saving model to sloan_vgg/model-00015-1.60569-0.32000-1.05842-0.43500.h5
# Epoch 16/40
# 25/25 [==============================] - 18s 607ms/step - loss: 1.6021 - accuracy: 0.3963 - val_loss: 1.0773 - val_accuracy: 0.4350
#
# Epoch 00016: saving model to sloan_vgg/model-00016-1.60213-0.39625-1.07733-0.43500.h5
# Epoch 17/40
# 25/25 [==============================] - 18s 607ms/step - loss: 1.6094 - accuracy: 0.3887 - val_loss: 1.0614 - val_accuracy: 0.4350
#
# Epoch 00017: saving model to sloan_vgg/model-00017-1.60939-0.38875-1.06144-0.43500.h5
# Epoch 18/40
# 25/25 [==============================] - 18s 629ms/step - loss: 1.5975 - accuracy: 0.4850 - val_loss: 1.0940 - val_accuracy: 0.4350
#
# Epoch 00018: saving model to sloan_vgg/model-00018-1.59753-0.48500-1.09401-0.43500.h5
# Epoch 19/40
# 25/25 [==============================] - 19s 638ms/step - loss: 1.6016 - accuracy: 0.4338 - val_loss: 1.1003 - val_accuracy: 0.4350
#
# Epoch 00019: saving model to sloan_vgg/model-00019-1.60156-0.43375-1.10026-0.43500.h5
# Epoch 20/40
# 25/25 [==============================] - 18s 635ms/step - loss: 1.6042 - accuracy: 0.4437 - val_loss: 1.0926 - val_accuracy: 0.4350
#
# Epoch 00020: saving model to sloan_vgg/model-00020-1.60417-0.44375-1.09260-0.43500.h5
# Epoch 21/40
# 25/25 [==============================] - 18s 626ms/step - loss: 1.6081 - accuracy: 0.4500 - val_loss: 1.0567 - val_accuracy: 0.4800
#
# Epoch 00021: saving model to sloan_vgg/model-00021-1.60806-0.45000-1.05673-0.48000.h5
# Epoch 22/40
# 25/25 [==============================] - 18s 632ms/step - loss: 1.5980 - accuracy: 0.4550 - val_loss: 1.1192 - val_accuracy: 0.4350
#
# Epoch 00022: saving model to sloan_vgg/model-00022-1.59796-0.45500-1.11922-0.43500.h5
# Epoch 23/40
# 25/25 [==============================] - 18s 633ms/step - loss: 1.6026 - accuracy: 0.3550 - val_loss: 1.0590 - val_accuracy: 0.4350
#
# Epoch 00023: saving model to sloan_vgg/model-00023-1.60261-0.35500-1.05902-0.43500.h5
# Epoch 24/40
# 25/25 [==============================] - 19s 638ms/step - loss: 1.5965 - accuracy: 0.5138 - val_loss: 1.0779 - val_accuracy: 0.4350
#
# Epoch 00024: saving model to sloan_vgg/model-00024-1.59648-0.51375-1.07788-0.43500.h5
# Epoch 25/40
# 25/25 [==============================] - 19s 640ms/step - loss: 1.5970 - accuracy: 0.4650 - val_loss: 1.0999 - val_accuracy: 0.4350
#
# Epoch 00025: saving model to sloan_vgg/model-00025-1.59700-0.46500-1.09990-0.43500.h5
# Epoch 26/40
# 25/25 [==============================] - 18s 630ms/step - loss: 1.6059 - accuracy: 0.4125 - val_loss: 1.0815 - val_accuracy: 0.4350
#
# Epoch 00026: saving model to sloan_vgg/model-00026-1.60589-0.41250-1.08148-0.43500.h5
# Epoch 27/40
# 25/25 [==============================] - 19s 653ms/step - loss: 1.6000 - accuracy: 0.3275 - val_loss: 1.0854 - val_accuracy: 0.4350
#
# Epoch 00027: saving model to sloan_vgg/model-00027-1.60002-0.32750-1.08543-0.43500.h5
# Epoch 28/40
# 25/25 [==============================] - 18s 608ms/step - loss: 1.5987 - accuracy: 0.4525 - val_loss: 1.0901 - val_accuracy: 0.4350
#
# Epoch 00028: saving model to sloan_vgg/model-00028-1.59868-0.45250-1.09011-0.43500.h5
# Epoch 29/40
# 25/25 [==============================] - 18s 639ms/step - loss: 1.6045 - accuracy: 0.4638 - val_loss: 1.0711 - val_accuracy: 0.4800
#
# Epoch 00029: saving model to sloan_vgg/model-00029-1.60450-0.46375-1.07107-0.48000.h5
# Epoch 30/40
# 25/25 [==============================] - 19s 637ms/step - loss: 1.5991 - accuracy: 0.5050 - val_loss: 1.0896 - val_accuracy: 0.4350
#
# Epoch 00030: saving model to sloan_vgg/model-00030-1.59906-0.50500-1.08963-0.43500.h5
# Epoch 31/40
# 25/25 [==============================] - 18s 634ms/step - loss: 1.5995 - accuracy: 0.4650 - val_loss: 1.0576 - val_accuracy: 0.4350
#
# Epoch 00031: saving model to sloan_vgg/model-00031-1.59946-0.46500-1.05763-0.43500.h5
# Epoch 32/40
# 25/25 [==============================] - 18s 637ms/step - loss: 1.5980 - accuracy: 0.4725 - val_loss: 1.0966 - val_accuracy: 0.4350
#
# Epoch 00032: saving model to sloan_vgg/model-00032-1.59798-0.47250-1.09664-0.43500.h5
# Epoch 33/40
# 25/25 [==============================] - 18s 643ms/step - loss: 1.5992 - accuracy: 0.4588 - val_loss: 1.0855 - val_accuracy: 0.4350
#
# Epoch 00033: saving model to sloan_vgg/model-00033-1.59923-0.45875-1.08548-0.43500.h5
# Epoch 34/40
# 25/25 [==============================] - 19s 638ms/step - loss: 1.6010 - accuracy: 0.5138 - val_loss: 1.0693 - val_accuracy: 0.4350
#
# Epoch 00034: saving model to sloan_vgg/model-00034-1.60098-0.51375-1.06932-0.43500.h5
# Epoch 35/40
# 25/25 [==============================] - 18s 626ms/step - loss: 1.5967 - accuracy: 0.5138 - val_loss: 1.0728 - val_accuracy: 0.4350
#
# Epoch 00035: saving model to sloan_vgg/model-00035-1.59670-0.51375-1.07283-0.43500.h5
# Epoch 36/40
# 25/25 [==============================] - 18s 634ms/step - loss: 1.5981 - accuracy: 0.3750 - val_loss: 1.0866 - val_accuracy: 0.4350
#
# Epoch 00036: saving model to sloan_vgg/model-00036-1.59806-0.37500-1.08657-0.43500.h5
# Epoch 37/40
# 25/25 [==============================] - 18s 635ms/step - loss: 1.5990 - accuracy: 0.5138 - val_loss: 1.0716 - val_accuracy: 0.4350
#
# Epoch 00037: saving model to sloan_vgg/model-00037-1.59902-0.51375-1.07164-0.43500.h5
# Epoch 38/40
# 25/25 [==============================] - 18s 628ms/step - loss: 1.6069 - accuracy: 0.4600 - val_loss: 1.0553 - val_accuracy: 0.4350
#
# Epoch 00038: saving model to sloan_vgg/model-00038-1.60689-0.46000-1.05529-0.43500.h5
# Epoch 39/40
# 25/25 [==============================] - 19s 650ms/step - loss: 1.6074 - accuracy: 0.3313 - val_loss: 1.0848 - val_accuracy: 0.4350
#
# Epoch 00039: saving model to sloan_vgg/model-00039-1.60743-0.33125-1.08479-0.43500.h5
# Epoch 40/40
# 25/25 [==============================] - 18s 637ms/step - loss: 1.6002 - accuracy: 0.4437 - val_loss: 1.0868 - val_accuracy: 0.4350
#
# Epoch 00040: saving model to sloan_vgg/model-00040-1.60017-0.44375-1.08682-0.43500.h5

# %% [markdown]
# ##### vgg scaled cropped - preprocessed

# %%
generate_graph(vgg_scaled_crop_flip_rotate)

# %% [markdown]
# ##### VGG 16 preprocess normal scaled crop

# %%
train_ds_normal_scaled_crop = prepare_dataset_normal_crop(train_ds_scaled_cropped) 
val_ds_normal_scaled_crop = prepare_dataset_normal_crop(val_ds_scaled_cropped, training = False)
vgg_model.fit(train_ds_normal_scaled_crop, validation_data = val_ds_normal_scaled_crop, epochs = 10, verbose = 1, workers = 3, class_weight = {0:1.13, 1:8.03, 2:1}, callbacks = callbacks_vgg)
# Out:
# Epoch 1/10
# 25/25 [==============================] - 17s 407ms/step - loss: 1.7022 - accuracy: 0.3262 - val_loss: 1.0557 - val_accuracy: 0.4350
#
# Epoch 00001: saving model to sloan_vgg/model-00001-1.70225-0.32625-1.05570-0.43500.h5
# Epoch 2/10
# 25/25 [==============================] - 9s 320ms/step - loss: 1.6094 - accuracy: 0.3925 - val_loss: 1.0988 - val_accuracy: 0.4350
#
# Epoch 00002: saving model to sloan_vgg/model-00002-1.60937-0.39250-1.09882-0.43500.h5
# Epoch 3/10
# 25/25 [==============================] - 10s 322ms/step - loss: 1.6164 - accuracy: 0.4725 - val_loss: 1.0750 - val_accuracy: 0.4350
#
# Epoch 00003: saving model to sloan_vgg/model-00003-1.61645-0.47250-1.07504-0.43500.h5
# Epoch 4/10
# 25/25 [==============================] - 10s 327ms/step - loss: 1.6046 - accuracy: 0.3512 - val_loss: 1.0450 - val_accuracy: 0.4350
#
# Epoch 00004: saving model to sloan_vgg/model-00004-1.60457-0.35125-1.04501-0.43500.h5
# Epoch 5/10
# 25/25 [==============================] - 10s 325ms/step - loss: 1.6050 - accuracy: 0.4787 - val_loss: 1.1254 - val_accuracy: 0.4350
#
# Epoch 00005: saving model to sloan_vgg/model-00005-1.60496-0.47875-1.12542-0.43500.h5
# Epoch 6/10
# 25/25 [==============================] - 10s 326ms/step - loss: 1.6126 - accuracy: 0.3338 - val_loss: 1.1340 - val_accuracy: 0.0850
#
# Epoch 00006: saving model to sloan_vgg/model-00006-1.61257-0.33375-1.13399-0.08500.h5
# Epoch 7/10
# 25/25 [==============================] - 10s 321ms/step - loss: 1.6153 - accuracy: 0.3600 - val_loss: 1.1597 - val_accuracy: 0.4350
#
# Epoch 00007: saving model to sloan_vgg/model-00007-1.61527-0.36000-1.15969-0.43500.h5
# Epoch 8/10
# 25/25 [==============================] - 10s 321ms/step - loss: 1.6204 - accuracy: 0.4263 - val_loss: 1.0564 - val_accuracy: 0.4350
#
# Epoch 00008: saving model to sloan_vgg/model-00008-1.62036-0.42625-1.05643-0.43500.h5
# Epoch 9/10
# 25/25 [==============================] - 10s 330ms/step - loss: 1.5956 - accuracy: 0.4075 - val_loss: 1.0913 - val_accuracy: 0.4350
#
# Epoch 00009: saving model to sloan_vgg/model-00009-1.59563-0.40750-1.09127-0.43500.h5
# Epoch 10/10
# 25/25 [==============================] - 10s 322ms/step - loss: 1.6113 - accuracy: 0.4325 - val_loss: 1.1052 - val_accuracy: 0.4350
#
# Epoch 00010: saving model to sloan_vgg/model-00010-1.61126-0.43250-1.10515-0.43500.h5

# %%
generate_graph(vgg_model)

# %% [markdown]
# ##### Model evaluation

# %%
vgg_scaled = load_model('./sloan_vgg/vgg16-scaled_0.36-92.25_0.32-089.h5')
vgg_unscaled = load_model('./sloan_vgg/vgg16-unscaled-0.04_098.62-0.74_086.5.h5') 
vgg_scaled_flip = load_model('./sloan_vgg/VGG_scaled_flip0.16_96.62-0.31_92.50.h5')
vgg_scaled_flip_rotate = load_model('./sloan_vgg/vgg_16_sclaled_flip_rotate_0.20-0.9550_0.27-0.925.h5')
vgg_scaled_crop_flip = load_model('./sloan_vgg/vgg_scaled_crop_flip1.60-0.44_1.07-0.4350.h5')
vgg_scaled_crop_flip_rotate = load_model('./sloan_vgg/vgg16_scl_crop_flip_rotate1.6-0.43_1.12-0.43.h5')



metrics = Metrics(vgg_scaled,val_ds_scaled)
print(metrics.calculate_scores())
print('---------------------------------------------------------------------------------------------------------------------')
metrics = Metrics(vgg_unscaled,val_ds)
print(metrics.calculate_scores())
print('---------------------------------------------------------------------------------------------------------------------')
metrics = Metrics(vgg_scaled_flip,val_ds_scaled)
print(metrics.calculate_scores())
print('---------------------------------------------------------------------------------------------------------------------')
metrics = Metrics(vgg_scaled_flip_rotate,val_ds_scaled)
print(metrics.calculate_scores())
print('---------------------------------------------------------------------------------------------------------------------')
metrics = Metrics(vgg_scaled_crop_flip,val_ds_scaled_cropped)
print(metrics.calculate_scores())
print('---------------------------------------------------------------------------------------------------------------------')
metrics = Metrics(vgg_scaled_crop_flip_rotate,val_ds_scaled_cropped)
print(metrics.calculate_scores())
print('---------------------------------------------------------------------------------------------------------------------')
# Out:
# calculating score.....
# [[89  1  6]
#  [ 1 10  6]
#  [ 4  4 79]]
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.93      0.94        96
#          1.0       0.67      0.59      0.62        17
#          2.0       0.87      0.91      0.89        87
#
#     accuracy                           0.89       200
#    macro avg       0.83      0.81      0.82       200
# weighted avg       0.89      0.89      0.89       200
#
# None
# ---------------------------------------------------------------------------------------------------------------------
# calculating score.....
# [[85  3  8]
#  [ 0  8  9]
#  [ 1  6 80]]
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.89      0.93        96
#          1.0       0.47      0.47      0.47        17
#          2.0       0.82      0.92      0.87        87
#
#     accuracy                           0.86       200
#    macro avg       0.76      0.76      0.76       200
# weighted avg       0.87      0.86      0.87       200
#
# None
# ---------------------------------------------------------------------------------------------------------------------
# calculating score.....
# [[90  4  2]
#  [ 0 10  7]
#  [ 0  2 85]]
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.94      0.97        96
#          1.0       0.62      0.59      0.61        17
#          2.0       0.90      0.98      0.94        87
#
#     accuracy                           0.93       200
#    macro avg       0.84      0.83      0.84       200
# weighted avg       0.93      0.93      0.92       200
#
# None
# ---------------------------------------------------------------------------------------------------------------------
# calculating score.....
# [[95  0  1]
#  [ 1 10  6]
#  [ 0  7 80]]
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99        96
#          1.0       0.59      0.59      0.59        17
#          2.0       0.92      0.92      0.92        87
#
#     accuracy                           0.93       200
#    macro avg       0.83      0.83      0.83       200
# weighted avg       0.93      0.93      0.93       200
#
# None
# ---------------------------------------------------------------------------------------------------------------------
# calculating score.....
# [[ 0  0 96]
#  [ 0  0 17]
#  [ 0  0 87]]
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        96
#          1.0       0.00      0.00      0.00        17
#          2.0       0.43      1.00      0.61        87
#
#     accuracy                           0.43       200
#    macro avg       0.14      0.33      0.20       200
# weighted avg       0.19      0.43      0.26       200
#
# None
# ---------------------------------------------------------------------------------------------------------------------
# calculating score.....
# [[ 0  0 96]
#  [ 0  0 17]
#  [ 0  0 87]]
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        96
#          1.0       0.00      0.00      0.00        17
#          2.0       0.43      1.00      0.61        87
#
#     accuracy                           0.43       200
#    macro avg       0.14      0.33      0.20       200
# weighted avg       0.19      0.43      0.26       200
#
# None
# ---------------------------------------------------------------------------------------------------------------------

# %%
vgg_scaled_preprocess_crop = load_model('./sloan_vgg/vgg16-preprocess-crop-1.61-0.4725-1.07-0.435.h5')

metrics = Metrics(vgg_scaled_preprocess_crop,val_ds_scaled_cropped)
print(metrics.calculate_scores())
print('---------------------------------------------------------------------------------------------------------------------')
# Out:
# calculating score.....
# [[ 0  0 96]
#  [ 0  0 17]
#  [ 0  0 87]]
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        96
#          1.0       0.00      0.00      0.00        17
#          2.0       0.43      1.00      0.61        87
#
#     accuracy                           0.43       200
#    macro avg       0.14      0.33      0.20       200
# weighted avg       0.19      0.43      0.26       200
#
# None
# ---------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Xception Network

# %% [markdown]
# ##### Xception model building

# %%
base_model_xception = tf.keras.applications.Xception(
    include_top=False,
    weights="imagenet",    
    input_shape=(img_height, img_width, channels),
    pooling='max',
    classes=3,
)
layer_count  = len(base_model_xception.layers)
print(f'There are a total of {layer_count} layers in the Xception network')
# making the base layers non trainable or freezing

# break_point  = 123 # for unscaled
break_point  = 130 # for scaled
for layer in base_model_xception.layers[0:break_point]:
    layer.trainable = False
for layer in base_model_xception.layers[break_point:]:
    layer.trainable = True

print(base_model_xception.input) 
input = base_model_xception.input
output = base_model_xception.output
x = Dense(num_classes, activation  = 'softmax')(output)

xception_model = Model(inputs = input, outputs = x)
xception_model.summary()
xception_model.compile(optimizer = optimizers.Adam(lr=1e-4), loss = 'categorical_crossentropy', metrics = ['accuracy'])
# Out:
# There are a total of 133 layers in the Xception network
# KerasTensor(type_spec=TensorSpec(shape=(None, 512, 512, 3), dtype=tf.float32, name='input_2'), name='input_2', description="created by layer 'input_2'")
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 512, 512, 3) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 255, 255, 32) 864         input_2[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 255, 255, 32) 128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 255, 255, 32) 0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 253, 253, 64) 18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 253, 253, 64) 256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 253, 253, 64) 0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, 253, 253, 128 8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, 253, 253, 128 512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, 253, 253, 128 0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, 253, 253, 128 17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, 253, 253, 128 512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 127, 127, 128 8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 127, 127, 128 0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 127, 127, 128 512         conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 127, 127, 128 0           block2_pool[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act (Activation (None, 127, 127, 128 0           add_12[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2 (None, 127, 127, 256 33920       block3_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormal (None, 127, 127, 256 1024        block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act (Activation (None, 127, 127, 256 0           block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2 (None, 127, 127, 256 67840       block3_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormal (None, 127, 127, 256 1024        block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 256)  32768       add_12[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 64, 64, 256)  0           block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 64, 256)  1024        conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 64, 64, 256)  0           block3_pool[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act (Activation (None, 64, 64, 256)  0           add_13[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2 (None, 64, 64, 728)  188672      block4_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormal (None, 64, 64, 728)  2912        block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act (Activation (None, 64, 64, 728)  0           block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2 (None, 64, 64, 728)  536536      block4_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormal (None, 64, 64, 728)  2912        block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 728)  186368      add_13[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 32, 32, 728)  0           block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 728)  2912        conv2d_6[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 32, 32, 728)  0           block4_pool[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act (Activation (None, 32, 32, 728)  0           add_14[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2 (None, 32, 32, 728)  536536      block5_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormal (None, 32, 32, 728)  2912        block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act (Activation (None, 32, 32, 728)  0           block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2 (None, 32, 32, 728)  536536      block5_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormal (None, 32, 32, 728)  2912        block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act (Activation (None, 32, 32, 728)  0           block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2 (None, 32, 32, 728)  536536      block5_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormal (None, 32, 32, 728)  2912        block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 32, 32, 728)  0           block5_sepconv3_bn[0][0]
#                                                                  add_14[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act (Activation (None, 32, 32, 728)  0           add_15[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2 (None, 32, 32, 728)  536536      block6_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormal (None, 32, 32, 728)  2912        block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act (Activation (None, 32, 32, 728)  0           block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2 (None, 32, 32, 728)  536536      block6_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormal (None, 32, 32, 728)  2912        block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act (Activation (None, 32, 32, 728)  0           block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2 (None, 32, 32, 728)  536536      block6_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormal (None, 32, 32, 728)  2912        block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 32, 32, 728)  0           block6_sepconv3_bn[0][0]
#                                                                  add_15[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act (Activation (None, 32, 32, 728)  0           add_16[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2 (None, 32, 32, 728)  536536      block7_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormal (None, 32, 32, 728)  2912        block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act (Activation (None, 32, 32, 728)  0           block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2 (None, 32, 32, 728)  536536      block7_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormal (None, 32, 32, 728)  2912        block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act (Activation (None, 32, 32, 728)  0           block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2 (None, 32, 32, 728)  536536      block7_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormal (None, 32, 32, 728)  2912        block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 32, 32, 728)  0           block7_sepconv3_bn[0][0]
#                                                                  add_16[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act (Activation (None, 32, 32, 728)  0           add_17[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2 (None, 32, 32, 728)  536536      block8_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormal (None, 32, 32, 728)  2912        block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act (Activation (None, 32, 32, 728)  0           block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2 (None, 32, 32, 728)  536536      block8_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormal (None, 32, 32, 728)  2912        block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act (Activation (None, 32, 32, 728)  0           block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2 (None, 32, 32, 728)  536536      block8_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormal (None, 32, 32, 728)  2912        block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 32, 32, 728)  0           block8_sepconv3_bn[0][0]
#                                                                  add_17[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_act (Activation (None, 32, 32, 728)  0           add_18[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2 (None, 32, 32, 728)  536536      block9_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormal (None, 32, 32, 728)  2912        block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_act (Activation (None, 32, 32, 728)  0           block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2 (None, 32, 32, 728)  536536      block9_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormal (None, 32, 32, 728)  2912        block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_act (Activation (None, 32, 32, 728)  0           block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2 (None, 32, 32, 728)  536536      block9_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormal (None, 32, 32, 728)  2912        block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 32, 32, 728)  0           block9_sepconv3_bn[0][0]
#                                                                  add_18[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_act (Activatio (None, 32, 32, 728)  0           add_19[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv (None, 32, 32, 728)  536536      block10_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNorma (None, 32, 32, 728)  2912        block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_act (Activatio (None, 32, 32, 728)  0           block10_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv (None, 32, 32, 728)  536536      block10_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNorma (None, 32, 32, 728)  2912        block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_act (Activatio (None, 32, 32, 728)  0           block10_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv (None, 32, 32, 728)  536536      block10_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNorma (None, 32, 32, 728)  2912        block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 32, 32, 728)  0           block10_sepconv3_bn[0][0]
#                                                                  add_19[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_act (Activatio (None, 32, 32, 728)  0           add_20[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv (None, 32, 32, 728)  536536      block11_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNorma (None, 32, 32, 728)  2912        block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_act (Activatio (None, 32, 32, 728)  0           block11_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv (None, 32, 32, 728)  536536      block11_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNorma (None, 32, 32, 728)  2912        block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_act (Activatio (None, 32, 32, 728)  0           block11_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv (None, 32, 32, 728)  536536      block11_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNorma (None, 32, 32, 728)  2912        block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 32, 32, 728)  0           block11_sepconv3_bn[0][0]
#                                                                  add_20[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_act (Activatio (None, 32, 32, 728)  0           add_21[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv (None, 32, 32, 728)  536536      block12_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNorma (None, 32, 32, 728)  2912        block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act (Activatio (None, 32, 32, 728)  0           block12_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv (None, 32, 32, 728)  536536      block12_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNorma (None, 32, 32, 728)  2912        block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act (Activatio (None, 32, 32, 728)  0           block12_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv (None, 32, 32, 728)  536536      block12_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNorma (None, 32, 32, 728)  2912        block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 32, 32, 728)  0           block12_sepconv3_bn[0][0]
#                                                                  add_21[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act (Activatio (None, 32, 32, 728)  0           add_22[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, 32, 32, 728)  536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, 32, 32, 728)  2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, 32, 32, 728)  0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, 32, 32, 1024) 752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, 32, 32, 1024) 4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 1024) 745472      add_22[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, 16, 16, 1024) 0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 1024) 4096        conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 16, 16, 1024) 0           block13_pool[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, 16, 16, 1536) 1582080     add_23[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, 16, 16, 1536) 6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, 16, 16, 1536) 0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, 16, 16, 2048) 3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, 16, 16, 2048) 8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, 16, 16, 2048) 0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_1 (GlobalM (None, 2048)         0           block14_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 3)            6147        global_max_pooling2d_1[0][0]
# ==================================================================================================
# Total params: 20,867,627
# Trainable params: 10,243
# Non-trainable params: 20,857,384
# __________________________________________________________________________________________________

# %% [markdown]
# ##### Xception unscaled

# %%
xception_model.fit(train_ds,validation_data=val_ds,epochs = 40, verbose = 1, workers = 3, class_weight = {0:1.13, 1:8.03, 2:1}, callbacks = callbacks_xception)
# Out:
# Epoch 1/40
# 25/25 [==============================] - 61s 365ms/step - loss: 1.2573 - accuracy: 0.6650 - val_loss: 0.5558 - val_accuracy: 0.8050
#
# Epoch 00001: saving model to sloan_xception/model-00001-1.25727-0.66500-0.55577-0.80500.h5
# Epoch 2/40
# 25/25 [==============================] - 10s 330ms/step - loss: 0.9318 - accuracy: 0.7362 - val_loss: 0.4640 - val_accuracy: 0.8150
#
# Epoch 00002: saving model to sloan_xception/model-00002-0.93177-0.73625-0.46404-0.81500.h5
# Epoch 3/40
# 25/25 [==============================] - 10s 331ms/step - loss: 0.7600 - accuracy: 0.7763 - val_loss: 0.5217 - val_accuracy: 0.8200
#
# Epoch 00003: saving model to sloan_xception/model-00003-0.76000-0.77625-0.52167-0.82000.h5
# Epoch 4/40
# 25/25 [==============================] - 10s 335ms/step - loss: 0.6515 - accuracy: 0.8188 - val_loss: 0.6289 - val_accuracy: 0.7150
#
# Epoch 00004: saving model to sloan_xception/model-00004-0.65153-0.81875-0.62888-0.71500.h5
# Epoch 5/40
# 25/25 [==============================] - 10s 334ms/step - loss: 0.6087 - accuracy: 0.8350 - val_loss: 0.7664 - val_accuracy: 0.6300
#
# Epoch 00005: saving model to sloan_xception/model-00005-0.60872-0.83500-0.76641-0.63000.h5
# Epoch 6/40
# 25/25 [==============================] - 10s 338ms/step - loss: 0.5379 - accuracy: 0.8500 - val_loss: 0.6889 - val_accuracy: 0.6950
#
# Epoch 00006: saving model to sloan_xception/model-00006-0.53791-0.85000-0.68895-0.69500.h5
# Epoch 7/40
# 25/25 [==============================] - 10s 333ms/step - loss: 0.4450 - accuracy: 0.8938 - val_loss: 0.5401 - val_accuracy: 0.8000
#
# Epoch 00007: saving model to sloan_xception/model-00007-0.44496-0.89375-0.54012-0.80000.h5
# Epoch 8/40
# 25/25 [==============================] - 10s 335ms/step - loss: 0.4716 - accuracy: 0.8813 - val_loss: 0.6982 - val_accuracy: 0.6950
#
# Epoch 00008: saving model to sloan_xception/model-00008-0.47157-0.88125-0.69821-0.69500.h5
# Epoch 9/40
# 25/25 [==============================] - 10s 338ms/step - loss: 0.4416 - accuracy: 0.8788 - val_loss: 0.6517 - val_accuracy: 0.7350
#
# Epoch 00009: saving model to sloan_xception/model-00009-0.44165-0.87875-0.65165-0.73500.h5
# Epoch 10/40
# 25/25 [==============================] - 10s 335ms/step - loss: 0.4365 - accuracy: 0.8700 - val_loss: 0.4499 - val_accuracy: 0.8150
#
# Epoch 00010: saving model to sloan_xception/model-00010-0.43649-0.87000-0.44987-0.81500.h5
# Epoch 11/40
# 25/25 [==============================] - 10s 337ms/step - loss: 0.3730 - accuracy: 0.8963 - val_loss: 0.5404 - val_accuracy: 0.8000
#
# Epoch 00011: saving model to sloan_xception/model-00011-0.37301-0.89625-0.54037-0.80000.h5
# Epoch 12/40
# 25/25 [==============================] - 10s 334ms/step - loss: 0.3723 - accuracy: 0.9013 - val_loss: 0.4990 - val_accuracy: 0.8450
#
# Epoch 00012: saving model to sloan_xception/model-00012-0.37227-0.90125-0.49903-0.84500.h5
# Epoch 13/40
# 25/25 [==============================] - 10s 337ms/step - loss: 0.3581 - accuracy: 0.9038 - val_loss: 0.4460 - val_accuracy: 0.8250
#
# Epoch 00013: saving model to sloan_xception/model-00013-0.35809-0.90375-0.44595-0.82500.h5
# Epoch 14/40
# 25/25 [==============================] - 10s 337ms/step - loss: 0.2638 - accuracy: 0.9300 - val_loss: 0.4334 - val_accuracy: 0.8550
#
# Epoch 00014: saving model to sloan_xception/model-00014-0.26383-0.93000-0.43336-0.85500.h5
# Epoch 15/40
# 25/25 [==============================] - 10s 335ms/step - loss: 0.2297 - accuracy: 0.9388 - val_loss: 0.4624 - val_accuracy: 0.8550
#
# Epoch 00015: saving model to sloan_xception/model-00015-0.22975-0.93875-0.46238-0.85500.h5
# Epoch 16/40
# 25/25 [==============================] - 10s 337ms/step - loss: 0.2595 - accuracy: 0.9362 - val_loss: 0.4261 - val_accuracy: 0.8500
#
# Epoch 00016: saving model to sloan_xception/model-00016-0.25948-0.93625-0.42608-0.85000.h5
# Epoch 17/40
# 25/25 [==============================] - 10s 337ms/step - loss: 0.2138 - accuracy: 0.9450 - val_loss: 0.4447 - val_accuracy: 0.8350
#
# Epoch 00017: saving model to sloan_xception/model-00017-0.21379-0.94500-0.44465-0.83500.h5
# Epoch 18/40
# 25/25 [==============================] - 10s 336ms/step - loss: 0.2159 - accuracy: 0.9438 - val_loss: 0.4185 - val_accuracy: 0.8700
#
# Epoch 00018: saving model to sloan_xception/model-00018-0.21586-0.94375-0.41851-0.87000.h5
# Epoch 19/40
# 25/25 [==============================] - 10s 334ms/step - loss: 0.1908 - accuracy: 0.9450 - val_loss: 0.4952 - val_accuracy: 0.8400
#
# Epoch 00019: saving model to sloan_xception/model-00019-0.19085-0.94500-0.49520-0.84000.h5
# Epoch 20/40
# 25/25 [==============================] - 10s 336ms/step - loss: 0.1900 - accuracy: 0.9425 - val_loss: 0.4792 - val_accuracy: 0.8650
#
# Epoch 00020: saving model to sloan_xception/model-00020-0.19003-0.94250-0.47916-0.86500.h5
# Epoch 21/40
# 25/25 [==============================] - 10s 335ms/step - loss: 0.1894 - accuracy: 0.9500 - val_loss: 0.5035 - val_accuracy: 0.8350
#
# Epoch 00021: saving model to sloan_xception/model-00021-0.18939-0.95000-0.50346-0.83500.h5
# Epoch 22/40
# 25/25 [==============================] - 10s 340ms/step - loss: 0.1681 - accuracy: 0.9575 - val_loss: 1.0420 - val_accuracy: 0.7300
#
# Epoch 00022: saving model to sloan_xception/model-00022-0.16814-0.95750-1.04197-0.73000.h5
# Epoch 23/40
# 25/25 [==============================] - 10s 332ms/step - loss: 0.1958 - accuracy: 0.9538 - val_loss: 0.4900 - val_accuracy: 0.8300
#
# Epoch 00023: saving model to sloan_xception/model-00023-0.19584-0.95375-0.48998-0.83000.h5
# Epoch 24/40
# 25/25 [==============================] - 10s 336ms/step - loss: 0.3304 - accuracy: 0.9375 - val_loss: 0.5695 - val_accuracy: 0.8150
#
# Epoch 00024: saving model to sloan_xception/model-00024-0.33038-0.93750-0.56953-0.81500.h5
# Epoch 25/40
# 25/25 [==============================] - 10s 336ms/step - loss: 0.1775 - accuracy: 0.9525 - val_loss: 0.5037 - val_accuracy: 0.8500
#
# Epoch 00025: saving model to sloan_xception/model-00025-0.17755-0.95250-0.50375-0.85000.h5
# Epoch 26/40
# 25/25 [==============================] - 10s 337ms/step - loss: 0.1645 - accuracy: 0.9563 - val_loss: 0.5112 - val_accuracy: 0.8400
#
# Epoch 00026: saving model to sloan_xception/model-00026-0.16450-0.95625-0.51116-0.84000.h5
# Epoch 27/40
# 25/25 [==============================] - 10s 337ms/step - loss: 0.1533 - accuracy: 0.9588 - val_loss: 0.5174 - val_accuracy: 0.8450
#
# Epoch 00027: saving model to sloan_xception/model-00027-0.15327-0.95875-0.51742-0.84500.h5
# Epoch 28/40
# 25/25 [==============================] - 10s 340ms/step - loss: 0.1309 - accuracy: 0.9663 - val_loss: 0.5129 - val_accuracy: 0.8650
#
# Epoch 00028: saving model to sloan_xception/model-00028-0.13095-0.96625-0.51294-0.86500.h5
# Epoch 29/40
# 25/25 [==============================] - 10s 338ms/step - loss: 0.1114 - accuracy: 0.9700 - val_loss: 0.4943 - val_accuracy: 0.8850
#
# Epoch 00029: saving model to sloan_xception/model-00029-0.11136-0.97000-0.49432-0.88500.h5
# Epoch 30/40
# 25/25 [==============================] - 10s 334ms/step - loss: 0.1893 - accuracy: 0.9588 - val_loss: 0.4555 - val_accuracy: 0.9050
#
# Epoch 00030: saving model to sloan_xception/model-00030-0.18934-0.95875-0.45550-0.90500.h5
# Epoch 31/40
# 25/25 [==============================] - 10s 332ms/step - loss: 0.1342 - accuracy: 0.9663 - val_loss: 0.5026 - val_accuracy: 0.8950
#
# Epoch 00031: saving model to sloan_xception/model-00031-0.13422-0.96625-0.50264-0.89500.h5
# Epoch 32/40
# 25/25 [==============================] - 10s 330ms/step - loss: 0.1160 - accuracy: 0.9737 - val_loss: 0.5778 - val_accuracy: 0.8650
#
# Epoch 00032: saving model to sloan_xception/model-00032-0.11603-0.97375-0.57785-0.86500.h5
# Epoch 33/40
# 25/25 [==============================] - 10s 326ms/step - loss: 0.1954 - accuracy: 0.9613 - val_loss: 0.6074 - val_accuracy: 0.8400
#
# Epoch 00033: saving model to sloan_xception/model-00033-0.19544-0.96125-0.60738-0.84000.h5
# Epoch 34/40
# 25/25 [==============================] - 10s 332ms/step - loss: 0.1812 - accuracy: 0.9450 - val_loss: 0.5238 - val_accuracy: 0.8800
#
# Epoch 00034: saving model to sloan_xception/model-00034-0.18122-0.94500-0.52381-0.88000.h5
# Epoch 35/40
# 25/25 [==============================] - 10s 325ms/step - loss: 0.1628 - accuracy: 0.9625 - val_loss: 0.5502 - val_accuracy: 0.8700
#
# Epoch 00035: saving model to sloan_xception/model-00035-0.16284-0.96250-0.55021-0.87000.h5
# Epoch 36/40
# 25/25 [==============================] - 10s 333ms/step - loss: 0.1311 - accuracy: 0.9638 - val_loss: 0.6273 - val_accuracy: 0.8400
#
# Epoch 00036: saving model to sloan_xception/model-00036-0.13109-0.96375-0.62727-0.84000.h5
# Epoch 37/40
# 25/25 [==============================] - 10s 354ms/step - loss: 0.0971 - accuracy: 0.9775 - val_loss: 0.5795 - val_accuracy: 0.8500
#
# Epoch 00037: saving model to sloan_xception/model-00037-0.09710-0.97750-0.57948-0.85000.h5
# Epoch 38/40
# 25/25 [==============================] - 10s 362ms/step - loss: 0.0817 - accuracy: 0.9775 - val_loss: 0.5156 - val_accuracy: 0.9000
#
# Epoch 00038: saving model to sloan_xception/model-00038-0.08168-0.97750-0.51557-0.90000.h5
# Epoch 39/40
# 25/25 [==============================] - 10s 336ms/step - loss: 0.1160 - accuracy: 0.9700 - val_loss: 0.5475 - val_accuracy: 0.8900
#
# Epoch 00039: saving model to sloan_xception/model-00039-0.11595-0.97000-0.54749-0.89000.h5
# Epoch 40/40
# 25/25 [==============================] - 9s 324ms/step - loss: 0.0865 - accuracy: 0.9775 - val_loss: 0.5604 - val_accuracy: 0.8900
#
# Epoch 00040: saving model to sloan_xception/model-00040-0.08652-0.97750-0.56044-0.89000.h5

# %% [markdown]
# ##### Xception scaled

# %%
xception_model.fit(train_ds_scaled,validation_data=val_ds_scaled,epochs = 40, verbose = 1, workers = 3, class_weight = {0:1.13, 1:8.03, 2:1}, callbacks = callbacks_xception)
# Out:
# Epoch 1/40
# 25/25 [==============================] - 12s 341ms/step - loss: 2.4807 - accuracy: 0.3862 - val_loss: 1.2055 - val_accuracy: 0.4200
#
# Epoch 00001: saving model to sloan_xception/model-00001-2.48067-0.38625-1.20550-0.42000.h5
# Epoch 2/40
# 25/25 [==============================] - 12s 425ms/step - loss: 1.5442 - accuracy: 0.5487 - val_loss: 1.1230 - val_accuracy: 0.4350
#
# Epoch 00002: saving model to sloan_xception/model-00002-1.54417-0.54875-1.12296-0.43500.h5
# Epoch 3/40
# 25/25 [==============================] - 12s 420ms/step - loss: 1.2923 - accuracy: 0.6350 - val_loss: 0.9425 - val_accuracy: 0.5100
#
# Epoch 00003: saving model to sloan_xception/model-00003-1.29228-0.63500-0.94253-0.51000.h5
# Epoch 4/40
# 25/25 [==============================] - 12s 433ms/step - loss: 1.1110 - accuracy: 0.6888 - val_loss: 0.9270 - val_accuracy: 0.5350
#
# Epoch 00004: saving model to sloan_xception/model-00004-1.11104-0.68875-0.92695-0.53500.h5
# Epoch 5/40
# 25/25 [==============================] - 12s 426ms/step - loss: 1.0026 - accuracy: 0.7100 - val_loss: 0.7571 - val_accuracy: 0.6450
#
# Epoch 00005: saving model to sloan_xception/model-00005-1.00258-0.71000-0.75711-0.64500.h5
# Epoch 6/40
# 25/25 [==============================] - 12s 428ms/step - loss: 0.9143 - accuracy: 0.7550 - val_loss: 0.7423 - val_accuracy: 0.6650
#
# Epoch 00006: saving model to sloan_xception/model-00006-0.91427-0.75500-0.74234-0.66500.h5
# Epoch 7/40
# 25/25 [==============================] - 12s 422ms/step - loss: 0.8537 - accuracy: 0.7675 - val_loss: 0.7681 - val_accuracy: 0.6650
#
# Epoch 00007: saving model to sloan_xception/model-00007-0.85371-0.76750-0.76811-0.66500.h5
# Epoch 8/40
# 25/25 [==============================] - 12s 422ms/step - loss: 0.8336 - accuracy: 0.7812 - val_loss: 0.6503 - val_accuracy: 0.7350
#
# Epoch 00008: saving model to sloan_xception/model-00008-0.83364-0.78125-0.65032-0.73500.h5
# Epoch 9/40
# 25/25 [==============================] - 13s 469ms/step - loss: 0.7674 - accuracy: 0.7975 - val_loss: 0.5980 - val_accuracy: 0.7800
#
# Epoch 00009: saving model to sloan_xception/model-00009-0.76735-0.79750-0.59802-0.78000.h5
# Epoch 10/40
# 25/25 [==============================] - 12s 426ms/step - loss: 0.7630 - accuracy: 0.7925 - val_loss: 0.5555 - val_accuracy: 0.7850
#
# Epoch 00010: saving model to sloan_xception/model-00010-0.76304-0.79250-0.55546-0.78500.h5
# Epoch 11/40
# 25/25 [==============================] - 12s 426ms/step - loss: 0.6975 - accuracy: 0.8375 - val_loss: 0.5974 - val_accuracy: 0.7750
#
# Epoch 00011: saving model to sloan_xception/model-00011-0.69746-0.83750-0.59738-0.77500.h5
# Epoch 12/40
# 25/25 [==============================] - 12s 425ms/step - loss: 0.6813 - accuracy: 0.8288 - val_loss: 0.5408 - val_accuracy: 0.8000
#
# Epoch 00012: saving model to sloan_xception/model-00012-0.68135-0.82875-0.54081-0.80000.h5
# Epoch 13/40
# 25/25 [==============================] - 12s 426ms/step - loss: 0.6697 - accuracy: 0.8263 - val_loss: 0.5236 - val_accuracy: 0.8050
#
# Epoch 00013: saving model to sloan_xception/model-00013-0.66970-0.82625-0.52361-0.80500.h5
# Epoch 14/40
# 25/25 [==============================] - 12s 428ms/step - loss: 0.6495 - accuracy: 0.8462 - val_loss: 0.5126 - val_accuracy: 0.8050
#
# Epoch 00014: saving model to sloan_xception/model-00014-0.64946-0.84625-0.51255-0.80500.h5
# Epoch 15/40
# 25/25 [==============================] - 12s 425ms/step - loss: 0.6069 - accuracy: 0.8363 - val_loss: 0.4952 - val_accuracy: 0.7900
#
# Epoch 00015: saving model to sloan_xception/model-00015-0.60687-0.83625-0.49518-0.79000.h5
# Epoch 16/40
# 25/25 [==============================] - 12s 423ms/step - loss: 0.6402 - accuracy: 0.8375 - val_loss: 0.4746 - val_accuracy: 0.8000
#
# Epoch 00016: saving model to sloan_xception/model-00016-0.64024-0.83750-0.47461-0.80000.h5
# Epoch 17/40
# 25/25 [==============================] - 12s 428ms/step - loss: 0.6243 - accuracy: 0.8275 - val_loss: 0.4553 - val_accuracy: 0.8050
#
# Epoch 00017: saving model to sloan_xception/model-00017-0.62430-0.82750-0.45530-0.80500.h5
# Epoch 18/40
# 25/25 [==============================] - 12s 426ms/step - loss: 0.6204 - accuracy: 0.8375 - val_loss: 0.4825 - val_accuracy: 0.8000
#
# Epoch 00018: saving model to sloan_xception/model-00018-0.62042-0.83750-0.48251-0.80000.h5
# Epoch 19/40
# 25/25 [==============================] - 12s 426ms/step - loss: 0.6266 - accuracy: 0.8550 - val_loss: 0.5761 - val_accuracy: 0.7900
#
# Epoch 00019: saving model to sloan_xception/model-00019-0.62661-0.85500-0.57612-0.79000.h5
# Epoch 20/40
# 25/25 [==============================] - 12s 421ms/step - loss: 0.5618 - accuracy: 0.8712 - val_loss: 0.4770 - val_accuracy: 0.8150
#
# Epoch 00020: saving model to sloan_xception/model-00020-0.56181-0.87125-0.47700-0.81500.h5
# Epoch 21/40
# 25/25 [==============================] - 12s 428ms/step - loss: 0.5443 - accuracy: 0.8612 - val_loss: 0.4040 - val_accuracy: 0.8250
#
# Epoch 00021: saving model to sloan_xception/model-00021-0.54428-0.86125-0.40399-0.82500.h5
# Epoch 22/40
# 25/25 [==============================] - 12s 427ms/step - loss: 0.5220 - accuracy: 0.8662 - val_loss: 0.4223 - val_accuracy: 0.8200
#
# Epoch 00022: saving model to sloan_xception/model-00022-0.52198-0.86625-0.42232-0.82000.h5
# Epoch 23/40
# 25/25 [==============================] - 12s 441ms/step - loss: 0.5263 - accuracy: 0.8737 - val_loss: 0.4162 - val_accuracy: 0.8200
#
# Epoch 00023: saving model to sloan_xception/model-00023-0.52628-0.87375-0.41617-0.82000.h5
# Epoch 24/40
# 25/25 [==============================] - 12s 427ms/step - loss: 0.5025 - accuracy: 0.8788 - val_loss: 0.3995 - val_accuracy: 0.8400
#
# Epoch 00024: saving model to sloan_xception/model-00024-0.50248-0.87875-0.39955-0.84000.h5
# Epoch 25/40
# 25/25 [==============================] - 12s 430ms/step - loss: 0.4831 - accuracy: 0.8825 - val_loss: 0.4103 - val_accuracy: 0.8400
#
# Epoch 00025: saving model to sloan_xception/model-00025-0.48307-0.88250-0.41028-0.84000.h5
# Epoch 26/40
# 25/25 [==============================] - 12s 424ms/step - loss: 0.4818 - accuracy: 0.8875 - val_loss: 0.4388 - val_accuracy: 0.8350
#
# Epoch 00026: saving model to sloan_xception/model-00026-0.48183-0.88750-0.43878-0.83500.h5
# Epoch 27/40
# 25/25 [==============================] - 12s 431ms/step - loss: 0.4812 - accuracy: 0.8863 - val_loss: 0.3833 - val_accuracy: 0.8450
#
# Epoch 00027: saving model to sloan_xception/model-00027-0.48118-0.88625-0.38334-0.84500.h5
# Epoch 28/40
# 25/25 [==============================] - 14s 501ms/step - loss: 0.4688 - accuracy: 0.8813 - val_loss: 0.4085 - val_accuracy: 0.8350
#
# Epoch 00028: saving model to sloan_xception/model-00028-0.46885-0.88125-0.40846-0.83500.h5
# Epoch 29/40
# 25/25 [==============================] - 14s 507ms/step - loss: 0.4779 - accuracy: 0.8838 - val_loss: 0.4110 - val_accuracy: 0.8350
#
# Epoch 00029: saving model to sloan_xception/model-00029-0.47793-0.88375-0.41096-0.83500.h5
# Epoch 30/40
# 25/25 [==============================] - 14s 500ms/step - loss: 0.4580 - accuracy: 0.8925 - val_loss: 0.4019 - val_accuracy: 0.8450
#
# Epoch 00030: saving model to sloan_xception/model-00030-0.45799-0.89250-0.40189-0.84500.h5
# Epoch 31/40
# 25/25 [==============================] - 13s 456ms/step - loss: 0.4267 - accuracy: 0.9000 - val_loss: 0.4104 - val_accuracy: 0.8400
#
# Epoch 00031: saving model to sloan_xception/model-00031-0.42670-0.90000-0.41045-0.84000.h5
# Epoch 32/40
# 25/25 [==============================] - 12s 441ms/step - loss: 0.4288 - accuracy: 0.8850 - val_loss: 0.4018 - val_accuracy: 0.8450
#
# Epoch 00032: saving model to sloan_xception/model-00032-0.42880-0.88500-0.40175-0.84500.h5
# Epoch 33/40
# 25/25 [==============================] - 12s 429ms/step - loss: 0.4777 - accuracy: 0.8750 - val_loss: 0.4268 - val_accuracy: 0.8400
#
# Epoch 00033: saving model to sloan_xception/model-00033-0.47770-0.87500-0.42676-0.84000.h5
# Epoch 34/40
# 25/25 [==============================] - 12s 427ms/step - loss: 0.4697 - accuracy: 0.8875 - val_loss: 0.4501 - val_accuracy: 0.8400
#
# Epoch 00034: saving model to sloan_xception/model-00034-0.46974-0.88750-0.45005-0.84000.h5
# Epoch 35/40
# 25/25 [==============================] - 12s 431ms/step - loss: 0.4294 - accuracy: 0.8950 - val_loss: 0.3694 - val_accuracy: 0.8550
#
# Epoch 00035: saving model to sloan_xception/model-00035-0.42938-0.89500-0.36942-0.85500.h5
# Epoch 36/40
# 25/25 [==============================] - 12s 427ms/step - loss: 0.3978 - accuracy: 0.9038 - val_loss: 0.4050 - val_accuracy: 0.8400
#
# Epoch 00036: saving model to sloan_xception/model-00036-0.39775-0.90375-0.40499-0.84000.h5
# Epoch 37/40
# 25/25 [==============================] - 12s 429ms/step - loss: 0.4143 - accuracy: 0.9062 - val_loss: 0.3913 - val_accuracy: 0.8450
#
# Epoch 00037: saving model to sloan_xception/model-00037-0.41430-0.90625-0.39135-0.84500.h5
# Epoch 38/40
# 25/25 [==============================] - 12s 432ms/step - loss: 0.3803 - accuracy: 0.9087 - val_loss: 0.3540 - val_accuracy: 0.8700
#
# Epoch 00038: saving model to sloan_xception/model-00038-0.38035-0.90875-0.35405-0.87000.h5
# Epoch 39/40
# 25/25 [==============================] - 12s 428ms/step - loss: 0.3938 - accuracy: 0.8975 - val_loss: 0.4198 - val_accuracy: 0.8500
#
# Epoch 00039: saving model to sloan_xception/model-00039-0.39380-0.89750-0.41982-0.85000.h5
# Epoch 40/40
# 25/25 [==============================] - 12s 426ms/step - loss: 0.3797 - accuracy: 0.9150 - val_loss: 0.4019 - val_accuracy: 0.8350
#
# Epoch 00040: saving model to sloan_xception/model-00040-0.37968-0.91500-0.40187-0.83500.h5

# %% [markdown]
# ##### Augmemntation techniques

# %%
train_ds_flip = prepare_dataset(train_ds, flip= True)
train_ds_flip_rotate = prepare_dataset(train_ds, flip_rotate = True)
train_ds_crop_flip = prepare_dataset_crop(train_ds_cropped, crop_flip = True)
train_ds_crop_flip_rotate = prepare_dataset_crop(train_ds_cropped, crop_flip_rotate = True)
val_ds_normal_crop = prepare_dataset_normal_crop(val_ds_cropped, training = False)

# xception_unscaled_flip = load_model('./sloan_xception/Xception_unscaled_0.18934-0.95875-0.45550-0.90500.h5')
# xception_flip_rotate = load_model('./sloan_xception/Xception_unscaled_model_flip-00036-0.14-0.9687-0.50-0.91500.h5') 
# xception_unscaled_crop_flip = load_model('./sloan_xception/Xception_unscaled_0.18934-0.95875-0.45550-0.90500.h5')
xception_unscaled_crop_flip_rotate = load_model('./sloan_xception/Xception_unscaled_0.18934-0.95875-0.45550-0.90500.h5')

# %% [markdown]
# ##### Xception unscaled flip

# %%
xception_unscaled_flip.fit(train_ds_flip,validation_data=val_ds,epochs = 40, verbose = 1, workers = 3, class_weight = {0:1.13, 1:8.03, 2:1},callbacks = callbacks_xception)
# Out:
# Epoch 1/40
# 25/25 [==============================] - 15s 526ms/step - loss: 0.1815 - accuracy: 0.9600 - val_loss: 0.4571 - val_accuracy: 0.8650
#
# Epoch 00001: saving model to sloan_xception/model-00001-0.18150-0.96000-0.45708-0.86500.h5
# Epoch 2/40
# 25/25 [==============================] - 15s 536ms/step - loss: 0.2624 - accuracy: 0.9262 - val_loss: 0.3806 - val_accuracy: 0.8900
#
# Epoch 00002: saving model to sloan_xception/model-00002-0.26244-0.92625-0.38062-0.89000.h5
# Epoch 3/40
# 25/25 [==============================] - 11s 363ms/step - loss: 0.2074 - accuracy: 0.9463 - val_loss: 0.3973 - val_accuracy: 0.9000
#
# Epoch 00003: saving model to sloan_xception/model-00003-0.20740-0.94625-0.39729-0.90000.h5
# Epoch 4/40
# 25/25 [==============================] - 11s 383ms/step - loss: 0.1548 - accuracy: 0.9513 - val_loss: 0.4170 - val_accuracy: 0.8900
#
# Epoch 00004: saving model to sloan_xception/model-00004-0.15480-0.95125-0.41697-0.89000.h5
# Epoch 5/40
# 25/25 [==============================] - 11s 365ms/step - loss: 0.1482 - accuracy: 0.9638 - val_loss: 0.4483 - val_accuracy: 0.8800
#
# Epoch 00005: saving model to sloan_xception/model-00005-0.14816-0.96375-0.44825-0.88000.h5
# Epoch 6/40
# 25/25 [==============================] - 11s 368ms/step - loss: 0.1723 - accuracy: 0.9550 - val_loss: 0.5620 - val_accuracy: 0.8350
#
# Epoch 00006: saving model to sloan_xception/model-00006-0.17231-0.95500-0.56200-0.83500.h5
# Epoch 7/40
# 25/25 [==============================] - 11s 364ms/step - loss: 0.1464 - accuracy: 0.9563 - val_loss: 0.4218 - val_accuracy: 0.9000
#
# Epoch 00007: saving model to sloan_xception/model-00007-0.14638-0.95625-0.42177-0.90000.h5
# Epoch 8/40
# 25/25 [==============================] - 11s 364ms/step - loss: 0.1038 - accuracy: 0.9737 - val_loss: 0.3734 - val_accuracy: 0.9050
#
# Epoch 00008: saving model to sloan_xception/model-00008-0.10378-0.97375-0.37338-0.90500.h5
# Epoch 9/40
# 25/25 [==============================] - 11s 365ms/step - loss: 0.1252 - accuracy: 0.9638 - val_loss: 0.4717 - val_accuracy: 0.8750
#
# Epoch 00009: saving model to sloan_xception/model-00009-0.12522-0.96375-0.47168-0.87500.h5
# Epoch 10/40
# 25/25 [==============================] - 11s 361ms/step - loss: 0.1365 - accuracy: 0.9550 - val_loss: 0.5360 - val_accuracy: 0.8600
#
# Epoch 00010: saving model to sloan_xception/model-00010-0.13655-0.95500-0.53596-0.86000.h5
# Epoch 11/40
# 25/25 [==============================] - 11s 366ms/step - loss: 0.1347 - accuracy: 0.9650 - val_loss: 0.3916 - val_accuracy: 0.9000
#
# Epoch 00011: saving model to sloan_xception/model-00011-0.13472-0.96500-0.39163-0.90000.h5
# Epoch 12/40
# 25/25 [==============================] - 11s 365ms/step - loss: 0.1242 - accuracy: 0.9688 - val_loss: 0.4493 - val_accuracy: 0.8950
#
# Epoch 00012: saving model to sloan_xception/model-00012-0.12421-0.96875-0.44929-0.89500.h5
# Epoch 13/40
# 25/25 [==============================] - 11s 373ms/step - loss: 0.1353 - accuracy: 0.9625 - val_loss: 0.4685 - val_accuracy: 0.8900
#
# Epoch 00013: saving model to sloan_xception/model-00013-0.13535-0.96250-0.46852-0.89000.h5
# Epoch 14/40
# 25/25 [==============================] - 11s 370ms/step - loss: 0.1716 - accuracy: 0.9613 - val_loss: 0.5438 - val_accuracy: 0.8600
#
# Epoch 00014: saving model to sloan_xception/model-00014-0.17164-0.96125-0.54381-0.86000.h5
# Epoch 15/40
# 25/25 [==============================] - 11s 369ms/step - loss: 0.1153 - accuracy: 0.9712 - val_loss: 0.5273 - val_accuracy: 0.8700
#
# Epoch 00015: saving model to sloan_xception/model-00015-0.11531-0.97125-0.52727-0.87000.h5
# Epoch 16/40
# 25/25 [==============================] - 11s 371ms/step - loss: 0.0875 - accuracy: 0.9762 - val_loss: 0.4542 - val_accuracy: 0.8950
#
# Epoch 00016: saving model to sloan_xception/model-00016-0.08754-0.97625-0.45418-0.89500.h5
# Epoch 17/40
# 25/25 [==============================] - 11s 371ms/step - loss: 0.0944 - accuracy: 0.9775 - val_loss: 0.4140 - val_accuracy: 0.8950
#
# Epoch 00017: saving model to sloan_xception/model-00017-0.09445-0.97750-0.41396-0.89500.h5
# Epoch 18/40
# 25/25 [==============================] - 11s 367ms/step - loss: 0.0986 - accuracy: 0.9750 - val_loss: 0.4948 - val_accuracy: 0.8850
#
# Epoch 00018: saving model to sloan_xception/model-00018-0.09860-0.97500-0.49478-0.88500.h5
# Epoch 19/40
# 25/25 [==============================] - 11s 364ms/step - loss: 0.0770 - accuracy: 0.9762 - val_loss: 0.4472 - val_accuracy: 0.8950
#
# Epoch 00019: saving model to sloan_xception/model-00019-0.07702-0.97625-0.44716-0.89500.h5
# Epoch 20/40
# 25/25 [==============================] - 11s 367ms/step - loss: 0.1196 - accuracy: 0.9737 - val_loss: 0.4375 - val_accuracy: 0.9150
#
# Epoch 00020: saving model to sloan_xception/model-00020-0.11959-0.97375-0.43745-0.91500.h5
# Epoch 21/40
# 25/25 [==============================] - 11s 365ms/step - loss: 0.1454 - accuracy: 0.9675 - val_loss: 0.8073 - val_accuracy: 0.8300
#
# Epoch 00021: saving model to sloan_xception/model-00021-0.14544-0.96750-0.80730-0.83000.h5
# Epoch 22/40
# 25/25 [==============================] - 11s 364ms/step - loss: 0.1619 - accuracy: 0.9588 - val_loss: 0.4230 - val_accuracy: 0.8950
#
# Epoch 00022: saving model to sloan_xception/model-00022-0.16186-0.95875-0.42297-0.89500.h5
# Epoch 23/40
# 25/25 [==============================] - 11s 370ms/step - loss: 0.1213 - accuracy: 0.9712 - val_loss: 0.4460 - val_accuracy: 0.8950
#
# Epoch 00023: saving model to sloan_xception/model-00023-0.12133-0.97125-0.44602-0.89500.h5
# Epoch 24/40
# 25/25 [==============================] - 11s 369ms/step - loss: 0.1709 - accuracy: 0.9538 - val_loss: 0.4427 - val_accuracy: 0.8950
#
# Epoch 00024: saving model to sloan_xception/model-00024-0.17092-0.95375-0.44274-0.89500.h5
# Epoch 25/40
# 25/25 [==============================] - 11s 374ms/step - loss: 0.1718 - accuracy: 0.9538 - val_loss: 0.4616 - val_accuracy: 0.8800
#
# Epoch 00025: saving model to sloan_xception/model-00025-0.17180-0.95375-0.46157-0.88000.h5
# Epoch 26/40
# 25/25 [==============================] - 11s 364ms/step - loss: 0.1315 - accuracy: 0.9625 - val_loss: 0.4551 - val_accuracy: 0.9000
#
# Epoch 00026: saving model to sloan_xception/model-00026-0.13145-0.96250-0.45510-0.90000.h5
# Epoch 27/40
# 25/25 [==============================] - 11s 363ms/step - loss: 0.1255 - accuracy: 0.9688 - val_loss: 0.4111 - val_accuracy: 0.9100
#
# Epoch 00027: saving model to sloan_xception/model-00027-0.12547-0.96875-0.41108-0.91000.h5
# Epoch 28/40
# 25/25 [==============================] - 11s 367ms/step - loss: 0.1264 - accuracy: 0.9650 - val_loss: 0.4680 - val_accuracy: 0.9050
#
# Epoch 00028: saving model to sloan_xception/model-00028-0.12645-0.96500-0.46798-0.90500.h5
# Epoch 29/40
# 25/25 [==============================] - 11s 364ms/step - loss: 0.1167 - accuracy: 0.9663 - val_loss: 0.4756 - val_accuracy: 0.8950
#
# Epoch 00029: saving model to sloan_xception/model-00029-0.11667-0.96625-0.47560-0.89500.h5
# Epoch 30/40
# 25/25 [==============================] - 11s 365ms/step - loss: 0.1226 - accuracy: 0.9700 - val_loss: 0.4598 - val_accuracy: 0.9100
#
# Epoch 00030: saving model to sloan_xception/model-00030-0.12261-0.97000-0.45978-0.91000.h5
# Epoch 31/40
# 25/25 [==============================] - 11s 370ms/step - loss: 0.0852 - accuracy: 0.9812 - val_loss: 0.5006 - val_accuracy: 0.8950
#
# Epoch 00031: saving model to sloan_xception/model-00031-0.08520-0.98125-0.50056-0.89500.h5
# Epoch 32/40
# 25/25 [==============================] - 11s 365ms/step - loss: 0.1032 - accuracy: 0.9712 - val_loss: 0.5228 - val_accuracy: 0.9000
#
# Epoch 00032: saving model to sloan_xception/model-00032-0.10316-0.97125-0.52281-0.90000.h5
# Epoch 33/40
# 25/25 [==============================] - 11s 371ms/step - loss: 0.0845 - accuracy: 0.9775 - val_loss: 0.4731 - val_accuracy: 0.9100
#
# Epoch 00033: saving model to sloan_xception/model-00033-0.08446-0.97750-0.47315-0.91000.h5
# Epoch 34/40
# 25/25 [==============================] - 11s 370ms/step - loss: 0.0646 - accuracy: 0.9875 - val_loss: 0.4981 - val_accuracy: 0.9150
#
# Epoch 00034: saving model to sloan_xception/model-00034-0.06459-0.98750-0.49809-0.91500.h5
# Epoch 35/40
# 25/25 [==============================] - 11s 365ms/step - loss: 0.0906 - accuracy: 0.9725 - val_loss: 0.5260 - val_accuracy: 0.8950
#
# Epoch 00035: saving model to sloan_xception/model-00035-0.09060-0.97250-0.52598-0.89500.h5
# Epoch 36/40
# 25/25 [==============================] - 11s 360ms/step - loss: 0.1474 - accuracy: 0.9688 - val_loss: 0.5050 - val_accuracy: 0.9150
#
# Epoch 00036: saving model to sloan_xception/model-00036-0.14736-0.96875-0.50501-0.91500.h5
# Epoch 37/40
# 25/25 [==============================] - 11s 368ms/step - loss: 0.0934 - accuracy: 0.9762 - val_loss: 0.5027 - val_accuracy: 0.9150
#
# Epoch 00037: saving model to sloan_xception/model-00037-0.09339-0.97625-0.50268-0.91500.h5
# Epoch 38/40
# 25/25 [==============================] - 11s 362ms/step - loss: 0.2200 - accuracy: 0.9575 - val_loss: 0.4989 - val_accuracy: 0.8950
#
# Epoch 00038: saving model to sloan_xception/model-00038-0.21996-0.95750-0.49886-0.89500.h5
# Epoch 39/40
# 25/25 [==============================] - 11s 365ms/step - loss: 0.0975 - accuracy: 0.9712 - val_loss: 0.4804 - val_accuracy: 0.9050
#
# Epoch 00039: saving model to sloan_xception/model-00039-0.09746-0.97125-0.48036-0.90500.h5
# Epoch 40/40
# 25/25 [==============================] - 11s 364ms/step - loss: 0.0603 - accuracy: 0.9850 - val_loss: 0.4865 - val_accuracy: 0.9100
#
# Epoch 00040: saving model to sloan_xception/model-00040-0.06031-0.98500-0.48647-0.91000.h5

# %%
generate_graph(xception_unscaled_flip)

# %% [markdown]
# ##### Xception unscaled flip_rotate

# %%
xception_flip_rotate.fit(train_ds_flip_rotate,validation_data=val_ds,epochs = 40, verbose = 1, workers = 3, class_weight = {0:1.13, 1:8.03, 2:1},callbacks = callbacks_xception)
# Out:
# Epoch 1/40
# 25/25 [==============================] - 18s 564ms/step - loss: 0.5283 - accuracy: 0.9087 - val_loss: 0.4511 - val_accuracy: 0.8800
#
# Epoch 00001: saving model to sloan_xception/model-00001-0.52835-0.90875-0.45112-0.88000.h5
# Epoch 2/40
# 25/25 [==============================] - 17s 569ms/step - loss: 0.4725 - accuracy: 0.9150 - val_loss: 0.7572 - val_accuracy: 0.7900
#
# Epoch 00002: saving model to sloan_xception/model-00002-0.47248-0.91500-0.75723-0.79000.h5
# Epoch 3/40
# 25/25 [==============================] - 16s 547ms/step - loss: 0.3129 - accuracy: 0.9250 - val_loss: 0.5010 - val_accuracy: 0.8500
#
# Epoch 00003: saving model to sloan_xception/model-00003-0.31287-0.92500-0.50099-0.85000.h5
# Epoch 4/40
# 25/25 [==============================] - 16s 551ms/step - loss: 0.2864 - accuracy: 0.9275 - val_loss: 0.4756 - val_accuracy: 0.8400
#
# Epoch 00004: saving model to sloan_xception/model-00004-0.28641-0.92750-0.47562-0.84000.h5
# Epoch 5/40
# 25/25 [==============================] - 17s 580ms/step - loss: 0.3164 - accuracy: 0.9225 - val_loss: 0.4024 - val_accuracy: 0.8750
#
# Epoch 00005: saving model to sloan_xception/model-00005-0.31641-0.92250-0.40244-0.87500.h5
# Epoch 6/40
# 25/25 [==============================] - 17s 586ms/step - loss: 0.4086 - accuracy: 0.9112 - val_loss: 0.3748 - val_accuracy: 0.8850
#
# Epoch 00006: saving model to sloan_xception/model-00006-0.40858-0.91125-0.37480-0.88500.h5
# Epoch 7/40
# 25/25 [==============================] - 17s 579ms/step - loss: 0.3542 - accuracy: 0.9087 - val_loss: 0.4354 - val_accuracy: 0.8550
#
# Epoch 00007: saving model to sloan_xception/model-00007-0.35417-0.90875-0.43536-0.85500.h5
# Epoch 8/40
# 25/25 [==============================] - 17s 555ms/step - loss: 0.3181 - accuracy: 0.9250 - val_loss: 0.4013 - val_accuracy: 0.8600
#
# Epoch 00008: saving model to sloan_xception/model-00008-0.31812-0.92500-0.40134-0.86000.h5
# Epoch 9/40
# 25/25 [==============================] - 17s 572ms/step - loss: 0.4118 - accuracy: 0.9100 - val_loss: 0.4151 - val_accuracy: 0.8550
#
# Epoch 00009: saving model to sloan_xception/model-00009-0.41179-0.91000-0.41511-0.85500.h5
# Epoch 10/40
# 25/25 [==============================] - 17s 566ms/step - loss: 0.3302 - accuracy: 0.9413 - val_loss: 0.4172 - val_accuracy: 0.8550
#
# Epoch 00010: saving model to sloan_xception/model-00010-0.33024-0.94125-0.41716-0.85500.h5
# Epoch 11/40
# 25/25 [==============================] - 17s 545ms/step - loss: 0.2740 - accuracy: 0.9362 - val_loss: 0.3332 - val_accuracy: 0.8800
#
# Epoch 00011: saving model to sloan_xception/model-00011-0.27395-0.93625-0.33315-0.88000.h5
# Epoch 12/40
# 25/25 [==============================] - 17s 569ms/step - loss: 0.2274 - accuracy: 0.9362 - val_loss: 0.3817 - val_accuracy: 0.8750
#
# Epoch 00012: saving model to sloan_xception/model-00012-0.22735-0.93625-0.38173-0.87500.h5
# Epoch 13/40
# 25/25 [==============================] - 17s 563ms/step - loss: 0.2206 - accuracy: 0.9388 - val_loss: 0.4239 - val_accuracy: 0.8400
#
# Epoch 00013: saving model to sloan_xception/model-00013-0.22056-0.93875-0.42391-0.84000.h5
# Epoch 14/40
# 25/25 [==============================] - 17s 566ms/step - loss: 0.2906 - accuracy: 0.9350 - val_loss: 0.9334 - val_accuracy: 0.7600
#
# Epoch 00014: saving model to sloan_xception/model-00014-0.29058-0.93500-0.93342-0.76000.h5
# Epoch 15/40
# 25/25 [==============================] - 16s 543ms/step - loss: 0.3590 - accuracy: 0.9137 - val_loss: 0.4471 - val_accuracy: 0.8500
#
# Epoch 00015: saving model to sloan_xception/model-00015-0.35900-0.91375-0.44710-0.85000.h5
# Epoch 16/40
# 25/25 [==============================] - 16s 558ms/step - loss: 0.2431 - accuracy: 0.9400 - val_loss: 0.6967 - val_accuracy: 0.7700
#
# Epoch 00016: saving model to sloan_xception/model-00016-0.24314-0.94000-0.69671-0.77000.h5
# Epoch 17/40
# 25/25 [==============================] - 17s 570ms/step - loss: 0.3011 - accuracy: 0.9287 - val_loss: 0.4592 - val_accuracy: 0.8600
#
# Epoch 00017: saving model to sloan_xception/model-00017-0.30113-0.92875-0.45920-0.86000.h5
# Epoch 18/40
# 25/25 [==============================] - 17s 556ms/step - loss: 0.2518 - accuracy: 0.9350 - val_loss: 0.3674 - val_accuracy: 0.8950
#
# Epoch 00018: saving model to sloan_xception/model-00018-0.25177-0.93500-0.36739-0.89500.h5
# Epoch 19/40
# 25/25 [==============================] - 17s 560ms/step - loss: 0.2090 - accuracy: 0.9513 - val_loss: 0.3908 - val_accuracy: 0.8600
#
# Epoch 00019: saving model to sloan_xception/model-00019-0.20902-0.95125-0.39079-0.86000.h5
# Epoch 20/40
# 25/25 [==============================] - 17s 571ms/step - loss: 0.2793 - accuracy: 0.9175 - val_loss: 0.3595 - val_accuracy: 0.8800
#
# Epoch 00020: saving model to sloan_xception/model-00020-0.27933-0.91750-0.35949-0.88000.h5
# Epoch 21/40
# 25/25 [==============================] - 17s 564ms/step - loss: 0.2212 - accuracy: 0.9488 - val_loss: 0.5022 - val_accuracy: 0.8450
#
# Epoch 00021: saving model to sloan_xception/model-00021-0.22119-0.94875-0.50216-0.84500.h5
# Epoch 22/40
# 25/25 [==============================] - 17s 552ms/step - loss: 0.2560 - accuracy: 0.9362 - val_loss: 0.3658 - val_accuracy: 0.8850
#
# Epoch 00022: saving model to sloan_xception/model-00022-0.25599-0.93625-0.36576-0.88500.h5
# Epoch 23/40
# 25/25 [==============================] - 17s 566ms/step - loss: 0.2518 - accuracy: 0.9388 - val_loss: 0.3210 - val_accuracy: 0.8800
#
# Epoch 00023: saving model to sloan_xception/model-00023-0.25177-0.93875-0.32102-0.88000.h5
# Epoch 24/40
# 25/25 [==============================] - 16s 554ms/step - loss: 0.1847 - accuracy: 0.9413 - val_loss: 0.3154 - val_accuracy: 0.8900
#
# Epoch 00024: saving model to sloan_xception/model-00024-0.18470-0.94125-0.31542-0.89000.h5
# Epoch 25/40
# 25/25 [==============================] - 16s 557ms/step - loss: 0.1747 - accuracy: 0.9538 - val_loss: 0.3718 - val_accuracy: 0.8850
#
# Epoch 00025: saving model to sloan_xception/model-00025-0.17468-0.95375-0.37180-0.88500.h5
# Epoch 26/40
# 25/25 [==============================] - 17s 564ms/step - loss: 0.1523 - accuracy: 0.9712 - val_loss: 0.3419 - val_accuracy: 0.8900
#
# Epoch 00026: saving model to sloan_xception/model-00026-0.15232-0.97125-0.34188-0.89000.h5
# Epoch 27/40
# 25/25 [==============================] - 16s 549ms/step - loss: 0.1403 - accuracy: 0.9563 - val_loss: 0.3495 - val_accuracy: 0.8900
#
# Epoch 00027: saving model to sloan_xception/model-00027-0.14028-0.95625-0.34953-0.89000.h5
# Epoch 28/40
# 25/25 [==============================] - 20s 697ms/step - loss: 0.1551 - accuracy: 0.9625 - val_loss: 0.4205 - val_accuracy: 0.8800
#
# Epoch 00028: saving model to sloan_xception/model-00028-0.15511-0.96250-0.42048-0.88000.h5
# Epoch 29/40
# 25/25 [==============================] - 29s 1s/step - loss: 0.1856 - accuracy: 0.9538 - val_loss: 0.3700 - val_accuracy: 0.8800
#
# Epoch 00029: saving model to sloan_xception/model-00029-0.18557-0.95375-0.37003-0.88000.h5
# Epoch 30/40
# 25/25 [==============================] - 28s 1s/step - loss: 0.2526 - accuracy: 0.9312 - val_loss: 0.3323 - val_accuracy: 0.9100
#
# Epoch 00030: saving model to sloan_xception/model-00030-0.25264-0.93125-0.33230-0.91000.h5
# Epoch 31/40
# 25/25 [==============================] - 28s 1s/step - loss: 0.1647 - accuracy: 0.9550 - val_loss: 0.3716 - val_accuracy: 0.8750
#
# Epoch 00031: saving model to sloan_xception/model-00031-0.16474-0.95500-0.37158-0.87500.h5
# Epoch 32/40
# 25/25 [==============================] - 28s 1s/step - loss: 0.2010 - accuracy: 0.9563 - val_loss: 0.4040 - val_accuracy: 0.8700
#
# Epoch 00032: saving model to sloan_xception/model-00032-0.20101-0.95625-0.40402-0.87000.h5
# Epoch 33/40
# 25/25 [==============================] - 28s 1s/step - loss: 0.2420 - accuracy: 0.9362 - val_loss: 0.4224 - val_accuracy: 0.8900
#
# Epoch 00033: saving model to sloan_xception/model-00033-0.24203-0.93625-0.42236-0.89000.h5
# Epoch 34/40
# 25/25 [==============================] - 28s 1s/step - loss: 0.1998 - accuracy: 0.9450 - val_loss: 0.3337 - val_accuracy: 0.9050
#
# Epoch 00034: saving model to sloan_xception/model-00034-0.19983-0.94500-0.33370-0.90500.h5
# Epoch 35/40
# 25/25 [==============================] - 28s 1s/step - loss: 0.1428 - accuracy: 0.9712 - val_loss: 0.3612 - val_accuracy: 0.8900
#
# Epoch 00035: saving model to sloan_xception/model-00035-0.14283-0.97125-0.36124-0.89000.h5
# Epoch 36/40
# 25/25 [==============================] - 28s 1s/step - loss: 0.1911 - accuracy: 0.9588 - val_loss: 0.4571 - val_accuracy: 0.8450
#
# Epoch 00036: saving model to sloan_xception/model-00036-0.19114-0.95875-0.45708-0.84500.h5
# Epoch 37/40
# 25/25 [==============================] - 28s 1s/step - loss: 0.1982 - accuracy: 0.9400 - val_loss: 0.4186 - val_accuracy: 0.8900
#
# Epoch 00037: saving model to sloan_xception/model-00037-0.19825-0.94000-0.41863-0.89000.h5
# Epoch 38/40
# 25/25 [==============================] - 28s 1s/step - loss: 0.1679 - accuracy: 0.9613 - val_loss: 0.4038 - val_accuracy: 0.8650
#
# Epoch 00038: saving model to sloan_xception/model-00038-0.16785-0.96125-0.40384-0.86500.h5
# Epoch 39/40
# 25/25 [==============================] - 28s 1s/step - loss: 0.1849 - accuracy: 0.9663 - val_loss: 0.3815 - val_accuracy: 0.8950
#
# Epoch 00039: saving model to sloan_xception/model-00039-0.18485-0.96625-0.38148-0.89500.h5
# Epoch 40/40
# 25/25 [==============================] - 28s 1s/step - loss: 0.2436 - accuracy: 0.9563 - val_loss: 0.4055 - val_accuracy: 0.8850
#
# Epoch 00040: saving model to sloan_xception/model-00040-0.24356-0.95625-0.40547-0.88500.h5

# %%
generate_graph(xception_flip_rotate)

# %% [markdown]
# ##### Xception crop flip

# %%
xception_unscaled_crop_flip.fit(train_ds_crop_flip,validation_data=val_ds_normal_crop,epochs = 40, verbose = 1, workers = 3, class_weight = {0:1.13, 1:8.03, 2:1}, callbacks = callbacks_xception)
# Out:
# Epoch 1/40
# 25/25 [==============================] - 16s 534ms/step - loss: 0.1426 - accuracy: 0.9700 - val_loss: 0.3175 - val_accuracy: 0.9250
#
# Epoch 00001: saving model to sloan_xception/model-00001-0.14256-0.97000-0.31753-0.92500.h5
# Epoch 2/40
# 25/25 [==============================] - 16s 546ms/step - loss: 0.2355 - accuracy: 0.9463 - val_loss: 0.3323 - val_accuracy: 0.9200
#
# Epoch 00002: saving model to sloan_xception/model-00002-0.23553-0.94625-0.33231-0.92000.h5
# Epoch 3/40
# 25/25 [==============================] - 16s 542ms/step - loss: 0.1467 - accuracy: 0.9525 - val_loss: 0.2861 - val_accuracy: 0.9200
#
# Epoch 00003: saving model to sloan_xception/model-00003-0.14667-0.95250-0.28612-0.92000.h5
# Epoch 4/40
# 25/25 [==============================] - 16s 538ms/step - loss: 0.1205 - accuracy: 0.9712 - val_loss: 0.3235 - val_accuracy: 0.9150
#
# Epoch 00004: saving model to sloan_xception/model-00004-0.12048-0.97125-0.32348-0.91500.h5
# Epoch 5/40
# 25/25 [==============================] - 16s 541ms/step - loss: 0.0810 - accuracy: 0.9800 - val_loss: 0.3189 - val_accuracy: 0.9250
#
# Epoch 00005: saving model to sloan_xception/model-00005-0.08099-0.98000-0.31889-0.92500.h5
# Epoch 6/40
# 25/25 [==============================] - 16s 541ms/step - loss: 0.0956 - accuracy: 0.9737 - val_loss: 0.3429 - val_accuracy: 0.9150
#
# Epoch 00006: saving model to sloan_xception/model-00006-0.09562-0.97375-0.34293-0.91500.h5
# Epoch 7/40
# 25/25 [==============================] - 16s 541ms/step - loss: 0.0969 - accuracy: 0.9725 - val_loss: 0.3348 - val_accuracy: 0.9200
#
# Epoch 00007: saving model to sloan_xception/model-00007-0.09694-0.97250-0.33483-0.92000.h5
# Epoch 8/40
# 25/25 [==============================] - 16s 542ms/step - loss: 0.1170 - accuracy: 0.9688 - val_loss: 0.3997 - val_accuracy: 0.9000
#
# Epoch 00008: saving model to sloan_xception/model-00008-0.11703-0.96875-0.39969-0.90000.h5
# Epoch 9/40
# 25/25 [==============================] - 16s 540ms/step - loss: 0.1105 - accuracy: 0.9725 - val_loss: 0.3552 - val_accuracy: 0.9150
#
# Epoch 00009: saving model to sloan_xception/model-00009-0.11052-0.97250-0.35518-0.91500.h5
# Epoch 10/40
# 25/25 [==============================] - 16s 546ms/step - loss: 0.1041 - accuracy: 0.9688 - val_loss: 0.3503 - val_accuracy: 0.9250
#
# Epoch 00010: saving model to sloan_xception/model-00010-0.10414-0.96875-0.35031-0.92500.h5
# Epoch 11/40
# 25/25 [==============================] - 16s 542ms/step - loss: 0.0938 - accuracy: 0.9725 - val_loss: 0.3466 - val_accuracy: 0.9300
#
# Epoch 00011: saving model to sloan_xception/model-00011-0.09378-0.97250-0.34664-0.93000.h5
# Epoch 12/40
# 25/25 [==============================] - 16s 546ms/step - loss: 0.0990 - accuracy: 0.9837 - val_loss: 0.3602 - val_accuracy: 0.9100
#
# Epoch 00012: saving model to sloan_xception/model-00012-0.09902-0.98375-0.36020-0.91000.h5
# Epoch 13/40
# 25/25 [==============================] - 16s 545ms/step - loss: 0.1279 - accuracy: 0.9613 - val_loss: 0.3648 - val_accuracy: 0.9000
#
# Epoch 00013: saving model to sloan_xception/model-00013-0.12791-0.96125-0.36482-0.90000.h5
# Epoch 14/40
# 25/25 [==============================] - 16s 538ms/step - loss: 0.1126 - accuracy: 0.9737 - val_loss: 0.3254 - val_accuracy: 0.9100
#
# Epoch 00014: saving model to sloan_xception/model-00014-0.11265-0.97375-0.32543-0.91000.h5
# Epoch 15/40
# 25/25 [==============================] - 16s 534ms/step - loss: 0.0761 - accuracy: 0.9800 - val_loss: 0.3111 - val_accuracy: 0.9100
#
# Epoch 00015: saving model to sloan_xception/model-00015-0.07614-0.98000-0.31109-0.91000.h5
# Epoch 16/40
# 25/25 [==============================] - 16s 543ms/step - loss: 0.0903 - accuracy: 0.9800 - val_loss: 0.3505 - val_accuracy: 0.9300
#
# Epoch 00016: saving model to sloan_xception/model-00016-0.09031-0.98000-0.35049-0.93000.h5
# Epoch 17/40
# 25/25 [==============================] - 16s 543ms/step - loss: 0.0664 - accuracy: 0.9837 - val_loss: 0.3448 - val_accuracy: 0.9200
#
# Epoch 00017: saving model to sloan_xception/model-00017-0.06636-0.98375-0.34479-0.92000.h5
# Epoch 18/40
# 25/25 [==============================] - 16s 541ms/step - loss: 0.0717 - accuracy: 0.9875 - val_loss: 0.3709 - val_accuracy: 0.9300
#
# Epoch 00018: saving model to sloan_xception/model-00018-0.07168-0.98750-0.37086-0.93000.h5
# Epoch 19/40
# 25/25 [==============================] - 16s 538ms/step - loss: 0.0906 - accuracy: 0.9800 - val_loss: 0.3398 - val_accuracy: 0.9200
#
# Epoch 00019: saving model to sloan_xception/model-00019-0.09062-0.98000-0.33984-0.92000.h5
# Epoch 20/40
# 25/25 [==============================] - 16s 548ms/step - loss: 0.0865 - accuracy: 0.9737 - val_loss: 0.3490 - val_accuracy: 0.9200
#
# Epoch 00020: saving model to sloan_xception/model-00020-0.08649-0.97375-0.34902-0.92000.h5
# Epoch 21/40
# 25/25 [==============================] - 16s 538ms/step - loss: 0.0874 - accuracy: 0.9812 - val_loss: 0.3159 - val_accuracy: 0.9150
#
# Epoch 00021: saving model to sloan_xception/model-00021-0.08743-0.98125-0.31591-0.91500.h5
# Epoch 22/40
# 25/25 [==============================] - 16s 544ms/step - loss: 0.0906 - accuracy: 0.9812 - val_loss: 0.3481 - val_accuracy: 0.9200
#
# Epoch 00022: saving model to sloan_xception/model-00022-0.09062-0.98125-0.34811-0.92000.h5
# Epoch 23/40
# 25/25 [==============================] - 16s 533ms/step - loss: 0.1058 - accuracy: 0.9787 - val_loss: 0.4494 - val_accuracy: 0.9100
#
# Epoch 00023: saving model to sloan_xception/model-00023-0.10583-0.97875-0.44939-0.91000.h5
# Epoch 24/40
# 25/25 [==============================] - 16s 542ms/step - loss: 0.1097 - accuracy: 0.9688 - val_loss: 0.3891 - val_accuracy: 0.9250
#
# Epoch 00024: saving model to sloan_xception/model-00024-0.10975-0.96875-0.38907-0.92500.h5
# Epoch 25/40
# 25/25 [==============================] - 16s 545ms/step - loss: 0.0948 - accuracy: 0.9787 - val_loss: 0.3337 - val_accuracy: 0.9300
#
# Epoch 00025: saving model to sloan_xception/model-00025-0.09480-0.97875-0.33372-0.93000.h5
# Epoch 26/40
# 25/25 [==============================] - 23s 820ms/step - loss: 0.0962 - accuracy: 0.9750 - val_loss: 0.3163 - val_accuracy: 0.9200
#
# Epoch 00026: saving model to sloan_xception/model-00026-0.09616-0.97500-0.31626-0.92000.h5
# Epoch 27/40
# 25/25 [==============================] - 23s 820ms/step - loss: 0.0765 - accuracy: 0.9850 - val_loss: 0.3071 - val_accuracy: 0.9300
#
# Epoch 00027: saving model to sloan_xception/model-00027-0.07648-0.98500-0.30714-0.93000.h5
# Epoch 28/40
# 25/25 [==============================] - 23s 818ms/step - loss: 0.0684 - accuracy: 0.9825 - val_loss: 0.3209 - val_accuracy: 0.9250
#
# Epoch 00028: saving model to sloan_xception/model-00028-0.06842-0.98250-0.32091-0.92500.h5
# Epoch 29/40
# 25/25 [==============================] - 23s 813ms/step - loss: 0.1017 - accuracy: 0.9775 - val_loss: 0.3700 - val_accuracy: 0.9300
#
# Epoch 00029: saving model to sloan_xception/model-00029-0.10169-0.97750-0.37002-0.93000.h5
# Epoch 30/40
# 25/25 [==============================] - 22s 804ms/step - loss: 0.0744 - accuracy: 0.9775 - val_loss: 0.3508 - val_accuracy: 0.9250
#
# Epoch 00030: saving model to sloan_xception/model-00030-0.07440-0.97750-0.35080-0.92500.h5
# Epoch 31/40
# 25/25 [==============================] - 22s 800ms/step - loss: 0.1256 - accuracy: 0.9638 - val_loss: 0.5862 - val_accuracy: 0.8450
#
# Epoch 00031: saving model to sloan_xception/model-00031-0.12561-0.96375-0.58620-0.84500.h5
# Epoch 32/40
# 25/25 [==============================] - 22s 807ms/step - loss: 0.1550 - accuracy: 0.9613 - val_loss: 0.4246 - val_accuracy: 0.9000
#
# Epoch 00032: saving model to sloan_xception/model-00032-0.15503-0.96125-0.42464-0.90000.h5
# Epoch 33/40
# 25/25 [==============================] - 23s 802ms/step - loss: 0.0977 - accuracy: 0.9775 - val_loss: 0.3209 - val_accuracy: 0.9250
#
# Epoch 00033: saving model to sloan_xception/model-00033-0.09769-0.97750-0.32089-0.92500.h5
# Epoch 34/40
# 25/25 [==============================] - 22s 788ms/step - loss: 0.0911 - accuracy: 0.9825 - val_loss: 0.3330 - val_accuracy: 0.9250
#
# Epoch 00034: saving model to sloan_xception/model-00034-0.09112-0.98250-0.33297-0.92500.h5
# Epoch 35/40
# 25/25 [==============================] - 23s 806ms/step - loss: 0.0884 - accuracy: 0.9737 - val_loss: 0.3492 - val_accuracy: 0.9200
#
# Epoch 00035: saving model to sloan_xception/model-00035-0.08841-0.97375-0.34919-0.92000.h5
# Epoch 36/40
# 25/25 [==============================] - 22s 805ms/step - loss: 0.0668 - accuracy: 0.9837 - val_loss: 0.3407 - val_accuracy: 0.9200
#
# Epoch 00036: saving model to sloan_xception/model-00036-0.06675-0.98375-0.34072-0.92000.h5
# Epoch 37/40
# 25/25 [==============================] - 22s 802ms/step - loss: 0.0902 - accuracy: 0.9775 - val_loss: 0.3462 - val_accuracy: 0.9150
#
# Epoch 00037: saving model to sloan_xception/model-00037-0.09022-0.97750-0.34620-0.91500.h5
# Epoch 38/40
# 25/25 [==============================] - 22s 792ms/step - loss: 0.0650 - accuracy: 0.9862 - val_loss: 0.3434 - val_accuracy: 0.9150
#
# Epoch 00038: saving model to sloan_xception/model-00038-0.06499-0.98625-0.34337-0.91500.h5
# Epoch 39/40
# 25/25 [==============================] - 22s 782ms/step - loss: 0.0537 - accuracy: 0.9837 - val_loss: 0.3557 - val_accuracy: 0.9200
#
# Epoch 00039: saving model to sloan_xception/model-00039-0.05368-0.98375-0.35569-0.92000.h5
# Epoch 40/40
# 25/25 [==============================] - 22s 791ms/step - loss: 0.0670 - accuracy: 0.9862 - val_loss: 0.4016 - val_accuracy: 0.9200
#
# Epoch 00040: saving model to sloan_xception/model-00040-0.06702-0.98625-0.40160-0.92000.h5

# %% [markdown]
# ##### Xception crop flip rotate

# %%
xception_unscaled_crop_flip_rotate.fit(train_ds_crop_flip_rotate,validation_data=val_ds_normal_crop,epochs = 40, verbose = 1, workers = 3, class_weight = {0:1.13, 1:8.03, 2:1},callbacks = callbacks_xception)
# Out:
# Epoch 1/40
# 25/25 [==============================] - 38s 1s/step - loss: 0.2278 - accuracy: 0.9488 - val_loss: 0.3850 - val_accuracy: 0.8550
#
# Epoch 00001: saving model to sloan_xception/model-00001-0.22777-0.94875-0.38505-0.85500.h5
# Epoch 2/40
# 25/25 [==============================] - 39s 1s/step - loss: 0.2349 - accuracy: 0.9425 - val_loss: 0.2504 - val_accuracy: 0.9300
#
# Epoch 00002: saving model to sloan_xception/model-00002-0.23489-0.94250-0.25042-0.93000.h5
# Epoch 3/40
# 25/25 [==============================] - 21s 703ms/step - loss: 0.1663 - accuracy: 0.9488 - val_loss: 0.2850 - val_accuracy: 0.9100
#
# Epoch 00003: saving model to sloan_xception/model-00003-0.16634-0.94875-0.28504-0.91000.h5
# Epoch 4/40
# 25/25 [==============================] - 21s 702ms/step - loss: 0.2359 - accuracy: 0.9488 - val_loss: 0.3343 - val_accuracy: 0.9000
#
# Epoch 00004: saving model to sloan_xception/model-00004-0.23592-0.94875-0.33431-0.90000.h5
# Epoch 5/40
# 25/25 [==============================] - 21s 699ms/step - loss: 0.2076 - accuracy: 0.9475 - val_loss: 0.2665 - val_accuracy: 0.9100
#
# Epoch 00005: saving model to sloan_xception/model-00005-0.20757-0.94750-0.26651-0.91000.h5
# Epoch 6/40
# 25/25 [==============================] - 21s 691ms/step - loss: 0.1779 - accuracy: 0.9513 - val_loss: 0.2604 - val_accuracy: 0.9200
#
# Epoch 00006: saving model to sloan_xception/model-00006-0.17786-0.95125-0.26038-0.92000.h5
# Epoch 7/40
# 25/25 [==============================] - 21s 704ms/step - loss: 0.2145 - accuracy: 0.9525 - val_loss: 0.3286 - val_accuracy: 0.8900
#
# Epoch 00007: saving model to sloan_xception/model-00007-0.21452-0.95250-0.32856-0.89000.h5
# Epoch 8/40
# 25/25 [==============================] - 21s 686ms/step - loss: 0.1989 - accuracy: 0.9575 - val_loss: 0.3011 - val_accuracy: 0.9050
#
# Epoch 00008: saving model to sloan_xception/model-00008-0.19889-0.95750-0.30110-0.90500.h5
# Epoch 9/40
# 25/25 [==============================] - 21s 695ms/step - loss: 0.1769 - accuracy: 0.9600 - val_loss: 0.3070 - val_accuracy: 0.9050
#
# Epoch 00009: saving model to sloan_xception/model-00009-0.17686-0.96000-0.30697-0.90500.h5
# Epoch 10/40
# 25/25 [==============================] - 21s 697ms/step - loss: 0.1551 - accuracy: 0.9613 - val_loss: 0.2964 - val_accuracy: 0.9000
#
# Epoch 00010: saving model to sloan_xception/model-00010-0.15508-0.96125-0.29639-0.90000.h5
# Epoch 11/40
# 25/25 [==============================] - 21s 703ms/step - loss: 0.1603 - accuracy: 0.9625 - val_loss: 0.2980 - val_accuracy: 0.9050
#
# Epoch 00011: saving model to sloan_xception/model-00011-0.16034-0.96250-0.29802-0.90500.h5
# Epoch 12/40
# 25/25 [==============================] - 21s 699ms/step - loss: 0.1994 - accuracy: 0.9475 - val_loss: 0.2776 - val_accuracy: 0.9200
#
# Epoch 00012: saving model to sloan_xception/model-00012-0.19940-0.94750-0.27759-0.92000.h5
# Epoch 13/40
# 25/25 [==============================] - 21s 684ms/step - loss: 0.2257 - accuracy: 0.9525 - val_loss: 0.3904 - val_accuracy: 0.8900
#
# Epoch 00013: saving model to sloan_xception/model-00013-0.22567-0.95250-0.39041-0.89000.h5
# Epoch 14/40
# 25/25 [==============================] - 21s 688ms/step - loss: 0.2301 - accuracy: 0.9488 - val_loss: 0.4363 - val_accuracy: 0.8600
#
# Epoch 00014: saving model to sloan_xception/model-00014-0.23008-0.94875-0.43628-0.86000.h5
# Epoch 15/40
# 25/25 [==============================] - 21s 690ms/step - loss: 0.1911 - accuracy: 0.9488 - val_loss: 0.2816 - val_accuracy: 0.9100
#
# Epoch 00015: saving model to sloan_xception/model-00015-0.19112-0.94875-0.28158-0.91000.h5
# Epoch 16/40
# 25/25 [==============================] - 21s 695ms/step - loss: 0.2339 - accuracy: 0.9463 - val_loss: 0.2515 - val_accuracy: 0.9200
#
# Epoch 00016: saving model to sloan_xception/model-00016-0.23385-0.94625-0.25153-0.92000.h5
# Epoch 17/40
# 25/25 [==============================] - 21s 695ms/step - loss: 0.1678 - accuracy: 0.9675 - val_loss: 0.2488 - val_accuracy: 0.9200
#
# Epoch 00017: saving model to sloan_xception/model-00017-0.16778-0.96750-0.24878-0.92000.h5
# Epoch 18/40
# 25/25 [==============================] - 21s 695ms/step - loss: 0.2055 - accuracy: 0.9463 - val_loss: 0.2642 - val_accuracy: 0.9100
#
# Epoch 00018: saving model to sloan_xception/model-00018-0.20549-0.94625-0.26416-0.91000.h5
# Epoch 19/40
# 25/25 [==============================] - 21s 695ms/step - loss: 0.1589 - accuracy: 0.9613 - val_loss: 0.3170 - val_accuracy: 0.9100
#
# Epoch 00019: saving model to sloan_xception/model-00019-0.15887-0.96125-0.31701-0.91000.h5
# Epoch 20/40
# 25/25 [==============================] - 21s 690ms/step - loss: 0.2057 - accuracy: 0.9550 - val_loss: 0.3374 - val_accuracy: 0.9000
#
# Epoch 00020: saving model to sloan_xception/model-00020-0.20567-0.95500-0.33741-0.90000.h5
# Epoch 21/40
# 25/25 [==============================] - 21s 690ms/step - loss: 0.1582 - accuracy: 0.9613 - val_loss: 0.2722 - val_accuracy: 0.9100
#
# Epoch 00021: saving model to sloan_xception/model-00021-0.15818-0.96125-0.27220-0.91000.h5
# Epoch 22/40
# 25/25 [==============================] - 21s 694ms/step - loss: 0.1465 - accuracy: 0.9575 - val_loss: 0.2815 - val_accuracy: 0.9150
#
# Epoch 00022: saving model to sloan_xception/model-00022-0.14652-0.95750-0.28151-0.91500.h5
# Epoch 23/40
# 25/25 [==============================] - 21s 693ms/step - loss: 0.1838 - accuracy: 0.9663 - val_loss: 0.2829 - val_accuracy: 0.9100
#
# Epoch 00023: saving model to sloan_xception/model-00023-0.18381-0.96625-0.28293-0.91000.h5
# Epoch 24/40
# 25/25 [==============================] - 21s 699ms/step - loss: 0.1483 - accuracy: 0.9675 - val_loss: 0.2680 - val_accuracy: 0.9150
#
# Epoch 00024: saving model to sloan_xception/model-00024-0.14825-0.96750-0.26798-0.91500.h5
# Epoch 25/40
# 25/25 [==============================] - 21s 704ms/step - loss: 0.1470 - accuracy: 0.9625 - val_loss: 0.2693 - val_accuracy: 0.9250
#
# Epoch 00025: saving model to sloan_xception/model-00025-0.14695-0.96250-0.26935-0.92500.h5
# Epoch 26/40
# 25/25 [==============================] - 22s 738ms/step - loss: 0.1582 - accuracy: 0.9663 - val_loss: 0.2605 - val_accuracy: 0.9150
#
# Epoch 00026: saving model to sloan_xception/model-00026-0.15817-0.96625-0.26050-0.91500.h5
# Epoch 27/40
# 25/25 [==============================] - 22s 725ms/step - loss: 0.1472 - accuracy: 0.9700 - val_loss: 0.2982 - val_accuracy: 0.9050
#
# Epoch 00027: saving model to sloan_xception/model-00027-0.14724-0.97000-0.29816-0.90500.h5
# Epoch 28/40
# 25/25 [==============================] - 22s 718ms/step - loss: 0.1590 - accuracy: 0.9663 - val_loss: 0.2739 - val_accuracy: 0.9200
#
# Epoch 00028: saving model to sloan_xception/model-00028-0.15899-0.96625-0.27390-0.92000.h5
# Epoch 29/40
# 25/25 [==============================] - 21s 700ms/step - loss: 0.1564 - accuracy: 0.9550 - val_loss: 0.2887 - val_accuracy: 0.9200
#
# Epoch 00029: saving model to sloan_xception/model-00029-0.15643-0.95500-0.28873-0.92000.h5
# Epoch 30/40
# 25/25 [==============================] - 21s 697ms/step - loss: 0.1571 - accuracy: 0.9613 - val_loss: 0.3019 - val_accuracy: 0.9150
#
# Epoch 00030: saving model to sloan_xception/model-00030-0.15713-0.96125-0.30193-0.91500.h5
# Epoch 31/40
# 25/25 [==============================] - 21s 699ms/step - loss: 0.1575 - accuracy: 0.9588 - val_loss: 0.3142 - val_accuracy: 0.9150
#
# Epoch 00031: saving model to sloan_xception/model-00031-0.15747-0.95875-0.31419-0.91500.h5
# Epoch 32/40
# 25/25 [==============================] - 21s 721ms/step - loss: 0.1969 - accuracy: 0.9550 - val_loss: 0.3150 - val_accuracy: 0.9050
#
# Epoch 00032: saving model to sloan_xception/model-00032-0.19695-0.95500-0.31504-0.90500.h5
# Epoch 33/40
# 25/25 [==============================] - 39s 1s/step - loss: 0.1835 - accuracy: 0.9525 - val_loss: 0.2931 - val_accuracy: 0.9250
#
# Epoch 00033: saving model to sloan_xception/model-00033-0.18354-0.95250-0.29309-0.92500.h5
# Epoch 34/40
# 25/25 [==============================] - 39s 1s/step - loss: 0.1708 - accuracy: 0.9463 - val_loss: 0.2700 - val_accuracy: 0.9200
#
# Epoch 00034: saving model to sloan_xception/model-00034-0.17079-0.94625-0.26996-0.92000.h5
# Epoch 35/40
# 25/25 [==============================] - 39s 1s/step - loss: 0.1514 - accuracy: 0.9638 - val_loss: 0.2755 - val_accuracy: 0.9200
#
# Epoch 00035: saving model to sloan_xception/model-00035-0.15144-0.96375-0.27553-0.92000.h5
# Epoch 36/40
# 25/25 [==============================] - 40s 1s/step - loss: 0.1440 - accuracy: 0.9613 - val_loss: 0.2701 - val_accuracy: 0.9200
#
# Epoch 00036: saving model to sloan_xception/model-00036-0.14403-0.96125-0.27014-0.92000.h5
# Epoch 37/40
# 25/25 [==============================] - 40s 1s/step - loss: 0.1086 - accuracy: 0.9750 - val_loss: 0.2758 - val_accuracy: 0.9150
#
# Epoch 00037: saving model to sloan_xception/model-00037-0.10861-0.97500-0.27576-0.91500.h5
# Epoch 38/40
# 25/25 [==============================] - 39s 1s/step - loss: 0.1535 - accuracy: 0.9625 - val_loss: 0.2914 - val_accuracy: 0.9200
#
# Epoch 00038: saving model to sloan_xception/model-00038-0.15345-0.96250-0.29143-0.92000.h5
# Epoch 39/40
# 25/25 [==============================] - 40s 1s/step - loss: 0.1901 - accuracy: 0.9625 - val_loss: 0.3972 - val_accuracy: 0.8900
#
# Epoch 00039: saving model to sloan_xception/model-00039-0.19010-0.96250-0.39725-0.89000.h5
# Epoch 40/40
# 25/25 [==============================] - 39s 1s/step - loss: 0.1929 - accuracy: 0.9488 - val_loss: 0.2614 - val_accuracy: 0.9200
#
# Epoch 00040: saving model to sloan_xception/model-00040-0.19289-0.94875-0.26137-0.92000.h5

# %% [markdown]
# ##### Preprocessing  - Xception crop flip rotate

# %%
# train_ds_normal_crop = prepare_dataset_normal_crop(train_ds_cropped) 
# val_ds_normal_crop = prepare_dataset_normal_crop(val_ds_cropped, training = False)
xception_model.fit(train_ds_normal_crop, validation_data = val_ds_normal_crop, epochs = 40, verbose = 1, workers = 3, class_weight = {0:1.13, 1:8.03, 2:1}, callbacks = callbacks_xception)
# Out:
# Epoch 1/20
# 25/25 [==============================] - 19s 636ms/step - loss: 0.7834 - accuracy: 0.7650 - val_loss: 0.5653 - val_accuracy: 0.7350
#
# Epoch 00001: saving model to sloan_xception/model-00001-0.78336-0.76500-0.56531-0.73500.h5
# Epoch 2/20
# 25/25 [==============================] - 19s 642ms/step - loss: 0.8176 - accuracy: 0.7387 - val_loss: 0.5602 - val_accuracy: 0.7350
#
# Epoch 00002: saving model to sloan_xception/model-00002-0.81760-0.73875-0.56020-0.73500.h5
# Epoch 3/20
# 25/25 [==============================] - 19s 636ms/step - loss: 0.7799 - accuracy: 0.7563 - val_loss: 0.5486 - val_accuracy: 0.7400
#
# Epoch 00003: saving model to sloan_xception/model-00003-0.77986-0.75625-0.54858-0.74000.h5
# Epoch 4/20
# 25/25 [==============================] - 19s 633ms/step - loss: 0.7491 - accuracy: 0.7700 - val_loss: 0.5359 - val_accuracy: 0.7500
#
# Epoch 00004: saving model to sloan_xception/model-00004-0.74906-0.77000-0.53587-0.75000.h5
# Epoch 5/20
# 25/25 [==============================] - 19s 630ms/step - loss: 0.7224 - accuracy: 0.7763 - val_loss: 0.5375 - val_accuracy: 0.7500
#
# Epoch 00005: saving model to sloan_xception/model-00005-0.72238-0.77625-0.53749-0.75000.h5
# Epoch 6/20
# 25/25 [==============================] - 18s 627ms/step - loss: 0.7319 - accuracy: 0.7850 - val_loss: 0.5304 - val_accuracy: 0.7500
#
# Epoch 00006: saving model to sloan_xception/model-00006-0.73192-0.78500-0.53038-0.75000.h5
# Epoch 7/20
# 25/25 [==============================] - 19s 636ms/step - loss: 0.7246 - accuracy: 0.7812 - val_loss: 0.5229 - val_accuracy: 0.7700
#
# Epoch 00007: saving model to sloan_xception/model-00007-0.72460-0.78125-0.52292-0.77000.h5
# Epoch 8/20
# 25/25 [==============================] - 19s 630ms/step - loss: 0.7183 - accuracy: 0.7825 - val_loss: 0.5250 - val_accuracy: 0.7750
#
# Epoch 00008: saving model to sloan_xception/model-00008-0.71829-0.78250-0.52503-0.77500.h5
# Epoch 9/20
# 25/25 [==============================] - 19s 637ms/step - loss: 0.7077 - accuracy: 0.7812 - val_loss: 0.5219 - val_accuracy: 0.7700
#
# Epoch 00009: saving model to sloan_xception/model-00009-0.70773-0.78125-0.52188-0.77000.h5
# Epoch 10/20
# 25/25 [==============================] - 19s 629ms/step - loss: 0.7095 - accuracy: 0.7837 - val_loss: 0.5108 - val_accuracy: 0.7800
#
# Epoch 00010: saving model to sloan_xception/model-00010-0.70949-0.78375-0.51076-0.78000.h5
# Epoch 11/20
# 25/25 [==============================] - 18s 619ms/step - loss: 0.6769 - accuracy: 0.8238 - val_loss: 0.4982 - val_accuracy: 0.7800
#
# Epoch 00011: saving model to sloan_xception/model-00011-0.67693-0.82375-0.49818-0.78000.h5
# Epoch 12/20
# 25/25 [==============================] - 18s 629ms/step - loss: 0.6922 - accuracy: 0.7937 - val_loss: 0.4942 - val_accuracy: 0.7800
#
# Epoch 00012: saving model to sloan_xception/model-00012-0.69217-0.79375-0.49415-0.78000.h5
# Epoch 13/20
# 25/25 [==============================] - 18s 625ms/step - loss: 0.6770 - accuracy: 0.8300 - val_loss: 0.4768 - val_accuracy: 0.7950
#
# Epoch 00013: saving model to sloan_xception/model-00013-0.67697-0.83000-0.47681-0.79500.h5
# Epoch 14/20
# 25/25 [==============================] - 18s 626ms/step - loss: 0.6553 - accuracy: 0.8150 - val_loss: 0.4990 - val_accuracy: 0.7850
#
# Epoch 00014: saving model to sloan_xception/model-00014-0.65530-0.81500-0.49899-0.78500.h5
# Epoch 15/20
# 25/25 [==============================] - 18s 620ms/step - loss: 0.6570 - accuracy: 0.8150 - val_loss: 0.4740 - val_accuracy: 0.7900
#
# Epoch 00015: saving model to sloan_xception/model-00015-0.65700-0.81500-0.47399-0.79000.h5
# Epoch 16/20
# 25/25 [==============================] - 18s 618ms/step - loss: 0.6665 - accuracy: 0.8112 - val_loss: 0.4830 - val_accuracy: 0.7900
#
# Epoch 00016: saving model to sloan_xception/model-00016-0.66646-0.81125-0.48298-0.79000.h5
# Epoch 17/20
# 25/25 [==============================] - 18s 616ms/step - loss: 0.6720 - accuracy: 0.7875 - val_loss: 0.4998 - val_accuracy: 0.7950
#
# Epoch 00017: saving model to sloan_xception/model-00017-0.67197-0.78750-0.49982-0.79500.h5
# Epoch 18/20
# 25/25 [==============================] - 18s 626ms/step - loss: 0.6741 - accuracy: 0.8012 - val_loss: 0.4700 - val_accuracy: 0.7950
#
# Epoch 00018: saving model to sloan_xception/model-00018-0.67406-0.80125-0.46999-0.79500.h5
# Epoch 19/20
# 25/25 [==============================] - 18s 621ms/step - loss: 0.6174 - accuracy: 0.8138 - val_loss: 0.4641 - val_accuracy: 0.7950
#
# Epoch 00019: saving model to sloan_xception/model-00019-0.61743-0.81375-0.46410-0.79500.h5
# Epoch 20/20
# 25/25 [==============================] - 18s 617ms/step - loss: 0.6246 - accuracy: 0.8238 - val_loss: 0.4725 - val_accuracy: 0.7950
#
# Epoch 00020: saving model to sloan_xception/model-00020-0.62455-0.82375-0.47251-0.79500.h5

# %% [markdown]
# ##### Model Evaluation

# %%
train_ds_normal_crop = prepare_dataset_normal_crop(train_ds_cropped) 
val_ds_normal_crop = prepare_dataset_normal_crop(val_ds_cropped, training = False)

xception_scaled = load_model('./sloan_xception/Xception_scaled_00024-0.50248-0.87875-0.39955-0.84000.h5')
xception_unscaled = load_model('./sloan_xception/Xception_unscaled_0.18934-0.95875-0.45550-0.90500.h5') 
xception_unscaled_flip = load_model('./sloan_xception/Xception_unscaled_model_flip-00036-0.14-0.9687-0.50-0.91500.h5')
xception_unscaled_flip_rotate = load_model('./sloan_xception/Xception_unsclaed_flip_rot-00030-0.25264-0.93125-0.33230-0.91000.h5')
xception_unscaled_crop_flip = load_model('./sloan_xception/Xception_crop_flip0.1351-0.9687-0.2933-0.9300.h5')
xception_unscaled_crop_flip_rotate = load_model('./sloan_xception/Xception_crop_flip_rotate_0.21518-0.93875-0.24829-0.93500.h5')
xception_preprocessing_crop = load_model('./sloan_xception/Xception_preprocess_croposs_0.6720-0.7875_0.4998-7950.h5')


metrics = Metrics(xception_scaled,val_ds_scaled)
print(metrics.calculate_scores())
print('---------------------------------------------------------------------------------------------------------------------')
metrics = Metrics(xception_unscaled,val_ds)
print(metrics.calculate_scores())
print('---------------------------------------------------------------------------------------------------------------------')
metrics = Metrics(xception_unscaled_flip,val_ds)
print(metrics.calculate_scores())
print('---------------------------------------------------------------------------------------------------------------------')
metrics = Metrics(xception_unscaled_flip_rotate,val_ds)
print(metrics.calculate_scores())
print('---------------------------------------------------------------------------------------------------------------------')
metrics = Metrics(xception_unscaled_crop_flip,val_ds_normal_crop)
print(metrics.calculate_scores())
print('---------------------------------------------------------------------------------------------------------------------')
metrics = Metrics(xception_unscaled_crop_flip_rotate,val_ds_normal_crop)
print(metrics.calculate_scores())
print('---------------------------------------------------------------------------------------------------------------------')
metrics = Metrics(xception_preprocessing_crop,val_ds_normal_crop)
print(metrics.calculate_scores())
print('---------------------------------------------------------------------------------------------------------------------')
# Out:
# calculating score.....
# [[91  3  2]
#  [ 0 11  6]
#  [ 9 12 66]]
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.95      0.93        96
#          1.0       0.42      0.65      0.51        17
#          2.0       0.89      0.76      0.82        87
#
#     accuracy                           0.84       200
#    macro avg       0.74      0.78      0.75       200
# weighted avg       0.86      0.84      0.85       200
#
# None
# ---------------------------------------------------------------------------------------------------------------------
# calculating score.....
# [[93  0  3]
#  [ 0 11  6]
#  [ 1  9 77]]
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.97      0.98        96
#          1.0       0.55      0.65      0.59        17
#          2.0       0.90      0.89      0.89        87
#
#     accuracy                           0.91       200
#    macro avg       0.81      0.83      0.82       200
# weighted avg       0.91      0.91      0.91       200
#
# None
# ---------------------------------------------------------------------------------------------------------------------
# calculating score.....
# [[94  0  2]
#  [ 0 11  6]
#  [ 0  9 78]]
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.98      0.99        96
#          1.0       0.55      0.65      0.59        17
#          2.0       0.91      0.90      0.90        87
#
#     accuracy                           0.92       200
#    macro avg       0.82      0.84      0.83       200
# weighted avg       0.92      0.92      0.92       200
#
# None
# ---------------------------------------------------------------------------------------------------------------------
# calculating score.....
# [[92  0  4]
#  [ 0 13  4]
#  [ 0 10 77]]
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.96      0.98        96
#          1.0       0.57      0.76      0.65        17
#          2.0       0.91      0.89      0.90        87
#
#     accuracy                           0.91       200
#    macro avg       0.82      0.87      0.84       200
# weighted avg       0.92      0.91      0.91       200
#
# None
# ---------------------------------------------------------------------------------------------------------------------
# calculating score.....
# [[94  0  2]
#  [ 0 12  5]
#  [ 0  7 80]]
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.98      0.99        96
#          1.0       0.63      0.71      0.67        17
#          2.0       0.92      0.92      0.92        87
#
#     accuracy                           0.93       200
#    macro avg       0.85      0.87      0.86       200
# weighted avg       0.93      0.93      0.93       200
#
# None
# ---------------------------------------------------------------------------------------------------------------------
# calculating score.....
# [[95  0  1]
#  [ 0 12  5]
#  [ 0  7 80]]
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.99      0.99        96
#          1.0       0.63      0.71      0.67        17
#          2.0       0.93      0.92      0.92        87
#
#     accuracy                           0.94       200
#    macro avg       0.85      0.87      0.86       200
# weighted avg       0.94      0.94      0.94       200
#
# None
# ---------------------------------------------------------------------------------------------------------------------
# calculating score.....
# [[88  0  8]
#  [ 0 15  2]
#  [ 6 25 56]]
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.92      0.93        96
#          1.0       0.38      0.88      0.53        17
#          2.0       0.85      0.64      0.73        87
#
#     accuracy                           0.80       200
#    macro avg       0.72      0.81      0.73       200
# weighted avg       0.85      0.80      0.81       200
#
# None
# ---------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Efficient Net

# %% [markdown]
# ##### Model building

# %%
base_model_effnet = tf.keras.applications.EfficientNetB2(
    include_top=False,
    weights="imagenet",    
    input_shape=(img_height, img_width, channels),
    pooling='max',
    classes=3,
)
layer_count  = len(base_model_effnet.layers)
print(f'There are a total of {layer_count} layers in the EfficientNetB2 network')
# making the base layers non trainable or freezing
break_point  = 330
for layer in base_model_effnet.layers[0:break_point]:
    layer.trainable = False
for layer in base_model_effnet.layers[break_point:]:
    layer.trainable = True

# please note higher the break point ; lesser the trainable layers lesser is the over fitting -> high breakpoint -> less over fitting 
base_model_effnet.inputs
input_layer = base_model_effnet.inputs

# Building a functional model
output = base_model_effnet.output
x = Dense(num_classes, activation  = 'softmax')(output)
effnet_model = Model(inputs = input_layer, outputs = x)
effnet_model.summary()
effnet_model.compile(optimizer = optimizers.Adam(lr=1e-4), loss = 'categorical_crossentropy', metrics = ['accuracy'],)
class_weight = {0:1.13, 1:8.03, 2:1}
# Out:
# There are a total of 340 layers in the EfficientNetB2 network
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 512, 512, 3) 0
# __________________________________________________________________________________________________
# rescaling_1 (Rescaling)         (None, 512, 512, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# normalization (Normalization)   (None, 512, 512, 3)  7           rescaling_1[0][0]
# __________________________________________________________________________________________________
# stem_conv_pad (ZeroPadding2D)   (None, 513, 513, 3)  0           normalization[0][0]
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 256, 256, 32) 864         stem_conv_pad[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 256, 256, 32) 128         stem_conv[0][0]
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 256, 256, 32) 0           stem_bn[0][0]
# __________________________________________________________________________________________________
# block1a_dwconv (DepthwiseConv2D (None, 256, 256, 32) 288         stem_activation[0][0]
# __________________________________________________________________________________________________
# block1a_bn (BatchNormalization) (None, 256, 256, 32) 128         block1a_dwconv[0][0]
# __________________________________________________________________________________________________
# block1a_activation (Activation) (None, 256, 256, 32) 0           block1a_bn[0][0]
# __________________________________________________________________________________________________
# block1a_se_squeeze (GlobalAvera (None, 32)           0           block1a_activation[0][0]
# __________________________________________________________________________________________________
# block1a_se_reshape (Reshape)    (None, 1, 1, 32)     0           block1a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1a_se_reduce (Conv2D)      (None, 1, 1, 8)      264         block1a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1a_se_expand (Conv2D)      (None, 1, 1, 32)     288         block1a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1a_se_excite (Multiply)    (None, 256, 256, 32) 0           block1a_activation[0][0]
#                                                                  block1a_se_expand[0][0]
# __________________________________________________________________________________________________
# block1a_project_conv (Conv2D)   (None, 256, 256, 16) 512         block1a_se_excite[0][0]
# __________________________________________________________________________________________________
# block1a_project_bn (BatchNormal (None, 256, 256, 16) 64          block1a_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_dwconv (DepthwiseConv2D (None, 256, 256, 16) 144         block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_bn (BatchNormalization) (None, 256, 256, 16) 64          block1b_dwconv[0][0]
# __________________________________________________________________________________________________
# block1b_activation (Activation) (None, 256, 256, 16) 0           block1b_bn[0][0]
# __________________________________________________________________________________________________
# block1b_se_squeeze (GlobalAvera (None, 16)           0           block1b_activation[0][0]
# __________________________________________________________________________________________________
# block1b_se_reshape (Reshape)    (None, 1, 1, 16)     0           block1b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block1b_se_reduce (Conv2D)      (None, 1, 1, 4)      68          block1b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block1b_se_expand (Conv2D)      (None, 1, 1, 16)     80          block1b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block1b_se_excite (Multiply)    (None, 256, 256, 16) 0           block1b_activation[0][0]
#                                                                  block1b_se_expand[0][0]
# __________________________________________________________________________________________________
# block1b_project_conv (Conv2D)   (None, 256, 256, 16) 256         block1b_se_excite[0][0]
# __________________________________________________________________________________________________
# block1b_project_bn (BatchNormal (None, 256, 256, 16) 64          block1b_project_conv[0][0]
# __________________________________________________________________________________________________
# block1b_drop (Dropout)          (None, 256, 256, 16) 0           block1b_project_bn[0][0]
# __________________________________________________________________________________________________
# block1b_add (Add)               (None, 256, 256, 16) 0           block1b_drop[0][0]
#                                                                  block1a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2a_expand_conv (Conv2D)    (None, 256, 256, 96) 1536        block1b_add[0][0]
# __________________________________________________________________________________________________
# block2a_expand_bn (BatchNormali (None, 256, 256, 96) 384         block2a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2a_expand_activation (Acti (None, 256, 256, 96) 0           block2a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv_pad (ZeroPadding (None, 257, 257, 96) 0           block2a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2a_dwconv (DepthwiseConv2D (None, 128, 128, 96) 864         block2a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block2a_bn (BatchNormalization) (None, 128, 128, 96) 384         block2a_dwconv[0][0]
# __________________________________________________________________________________________________
# block2a_activation (Activation) (None, 128, 128, 96) 0           block2a_bn[0][0]
# __________________________________________________________________________________________________
# block2a_se_squeeze (GlobalAvera (None, 96)           0           block2a_activation[0][0]
# __________________________________________________________________________________________________
# block2a_se_reshape (Reshape)    (None, 1, 1, 96)     0           block2a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2a_se_reduce (Conv2D)      (None, 1, 1, 4)      388         block2a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2a_se_expand (Conv2D)      (None, 1, 1, 96)     480         block2a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2a_se_excite (Multiply)    (None, 128, 128, 96) 0           block2a_activation[0][0]
#                                                                  block2a_se_expand[0][0]
# __________________________________________________________________________________________________
# block2a_project_conv (Conv2D)   (None, 128, 128, 24) 2304        block2a_se_excite[0][0]
# __________________________________________________________________________________________________
# block2a_project_bn (BatchNormal (None, 128, 128, 24) 96          block2a_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_conv (Conv2D)    (None, 128, 128, 144 3456        block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_expand_bn (BatchNormali (None, 128, 128, 144 576         block2b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2b_expand_activation (Acti (None, 128, 128, 144 0           block2b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2b_dwconv (DepthwiseConv2D (None, 128, 128, 144 1296        block2b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2b_bn (BatchNormalization) (None, 128, 128, 144 576         block2b_dwconv[0][0]
# __________________________________________________________________________________________________
# block2b_activation (Activation) (None, 128, 128, 144 0           block2b_bn[0][0]
# __________________________________________________________________________________________________
# block2b_se_squeeze (GlobalAvera (None, 144)          0           block2b_activation[0][0]
# __________________________________________________________________________________________________
# block2b_se_reshape (Reshape)    (None, 1, 1, 144)    0           block2b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2b_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block2b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2b_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block2b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2b_se_excite (Multiply)    (None, 128, 128, 144 0           block2b_activation[0][0]
#                                                                  block2b_se_expand[0][0]
# __________________________________________________________________________________________________
# block2b_project_conv (Conv2D)   (None, 128, 128, 24) 3456        block2b_se_excite[0][0]
# __________________________________________________________________________________________________
# block2b_project_bn (BatchNormal (None, 128, 128, 24) 96          block2b_project_conv[0][0]
# __________________________________________________________________________________________________
# block2b_drop (Dropout)          (None, 128, 128, 24) 0           block2b_project_bn[0][0]
# __________________________________________________________________________________________________
# block2b_add (Add)               (None, 128, 128, 24) 0           block2b_drop[0][0]
#                                                                  block2a_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_expand_conv (Conv2D)    (None, 128, 128, 144 3456        block2b_add[0][0]
# __________________________________________________________________________________________________
# block2c_expand_bn (BatchNormali (None, 128, 128, 144 576         block2c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block2c_expand_activation (Acti (None, 128, 128, 144 0           block2c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block2c_dwconv (DepthwiseConv2D (None, 128, 128, 144 1296        block2c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block2c_bn (BatchNormalization) (None, 128, 128, 144 576         block2c_dwconv[0][0]
# __________________________________________________________________________________________________
# block2c_activation (Activation) (None, 128, 128, 144 0           block2c_bn[0][0]
# __________________________________________________________________________________________________
# block2c_se_squeeze (GlobalAvera (None, 144)          0           block2c_activation[0][0]
# __________________________________________________________________________________________________
# block2c_se_reshape (Reshape)    (None, 1, 1, 144)    0           block2c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block2c_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block2c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block2c_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block2c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block2c_se_excite (Multiply)    (None, 128, 128, 144 0           block2c_activation[0][0]
#                                                                  block2c_se_expand[0][0]
# __________________________________________________________________________________________________
# block2c_project_conv (Conv2D)   (None, 128, 128, 24) 3456        block2c_se_excite[0][0]
# __________________________________________________________________________________________________
# block2c_project_bn (BatchNormal (None, 128, 128, 24) 96          block2c_project_conv[0][0]
# __________________________________________________________________________________________________
# block2c_drop (Dropout)          (None, 128, 128, 24) 0           block2c_project_bn[0][0]
# __________________________________________________________________________________________________
# block2c_add (Add)               (None, 128, 128, 24) 0           block2c_drop[0][0]
#                                                                  block2b_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_conv (Conv2D)    (None, 128, 128, 144 3456        block2c_add[0][0]
# __________________________________________________________________________________________________
# block3a_expand_bn (BatchNormali (None, 128, 128, 144 576         block3a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3a_expand_activation (Acti (None, 128, 128, 144 0           block3a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv_pad (ZeroPadding (None, 131, 131, 144 0           block3a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3a_dwconv (DepthwiseConv2D (None, 64, 64, 144)  3600        block3a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block3a_bn (BatchNormalization) (None, 64, 64, 144)  576         block3a_dwconv[0][0]
# __________________________________________________________________________________________________
# block3a_activation (Activation) (None, 64, 64, 144)  0           block3a_bn[0][0]
# __________________________________________________________________________________________________
# block3a_se_squeeze (GlobalAvera (None, 144)          0           block3a_activation[0][0]
# __________________________________________________________________________________________________
# block3a_se_reshape (Reshape)    (None, 1, 1, 144)    0           block3a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3a_se_reduce (Conv2D)      (None, 1, 1, 6)      870         block3a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3a_se_expand (Conv2D)      (None, 1, 1, 144)    1008        block3a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3a_se_excite (Multiply)    (None, 64, 64, 144)  0           block3a_activation[0][0]
#                                                                  block3a_se_expand[0][0]
# __________________________________________________________________________________________________
# block3a_project_conv (Conv2D)   (None, 64, 64, 48)   6912        block3a_se_excite[0][0]
# __________________________________________________________________________________________________
# block3a_project_bn (BatchNormal (None, 64, 64, 48)   192         block3a_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_conv (Conv2D)    (None, 64, 64, 288)  13824       block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_expand_bn (BatchNormali (None, 64, 64, 288)  1152        block3b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3b_expand_activation (Acti (None, 64, 64, 288)  0           block3b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3b_dwconv (DepthwiseConv2D (None, 64, 64, 288)  7200        block3b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3b_bn (BatchNormalization) (None, 64, 64, 288)  1152        block3b_dwconv[0][0]
# __________________________________________________________________________________________________
# block3b_activation (Activation) (None, 64, 64, 288)  0           block3b_bn[0][0]
# __________________________________________________________________________________________________
# block3b_se_squeeze (GlobalAvera (None, 288)          0           block3b_activation[0][0]
# __________________________________________________________________________________________________
# block3b_se_reshape (Reshape)    (None, 1, 1, 288)    0           block3b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3b_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block3b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3b_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block3b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3b_se_excite (Multiply)    (None, 64, 64, 288)  0           block3b_activation[0][0]
#                                                                  block3b_se_expand[0][0]
# __________________________________________________________________________________________________
# block3b_project_conv (Conv2D)   (None, 64, 64, 48)   13824       block3b_se_excite[0][0]
# __________________________________________________________________________________________________
# block3b_project_bn (BatchNormal (None, 64, 64, 48)   192         block3b_project_conv[0][0]
# __________________________________________________________________________________________________
# block3b_drop (Dropout)          (None, 64, 64, 48)   0           block3b_project_bn[0][0]
# __________________________________________________________________________________________________
# block3b_add (Add)               (None, 64, 64, 48)   0           block3b_drop[0][0]
#                                                                  block3a_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_expand_conv (Conv2D)    (None, 64, 64, 288)  13824       block3b_add[0][0]
# __________________________________________________________________________________________________
# block3c_expand_bn (BatchNormali (None, 64, 64, 288)  1152        block3c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block3c_expand_activation (Acti (None, 64, 64, 288)  0           block3c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block3c_dwconv (DepthwiseConv2D (None, 64, 64, 288)  7200        block3c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block3c_bn (BatchNormalization) (None, 64, 64, 288)  1152        block3c_dwconv[0][0]
# __________________________________________________________________________________________________
# block3c_activation (Activation) (None, 64, 64, 288)  0           block3c_bn[0][0]
# __________________________________________________________________________________________________
# block3c_se_squeeze (GlobalAvera (None, 288)          0           block3c_activation[0][0]
# __________________________________________________________________________________________________
# block3c_se_reshape (Reshape)    (None, 1, 1, 288)    0           block3c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block3c_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block3c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block3c_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block3c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block3c_se_excite (Multiply)    (None, 64, 64, 288)  0           block3c_activation[0][0]
#                                                                  block3c_se_expand[0][0]
# __________________________________________________________________________________________________
# block3c_project_conv (Conv2D)   (None, 64, 64, 48)   13824       block3c_se_excite[0][0]
# __________________________________________________________________________________________________
# block3c_project_bn (BatchNormal (None, 64, 64, 48)   192         block3c_project_conv[0][0]
# __________________________________________________________________________________________________
# block3c_drop (Dropout)          (None, 64, 64, 48)   0           block3c_project_bn[0][0]
# __________________________________________________________________________________________________
# block3c_add (Add)               (None, 64, 64, 48)   0           block3c_drop[0][0]
#                                                                  block3b_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_conv (Conv2D)    (None, 64, 64, 288)  13824       block3c_add[0][0]
# __________________________________________________________________________________________________
# block4a_expand_bn (BatchNormali (None, 64, 64, 288)  1152        block4a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4a_expand_activation (Acti (None, 64, 64, 288)  0           block4a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv_pad (ZeroPadding (None, 65, 65, 288)  0           block4a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4a_dwconv (DepthwiseConv2D (None, 32, 32, 288)  2592        block4a_dwconv_pad[0][0]
# __________________________________________________________________________________________________
# block4a_bn (BatchNormalization) (None, 32, 32, 288)  1152        block4a_dwconv[0][0]
# __________________________________________________________________________________________________
# block4a_activation (Activation) (None, 32, 32, 288)  0           block4a_bn[0][0]
# __________________________________________________________________________________________________
# block4a_se_squeeze (GlobalAvera (None, 288)          0           block4a_activation[0][0]
# __________________________________________________________________________________________________
# block4a_se_reshape (Reshape)    (None, 1, 1, 288)    0           block4a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4a_se_reduce (Conv2D)      (None, 1, 1, 12)     3468        block4a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4a_se_expand (Conv2D)      (None, 1, 1, 288)    3744        block4a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4a_se_excite (Multiply)    (None, 32, 32, 288)  0           block4a_activation[0][0]
#                                                                  block4a_se_expand[0][0]
# __________________________________________________________________________________________________
# block4a_project_conv (Conv2D)   (None, 32, 32, 88)   25344       block4a_se_excite[0][0]
# __________________________________________________________________________________________________
# block4a_project_bn (BatchNormal (None, 32, 32, 88)   352         block4a_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_conv (Conv2D)    (None, 32, 32, 528)  46464       block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_expand_bn (BatchNormali (None, 32, 32, 528)  2112        block4b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4b_expand_activation (Acti (None, 32, 32, 528)  0           block4b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4b_dwconv (DepthwiseConv2D (None, 32, 32, 528)  4752        block4b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4b_bn (BatchNormalization) (None, 32, 32, 528)  2112        block4b_dwconv[0][0]
# __________________________________________________________________________________________________
# block4b_activation (Activation) (None, 32, 32, 528)  0           block4b_bn[0][0]
# __________________________________________________________________________________________________
# block4b_se_squeeze (GlobalAvera (None, 528)          0           block4b_activation[0][0]
# __________________________________________________________________________________________________
# block4b_se_reshape (Reshape)    (None, 1, 1, 528)    0           block4b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4b_se_reduce (Conv2D)      (None, 1, 1, 22)     11638       block4b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4b_se_expand (Conv2D)      (None, 1, 1, 528)    12144       block4b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4b_se_excite (Multiply)    (None, 32, 32, 528)  0           block4b_activation[0][0]
#                                                                  block4b_se_expand[0][0]
# __________________________________________________________________________________________________
# block4b_project_conv (Conv2D)   (None, 32, 32, 88)   46464       block4b_se_excite[0][0]
# __________________________________________________________________________________________________
# block4b_project_bn (BatchNormal (None, 32, 32, 88)   352         block4b_project_conv[0][0]
# __________________________________________________________________________________________________
# block4b_drop (Dropout)          (None, 32, 32, 88)   0           block4b_project_bn[0][0]
# __________________________________________________________________________________________________
# block4b_add (Add)               (None, 32, 32, 88)   0           block4b_drop[0][0]
#                                                                  block4a_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_expand_conv (Conv2D)    (None, 32, 32, 528)  46464       block4b_add[0][0]
# __________________________________________________________________________________________________
# block4c_expand_bn (BatchNormali (None, 32, 32, 528)  2112        block4c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4c_expand_activation (Acti (None, 32, 32, 528)  0           block4c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4c_dwconv (DepthwiseConv2D (None, 32, 32, 528)  4752        block4c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4c_bn (BatchNormalization) (None, 32, 32, 528)  2112        block4c_dwconv[0][0]
# __________________________________________________________________________________________________
# block4c_activation (Activation) (None, 32, 32, 528)  0           block4c_bn[0][0]
# __________________________________________________________________________________________________
# block4c_se_squeeze (GlobalAvera (None, 528)          0           block4c_activation[0][0]
# __________________________________________________________________________________________________
# block4c_se_reshape (Reshape)    (None, 1, 1, 528)    0           block4c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4c_se_reduce (Conv2D)      (None, 1, 1, 22)     11638       block4c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4c_se_expand (Conv2D)      (None, 1, 1, 528)    12144       block4c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4c_se_excite (Multiply)    (None, 32, 32, 528)  0           block4c_activation[0][0]
#                                                                  block4c_se_expand[0][0]
# __________________________________________________________________________________________________
# block4c_project_conv (Conv2D)   (None, 32, 32, 88)   46464       block4c_se_excite[0][0]
# __________________________________________________________________________________________________
# block4c_project_bn (BatchNormal (None, 32, 32, 88)   352         block4c_project_conv[0][0]
# __________________________________________________________________________________________________
# block4c_drop (Dropout)          (None, 32, 32, 88)   0           block4c_project_bn[0][0]
# __________________________________________________________________________________________________
# block4c_add (Add)               (None, 32, 32, 88)   0           block4c_drop[0][0]
#                                                                  block4b_add[0][0]
# __________________________________________________________________________________________________
# block4d_expand_conv (Conv2D)    (None, 32, 32, 528)  46464       block4c_add[0][0]
# __________________________________________________________________________________________________
# block4d_expand_bn (BatchNormali (None, 32, 32, 528)  2112        block4d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block4d_expand_activation (Acti (None, 32, 32, 528)  0           block4d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block4d_dwconv (DepthwiseConv2D (None, 32, 32, 528)  4752        block4d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block4d_bn (BatchNormalization) (None, 32, 32, 528)  2112        block4d_dwconv[0][0]
# __________________________________________________________________________________________________
# block4d_activation (Activation) (None, 32, 32, 528)  0           block4d_bn[0][0]
# __________________________________________________________________________________________________
# block4d_se_squeeze (GlobalAvera (None, 528)          0           block4d_activation[0][0]
# __________________________________________________________________________________________________
# block4d_se_reshape (Reshape)    (None, 1, 1, 528)    0           block4d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block4d_se_reduce (Conv2D)      (None, 1, 1, 22)     11638       block4d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block4d_se_expand (Conv2D)      (None, 1, 1, 528)    12144       block4d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block4d_se_excite (Multiply)    (None, 32, 32, 528)  0           block4d_activation[0][0]
#                                                                  block4d_se_expand[0][0]
# __________________________________________________________________________________________________
# block4d_project_conv (Conv2D)   (None, 32, 32, 88)   46464       block4d_se_excite[0][0]
# __________________________________________________________________________________________________
# block4d_project_bn (BatchNormal (None, 32, 32, 88)   352         block4d_project_conv[0][0]
# __________________________________________________________________________________________________
# block4d_drop (Dropout)          (None, 32, 32, 88)   0           block4d_project_bn[0][0]
# __________________________________________________________________________________________________
# block4d_add (Add)               (None, 32, 32, 88)   0           block4d_drop[0][0]
#                                                                  block4c_add[0][0]
# __________________________________________________________________________________________________
# block5a_expand_conv (Conv2D)    (None, 32, 32, 528)  46464       block4d_add[0][0]
# __________________________________________________________________________________________________
# block5a_expand_bn (BatchNormali (None, 32, 32, 528)  2112        block5a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5a_expand_activation (Acti (None, 32, 32, 528)  0           block5a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5a_dwconv (DepthwiseConv2D (None, 32, 32, 528)  13200       block5a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5a_bn (BatchNormalization) (None, 32, 32, 528)  2112        block5a_dwconv[0][0]
# __________________________________________________________________________________________________
# block5a_activation (Activation) (None, 32, 32, 528)  0           block5a_bn[0][0]
# __________________________________________________________________________________________________
# block5a_se_squeeze (GlobalAvera (None, 528)          0           block5a_activation[0][0]
# __________________________________________________________________________________________________
# block5a_se_reshape (Reshape)    (None, 1, 1, 528)    0           block5a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5a_se_reduce (Conv2D)      (None, 1, 1, 22)     11638       block5a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5a_se_expand (Conv2D)      (None, 1, 1, 528)    12144       block5a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5a_se_excite (Multiply)    (None, 32, 32, 528)  0           block5a_activation[0][0]
#                                                                  block5a_se_expand[0][0]
# __________________________________________________________________________________________________
# block5a_project_conv (Conv2D)   (None, 32, 32, 120)  63360       block5a_se_excite[0][0]
# __________________________________________________________________________________________________
# block5a_project_bn (BatchNormal (None, 32, 32, 120)  480         block5a_project_conv[0][0]
# __________________________________________________________________________________________________
# block5b_expand_conv (Conv2D)    (None, 32, 32, 720)  86400       block5a_project_bn[0][0]
# __________________________________________________________________________________________________
# block5b_expand_bn (BatchNormali (None, 32, 32, 720)  2880        block5b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5b_expand_activation (Acti (None, 32, 32, 720)  0           block5b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5b_dwconv (DepthwiseConv2D (None, 32, 32, 720)  18000       block5b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5b_bn (BatchNormalization) (None, 32, 32, 720)  2880        block5b_dwconv[0][0]
# __________________________________________________________________________________________________
# block5b_activation (Activation) (None, 32, 32, 720)  0           block5b_bn[0][0]
# __________________________________________________________________________________________________
# block5b_se_squeeze (GlobalAvera (None, 720)          0           block5b_activation[0][0]
# __________________________________________________________________________________________________
# block5b_se_reshape (Reshape)    (None, 1, 1, 720)    0           block5b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5b_se_reduce (Conv2D)      (None, 1, 1, 30)     21630       block5b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5b_se_expand (Conv2D)      (None, 1, 1, 720)    22320       block5b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5b_se_excite (Multiply)    (None, 32, 32, 720)  0           block5b_activation[0][0]
#                                                                  block5b_se_expand[0][0]
# __________________________________________________________________________________________________
# block5b_project_conv (Conv2D)   (None, 32, 32, 120)  86400       block5b_se_excite[0][0]
# __________________________________________________________________________________________________
# block5b_project_bn (BatchNormal (None, 32, 32, 120)  480         block5b_project_conv[0][0]
# __________________________________________________________________________________________________
# block5b_drop (Dropout)          (None, 32, 32, 120)  0           block5b_project_bn[0][0]
# __________________________________________________________________________________________________
# block5b_add (Add)               (None, 32, 32, 120)  0           block5b_drop[0][0]
#                                                                  block5a_project_bn[0][0]
# __________________________________________________________________________________________________
# block5c_expand_conv (Conv2D)    (None, 32, 32, 720)  86400       block5b_add[0][0]
# __________________________________________________________________________________________________
# block5c_expand_bn (BatchNormali (None, 32, 32, 720)  2880        block5c_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5c_expand_activation (Acti (None, 32, 32, 720)  0           block5c_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5c_dwconv (DepthwiseConv2D (None, 32, 32, 720)  18000       block5c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5c_bn (BatchNormalization) (None, 32, 32, 720)  2880        block5c_dwconv[0][0]
# __________________________________________________________________________________________________
# block5c_activation (Activation) (None, 32, 32, 720)  0           block5c_bn[0][0]
# __________________________________________________________________________________________________
# block5c_se_squeeze (GlobalAvera (None, 720)          0           block5c_activation[0][0]
# __________________________________________________________________________________________________
# block5c_se_reshape (Reshape)    (None, 1, 1, 720)    0           block5c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5c_se_reduce (Conv2D)      (None, 1, 1, 30)     21630       block5c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block5c_se_expand (Conv2D)      (None, 1, 1, 720)    22320       block5c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block5c_se_excite (Multiply)    (None, 32, 32, 720)  0           block5c_activation[0][0]
#                                                                  block5c_se_expand[0][0]
# __________________________________________________________________________________________________
# block5c_project_conv (Conv2D)   (None, 32, 32, 120)  86400       block5c_se_excite[0][0]
# __________________________________________________________________________________________________
# block5c_project_bn (BatchNormal (None, 32, 32, 120)  480         block5c_project_conv[0][0]
# __________________________________________________________________________________________________
# block5c_drop (Dropout)          (None, 32, 32, 120)  0           block5c_project_bn[0][0]
# __________________________________________________________________________________________________
# block5c_add (Add)               (None, 32, 32, 120)  0           block5c_drop[0][0]
#                                                                  block5b_add[0][0]
# __________________________________________________________________________________________________
# block5d_expand_conv (Conv2D)    (None, 32, 32, 720)  86400       block5c_add[0][0]
# __________________________________________________________________________________________________
# block5d_expand_bn (BatchNormali (None, 32, 32, 720)  2880        block5d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block5d_expand_activation (Acti (None, 32, 32, 720)  0           block5d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block5d_dwconv (DepthwiseConv2D (None, 32, 32, 720)  18000       block5d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block5d_bn (BatchNormalization) (None, 32, 32, 720)  2880        block5d_dwconv[0][0]
# __________________________________________________________________________________________________
# block5d_activation (Activation) (None, 32, 32, 720)  0           block5d_bn[0][0]
# __________________________________________________________________________________________________
# block5d_se_squeeze (GlobalAvera (None, 720)          0           block5d_activation[0][0]
# __________________________________________________________________________________________________
# block5d_se_reshape (Reshape)    (None, 1, 1, 720)    0           block5d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block5d_se_reduce (Conv2D)      (None, 1, 1, 30)     21630       block5d_se_reshape[0][0]
# __________________________________________________________________________________________________
# ...
# block6c_dwconv (DepthwiseConv2D (None, 16, 16, 1248) 31200       block6c_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6c_bn (BatchNormalization) (None, 16, 16, 1248) 4992        block6c_dwconv[0][0]
# __________________________________________________________________________________________________
# block6c_activation (Activation) (None, 16, 16, 1248) 0           block6c_bn[0][0]
# __________________________________________________________________________________________________
# block6c_se_squeeze (GlobalAvera (None, 1248)         0           block6c_activation[0][0]
# __________________________________________________________________________________________________
# block6c_se_reshape (Reshape)    (None, 1, 1, 1248)   0           block6c_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6c_se_reduce (Conv2D)      (None, 1, 1, 52)     64948       block6c_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6c_se_expand (Conv2D)      (None, 1, 1, 1248)   66144       block6c_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6c_se_excite (Multiply)    (None, 16, 16, 1248) 0           block6c_activation[0][0]
#                                                                  block6c_se_expand[0][0]
# __________________________________________________________________________________________________
# block6c_project_conv (Conv2D)   (None, 16, 16, 208)  259584      block6c_se_excite[0][0]
# __________________________________________________________________________________________________
# block6c_project_bn (BatchNormal (None, 16, 16, 208)  832         block6c_project_conv[0][0]
# __________________________________________________________________________________________________
# block6c_drop (Dropout)          (None, 16, 16, 208)  0           block6c_project_bn[0][0]
# __________________________________________________________________________________________________
# block6c_add (Add)               (None, 16, 16, 208)  0           block6c_drop[0][0]
#                                                                  block6b_add[0][0]
# __________________________________________________________________________________________________
# block6d_expand_conv (Conv2D)    (None, 16, 16, 1248) 259584      block6c_add[0][0]
# __________________________________________________________________________________________________
# block6d_expand_bn (BatchNormali (None, 16, 16, 1248) 4992        block6d_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6d_expand_activation (Acti (None, 16, 16, 1248) 0           block6d_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6d_dwconv (DepthwiseConv2D (None, 16, 16, 1248) 31200       block6d_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6d_bn (BatchNormalization) (None, 16, 16, 1248) 4992        block6d_dwconv[0][0]
# __________________________________________________________________________________________________
# block6d_activation (Activation) (None, 16, 16, 1248) 0           block6d_bn[0][0]
# __________________________________________________________________________________________________
# block6d_se_squeeze (GlobalAvera (None, 1248)         0           block6d_activation[0][0]
# __________________________________________________________________________________________________
# block6d_se_reshape (Reshape)    (None, 1, 1, 1248)   0           block6d_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6d_se_reduce (Conv2D)      (None, 1, 1, 52)     64948       block6d_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6d_se_expand (Conv2D)      (None, 1, 1, 1248)   66144       block6d_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6d_se_excite (Multiply)    (None, 16, 16, 1248) 0           block6d_activation[0][0]
#                                                                  block6d_se_expand[0][0]
# __________________________________________________________________________________________________
# block6d_project_conv (Conv2D)   (None, 16, 16, 208)  259584      block6d_se_excite[0][0]
# __________________________________________________________________________________________________
# block6d_project_bn (BatchNormal (None, 16, 16, 208)  832         block6d_project_conv[0][0]
# __________________________________________________________________________________________________
# block6d_drop (Dropout)          (None, 16, 16, 208)  0           block6d_project_bn[0][0]
# __________________________________________________________________________________________________
# block6d_add (Add)               (None, 16, 16, 208)  0           block6d_drop[0][0]
#                                                                  block6c_add[0][0]
# __________________________________________________________________________________________________
# block6e_expand_conv (Conv2D)    (None, 16, 16, 1248) 259584      block6d_add[0][0]
# __________________________________________________________________________________________________
# block6e_expand_bn (BatchNormali (None, 16, 16, 1248) 4992        block6e_expand_conv[0][0]
# __________________________________________________________________________________________________
# block6e_expand_activation (Acti (None, 16, 16, 1248) 0           block6e_expand_bn[0][0]
# __________________________________________________________________________________________________
# block6e_dwconv (DepthwiseConv2D (None, 16, 16, 1248) 31200       block6e_expand_activation[0][0]
# __________________________________________________________________________________________________
# block6e_bn (BatchNormalization) (None, 16, 16, 1248) 4992        block6e_dwconv[0][0]
# __________________________________________________________________________________________________
# block6e_activation (Activation) (None, 16, 16, 1248) 0           block6e_bn[0][0]
# __________________________________________________________________________________________________
# block6e_se_squeeze (GlobalAvera (None, 1248)         0           block6e_activation[0][0]
# __________________________________________________________________________________________________
# block6e_se_reshape (Reshape)    (None, 1, 1, 1248)   0           block6e_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block6e_se_reduce (Conv2D)      (None, 1, 1, 52)     64948       block6e_se_reshape[0][0]
# __________________________________________________________________________________________________
# block6e_se_expand (Conv2D)      (None, 1, 1, 1248)   66144       block6e_se_reduce[0][0]
# __________________________________________________________________________________________________
# block6e_se_excite (Multiply)    (None, 16, 16, 1248) 0           block6e_activation[0][0]
#                                                                  block6e_se_expand[0][0]
# __________________________________________________________________________________________________
# block6e_project_conv (Conv2D)   (None, 16, 16, 208)  259584      block6e_se_excite[0][0]
# __________________________________________________________________________________________________
# block6e_project_bn (BatchNormal (None, 16, 16, 208)  832         block6e_project_conv[0][0]
# __________________________________________________________________________________________________
# block6e_drop (Dropout)          (None, 16, 16, 208)  0           block6e_project_bn[0][0]
# __________________________________________________________________________________________________
# block6e_add (Add)               (None, 16, 16, 208)  0           block6e_drop[0][0]
#                                                                  block6d_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_conv (Conv2D)    (None, 16, 16, 1248) 259584      block6e_add[0][0]
# __________________________________________________________________________________________________
# block7a_expand_bn (BatchNormali (None, 16, 16, 1248) 4992        block7a_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7a_expand_activation (Acti (None, 16, 16, 1248) 0           block7a_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7a_dwconv (DepthwiseConv2D (None, 16, 16, 1248) 11232       block7a_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7a_bn (BatchNormalization) (None, 16, 16, 1248) 4992        block7a_dwconv[0][0]
# __________________________________________________________________________________________________
# block7a_activation (Activation) (None, 16, 16, 1248) 0           block7a_bn[0][0]
# __________________________________________________________________________________________________
# block7a_se_squeeze (GlobalAvera (None, 1248)         0           block7a_activation[0][0]
# __________________________________________________________________________________________________
# block7a_se_reshape (Reshape)    (None, 1, 1, 1248)   0           block7a_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7a_se_reduce (Conv2D)      (None, 1, 1, 52)     64948       block7a_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7a_se_expand (Conv2D)      (None, 1, 1, 1248)   66144       block7a_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7a_se_excite (Multiply)    (None, 16, 16, 1248) 0           block7a_activation[0][0]
#                                                                  block7a_se_expand[0][0]
# __________________________________________________________________________________________________
# block7a_project_conv (Conv2D)   (None, 16, 16, 352)  439296      block7a_se_excite[0][0]
# __________________________________________________________________________________________________
# block7a_project_bn (BatchNormal (None, 16, 16, 352)  1408        block7a_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_conv (Conv2D)    (None, 16, 16, 2112) 743424      block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_expand_bn (BatchNormali (None, 16, 16, 2112) 8448        block7b_expand_conv[0][0]
# __________________________________________________________________________________________________
# block7b_expand_activation (Acti (None, 16, 16, 2112) 0           block7b_expand_bn[0][0]
# __________________________________________________________________________________________________
# block7b_dwconv (DepthwiseConv2D (None, 16, 16, 2112) 19008       block7b_expand_activation[0][0]
# __________________________________________________________________________________________________
# block7b_bn (BatchNormalization) (None, 16, 16, 2112) 8448        block7b_dwconv[0][0]
# __________________________________________________________________________________________________
# block7b_activation (Activation) (None, 16, 16, 2112) 0           block7b_bn[0][0]
# __________________________________________________________________________________________________
# block7b_se_squeeze (GlobalAvera (None, 2112)         0           block7b_activation[0][0]
# __________________________________________________________________________________________________
# block7b_se_reshape (Reshape)    (None, 1, 1, 2112)   0           block7b_se_squeeze[0][0]
# __________________________________________________________________________________________________
# block7b_se_reduce (Conv2D)      (None, 1, 1, 88)     185944      block7b_se_reshape[0][0]
# __________________________________________________________________________________________________
# block7b_se_expand (Conv2D)      (None, 1, 1, 2112)   187968      block7b_se_reduce[0][0]
# __________________________________________________________________________________________________
# block7b_se_excite (Multiply)    (None, 16, 16, 2112) 0           block7b_activation[0][0]
#                                                                  block7b_se_expand[0][0]
# __________________________________________________________________________________________________
# block7b_project_conv (Conv2D)   (None, 16, 16, 352)  743424      block7b_se_excite[0][0]
# __________________________________________________________________________________________________
# block7b_project_bn (BatchNormal (None, 16, 16, 352)  1408        block7b_project_conv[0][0]
# __________________________________________________________________________________________________
# block7b_drop (Dropout)          (None, 16, 16, 352)  0           block7b_project_bn[0][0]
# __________________________________________________________________________________________________
# block7b_add (Add)               (None, 16, 16, 352)  0           block7b_drop[0][0]
#                                                                  block7a_project_bn[0][0]
# __________________________________________________________________________________________________
# top_conv (Conv2D)               (None, 16, 16, 1408) 495616      block7b_add[0][0]
# __________________________________________________________________________________________________
# top_bn (BatchNormalization)     (None, 16, 16, 1408) 5632        top_conv[0][0]
# __________________________________________________________________________________________________
# top_activation (Activation)     (None, 16, 16, 1408) 0           top_bn[0][0]
# __________________________________________________________________________________________________
# max_pool (GlobalMaxPooling2D)   (None, 1408)         0           top_activation[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 3)            4227        max_pool[0][0]
# ==================================================================================================
# Total params: 7,772,796
# Trainable params: 1,434,755
# Non-trainable params: 6,338,041
# __________________________________________________________________________________________________

# %% [markdown]
# ##### efficient net unscaled

# %%
effnet_model.fit(train_ds,validation_data=val_ds,epochs = 40, verbose = 1, workers = 3, class_weight = {0:1.13, 1:8.03, 2:1}, callbacks = callbacks_efficient)
# Out:
# Epoch 1/40
# 25/25 [==============================] - 12s 407ms/step - loss: 1.2636 - accuracy: 0.8425 - val_loss: 1.0022 - val_accuracy: 0.7950
#
# Epoch 00001: saving model to sloan_efficient/model-00001-1.26-0.84-1.00-0.80.h5
# Epoch 2/40
# 25/25 [==============================] - 12s 414ms/step - loss: 0.4338 - accuracy: 0.9013 - val_loss: 0.4531 - val_accuracy: 0.8850
#
# Epoch 00002: saving model to sloan_efficient/model-00002-0.43-0.90-0.45-0.88.h5
# Epoch 3/40
# 25/25 [==============================] - 12s 414ms/step - loss: 0.3661 - accuracy: 0.9275 - val_loss: 0.4791 - val_accuracy: 0.8800
#
# Epoch 00003: saving model to sloan_efficient/model-00003-0.37-0.93-0.48-0.88.h5
# Epoch 4/40
# 25/25 [==============================] - 12s 414ms/step - loss: 0.4579 - accuracy: 0.9125 - val_loss: 0.4672 - val_accuracy: 0.8800
#
# Epoch 00004: saving model to sloan_efficient/model-00004-0.46-0.91-0.47-0.88.h5
# Epoch 5/40
# 25/25 [==============================] - 12s 411ms/step - loss: 0.4095 - accuracy: 0.9100 - val_loss: 0.3818 - val_accuracy: 0.9000
#
# Epoch 00005: saving model to sloan_efficient/model-00005-0.41-0.91-0.38-0.90.h5
# Epoch 6/40
# 25/25 [==============================] - 12s 417ms/step - loss: 0.3239 - accuracy: 0.9212 - val_loss: 0.4381 - val_accuracy: 0.8900
#
# Epoch 00006: saving model to sloan_efficient/model-00006-0.32-0.92-0.44-0.89.h5
# Epoch 7/40
# 25/25 [==============================] - 12s 414ms/step - loss: 0.5739 - accuracy: 0.8913 - val_loss: 0.6803 - val_accuracy: 0.8850
#
# Epoch 00007: saving model to sloan_efficient/model-00007-0.57-0.89-0.68-0.88.h5
# Epoch 8/40
# 25/25 [==============================] - 12s 412ms/step - loss: 0.5053 - accuracy: 0.9125 - val_loss: 0.8590 - val_accuracy: 0.8850
#
# Epoch 00008: saving model to sloan_efficient/model-00008-0.51-0.91-0.86-0.88.h5
# Epoch 9/40
# 25/25 [==============================] - 12s 409ms/step - loss: 0.2632 - accuracy: 0.9375 - val_loss: 0.8995 - val_accuracy: 0.8200
#
# Epoch 00009: saving model to sloan_efficient/model-00009-0.26-0.94-0.90-0.82.h5
# Epoch 10/40
# 25/25 [==============================] - 12s 414ms/step - loss: 0.6003 - accuracy: 0.8763 - val_loss: 0.4830 - val_accuracy: 0.8900
#
# Epoch 00010: saving model to sloan_efficient/model-00010-0.60-0.88-0.48-0.89.h5
# Epoch 11/40
# 25/25 [==============================] - 12s 412ms/step - loss: 0.4944 - accuracy: 0.9112 - val_loss: 0.8114 - val_accuracy: 0.8200
#
# Epoch 00011: saving model to sloan_efficient/model-00011-0.49-0.91-0.81-0.82.h5
# Epoch 12/40
# 25/25 [==============================] - 12s 414ms/step - loss: 0.4225 - accuracy: 0.9137 - val_loss: 0.5857 - val_accuracy: 0.8850
#
# Epoch 00012: saving model to sloan_efficient/model-00012-0.42-0.91-0.59-0.88.h5
# Epoch 13/40
# 25/25 [==============================] - 12s 411ms/step - loss: 0.6794 - accuracy: 0.8850 - val_loss: 0.5755 - val_accuracy: 0.8850
#
# Epoch 00013: saving model to sloan_efficient/model-00013-0.68-0.88-0.58-0.88.h5
# Epoch 14/40
# 25/25 [==============================] - 12s 416ms/step - loss: 0.5899 - accuracy: 0.8875 - val_loss: 0.6303 - val_accuracy: 0.8900
#
# Epoch 00014: saving model to sloan_efficient/model-00014-0.59-0.89-0.63-0.89.h5
# Epoch 15/40
# 25/25 [==============================] - 12s 407ms/step - loss: 0.6576 - accuracy: 0.8925 - val_loss: 0.5102 - val_accuracy: 0.9050
#
# Epoch 00015: saving model to sloan_efficient/model-00015-0.66-0.89-0.51-0.90.h5
# Epoch 16/40
# 25/25 [==============================] - 12s 413ms/step - loss: 0.2964 - accuracy: 0.9300 - val_loss: 0.5551 - val_accuracy: 0.8900
#
# Epoch 00016: saving model to sloan_efficient/model-00016-0.30-0.93-0.56-0.89.h5
# Epoch 17/40
# 25/25 [==============================] - 12s 412ms/step - loss: 0.6405 - accuracy: 0.9112 - val_loss: 1.0853 - val_accuracy: 0.8100
#
# Epoch 00017: saving model to sloan_efficient/model-00017-0.64-0.91-1.09-0.81.h5
# Epoch 18/40
# 25/25 [==============================] - 12s 411ms/step - loss: 0.4521 - accuracy: 0.9337 - val_loss: 0.5142 - val_accuracy: 0.8650
#
# Epoch 00018: saving model to sloan_efficient/model-00018-0.45-0.93-0.51-0.87.h5
# Epoch 19/40
# 25/25 [==============================] - 12s 412ms/step - loss: 0.4397 - accuracy: 0.9100 - val_loss: 0.3790 - val_accuracy: 0.9050
#
# Epoch 00019: saving model to sloan_efficient/model-00019-0.44-0.91-0.38-0.90.h5
# Epoch 20/40
# 25/25 [==============================] - 12s 410ms/step - loss: 1.0898 - accuracy: 0.8800 - val_loss: 0.8417 - val_accuracy: 0.8450
#
# Epoch 00020: saving model to sloan_efficient/model-00020-1.09-0.88-0.84-0.85.h5
# Epoch 21/40
# 25/25 [==============================] - 12s 412ms/step - loss: 0.3354 - accuracy: 0.9287 - val_loss: 0.5623 - val_accuracy: 0.8850
#
# Epoch 00021: saving model to sloan_efficient/model-00021-0.34-0.93-0.56-0.88.h5
# Epoch 22/40
# 25/25 [==============================] - 12s 409ms/step - loss: 0.2893 - accuracy: 0.9463 - val_loss: 0.9992 - val_accuracy: 0.8100
#
# Epoch 00022: saving model to sloan_efficient/model-00022-0.29-0.95-1.00-0.81.h5
# Epoch 23/40
# 25/25 [==============================] - 12s 410ms/step - loss: 0.2615 - accuracy: 0.9425 - val_loss: 0.5122 - val_accuracy: 0.8750
#
# Epoch 00023: saving model to sloan_efficient/model-00023-0.26-0.94-0.51-0.88.h5
# Epoch 24/40
# 25/25 [==============================] - 12s 408ms/step - loss: 0.4458 - accuracy: 0.9287 - val_loss: 0.8689 - val_accuracy: 0.8400
#
# Epoch 00024: saving model to sloan_efficient/model-00024-0.45-0.93-0.87-0.84.h5
# Epoch 25/40
# 25/25 [==============================] - 12s 413ms/step - loss: 0.4495 - accuracy: 0.8963 - val_loss: 0.6520 - val_accuracy: 0.8850
#
# Epoch 00025: saving model to sloan_efficient/model-00025-0.45-0.90-0.65-0.88.h5
# Epoch 26/40
# 25/25 [==============================] - 12s 410ms/step - loss: 0.3850 - accuracy: 0.9100 - val_loss: 0.5956 - val_accuracy: 0.8750
#
# Epoch 00026: saving model to sloan_efficient/model-00026-0.39-0.91-0.60-0.88.h5
# Epoch 27/40
# 25/25 [==============================] - 12s 409ms/step - loss: 0.2653 - accuracy: 0.9500 - val_loss: 0.4806 - val_accuracy: 0.9100
#
# Epoch 00027: saving model to sloan_efficient/model-00027-0.27-0.95-0.48-0.91.h5
# Epoch 28/40
# 25/25 [==============================] - 12s 412ms/step - loss: 0.3277 - accuracy: 0.9488 - val_loss: 0.5349 - val_accuracy: 0.8900
#
# Epoch 00028: saving model to sloan_efficient/model-00028-0.33-0.95-0.53-0.89.h5
# Epoch 29/40
# 25/25 [==============================] - 12s 413ms/step - loss: 0.5526 - accuracy: 0.9112 - val_loss: 0.4884 - val_accuracy: 0.9050
#
# Epoch 00029: saving model to sloan_efficient/model-00029-0.55-0.91-0.49-0.90.h5
# Epoch 30/40
# 25/25 [==============================] - 12s 410ms/step - loss: 0.2490 - accuracy: 0.9513 - val_loss: 0.5473 - val_accuracy: 0.8900
#
# Epoch 00030: saving model to sloan_efficient/model-00030-0.25-0.95-0.55-0.89.h5
# Epoch 31/40
# 25/25 [==============================] - 12s 405ms/step - loss: 0.1470 - accuracy: 0.9675 - val_loss: 0.4781 - val_accuracy: 0.8800
#
# Epoch 00031: saving model to sloan_efficient/model-00031-0.15-0.97-0.48-0.88.h5
# Epoch 32/40
# 25/25 [==============================] - 12s 406ms/step - loss: 0.3049 - accuracy: 0.9413 - val_loss: 0.6567 - val_accuracy: 0.8800
#
# Epoch 00032: saving model to sloan_efficient/model-00032-0.30-0.94-0.66-0.88.h5
# Epoch 33/40
# 25/25 [==============================] - 12s 407ms/step - loss: 0.3239 - accuracy: 0.9200 - val_loss: 0.8404 - val_accuracy: 0.8150
#
# Epoch 00033: saving model to sloan_efficient/model-00033-0.32-0.92-0.84-0.81.h5
# Epoch 34/40
# 25/25 [==============================] - 12s 413ms/step - loss: 0.4812 - accuracy: 0.9050 - val_loss: 0.8232 - val_accuracy: 0.8300
#
# Epoch 00034: saving model to sloan_efficient/model-00034-0.48-0.90-0.82-0.83.h5
# Epoch 35/40
# 25/25 [==============================] - 12s 415ms/step - loss: 0.2189 - accuracy: 0.9538 - val_loss: 0.5368 - val_accuracy: 0.8750
#
# Epoch 00035: saving model to sloan_efficient/model-00035-0.22-0.95-0.54-0.88.h5
# Epoch 36/40
# 25/25 [==============================] - 12s 414ms/step - loss: 0.1343 - accuracy: 0.9663 - val_loss: 0.4748 - val_accuracy: 0.8900
#
# Epoch 00036: saving model to sloan_efficient/model-00036-0.13-0.97-0.47-0.89.h5
# Epoch 37/40
# 25/25 [==============================] - 12s 413ms/step - loss: 0.2208 - accuracy: 0.9550 - val_loss: 0.4861 - val_accuracy: 0.8850
#
# Epoch 00037: saving model to sloan_efficient/model-00037-0.22-0.95-0.49-0.88.h5
# Epoch 38/40
# 25/25 [==============================] - 12s 410ms/step - loss: 0.3121 - accuracy: 0.9200 - val_loss: 0.7820 - val_accuracy: 0.8450
#
# Epoch 00038: saving model to sloan_efficient/model-00038-0.31-0.92-0.78-0.85.h5
# Epoch 39/40
# 25/25 [==============================] - 12s 412ms/step - loss: 0.3083 - accuracy: 0.9500 - val_loss: 0.7334 - val_accuracy: 0.8500
#
# Epoch 00039: saving model to sloan_efficient/model-00039-0.31-0.95-0.73-0.85.h5
# Epoch 40/40
# 25/25 [==============================] - 12s 410ms/step - loss: 0.3106 - accuracy: 0.9388 - val_loss: 0.3978 - val_accuracy: 0.8900
#
# Epoch 00040: saving model to sloan_efficient/model-00040-0.31-0.94-0.40-0.89.h5

# %% [markdown]
# ##### efficient net scaled

# %%
effnet_model.fit(train_ds_scaled,validation_data=val_ds_scaled,epochs = 15, verbose = 1, workers = 3, class_weight = {0:1.13, 1:8.03, 2:1}, callbacks = callbacks_efficient)
# Out:
# Epoch 1/15
# 25/25 [==============================] - 11s 385ms/step - loss: 2.9410 - accuracy: 0.3512 - val_loss: 2.4867 - val_accuracy: 0.0850
#
# Epoch 00001: saving model to sloan_efficient/model-00001-2.94-0.35-2.49-0.09.h5
# Epoch 2/15
# 25/25 [==============================] - 11s 386ms/step - loss: 2.8590 - accuracy: 0.3450 - val_loss: 3.4268 - val_accuracy: 0.4350
#
# Epoch 00002: saving model to sloan_efficient/model-00002-2.86-0.34-3.43-0.44.h5
# Epoch 3/15
# 25/25 [==============================] - 11s 384ms/step - loss: 2.9926 - accuracy: 0.3837 - val_loss: 1.6872 - val_accuracy: 0.4350
#
# Epoch 00003: saving model to sloan_efficient/model-00003-2.99-0.38-1.69-0.44.h5
# Epoch 4/15
# 25/25 [==============================] - 11s 385ms/step - loss: 2.9290 - accuracy: 0.3038 - val_loss: 3.5419 - val_accuracy: 0.4350
#
# Epoch 00004: saving model to sloan_efficient/model-00004-2.93-0.30-3.54-0.44.h5
# Epoch 5/15
# 25/25 [==============================] - 11s 387ms/step - loss: 2.7024 - accuracy: 0.3587 - val_loss: 1.9658 - val_accuracy: 0.4350
#
# Epoch 00005: saving model to sloan_efficient/model-00005-2.70-0.36-1.97-0.44.h5
# Epoch 6/15
# 25/25 [==============================] - 11s 384ms/step - loss: 3.6927 - accuracy: 0.3325 - val_loss: 3.4290 - val_accuracy: 0.4350
#
# Epoch 00006: saving model to sloan_efficient/model-00006-3.69-0.33-3.43-0.44.h5
# Epoch 7/15
# 25/25 [==============================] - 11s 391ms/step - loss: 3.1259 - accuracy: 0.3363 - val_loss: 1.4424 - val_accuracy: 0.0850
#
# Epoch 00007: saving model to sloan_efficient/model-00007-3.13-0.34-1.44-0.09.h5
# Epoch 8/15
# 25/25 [==============================] - 11s 386ms/step - loss: 2.6113 - accuracy: 0.3537 - val_loss: 2.8427 - val_accuracy: 0.0850
#
# Epoch 00008: saving model to sloan_efficient/model-00008-2.61-0.35-2.84-0.09.h5
# Epoch 9/15
# 25/25 [==============================] - 11s 383ms/step - loss: 3.7332 - accuracy: 0.3225 - val_loss: 2.5268 - val_accuracy: 0.4350
#
# Epoch 00009: saving model to sloan_efficient/model-00009-3.73-0.32-2.53-0.44.h5
# Epoch 10/15
# 25/25 [==============================] - 11s 385ms/step - loss: 4.3983 - accuracy: 0.3537 - val_loss: 1.3035 - val_accuracy: 0.4800
#
# Epoch 00010: saving model to sloan_efficient/model-00010-4.40-0.35-1.30-0.48.h5
# Epoch 11/15
# 25/25 [==============================] - 11s 385ms/step - loss: 2.6491 - accuracy: 0.3613 - val_loss: 1.0311 - val_accuracy: 0.4350
#
# Epoch 00011: saving model to sloan_efficient/model-00011-2.65-0.36-1.03-0.44.h5
# Epoch 12/15
# 25/25 [==============================] - 11s 386ms/step - loss: 2.6564 - accuracy: 0.3200 - val_loss: 2.8895 - val_accuracy: 0.4350
#
# Epoch 00012: saving model to sloan_efficient/model-00012-2.66-0.32-2.89-0.44.h5
# Epoch 13/15
# 25/25 [==============================] - 11s 383ms/step - loss: 2.9000 - accuracy: 0.3663 - val_loss: 1.1074 - val_accuracy: 0.4350
#
# Epoch 00013: saving model to sloan_efficient/model-00013-2.90-0.37-1.11-0.44.h5
# Epoch 14/15
# 25/25 [==============================] - 11s 384ms/step - loss: 3.8596 - accuracy: 0.3237 - val_loss: 8.3361 - val_accuracy: 0.0850
#
# Epoch 00014: saving model to sloan_efficient/model-00014-3.86-0.32-8.34-0.09.h5
# Epoch 15/15
# 25/25 [==============================] - 11s 387ms/step - loss: 4.1768 - accuracy: 0.2937 - val_loss: 2.2875 - val_accuracy: 0.4350
#
# Epoch 00015: saving model to sloan_efficient/model-00015-4.18-0.29-2.29-0.44.h5

# %% [markdown]
# ##### Augmenation techniques

# %%
train_ds_flip = prepare_dataset(train_ds, flip= True)
train_ds_flip_rotate = prepare_dataset(train_ds, flip_rotate = True)
train_ds_crop_flip = prepare_dataset_crop(train_ds_cropped, crop_flip = True)
train_ds_crop_flip_rotate = prepare_dataset_crop(train_ds_cropped, crop_flip_rotate = True)
val_ds_normal_crop = prepare_dataset_normal_crop(val_ds_cropped, training = False)

efficient_unscaled_flip = load_model('./sloan_efficient/Effnet_unscaled-0.55-0.91-0.49-0.90.h5')
efficient_unscaled_flip_rotate = load_model('./sloan_efficient/Effnet_unscaled-0.55-0.91-0.49-0.90.h5') 
efficient_unscaled_crop_flip = load_model('./sloan_efficient/Effnet_unscaled-0.55-0.91-0.49-0.90.h5')
efficient_unscaled_crop_flip_rotate = load_model('./sloan_efficient/Effnet_unscaled-0.55-0.91-0.49-0.90.h5')

# %% [markdown]
# ##### Efficient unscaled flip

# %%
efficient_unscaled_flip.fit(train_ds_flip,validation_data=val_ds, epochs = 40, verbose = 1, workers = 3, class_weight = {0:1.13, 1:8.03, 2:1}, callbacks = callbacks_efficient)
# Out:
# Epoch 1/40
# 25/25 [==============================] - 17s 460ms/step - loss: 0.6751 - accuracy: 0.8675 - val_loss: 0.6340 - val_accuracy: 0.8800
#
# Epoch 00001: saving model to sloan_efficient/model-00001-0.68-0.8675-0.63-0.8800.h5
# Epoch 2/40
# 25/25 [==============================] - 12s 403ms/step - loss: 0.9782 - accuracy: 0.8537 - val_loss: 1.7031 - val_accuracy: 0.7750
#
# Epoch 00002: saving model to sloan_efficient/model-00002-0.98-0.8537-1.70-0.7750.h5
# Epoch 3/40
# 25/25 [==============================] - 11s 399ms/step - loss: 1.0983 - accuracy: 0.8487 - val_loss: 0.7066 - val_accuracy: 0.8900
#
# Epoch 00003: saving model to sloan_efficient/model-00003-1.10-0.8487-0.71-0.8900.h5
# Epoch 4/40
# 25/25 [==============================] - 12s 403ms/step - loss: 0.6836 - accuracy: 0.8825 - val_loss: 1.2376 - val_accuracy: 0.8050
#
# Epoch 00004: saving model to sloan_efficient/model-00004-0.68-0.8825-1.24-0.8050.h5
# Epoch 5/40
# 25/25 [==============================] - 12s 399ms/step - loss: 1.0654 - accuracy: 0.8525 - val_loss: 0.5853 - val_accuracy: 0.8950
#
# Epoch 00005: saving model to sloan_efficient/model-00005-1.07-0.8525-0.59-0.8950.h5
# Epoch 6/40
# 25/25 [==============================] - 12s 399ms/step - loss: 0.5642 - accuracy: 0.9050 - val_loss: 0.8356 - val_accuracy: 0.8600
#
# Epoch 00006: saving model to sloan_efficient/model-00006-0.56-0.9050-0.84-0.8600.h5
# Epoch 7/40
# 25/25 [==============================] - 11s 399ms/step - loss: 0.5534 - accuracy: 0.9150 - val_loss: 0.7510 - val_accuracy: 0.8850
#
# Epoch 00007: saving model to sloan_efficient/model-00007-0.55-0.9150-0.75-0.8850.h5
# Epoch 8/40
# 25/25 [==============================] - 12s 401ms/step - loss: 0.4626 - accuracy: 0.9287 - val_loss: 0.7767 - val_accuracy: 0.8600
#
# Epoch 00008: saving model to sloan_efficient/model-00008-0.46-0.9287-0.78-0.8600.h5
# Epoch 9/40
# 25/25 [==============================] - 12s 404ms/step - loss: 0.3877 - accuracy: 0.9137 - val_loss: 0.5906 - val_accuracy: 0.9000
#
# Epoch 00009: saving model to sloan_efficient/model-00009-0.39-0.9137-0.59-0.9000.h5
# Epoch 10/40
# 25/25 [==============================] - 11s 395ms/step - loss: 0.5216 - accuracy: 0.9038 - val_loss: 0.8226 - val_accuracy: 0.8750
#
# Epoch 00010: saving model to sloan_efficient/model-00010-0.52-0.9038-0.82-0.8750.h5
# Epoch 11/40
# 25/25 [==============================] - 11s 397ms/step - loss: 0.6211 - accuracy: 0.8888 - val_loss: 0.8570 - val_accuracy: 0.8400
#
# Epoch 00011: saving model to sloan_efficient/model-00011-0.62-0.8888-0.86-0.8400.h5
# Epoch 12/40
# 25/25 [==============================] - 11s 399ms/step - loss: 0.4599 - accuracy: 0.9112 - val_loss: 0.8109 - val_accuracy: 0.8550
#
# Epoch 00012: saving model to sloan_efficient/model-00012-0.46-0.9112-0.81-0.8550.h5
# Epoch 13/40
# 25/25 [==============================] - 12s 403ms/step - loss: 0.5100 - accuracy: 0.9062 - val_loss: 0.4535 - val_accuracy: 0.9100
#
# Epoch 00013: saving model to sloan_efficient/model-00013-0.51-0.9062-0.45-0.9100.h5
# Epoch 14/40
# 25/25 [==============================] - 12s 400ms/step - loss: 0.5039 - accuracy: 0.9162 - val_loss: 0.7500 - val_accuracy: 0.8700
#
# Epoch 00014: saving model to sloan_efficient/model-00014-0.50-0.9162-0.75-0.8700.h5
# Epoch 15/40
# 25/25 [==============================] - 12s 407ms/step - loss: 0.3772 - accuracy: 0.9237 - val_loss: 0.8759 - val_accuracy: 0.8500
#
# Epoch 00015: saving model to sloan_efficient/model-00015-0.38-0.9237-0.88-0.8500.h5
# Epoch 16/40
# 25/25 [==============================] - 12s 403ms/step - loss: 0.6046 - accuracy: 0.9100 - val_loss: 0.7634 - val_accuracy: 0.8600
#
# Epoch 00016: saving model to sloan_efficient/model-00016-0.60-0.9100-0.76-0.8600.h5
# Epoch 17/40
# 25/25 [==============================] - 12s 402ms/step - loss: 0.5986 - accuracy: 0.8988 - val_loss: 0.6458 - val_accuracy: 0.8750
#
# Epoch 00017: saving model to sloan_efficient/model-00017-0.60-0.8988-0.65-0.8750.h5
# Epoch 18/40
# 25/25 [==============================] - 12s 400ms/step - loss: 0.6106 - accuracy: 0.8975 - val_loss: 1.3363 - val_accuracy: 0.7750
#
# Epoch 00018: saving model to sloan_efficient/model-00018-0.61-0.8975-1.34-0.7750.h5
# Epoch 19/40
# 25/25 [==============================] - 12s 400ms/step - loss: 0.4881 - accuracy: 0.9000 - val_loss: 0.5717 - val_accuracy: 0.9000
#
# Epoch 00019: saving model to sloan_efficient/model-00019-0.49-0.9000-0.57-0.9000.h5
# Epoch 20/40
# 25/25 [==============================] - 12s 402ms/step - loss: 0.4332 - accuracy: 0.9400 - val_loss: 0.9745 - val_accuracy: 0.8450
#
# Epoch 00020: saving model to sloan_efficient/model-00020-0.43-0.9400-0.97-0.8450.h5
# Epoch 21/40
# 25/25 [==============================] - 12s 403ms/step - loss: 0.5506 - accuracy: 0.9038 - val_loss: 2.2163 - val_accuracy: 0.6600
#
# Epoch 00021: saving model to sloan_efficient/model-00021-0.55-0.9038-2.22-0.6600.h5
# Epoch 22/40
# 25/25 [==============================] - 11s 395ms/step - loss: 0.5475 - accuracy: 0.9025 - val_loss: 0.5358 - val_accuracy: 0.9050
#
# Epoch 00022: saving model to sloan_efficient/model-00022-0.55-0.9025-0.54-0.9050.h5
# Epoch 23/40
# 25/25 [==============================] - 12s 404ms/step - loss: 0.4805 - accuracy: 0.9087 - val_loss: 0.5656 - val_accuracy: 0.9100
#
# Epoch 00023: saving model to sloan_efficient/model-00023-0.48-0.9087-0.57-0.9100.h5
# Epoch 24/40
# 25/25 [==============================] - 12s 405ms/step - loss: 0.4215 - accuracy: 0.9237 - val_loss: 0.6484 - val_accuracy: 0.9000
#
# Epoch 00024: saving model to sloan_efficient/model-00024-0.42-0.9237-0.65-0.9000.h5
# Epoch 25/40
# 25/25 [==============================] - 12s 406ms/step - loss: 0.6930 - accuracy: 0.9038 - val_loss: 1.0951 - val_accuracy: 0.8050
#
# Epoch 00025: saving model to sloan_efficient/model-00025-0.69-0.9038-1.10-0.8050.h5
# Epoch 26/40
# 25/25 [==============================] - 12s 399ms/step - loss: 0.4060 - accuracy: 0.9212 - val_loss: 0.9108 - val_accuracy: 0.8200
#
# Epoch 00026: saving model to sloan_efficient/model-00026-0.41-0.9212-0.91-0.8200.h5
# Epoch 27/40
# 25/25 [==============================] - 12s 400ms/step - loss: 0.5576 - accuracy: 0.9112 - val_loss: 0.5270 - val_accuracy: 0.9000
#
# Epoch 00027: saving model to sloan_efficient/model-00027-0.56-0.9112-0.53-0.9000.h5
# Epoch 28/40
# 25/25 [==============================] - 12s 398ms/step - loss: 0.5943 - accuracy: 0.8963 - val_loss: 0.8524 - val_accuracy: 0.8750
#
# Epoch 00028: saving model to sloan_efficient/model-00028-0.59-0.8963-0.85-0.8750.h5
# Epoch 29/40
# 25/25 [==============================] - 12s 404ms/step - loss: 0.5030 - accuracy: 0.9287 - val_loss: 1.4037 - val_accuracy: 0.8000
#
# Epoch 00029: saving model to sloan_efficient/model-00029-0.50-0.9287-1.40-0.8000.h5
# Epoch 30/40
# 25/25 [==============================] - 12s 406ms/step - loss: 0.3988 - accuracy: 0.9262 - val_loss: 0.6513 - val_accuracy: 0.8650
#
# Epoch 00030: saving model to sloan_efficient/model-00030-0.40-0.9262-0.65-0.8650.h5
# Epoch 31/40
# 25/25 [==============================] - 12s 401ms/step - loss: 0.2886 - accuracy: 0.9300 - val_loss: 0.5313 - val_accuracy: 0.8800
#
# Epoch 00031: saving model to sloan_efficient/model-00031-0.29-0.9300-0.53-0.8800.h5
# Epoch 32/40
# 25/25 [==============================] - 12s 406ms/step - loss: 0.3331 - accuracy: 0.9362 - val_loss: 0.4356 - val_accuracy: 0.9150
#
# Epoch 00032: saving model to sloan_efficient/model-00032-0.33-0.9362-0.44-0.9150.h5
# Epoch 33/40
# 25/25 [==============================] - 12s 404ms/step - loss: 0.5486 - accuracy: 0.9125 - val_loss: 0.5001 - val_accuracy: 0.9150
#
# Epoch 00033: saving model to sloan_efficient/model-00033-0.55-0.9125-0.50-0.9150.h5
# Epoch 34/40
# 25/25 [==============================] - 12s 399ms/step - loss: 0.2489 - accuracy: 0.9413 - val_loss: 0.5097 - val_accuracy: 0.9100
#
# Epoch 00034: saving model to sloan_efficient/model-00034-0.25-0.9413-0.51-0.9100.h5
# Epoch 35/40
# 25/25 [==============================] - 12s 402ms/step - loss: 0.3620 - accuracy: 0.9413 - val_loss: 0.4285 - val_accuracy: 0.9300
#
# Epoch 00035: saving model to sloan_efficient/model-00035-0.36-0.9413-0.43-0.9300.h5
# Epoch 36/40
# 25/25 [==============================] - 12s 405ms/step - loss: 0.2813 - accuracy: 0.9438 - val_loss: 0.4427 - val_accuracy: 0.9200
#
# Epoch 00036: saving model to sloan_efficient/model-00036-0.28-0.9438-0.44-0.9200.h5
# Epoch 37/40
# 25/25 [==============================] - 12s 399ms/step - loss: 0.2059 - accuracy: 0.9475 - val_loss: 0.4623 - val_accuracy: 0.9200
#
# Epoch 00037: saving model to sloan_efficient/model-00037-0.21-0.9475-0.46-0.9200.h5
# Epoch 38/40
# 25/25 [==============================] - 12s 402ms/step - loss: 0.2019 - accuracy: 0.9550 - val_loss: 0.5329 - val_accuracy: 0.8900
#
# Epoch 00038: saving model to sloan_efficient/model-00038-0.20-0.9550-0.53-0.8900.h5
# Epoch 39/40
# 25/25 [==============================] - 12s 400ms/step - loss: 0.2742 - accuracy: 0.9400 - val_loss: 0.7010 - val_accuracy: 0.8650
#
# Epoch 00039: saving model to sloan_efficient/model-00039-0.27-0.9400-0.70-0.8650.h5
# Epoch 40/40
# 25/25 [==============================] - 12s 399ms/step - loss: 0.3185 - accuracy: 0.9300 - val_loss: 0.6101 - val_accuracy: 0.8800
#
# Epoch 00040: saving model to sloan_efficient/model-00040-0.32-0.9300-0.61-0.8800.h5

# %%
generate_graph(efficient_unscaled_flip)

# %% [markdown]
# ##### Efficient unscaled flip rotate

# %%
efficient_unscaled_flip_rotate.fit(train_ds_flip_rotate,validation_data=val_ds, epochs = 30, verbose = 1, workers = 3, class_weight = {0:1.13, 1:8.03, 2:1}, callbacks = callbacks_efficient)
# Out:
# Epoch 1/30
# 25/25 [==============================] - 22s 620ms/step - loss: 0.9538 - accuracy: 0.8550 - val_loss: 1.1315 - val_accuracy: 0.8000
#
# Epoch 00001: saving model to sloan_efficient/model-00001-0.95-0.8550-1.13-0.8000.h5
# Epoch 2/30
# 25/25 [==============================] - 16s 549ms/step - loss: 1.2355 - accuracy: 0.8388 - val_loss: 1.0797 - val_accuracy: 0.8100
#
# Epoch 00002: saving model to sloan_efficient/model-00002-1.24-0.8388-1.08-0.8100.h5
# Epoch 3/30
# 25/25 [==============================] - 16s 546ms/step - loss: 1.1761 - accuracy: 0.8712 - val_loss: 1.6337 - val_accuracy: 0.7500
#
# Epoch 00003: saving model to sloan_efficient/model-00003-1.18-0.8712-1.63-0.7500.h5
# Epoch 4/30
# 25/25 [==============================] - 16s 540ms/step - loss: 1.2402 - accuracy: 0.8175 - val_loss: 0.3579 - val_accuracy: 0.9200
#
# Epoch 00004: saving model to sloan_efficient/model-00004-1.24-0.8175-0.36-0.9200.h5
# Epoch 5/30
# 25/25 [==============================] - 16s 547ms/step - loss: 0.9378 - accuracy: 0.8838 - val_loss: 0.3704 - val_accuracy: 0.9200
#
# Epoch 00005: saving model to sloan_efficient/model-00005-0.94-0.8838-0.37-0.9200.h5
# Epoch 6/30
# 25/25 [==============================] - 16s 544ms/step - loss: 0.8697 - accuracy: 0.8675 - val_loss: 1.2397 - val_accuracy: 0.7800
#
# Epoch 00006: saving model to sloan_efficient/model-00006-0.87-0.8675-1.24-0.7800.h5
# Epoch 7/30
# 25/25 [==============================] - 16s 548ms/step - loss: 1.1433 - accuracy: 0.8413 - val_loss: 1.1502 - val_accuracy: 0.8000
#
# Epoch 00007: saving model to sloan_efficient/model-00007-1.14-0.8413-1.15-0.8000.h5
# Epoch 8/30
# 25/25 [==============================] - 16s 545ms/step - loss: 1.0593 - accuracy: 0.8500 - val_loss: 0.7349 - val_accuracy: 0.8900
#
# Epoch 00008: saving model to sloan_efficient/model-00008-1.06-0.8500-0.73-0.8900.h5
# Epoch 9/30
# 25/25 [==============================] - 16s 550ms/step - loss: 1.1285 - accuracy: 0.8487 - val_loss: 0.4836 - val_accuracy: 0.9150
#
# Epoch 00009: saving model to sloan_efficient/model-00009-1.13-0.8487-0.48-0.9150.h5
# Epoch 10/30
# 25/25 [==============================] - 16s 551ms/step - loss: 1.2357 - accuracy: 0.8487 - val_loss: 0.7274 - val_accuracy: 0.8700
#
# Epoch 00010: saving model to sloan_efficient/model-00010-1.24-0.8487-0.73-0.8700.h5
# Epoch 11/30
# 25/25 [==============================] - 16s 560ms/step - loss: 0.7544 - accuracy: 0.8950 - val_loss: 0.7558 - val_accuracy: 0.8500
#
# Epoch 00011: saving model to sloan_efficient/model-00011-0.75-0.8950-0.76-0.8500.h5
# Epoch 12/30
# 25/25 [==============================] - 16s 560ms/step - loss: 0.6411 - accuracy: 0.9025 - val_loss: 1.3325 - val_accuracy: 0.7700
#
# Epoch 00012: saving model to sloan_efficient/model-00012-0.64-0.9025-1.33-0.7700.h5
# Epoch 13/30
# 25/25 [==============================] - 16s 544ms/step - loss: 0.7164 - accuracy: 0.8850 - val_loss: 0.5936 - val_accuracy: 0.8900
#
# Epoch 00013: saving model to sloan_efficient/model-00013-0.72-0.8850-0.59-0.8900.h5
# Epoch 14/30
# 25/25 [==============================] - 16s 562ms/step - loss: 0.9746 - accuracy: 0.8838 - val_loss: 0.4683 - val_accuracy: 0.8950
#
# Epoch 00014: saving model to sloan_efficient/model-00014-0.97-0.8838-0.47-0.8950.h5
# Epoch 15/30
# 25/25 [==============================] - 16s 552ms/step - loss: 0.7800 - accuracy: 0.8763 - val_loss: 0.5249 - val_accuracy: 0.9100
#
# Epoch 00015: saving model to sloan_efficient/model-00015-0.78-0.8763-0.52-0.9100.h5
# Epoch 16/30
# 25/25 [==============================] - 16s 540ms/step - loss: 0.6313 - accuracy: 0.8975 - val_loss: 0.6747 - val_accuracy: 0.8200
#
# Epoch 00016: saving model to sloan_efficient/model-00016-0.63-0.8975-0.67-0.8200.h5
# Epoch 17/30
# 25/25 [==============================] - 16s 550ms/step - loss: 0.8015 - accuracy: 0.8712 - val_loss: 1.0830 - val_accuracy: 0.7950
#
# Epoch 00017: saving model to sloan_efficient/model-00017-0.80-0.8712-1.08-0.7950.h5
# Epoch 18/30
# 25/25 [==============================] - 16s 550ms/step - loss: 0.6735 - accuracy: 0.8838 - val_loss: 1.0788 - val_accuracy: 0.8300
#
# Epoch 00018: saving model to sloan_efficient/model-00018-0.67-0.8838-1.08-0.8300.h5
# Epoch 19/30
# 25/25 [==============================] - 16s 546ms/step - loss: 0.6079 - accuracy: 0.9000 - val_loss: 0.4215 - val_accuracy: 0.9000
#
# Epoch 00019: saving model to sloan_efficient/model-00019-0.61-0.9000-0.42-0.9000.h5
# Epoch 20/30
# 25/25 [==============================] - 16s 545ms/step - loss: 0.4136 - accuracy: 0.9150 - val_loss: 0.6590 - val_accuracy: 0.8550
#
# Epoch 00020: saving model to sloan_efficient/model-00020-0.41-0.9150-0.66-0.8550.h5
# Epoch 21/30
# 25/25 [==============================] - 16s 541ms/step - loss: 0.7657 - accuracy: 0.8800 - val_loss: 0.9977 - val_accuracy: 0.8200
#
# Epoch 00021: saving model to sloan_efficient/model-00021-0.77-0.8800-1.00-0.8200.h5
# Epoch 22/30
# 25/25 [==============================] - 16s 564ms/step - loss: 0.8826 - accuracy: 0.8788 - val_loss: 1.0514 - val_accuracy: 0.8250
#
# Epoch 00022: saving model to sloan_efficient/model-00022-0.88-0.8788-1.05-0.8250.h5
# Epoch 23/30
# 25/25 [==============================] - 16s 543ms/step - loss: 0.5763 - accuracy: 0.9150 - val_loss: 0.5071 - val_accuracy: 0.8850
#
# Epoch 00023: saving model to sloan_efficient/model-00023-0.58-0.9150-0.51-0.8850.h5
# Epoch 24/30
# 25/25 [==============================] - 16s 540ms/step - loss: 0.4191 - accuracy: 0.9137 - val_loss: 0.5824 - val_accuracy: 0.8950
#
# Epoch 00024: saving model to sloan_efficient/model-00024-0.42-0.9137-0.58-0.8950.h5
# Epoch 25/30
# 25/25 [==============================] - 17s 557ms/step - loss: 0.5399 - accuracy: 0.9237 - val_loss: 0.5178 - val_accuracy: 0.8900
#
# Epoch 00025: saving model to sloan_efficient/model-00025-0.54-0.9237-0.52-0.8900.h5
# Epoch 26/30
# 25/25 [==============================] - 16s 543ms/step - loss: 0.5475 - accuracy: 0.9112 - val_loss: 0.5339 - val_accuracy: 0.8900
#
# Epoch 00026: saving model to sloan_efficient/model-00026-0.55-0.9112-0.53-0.8900.h5
# Epoch 27/30
# 25/25 [==============================] - 16s 555ms/step - loss: 0.7884 - accuracy: 0.8838 - val_loss: 0.5564 - val_accuracy: 0.8900
#
# Epoch 00027: saving model to sloan_efficient/model-00027-0.79-0.8838-0.56-0.8900.h5
# Epoch 28/30
# 25/25 [==============================] - 16s 553ms/step - loss: 0.6512 - accuracy: 0.9087 - val_loss: 0.6877 - val_accuracy: 0.8300
#
# Epoch 00028: saving model to sloan_efficient/model-00028-0.65-0.9087-0.69-0.8300.h5
# Epoch 29/30
# 25/25 [==============================] - 16s 552ms/step - loss: 0.7695 - accuracy: 0.8763 - val_loss: 0.7254 - val_accuracy: 0.8900
#
# Epoch 00029: saving model to sloan_efficient/model-00029-0.77-0.8763-0.73-0.8900.h5
# Epoch 30/30
# 25/25 [==============================] - 16s 554ms/step - loss: 0.4847 - accuracy: 0.9175 - val_loss: 0.7547 - val_accuracy: 0.8750
#
# Epoch 00030: saving model to sloan_efficient/model-00030-0.48-0.9175-0.75-0.8750.h5

# %% [markdown]
# ##### Efficient unscaled crop flip

# %%
efficient_unscaled_crop_flip.fit(train_ds_crop_flip,validation_data=val_ds_normal_crop, epochs = 30, verbose = 1, workers = 3, class_weight = {0:1.13, 1:8.03, 2:1}, callbacks = callbacks_efficient)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/30
# 25/25 [==============================] - 151s 4s/step - loss: 4.0241 - accuracy: 0.6687 - val_loss: 1.4895 - val_accuracy: 0.8350
#
# Epoch 00001: saving model to sloan_efficient/model-00001-4.02-0.6687-1.49-0.8350.h5
# Epoch 2/30
# 25/25 [==============================] - 20s 669ms/step - loss: 3.2663 - accuracy: 0.7063 - val_loss: 0.5659 - val_accuracy: 0.9100
#
# Epoch 00002: saving model to sloan_efficient/model-00002-3.27-0.7063-0.57-0.9100.h5
# Epoch 3/30
# 25/25 [==============================] - 20s 670ms/step - loss: 2.1248 - accuracy: 0.7675 - val_loss: 1.5306 - val_accuracy: 0.7850
#
# Epoch 00003: saving model to sloan_efficient/model-00003-2.12-0.7675-1.53-0.7850.h5
# Epoch 4/30
# 25/25 [==============================] - 20s 659ms/step - loss: 2.2764 - accuracy: 0.7763 - val_loss: 1.1234 - val_accuracy: 0.8300
#
# Epoch 00004: saving model to sloan_efficient/model-00004-2.28-0.7763-1.12-0.8300.h5
# Epoch 5/30
# 25/25 [==============================] - 20s 665ms/step - loss: 1.6005 - accuracy: 0.8225 - val_loss: 0.7349 - val_accuracy: 0.8850
#
# Epoch 00005: saving model to sloan_efficient/model-00005-1.60-0.8225-0.73-0.8850.h5
# Epoch 6/30
# 25/25 [==============================] - 20s 658ms/step - loss: 1.3552 - accuracy: 0.8600 - val_loss: 1.1492 - val_accuracy: 0.8000
#
# Epoch 00006: saving model to sloan_efficient/model-00006-1.36-0.8600-1.15-0.8000.h5
# Epoch 7/30
# 25/25 [==============================] - 20s 661ms/step - loss: 1.1833 - accuracy: 0.8300 - val_loss: 0.9155 - val_accuracy: 0.8500
#
# Epoch 00007: saving model to sloan_efficient/model-00007-1.18-0.8300-0.92-0.8500.h5
# Epoch 8/30
# 25/25 [==============================] - 20s 666ms/step - loss: 1.8841 - accuracy: 0.8175 - val_loss: 2.6979 - val_accuracy: 0.6800
#
# Epoch 00008: saving model to sloan_efficient/model-00008-1.88-0.8175-2.70-0.6800.h5
# Epoch 9/30
# 25/25 [==============================] - 20s 654ms/step - loss: 1.1959 - accuracy: 0.8587 - val_loss: 1.8881 - val_accuracy: 0.7350
#
# Epoch 00009: saving model to sloan_efficient/model-00009-1.20-0.8587-1.89-0.7350.h5
# Epoch 10/30
# 25/25 [==============================] - 20s 668ms/step - loss: 1.3552 - accuracy: 0.8175 - val_loss: 1.5625 - val_accuracy: 0.7800
#
# Epoch 00010: saving model to sloan_efficient/model-00010-1.36-0.8175-1.56-0.7800.h5
# Epoch 11/30
# 25/25 [==============================] - 20s 656ms/step - loss: 1.7966 - accuracy: 0.8400 - val_loss: 3.0996 - val_accuracy: 0.6500
#
# Epoch 00011: saving model to sloan_efficient/model-00011-1.80-0.8400-3.10-0.6500.h5
# Epoch 12/30
# 25/25 [==============================] - 20s 661ms/step - loss: 1.4978 - accuracy: 0.8138 - val_loss: 0.7370 - val_accuracy: 0.8650
#
# Epoch 00012: saving model to sloan_efficient/model-00012-1.50-0.8138-0.74-0.8650.h5
# Epoch 13/30
# 25/25 [==============================] - 20s 666ms/step - loss: 1.0537 - accuracy: 0.8475 - val_loss: 1.4138 - val_accuracy: 0.7900
#
# Epoch 00013: saving model to sloan_efficient/model-00013-1.05-0.8475-1.41-0.7900.h5
# Epoch 14/30
# 25/25 [==============================] - 20s 664ms/step - loss: 0.6843 - accuracy: 0.8788 - val_loss: 0.6878 - val_accuracy: 0.8600
#
# Epoch 00014: saving model to sloan_efficient/model-00014-0.68-0.8788-0.69-0.8600.h5
# Epoch 15/30
# 25/25 [==============================] - 20s 661ms/step - loss: 0.8944 - accuracy: 0.8825 - val_loss: 1.4364 - val_accuracy: 0.7850
#
# Epoch 00015: saving model to sloan_efficient/model-00015-0.89-0.8825-1.44-0.7850.h5
# Epoch 16/30
# 25/25 [==============================] - 20s 661ms/step - loss: 0.9344 - accuracy: 0.8775 - val_loss: 0.4184 - val_accuracy: 0.9450
#
# Epoch 00016: saving model to sloan_efficient/model-00016-0.93-0.8775-0.42-0.9450.h5
# Epoch 17/30
# 25/25 [==============================] - 20s 663ms/step - loss: 1.1973 - accuracy: 0.8637 - val_loss: 0.5272 - val_accuracy: 0.9200
#
# Epoch 00017: saving model to sloan_efficient/model-00017-1.20-0.8637-0.53-0.9200.h5
# Epoch 18/30
# 25/25 [==============================] - 20s 663ms/step - loss: 0.8506 - accuracy: 0.8725 - val_loss: 0.7878 - val_accuracy: 0.8650
#
# Epoch 00018: saving model to sloan_efficient/model-00018-0.85-0.8725-0.79-0.8650.h5
# Epoch 19/30
# 25/25 [==============================] - 20s 655ms/step - loss: 0.7328 - accuracy: 0.8788 - val_loss: 0.3767 - val_accuracy: 0.9250
#
# Epoch 00019: saving model to sloan_efficient/model-00019-0.73-0.8788-0.38-0.9250.h5
# Epoch 20/30
# 25/25 [==============================] - 20s 658ms/step - loss: 0.6118 - accuracy: 0.9175 - val_loss: 0.4952 - val_accuracy: 0.9250
#
# Epoch 00020: saving model to sloan_efficient/model-00020-0.61-0.9175-0.50-0.9250.h5
# Epoch 21/30
# 25/25 [==============================] - 20s 666ms/step - loss: 0.7260 - accuracy: 0.8438 - val_loss: 0.9029 - val_accuracy: 0.8400
#
# Epoch 00021: saving model to sloan_efficient/model-00021-0.73-0.8438-0.90-0.8400.h5
# Epoch 22/30
# 25/25 [==============================] - 20s 659ms/step - loss: 0.7753 - accuracy: 0.8687 - val_loss: 0.4882 - val_accuracy: 0.9300
#
# Epoch 00022: saving model to sloan_efficient/model-00022-0.78-0.8687-0.49-0.9300.h5
# Epoch 23/30
# 25/25 [==============================] - 20s 664ms/step - loss: 0.6265 - accuracy: 0.8913 - val_loss: 0.4961 - val_accuracy: 0.9250
#
# Epoch 00023: saving model to sloan_efficient/model-00023-0.63-0.8913-0.50-0.9250.h5
# Epoch 24/30
# 25/25 [==============================] - 20s 663ms/step - loss: 0.7605 - accuracy: 0.8888 - val_loss: 1.0604 - val_accuracy: 0.8500
#
# Epoch 00024: saving model to sloan_efficient/model-00024-0.76-0.8888-1.06-0.8500.h5
# Epoch 25/30
# 25/25 [==============================] - 20s 669ms/step - loss: 1.4232 - accuracy: 0.8300 - val_loss: 1.4579 - val_accuracy: 0.7700
#
# Epoch 00025: saving model to sloan_efficient/model-00025-1.42-0.8300-1.46-0.7700.h5
# Epoch 26/30
# 25/25 [==============================] - 20s 668ms/step - loss: 1.1260 - accuracy: 0.8587 - val_loss: 0.4950 - val_accuracy: 0.9200
#
# Epoch 00026: saving model to sloan_efficient/model-00026-1.13-0.8587-0.50-0.9200.h5
# Epoch 27/30
# 25/25 [==============================] - 20s 665ms/step - loss: 1.1033 - accuracy: 0.8775 - val_loss: 0.7476 - val_accuracy: 0.9000
#
# Epoch 00027: saving model to sloan_efficient/model-00027-1.10-0.8775-0.75-0.9000.h5
# Epoch 28/30
# 25/25 [==============================] - 20s 656ms/step - loss: 0.5332 - accuracy: 0.9025 - val_loss: 0.4947 - val_accuracy: 0.9050
#
# Epoch 00028: saving model to sloan_efficient/model-00028-0.53-0.9025-0.49-0.9050.h5
# Epoch 29/30
# 25/25 [==============================] - 20s 664ms/step - loss: 0.6492 - accuracy: 0.8913 - val_loss: 0.9380 - val_accuracy: 0.8500
#
# Epoch 00029: saving model to sloan_efficient/model-00029-0.65-0.8913-0.94-0.8500.h5
# Epoch 30/30
# 25/25 [==============================] - 20s 664ms/step - loss: 0.5830 - accuracy: 0.8825 - val_loss: 0.5712 - val_accuracy: 0.8950
#
# Epoch 00030: saving model to sloan_efficient/model-00030-0.58-0.8825-0.57-0.8950.h5

# %% [markdown]
# ##### Efficient unscaled crop flip rotate

# %%
efficient_unscaled_crop_flip_rotate.fit(train_ds_crop_flip_rotate,validation_data=val_ds_normal_crop, epochs = 30, verbose = 1, workers = 3, class_weight = {0:1.13, 1:8.03, 2:1}, callbacks = callbacks_efficient)
# Out:
# Epoch 1/30
# 25/25 [==============================] - 33s 946ms/step - loss: 3.0900 - accuracy: 0.6450 - val_loss: 3.1085 - val_accuracy: 0.5600
#
# Epoch 00001: saving model to sloan_efficient/model-00001-3.09-0.6450-3.11-0.5600.h5
# Epoch 2/30
# 25/25 [==============================] - 26s 873ms/step - loss: 2.5834 - accuracy: 0.7212 - val_loss: 3.5645 - val_accuracy: 0.4400
#
# Epoch 00002: saving model to sloan_efficient/model-00002-2.58-0.7212-3.56-0.4400.h5
# Epoch 3/30
# 25/25 [==============================] - 26s 863ms/step - loss: 3.4907 - accuracy: 0.7337 - val_loss: 2.3470 - val_accuracy: 0.6850
#
# Epoch 00003: saving model to sloan_efficient/model-00003-3.49-0.7337-2.35-0.6850.h5
# Epoch 4/30
# 25/25 [==============================] - 26s 874ms/step - loss: 3.1626 - accuracy: 0.7525 - val_loss: 4.0332 - val_accuracy: 0.5850
#
# Epoch 00004: saving model to sloan_efficient/model-00004-3.16-0.7525-4.03-0.5850.h5
# Epoch 5/30
# 25/25 [==============================] - 26s 866ms/step - loss: 3.3598 - accuracy: 0.7638 - val_loss: 1.3743 - val_accuracy: 0.7700
#
# Epoch 00005: saving model to sloan_efficient/model-00005-3.36-0.7638-1.37-0.7700.h5
# Epoch 6/30
# 25/25 [==============================] - 26s 877ms/step - loss: 1.7581 - accuracy: 0.7975 - val_loss: 1.7802 - val_accuracy: 0.7600
#
# Epoch 00006: saving model to sloan_efficient/model-00006-1.76-0.7975-1.78-0.7600.h5
# Epoch 7/30
# 25/25 [==============================] - 26s 873ms/step - loss: 1.7511 - accuracy: 0.8175 - val_loss: 1.0969 - val_accuracy: 0.8200
#
# Epoch 00007: saving model to sloan_efficient/model-00007-1.75-0.8175-1.10-0.8200.h5
# Epoch 8/30
# 25/25 [==============================] - 26s 872ms/step - loss: 1.2017 - accuracy: 0.8425 - val_loss: 1.2154 - val_accuracy: 0.8200
#
# Epoch 00008: saving model to sloan_efficient/model-00008-1.20-0.8425-1.22-0.8200.h5
# Epoch 9/30
# 25/25 [==============================] - 26s 873ms/step - loss: 1.0433 - accuracy: 0.8450 - val_loss: 0.4952 - val_accuracy: 0.9200
#
# Epoch 00009: saving model to sloan_efficient/model-00009-1.04-0.8450-0.50-0.9200.h5
# Epoch 10/30
# 25/25 [==============================] - 26s 864ms/step - loss: 1.0774 - accuracy: 0.8712 - val_loss: 0.7753 - val_accuracy: 0.8250
#
# Epoch 00010: saving model to sloan_efficient/model-00010-1.08-0.8712-0.78-0.8250.h5
# Epoch 11/30
# 25/25 [==============================] - 26s 873ms/step - loss: 0.9421 - accuracy: 0.8462 - val_loss: 0.4824 - val_accuracy: 0.9300
#
# Epoch 00011: saving model to sloan_efficient/model-00011-0.94-0.8462-0.48-0.9300.h5
# Epoch 12/30
# 25/25 [==============================] - 26s 857ms/step - loss: 1.0199 - accuracy: 0.8550 - val_loss: 0.6007 - val_accuracy: 0.8800
#
# Epoch 00012: saving model to sloan_efficient/model-00012-1.02-0.8550-0.60-0.8800.h5
# Epoch 13/30
# 25/25 [==============================] - 26s 869ms/step - loss: 1.4513 - accuracy: 0.8175 - val_loss: 2.1738 - val_accuracy: 0.7000
#
# Epoch 00013: saving model to sloan_efficient/model-00013-1.45-0.8175-2.17-0.7000.h5
# Epoch 14/30
# 25/25 [==============================] - 26s 877ms/step - loss: 2.2262 - accuracy: 0.8163 - val_loss: 1.2707 - val_accuracy: 0.8050
#
# Epoch 00014: saving model to sloan_efficient/model-00014-2.23-0.8163-1.27-0.8050.h5
# Epoch 15/30
# 25/25 [==============================] - 26s 864ms/step - loss: 1.1609 - accuracy: 0.8425 - val_loss: 0.5840 - val_accuracy: 0.9000
#
# Epoch 00015: saving model to sloan_efficient/model-00015-1.16-0.8425-0.58-0.9000.h5
# Epoch 16/30
# 25/25 [==============================] - 26s 874ms/step - loss: 0.8667 - accuracy: 0.8550 - val_loss: 1.3689 - val_accuracy: 0.7550
#
# Epoch 00016: saving model to sloan_efficient/model-00016-0.87-0.8550-1.37-0.7550.h5
# Epoch 17/30
# 25/25 [==============================] - 26s 873ms/step - loss: 1.2588 - accuracy: 0.8462 - val_loss: 1.0027 - val_accuracy: 0.8000
#
# Epoch 00017: saving model to sloan_efficient/model-00017-1.26-0.8462-1.00-0.8000.h5
# Epoch 18/30
# 25/25 [==============================] - 26s 860ms/step - loss: 1.0072 - accuracy: 0.8537 - val_loss: 1.7070 - val_accuracy: 0.7200
#
# Epoch 00018: saving model to sloan_efficient/model-00018-1.01-0.8537-1.71-0.7200.h5
# Epoch 19/30
# 25/25 [==============================] - 26s 871ms/step - loss: 1.1735 - accuracy: 0.8375 - val_loss: 1.8657 - val_accuracy: 0.7300
#
# Epoch 00019: saving model to sloan_efficient/model-00019-1.17-0.8375-1.87-0.7300.h5
# Epoch 20/30
# 25/25 [==============================] - 26s 863ms/step - loss: 1.2939 - accuracy: 0.8425 - val_loss: 0.6516 - val_accuracy: 0.9100
#
# Epoch 00020: saving model to sloan_efficient/model-00020-1.29-0.8425-0.65-0.9100.h5
# Epoch 21/30
# 25/25 [==============================] - 26s 867ms/step - loss: 1.4352 - accuracy: 0.8263 - val_loss: 1.3795 - val_accuracy: 0.7650
#
# Epoch 00021: saving model to sloan_efficient/model-00021-1.44-0.8263-1.38-0.7650.h5
# Epoch 22/30
# 25/25 [==============================] - 26s 866ms/step - loss: 1.3320 - accuracy: 0.8250 - val_loss: 1.9850 - val_accuracy: 0.7350
#
# Epoch 00022: saving model to sloan_efficient/model-00022-1.33-0.8250-1.98-0.7350.h5
# Epoch 23/30
# 25/25 [==============================] - 26s 865ms/step - loss: 0.9598 - accuracy: 0.8587 - val_loss: 0.9629 - val_accuracy: 0.8300
#
# Epoch 00023: saving model to sloan_efficient/model-00023-0.96-0.8587-0.96-0.8300.h5
# Epoch 24/30
# 25/25 [==============================] - 26s 880ms/step - loss: 1.0137 - accuracy: 0.8562 - val_loss: 0.5754 - val_accuracy: 0.9150
#
# Epoch 00024: saving model to sloan_efficient/model-00024-1.01-0.8562-0.58-0.9150.h5
# Epoch 25/30
# 25/25 [==============================] - 26s 864ms/step - loss: 0.9063 - accuracy: 0.8775 - val_loss: 0.8277 - val_accuracy: 0.8350
#
# Epoch 00025: saving model to sloan_efficient/model-00025-0.91-0.8775-0.83-0.8350.h5
# Epoch 26/30
# 25/25 [==============================] - 26s 862ms/step - loss: 0.9162 - accuracy: 0.8600 - val_loss: 0.6198 - val_accuracy: 0.9000
#
# Epoch 00026: saving model to sloan_efficient/model-00026-0.92-0.8600-0.62-0.9000.h5
# Epoch 27/30
# 25/25 [==============================] - 26s 865ms/step - loss: 0.9732 - accuracy: 0.8700 - val_loss: 2.1937 - val_accuracy: 0.7500
#
# Epoch 00027: saving model to sloan_efficient/model-00027-0.97-0.8700-2.19-0.7500.h5
# Epoch 28/30
# 25/25 [==============================] - 26s 874ms/step - loss: 1.4744 - accuracy: 0.8400 - val_loss: 1.6132 - val_accuracy: 0.8050
#
# Epoch 00028: saving model to sloan_efficient/model-00028-1.47-0.8400-1.61-0.8050.h5
# Epoch 29/30
# 25/25 [==============================] - 26s 869ms/step - loss: 0.9535 - accuracy: 0.8537 - val_loss: 1.4922 - val_accuracy: 0.7650
#
# Epoch 00029: saving model to sloan_efficient/model-00029-0.95-0.8537-1.49-0.7650.h5
# Epoch 30/30
# 25/25 [==============================] - 26s 875ms/step - loss: 0.7104 - accuracy: 0.8900 - val_loss: 0.7182 - val_accuracy: 0.8650
#
# Epoch 00030: saving model to sloan_efficient/model-00030-0.71-0.8900-0.72-0.8650.h5

# %% [markdown]
# ##### Efficient net preprocess crop

# %%
train_ds_normal_crop = prepare_dataset_normal_crop(train_ds_cropped) 
val_ds_normal_crop = prepare_dataset_normal_crop(val_ds_cropped, training = False)
effnet_model.fit(train_ds_normal_crop, validation_data = val_ds_normal_crop, epochs = 40, verbose = 1, workers = 3, class_weight = {0:1.13, 1:8.03, 2:1}, callbacks = callbacks_efficient)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/40
# 25/25 [==============================] - 31s 630ms/step - loss: 13.2921 - accuracy: 0.4325 - val_loss: 0.9010 - val_accuracy: 0.6200
#
# Epoch 00001: saving model to sloan_efficient/model-00001-13.29-0.4325-0.90-0.6200.h5
# Epoch 2/40
# 25/25 [==============================] - 18s 598ms/step - loss: 2.4853 - accuracy: 0.6400 - val_loss: 0.7998 - val_accuracy: 0.6400
#
# Epoch 00002: saving model to sloan_efficient/model-00002-2.49-0.6400-0.80-0.6400.h5
# Epoch 3/40
# 25/25 [==============================] - 18s 594ms/step - loss: 1.4679 - accuracy: 0.7538 - val_loss: 1.4077 - val_accuracy: 0.6000
#
# Epoch 00003: saving model to sloan_efficient/model-00003-1.47-0.7538-1.41-0.6000.h5
# Epoch 4/40
# 25/25 [==============================] - 18s 597ms/step - loss: 1.2738 - accuracy: 0.7600 - val_loss: 1.0891 - val_accuracy: 0.6350
#
# Epoch 00004: saving model to sloan_efficient/model-00004-1.27-0.7600-1.09-0.6350.h5
# Epoch 5/40
# 25/25 [==============================] - 18s 597ms/step - loss: 1.4671 - accuracy: 0.7538 - val_loss: 0.6573 - val_accuracy: 0.7200
#
# Epoch 00005: saving model to sloan_efficient/model-00005-1.47-0.7538-0.66-0.7200.h5
# Epoch 6/40
# 25/25 [==============================] - 18s 596ms/step - loss: 1.5393 - accuracy: 0.7625 - val_loss: 1.7398 - val_accuracy: 0.5350
#
# Epoch 00006: saving model to sloan_efficient/model-00006-1.54-0.7625-1.74-0.5350.h5
# Epoch 7/40
# 25/25 [==============================] - 18s 594ms/step - loss: 1.2111 - accuracy: 0.7800 - val_loss: 0.4222 - val_accuracy: 0.8250
#
# Epoch 00007: saving model to sloan_efficient/model-00007-1.21-0.7800-0.42-0.8250.h5
# Epoch 8/40
# 25/25 [==============================] - 18s 594ms/step - loss: 1.2929 - accuracy: 0.8112 - val_loss: 2.6024 - val_accuracy: 0.5100
#
# Epoch 00008: saving model to sloan_efficient/model-00008-1.29-0.8112-2.60-0.5100.h5
# Epoch 9/40
# 25/25 [==============================] - 18s 594ms/step - loss: 1.3635 - accuracy: 0.7613 - val_loss: 0.4750 - val_accuracy: 0.8500
#
# Epoch 00009: saving model to sloan_efficient/model-00009-1.36-0.7613-0.47-0.8500.h5
# Epoch 10/40
# 25/25 [==============================] - 18s 594ms/step - loss: 1.8627 - accuracy: 0.7738 - val_loss: 0.5847 - val_accuracy: 0.8050
#
# Epoch 00010: saving model to sloan_efficient/model-00010-1.86-0.7738-0.58-0.8050.h5
# Epoch 11/40
# 25/25 [==============================] - 18s 596ms/step - loss: 2.6063 - accuracy: 0.7538 - val_loss: 0.6288 - val_accuracy: 0.8400
#
# Epoch 00011: saving model to sloan_efficient/model-00011-2.61-0.7538-0.63-0.8400.h5
# Epoch 12/40
# 25/25 [==============================] - 18s 595ms/step - loss: 2.0319 - accuracy: 0.6913 - val_loss: 0.6367 - val_accuracy: 0.8300
#
# Epoch 00012: saving model to sloan_efficient/model-00012-2.03-0.6913-0.64-0.8300.h5
# Epoch 13/40
# 25/25 [==============================] - 18s 598ms/step - loss: 2.1426 - accuracy: 0.7675 - val_loss: 3.0366 - val_accuracy: 0.6250
#
# Epoch 00013: saving model to sloan_efficient/model-00013-2.14-0.7675-3.04-0.6250.h5
# Epoch 14/40
# 25/25 [==============================] - 18s 594ms/step - loss: 1.8933 - accuracy: 0.7862 - val_loss: 3.3950 - val_accuracy: 0.4150
#
# Epoch 00014: saving model to sloan_efficient/model-00014-1.89-0.7862-3.40-0.4150.h5
# Epoch 15/40
# 25/25 [==============================] - 18s 594ms/step - loss: 1.3538 - accuracy: 0.8025 - val_loss: 1.6915 - val_accuracy: 0.6950
#
# Epoch 00015: saving model to sloan_efficient/model-00015-1.35-0.8025-1.69-0.6950.h5
# Epoch 16/40
# 25/25 [==============================] - 18s 597ms/step - loss: 0.9016 - accuracy: 0.8587 - val_loss: 2.8916 - val_accuracy: 0.5650
#
# Epoch 00016: saving model to sloan_efficient/model-00016-0.90-0.8587-2.89-0.5650.h5
# Epoch 17/40
# 25/25 [==============================] - 18s 596ms/step - loss: 0.8200 - accuracy: 0.8388 - val_loss: 0.4906 - val_accuracy: 0.8700
#
# Epoch 00017: saving model to sloan_efficient/model-00017-0.82-0.8388-0.49-0.8700.h5
# Epoch 18/40
# 25/25 [==============================] - 18s 594ms/step - loss: 0.8847 - accuracy: 0.8537 - val_loss: 0.3979 - val_accuracy: 0.9150
#
# Epoch 00018: saving model to sloan_efficient/model-00018-0.88-0.8537-0.40-0.9150.h5
# Epoch 19/40
# 25/25 [==============================] - 18s 592ms/step - loss: 1.6715 - accuracy: 0.7937 - val_loss: 1.1323 - val_accuracy: 0.7950
#
# Epoch 00019: saving model to sloan_efficient/model-00019-1.67-0.7937-1.13-0.7950.h5
# Epoch 20/40
# 25/25 [==============================] - 18s 599ms/step - loss: 1.0689 - accuracy: 0.8250 - val_loss: 1.2760 - val_accuracy: 0.7750
#
# Epoch 00020: saving model to sloan_efficient/model-00020-1.07-0.8250-1.28-0.7750.h5
# Epoch 21/40
# 25/25 [==============================] - 18s 595ms/step - loss: 1.0098 - accuracy: 0.8712 - val_loss: 1.1703 - val_accuracy: 0.7800
#
# Epoch 00021: saving model to sloan_efficient/model-00021-1.01-0.8712-1.17-0.7800.h5
# Epoch 22/40
# 25/25 [==============================] - 18s 591ms/step - loss: 0.9664 - accuracy: 0.8325 - val_loss: 0.5093 - val_accuracy: 0.8650
#
# Epoch 00022: saving model to sloan_efficient/model-00022-0.97-0.8325-0.51-0.8650.h5
# Epoch 23/40
# 25/25 [==============================] - 18s 597ms/step - loss: 0.7108 - accuracy: 0.8662 - val_loss: 1.0338 - val_accuracy: 0.8150
#
# Epoch 00023: saving model to sloan_efficient/model-00023-0.71-0.8662-1.03-0.8150.h5
# Epoch 24/40
# 25/25 [==============================] - 18s 597ms/step - loss: 0.6589 - accuracy: 0.8788 - val_loss: 1.0737 - val_accuracy: 0.7950
#
# Epoch 00024: saving model to sloan_efficient/model-00024-0.66-0.8788-1.07-0.7950.h5
# Epoch 25/40
# 25/25 [==============================] - 18s 599ms/step - loss: 0.8740 - accuracy: 0.8537 - val_loss: 0.8231 - val_accuracy: 0.8050
#
# Epoch 00025: saving model to sloan_efficient/model-00025-0.87-0.8537-0.82-0.8050.h5
# Epoch 26/40
# 25/25 [==============================] - 18s 596ms/step - loss: 0.7608 - accuracy: 0.8763 - val_loss: 0.9923 - val_accuracy: 0.7850
#
# Epoch 00026: saving model to sloan_efficient/model-00026-0.76-0.8763-0.99-0.7850.h5
# Epoch 27/40
# 25/25 [==============================] - 18s 592ms/step - loss: 0.5691 - accuracy: 0.8850 - val_loss: 0.6182 - val_accuracy: 0.8450
#
# Epoch 00027: saving model to sloan_efficient/model-00027-0.57-0.8850-0.62-0.8450.h5
# Epoch 28/40
# 25/25 [==============================] - 18s 596ms/step - loss: 0.6680 - accuracy: 0.8700 - val_loss: 1.1739 - val_accuracy: 0.7700
#
# Epoch 00028: saving model to sloan_efficient/model-00028-0.67-0.8700-1.17-0.7700.h5
# Epoch 29/40
# 25/25 [==============================] - 18s 599ms/step - loss: 0.7434 - accuracy: 0.8687 - val_loss: 1.3760 - val_accuracy: 0.7050
#
# Epoch 00029: saving model to sloan_efficient/model-00029-0.74-0.8687-1.38-0.7050.h5
# Epoch 30/40
# 25/25 [==============================] - 18s 597ms/step - loss: 0.6471 - accuracy: 0.8825 - val_loss: 0.4031 - val_accuracy: 0.9200
#
# Epoch 00030: saving model to sloan_efficient/model-00030-0.65-0.8825-0.40-0.9200.h5
# Epoch 31/40
# 25/25 [==============================] - 18s 596ms/step - loss: 0.6170 - accuracy: 0.8800 - val_loss: 1.9462 - val_accuracy: 0.6950
#
# Epoch 00031: saving model to sloan_efficient/model-00031-0.62-0.8800-1.95-0.6950.h5
# Epoch 32/40
# 25/25 [==============================] - 18s 595ms/step - loss: 0.4651 - accuracy: 0.9200 - val_loss: 0.8261 - val_accuracy: 0.8400
#
# Epoch 00032: saving model to sloan_efficient/model-00032-0.47-0.9200-0.83-0.8400.h5
# Epoch 33/40
# 25/25 [==============================] - 18s 596ms/step - loss: 0.7325 - accuracy: 0.8763 - val_loss: 3.6599 - val_accuracy: 0.4000
#
# Epoch 00033: saving model to sloan_efficient/model-00033-0.73-0.8763-3.66-0.4000.h5
# Epoch 34/40
# 25/25 [==============================] - 18s 594ms/step - loss: 1.0613 - accuracy: 0.8275 - val_loss: 1.8334 - val_accuracy: 0.7200
#
# Epoch 00034: saving model to sloan_efficient/model-00034-1.06-0.8275-1.83-0.7200.h5
# Epoch 35/40
# 25/25 [==============================] - 18s 595ms/step - loss: 0.6701 - accuracy: 0.8700 - val_loss: 0.7670 - val_accuracy: 0.8200
#
# Epoch 00035: saving model to sloan_efficient/model-00035-0.67-0.8700-0.77-0.8200.h5
# Epoch 36/40
# 25/25 [==============================] - 18s 592ms/step - loss: 0.7319 - accuracy: 0.8725 - val_loss: 0.6079 - val_accuracy: 0.8750
#
# Epoch 00036: saving model to sloan_efficient/model-00036-0.73-0.8725-0.61-0.8750.h5
# Epoch 37/40
# 25/25 [==============================] - 18s 602ms/step - loss: 1.1185 - accuracy: 0.8562 - val_loss: 3.2074 - val_accuracy: 0.6300
#
# Epoch 00037: saving model to sloan_efficient/model-00037-1.12-0.8562-3.21-0.6300.h5
# Epoch 38/40
# 25/25 [==============================] - 18s 594ms/step - loss: 1.0667 - accuracy: 0.8700 - val_loss: 1.9523 - val_accuracy: 0.7250
#
# Epoch 00038: saving model to sloan_efficient/model-00038-1.07-0.8700-1.95-0.7250.h5
# Epoch 39/40
# 25/25 [==============================] - 18s 596ms/step - loss: 1.0686 - accuracy: 0.8512 - val_loss: 0.4545 - val_accuracy: 0.9300
#
# Epoch 00039: saving model to sloan_efficient/model-00039-1.07-0.8512-0.45-0.9300.h5
# Epoch 40/40
# 25/25 [==============================] - 18s 595ms/step - loss: 0.5904 - accuracy: 0.8950 - val_loss: 1.3079 - val_accuracy: 0.7650
#
# Epoch 00040: saving model to sloan_efficient/model-00040-0.59-0.8950-1.31-0.7650.h5

# %% [markdown]
# ##### Model Evaluation

# %%
val_ds_normal_crop = prepare_dataset_normal_crop(val_ds_cropped, training = False)

effnet_scaled = load_model('./sloan_efficient/Effnet_scaled-4.33-0.40-2.95-0.44.h5')
effnet_unscaled = load_model('./sloan_efficient/Effnet_unscaled-0.55-0.91-0.49-0.90.h5') 
effnet_unscaled_flip = load_model('./sloan_efficient/Eff_unscaled_flip-0.36-0.9413-0.43-0.9300.h5')
effnet_unscaled_flip_rotate = load_model('./sloan_efficient/Eff_unscaled_flip_rotate-0.61-0.9000-0.42-0.9000.h5')
effnet_unscaled_crop_flip = load_model('./sloan_efficient/Effnet_unscaled_crop_flip-0.93-0.8775-0.42-0.9450.h5')
effnet_unscaled_crop_flip_rotate = load_model('./sloan_efficient/effnet_unscaled_crop_flip_rotate-0.94-0.8462-0.48-0.9300.h5')
effnet_preprocessing_crop = load_model('./sloan_efficient/effnet_crop_preprocessed-0.65-0.8825-0.40-0.9200.h5')


metrics = Metrics(effnet_scaled,val_ds_scaled)
print(metrics.calculate_scores())
print('---------------------------------------------------------------------------------------------------------------------')
metrics = Metrics(effnet_unscaled,val_ds)
print(metrics.calculate_scores())
print('---------------------------------------------------------------------------------------------------------------------')
metrics = Metrics(effnet_unscaled_flip,val_ds)
print(metrics.calculate_scores())
print('---------------------------------------------------------------------------------------------------------------------')
metrics = Metrics(effnet_unscaled_flip_rotate,val_ds)
print(metrics.calculate_scores())
print('---------------------------------------------------------------------------------------------------------------------')
metrics = Metrics(effnet_unscaled_crop_flip,val_ds_normal_crop)
print(metrics.calculate_scores())
print('---------------------------------------------------------------------------------------------------------------------')
metrics = Metrics(effnet_unscaled_crop_flip_rotate,val_ds_normal_crop)
print(metrics.calculate_scores())
print('---------------------------------------------------------------------------------------------------------------------')
metrics = Metrics(effnet_preprocessing_crop,val_ds_normal_crop)
print(metrics.calculate_scores())
print('---------------------------------------------------------------------------------------------------------------------')
# Out:
# calculating score.....
# [[ 0  0 96]
#  [ 0  0 17]
#  [ 0  0 87]]
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        96
#          1.0       0.00      0.00      0.00        17
#          2.0       0.43      1.00      0.61        87
#
#     accuracy                           0.43       200
#    macro avg       0.14      0.33      0.20       200
# weighted avg       0.19      0.43      0.26       200
#
# None
# ---------------------------------------------------------------------------------------------------------------------
# calculating score.....
# [[90  1  5]
#  [ 0 11  6]
#  [ 1  6 80]]
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.94      0.96        96
#          1.0       0.61      0.65      0.63        17
#          2.0       0.88      0.92      0.90        87
#
#     accuracy                           0.91       200
#    macro avg       0.83      0.83      0.83       200
# weighted avg       0.91      0.91      0.91       200
#
# None
# ---------------------------------------------------------------------------------------------------------------------
# calculating score.....
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f69c4650050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [[93  0  3]
#  [ 0 10  7]
#  [ 1  3 83]]
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.97      0.98        96
#          1.0       0.77      0.59      0.67        17
#          2.0       0.89      0.95      0.92        87
#
#     accuracy                           0.93       200
#    macro avg       0.88      0.84      0.86       200
# weighted avg       0.93      0.93      0.93       200
#
# None
# ---------------------------------------------------------------------------------------------------------------------
# calculating score.....
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f69e46f4cb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [[92  0  4]
#  [ 1 11  5]
#  [ 3  7 77]]
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.96      0.96        96
#          1.0       0.61      0.65      0.63        17
#          2.0       0.90      0.89      0.89        87
#
#     accuracy                           0.90       200
#    macro avg       0.82      0.83      0.83       200
# weighted avg       0.90      0.90      0.90       200
#
# None
# ---------------------------------------------------------------------------------------------------------------------
# calculating score.....
# [[95  1  0]
#  [ 0 11  6]
#  [ 0  4 83]]
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.99      0.99        96
#          1.0       0.69      0.65      0.67        17
#          2.0       0.93      0.95      0.94        87
#
#     accuracy                           0.94       200
#    macro avg       0.87      0.86      0.87       200
# weighted avg       0.94      0.94      0.94       200
#
# None
# ---------------------------------------------------------------------------------------------------------------------
# calculating score.....
# [[93  1  2]
#  [ 1 10  6]
#  [ 2  2 83]]
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.97      0.97        96
#          1.0       0.77      0.59      0.67        17
#          2.0       0.91      0.95      0.93        87
#
#     accuracy                           0.93       200
#    macro avg       0.88      0.84      0.86       200
# weighted avg       0.93      0.93      0.93       200
#
# None
# ---------------------------------------------------------------------------------------------------------------------
# calculating score.....
# [[93  3  0]
#  [ 0 11  6]
#  [ 1  6 80]]
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.97      0.98        96
#          1.0       0.55      0.65      0.59        17
#          2.0       0.93      0.92      0.92        87
#
#     accuracy                           0.92       200
#    macro avg       0.82      0.85      0.83       200
# weighted avg       0.93      0.92      0.92       200
#
# None
# ---------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ##### Densenet 121

# %%
base_model_densenet = tf.keras.applications.DenseNet121(
    include_top=False,
    weights="imagenet",    
    input_shape=(img_height, img_width, channels),
    pooling='max',
    classes=3,
)
layer_count  = len(base_model_densenet.layers)
print(f'There are a total of {layer_count} layers in the Densenet121 network')
# making the base layers non trainable or freezing
break_point  = 428
for layer in base_model_densenet.layers[0:break_point]:
    layer.trainable = False
for layer in base_model_densenet.layers[break_point:]:
    layer.trainable = True

# please note higher the break point ; lesser the trainable layers lesser is the over fitting -> high breakpoint -> less over fitting 
base_model_densenet.inputs
input_layer = base_model_densenet.inputs
# Building a functional model

output = base_model_densenet.output
print(output)
x = Dense(num_classes, activation  = 'softmax')(output)

densenet_model = Model(inputs = input_layer, outputs = x)
densenet_model.summary()
densenet_model.compile(optimizer = optimizers.Adam(lr=1e-4), loss = 'categorical_crossentropy', metrics = ['accuracy'])
# Out:
# There are a total of 428 layers in the Densenet121 network
# KerasTensor(type_spec=TensorSpec(shape=(None, 1024), dtype=tf.float32, name=None), name='max_pool/Max:0', description="created by layer 'max_pool'")
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 512, 512, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 518, 518, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 256, 256, 64) 9408        zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 256, 256, 64) 256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 256, 256, 64) 0           conv1/bn[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 258, 258, 64) 0           conv1/relu[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 128, 128, 64) 0           zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 128, 128, 64) 256         pool1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_relu (Activation (None, 128, 128, 64) 0           conv2_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 128, 128, 128 8192        conv2_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 128, 128, 128 512         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 128, 128, 128 0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 128, 128, 32) 36864       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_concat (Concatenat (None, 128, 128, 96) 0           pool1[0][0]
#                                                                  conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_bn (BatchNormali (None, 128, 128, 96) 384         conv2_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_relu (Activation (None, 128, 128, 96) 0           conv2_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 128, 128, 128 12288       conv2_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 128, 128, 128 512         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 128, 128, 128 0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 128, 128, 32) 36864       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_concat (Concatenat (None, 128, 128, 128 0           conv2_block1_concat[0][0]
#                                                                  conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_bn (BatchNormali (None, 128, 128, 128 512         conv2_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_relu (Activation (None, 128, 128, 128 0           conv2_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 128, 128, 128 16384       conv2_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 128, 128, 128 512         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 128, 128, 128 0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 128, 128, 32) 36864       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_concat (Concatenat (None, 128, 128, 160 0           conv2_block2_concat[0][0]
#                                                                  conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_bn (BatchNormali (None, 128, 128, 160 640         conv2_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_relu (Activation (None, 128, 128, 160 0           conv2_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_conv (Conv2D)    (None, 128, 128, 128 20480       conv2_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_bn (BatchNormali (None, 128, 128, 128 512         conv2_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_relu (Activation (None, 128, 128, 128 0           conv2_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_2_conv (Conv2D)    (None, 128, 128, 32) 36864       conv2_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_concat (Concatenat (None, 128, 128, 192 0           conv2_block3_concat[0][0]
#                                                                  conv2_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_bn (BatchNormali (None, 128, 128, 192 768         conv2_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_relu (Activation (None, 128, 128, 192 0           conv2_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_conv (Conv2D)    (None, 128, 128, 128 24576       conv2_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_bn (BatchNormali (None, 128, 128, 128 512         conv2_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_relu (Activation (None, 128, 128, 128 0           conv2_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_2_conv (Conv2D)    (None, 128, 128, 32) 36864       conv2_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_concat (Concatenat (None, 128, 128, 224 0           conv2_block4_concat[0][0]
#                                                                  conv2_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_bn (BatchNormali (None, 128, 128, 224 896         conv2_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_relu (Activation (None, 128, 128, 224 0           conv2_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_conv (Conv2D)    (None, 128, 128, 128 28672       conv2_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_bn (BatchNormali (None, 128, 128, 128 512         conv2_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_relu (Activation (None, 128, 128, 128 0           conv2_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_2_conv (Conv2D)    (None, 128, 128, 32) 36864       conv2_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_concat (Concatenat (None, 128, 128, 256 0           conv2_block5_concat[0][0]
#                                                                  conv2_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# pool2_bn (BatchNormalization)   (None, 128, 128, 256 1024        conv2_block6_concat[0][0]
# __________________________________________________________________________________________________
# pool2_relu (Activation)         (None, 128, 128, 256 0           pool2_bn[0][0]
# __________________________________________________________________________________________________
# pool2_conv (Conv2D)             (None, 128, 128, 128 32768       pool2_relu[0][0]
# __________________________________________________________________________________________________
# pool2_pool (AveragePooling2D)   (None, 64, 64, 128)  0           pool2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 64, 64, 128)  512         pool2_pool[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_relu (Activation (None, 64, 64, 128)  0           conv3_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 64, 64, 128)  16384       conv3_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 64, 64, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 64, 64, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 64, 64, 32)   36864       conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_concat (Concatenat (None, 64, 64, 160)  0           pool2_pool[0][0]
#                                                                  conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_bn (BatchNormali (None, 64, 64, 160)  640         conv3_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_relu (Activation (None, 64, 64, 160)  0           conv3_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 64, 64, 128)  20480       conv3_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 64, 64, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 64, 64, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 64, 64, 32)   36864       conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_concat (Concatenat (None, 64, 64, 192)  0           conv3_block1_concat[0][0]
#                                                                  conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_bn (BatchNormali (None, 64, 64, 192)  768         conv3_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_relu (Activation (None, 64, 64, 192)  0           conv3_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 64, 64, 128)  24576       conv3_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 64, 64, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 64, 64, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 64, 64, 32)   36864       conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_concat (Concatenat (None, 64, 64, 224)  0           conv3_block2_concat[0][0]
#                                                                  conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_bn (BatchNormali (None, 64, 64, 224)  896         conv3_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_relu (Activation (None, 64, 64, 224)  0           conv3_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 64, 64, 128)  28672       conv3_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 64, 64, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 64, 64, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 64, 64, 32)   36864       conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_concat (Concatenat (None, 64, 64, 256)  0           conv3_block3_concat[0][0]
#                                                                  conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_bn (BatchNormali (None, 64, 64, 256)  1024        conv3_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_relu (Activation (None, 64, 64, 256)  0           conv3_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_conv (Conv2D)    (None, 64, 64, 128)  32768       conv3_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_bn (BatchNormali (None, 64, 64, 128)  512         conv3_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_relu (Activation (None, 64, 64, 128)  0           conv3_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_2_conv (Conv2D)    (None, 64, 64, 32)   36864       conv3_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_concat (Concatenat (None, 64, 64, 288)  0           conv3_block4_concat[0][0]
#                                                                  conv3_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_bn (BatchNormali (None, 64, 64, 288)  1152        conv3_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_relu (Activation (None, 64, 64, 288)  0           conv3_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_conv (Conv2D)    (None, 64, 64, 128)  36864       conv3_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_bn (BatchNormali (None, 64, 64, 128)  512         conv3_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_relu (Activation (None, 64, 64, 128)  0           conv3_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_2_conv (Conv2D)    (None, 64, 64, 32)   36864       conv3_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_concat (Concatenat (None, 64, 64, 320)  0           conv3_block5_concat[0][0]
#                                                                  conv3_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_bn (BatchNormali (None, 64, 64, 320)  1280        conv3_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_relu (Activation (None, 64, 64, 320)  0           conv3_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_conv (Conv2D)    (None, 64, 64, 128)  40960       conv3_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_bn (BatchNormali (None, 64, 64, 128)  512         conv3_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_relu (Activation (None, 64, 64, 128)  0           conv3_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_2_conv (Conv2D)    (None, 64, 64, 32)   36864       conv3_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_concat (Concatenat (None, 64, 64, 352)  0           conv3_block6_concat[0][0]
#                                                                  conv3_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_bn (BatchNormali (None, 64, 64, 352)  1408        conv3_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_relu (Activation (None, 64, 64, 352)  0           conv3_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_conv (Conv2D)    (None, 64, 64, 128)  45056       conv3_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_bn (BatchNormali (None, 64, 64, 128)  512         conv3_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_relu (Activation (None, 64, 64, 128)  0           conv3_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_2_conv (Conv2D)    (None, 64, 64, 32)   36864       conv3_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_concat (Concatenat (None, 64, 64, 384)  0           conv3_block7_concat[0][0]
#                                                                  conv3_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_bn (BatchNormali (None, 64, 64, 384)  1536        conv3_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_relu (Activation (None, 64, 64, 384)  0           conv3_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_conv (Conv2D)    (None, 64, 64, 128)  49152       conv3_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_bn (BatchNormali (None, 64, 64, 128)  512         conv3_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_relu (Activation (None, 64, 64, 128)  0           conv3_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_2_conv (Conv2D)    (None, 64, 64, 32)   36864       conv3_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_concat (Concatenat (None, 64, 64, 416)  0           conv3_block8_concat[0][0]
#                                                                  conv3_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_bn (BatchNormal (None, 64, 64, 416)  1664        conv3_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_relu (Activatio (None, 64, 64, 416)  0           conv3_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_conv (Conv2D)   (None, 64, 64, 128)  53248       conv3_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_bn (BatchNormal (None, 64, 64, 128)  512         conv3_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_relu (Activatio (None, 64, 64, 128)  0           conv3_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_2_conv (Conv2D)   (None, 64, 64, 32)   36864       conv3_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_concat (Concatena (None, 64, 64, 448)  0           conv3_block9_concat[0][0]
#                                                                  conv3_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_bn (BatchNormal (None, 64, 64, 448)  1792        conv3_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_relu (Activatio (None, 64, 64, 448)  0           conv3_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_conv (Conv2D)   (None, 64, 64, 128)  57344       conv3_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_bn (BatchNormal (None, 64, 64, 128)  512         conv3_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_relu (Activatio (None, 64, 64, 128)  0           conv3_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_2_conv (Conv2D)   (None, 64, 64, 32)   36864       conv3_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_concat (Concatena (None, 64, 64, 480)  0           conv3_block10_concat[0][0]
#                                                                  conv3_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_bn (BatchNormal (None, 64, 64, 480)  1920        conv3_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_relu (Activatio (None, 64, 64, 480)  0           conv3_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_conv (Conv2D)   (None, 64, 64, 128)  61440       conv3_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_bn (BatchNormal (None, 64, 64, 128)  512         conv3_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_relu (Activatio (None, 64, 64, 128)  0           conv3_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_2_conv (Conv2D)   (None, 64, 64, 32)   36864       conv3_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_concat (Concatena (None, 64, 64, 512)  0           conv3_block11_concat[0][0]
#                                                                  conv3_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# pool3_bn (BatchNormalization)   (None, 64, 64, 512)  2048        conv3_block12_concat[0][0]
# __________________________________________________________________________________________________
# pool3_relu (Activation)         (None, 64, 64, 512)  0           pool3_bn[0][0]
# __________________________________________________________________________________________________
# pool3_conv (Conv2D)             (None, 64, 64, 256)  131072      pool3_relu[0][0]
# __________________________________________________________________________________________________
# pool3_pool (AveragePooling2D)   (None, 32, 32, 256)  0           pool3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 32, 32, 256)  1024        pool3_pool[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_relu (Activation (None, 32, 32, 256)  0           conv4_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 32, 32, 128)  32768       conv4_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 32, 32, 128)  512         conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 32, 32, 128)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_concat (Concatenat (None, 32, 32, 288)  0           pool3_pool[0][0]
#                                                                  conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_bn (BatchNormali (None, 32, 32, 288)  1152        conv4_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_relu (Activation (None, 32, 32, 288)  0           conv4_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 32, 32, 128)  36864       conv4_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 32, 32, 128)  512         conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 32, 32, 128)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_concat (Concatenat (None, 32, 32, 320)  0           conv4_block1_concat[0][0]
#                                                                  conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_bn (BatchNormali (None, 32, 32, 320)  1280        conv4_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_relu (Activation (None, 32, 32, 320)  0           conv4_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 32, 32, 128)  40960       conv4_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 32, 32, 128)  512         conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 32, 32, 128)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_concat (Concatenat (None, 32, 32, 352)  0           conv4_block2_concat[0][0]
#                                                                  conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_bn (BatchNormali (None, 32, 32, 352)  1408        conv4_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_relu (Activation (None, 32, 32, 352)  0           conv4_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 32, 32, 128)  45056       conv4_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 32, 32, 128)  512         conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 32, 32, 128)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_concat (Concatenat (None, 32, 32, 384)  0           conv4_block3_concat[0][0]
#                                                                  conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_bn (BatchNormali (None, 32, 32, 384)  1536        conv4_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_relu (Activation (None, 32, 32, 384)  0           conv4_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 32, 32, 128)  49152       conv4_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 32, 32, 128)  512         conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 32, 32, 128)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_concat (Concatenat (None, 32, 32, 416)  0           conv4_block4_concat[0][0]
#                                                                  conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_bn (BatchNormali (None, 32, 32, 416)  1664        conv4_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_relu (Activation (None, 32, 32, 416)  0           conv4_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 32, 32, 128)  53248       conv4_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 32, 32, 128)  512         conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 32, 32, 128)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_concat (Concatenat (None, 32, 32, 448)  0           conv4_block5_concat[0][0]
#                                                                  conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_bn (BatchNormali (None, 32, 32, 448)  1792        conv4_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_relu (Activation (None, 32, 32, 448)  0           conv4_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, 32, 32, 128)  57344       conv4_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, 32, 32, 128)  512         conv4_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (Activation (None, 32, 32, 128)  0           conv4_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv4_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_concat (Concatenat (None, 32, 32, 480)  0           conv4_block6_concat[0][0]
#                                                                  conv4_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_0_bn (BatchNormali (None, 32, 32, 480)  1920        conv4_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block8_0_relu (Activation (None, 32, 32, 480)  0           conv4_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_conv (Conv2D)    (None, 32, 32, 128)  61440       conv4_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_bn (BatchNormali (None, 32, 32, 128)  512         conv4_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_relu (Activation (None, 32, 32, 128)  0           conv4_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv4_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_concat (Concatenat (None, 32, 32, 512)  0           conv4_block7_concat[0][0]
#                                                                  conv4_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_0_bn (BatchNormali (None, 32, 32, 512)  2048        conv4_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block9_0_relu (Activation (None, 32, 32, 512)  0           conv4_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_conv (Conv2D)    (None, 32, 32, 128)  65536       conv4_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_bn (BatchNormali (None, 32, 32, 128)  512         conv4_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_relu (Activation (None, 32, 32, 128)  0           conv4_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv4_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_concat (Concatenat (None, 32, 32, 544)  0           conv4_block8_concat[0][0]
#                                                                  conv4_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_0_bn (BatchNormal (None, 32, 32, 544)  2176        conv4_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block10_0_relu (Activatio (None, 32, 32, 544)  0           conv4_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_conv (Conv2D)   (None, 32, 32, 128)  69632       conv4_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_bn (BatchNormal (None, 32, 32, 128)  512         conv4_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_relu (Activatio (None, 32, 32, 128)  0           conv4_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_conv (Conv2D)   (None, 32, 32, 32)   36864       conv4_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_concat (Concatena (None, 32, 32, 576)  0           conv4_block9_concat[0][0]
#                                                                  conv4_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_0_bn (BatchNormal (None, 32, 32, 576)  2304        conv4_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block11_0_relu (Activatio (None, 32, 32, 576)  0           conv4_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_conv (Conv2D)   (None, 32, 32, 128)  73728       conv4_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_bn (BatchNormal (None, 32, 32, 128)  512         conv4_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_relu (Activatio (None, 32, 32, 128)  0           conv4_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_conv (Conv2D)   (None, 32, 32, 32)   36864       conv4_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_concat (Concatena (None, 32, 32, 608)  0           conv4_block10_concat[0][0]
#                                                                  conv4_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_0_bn (BatchNormal (None, 32, 32, 608)  2432        conv4_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block12_0_relu (Activatio (None, 32, 32, 608)  0           conv4_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_conv (Conv2D)   (None, 32, 32, 128)  77824       conv4_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_bn (BatchNormal (None, 32, 32, 128)  512         conv4_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_relu (Activatio (None, 32, 32, 128)  0           conv4_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_conv (Conv2D)   (None, 32, 32, 32)   36864       conv4_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_concat (Concatena (None, 32, 32, 640)  0           conv4_block11_concat[0][0]
#                                                                  conv4_block12_2_conv[0][0]
# ...
# __________________________________________________________________________________________________
# conv5_block7_0_bn (BatchNormali (None, 16, 16, 704)  2816        conv5_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block7_0_relu (Activation (None, 16, 16, 704)  0           conv5_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block7_1_conv (Conv2D)    (None, 16, 16, 128)  90112       conv5_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block7_1_bn (BatchNormali (None, 16, 16, 128)  512         conv5_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block7_1_relu (Activation (None, 16, 16, 128)  0           conv5_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block7_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv5_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block7_concat (Concatenat (None, 16, 16, 736)  0           conv5_block6_concat[0][0]
#                                                                  conv5_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block8_0_bn (BatchNormali (None, 16, 16, 736)  2944        conv5_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block8_0_relu (Activation (None, 16, 16, 736)  0           conv5_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block8_1_conv (Conv2D)    (None, 16, 16, 128)  94208       conv5_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block8_1_bn (BatchNormali (None, 16, 16, 128)  512         conv5_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block8_1_relu (Activation (None, 16, 16, 128)  0           conv5_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block8_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv5_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block8_concat (Concatenat (None, 16, 16, 768)  0           conv5_block7_concat[0][0]
#                                                                  conv5_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block9_0_bn (BatchNormali (None, 16, 16, 768)  3072        conv5_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block9_0_relu (Activation (None, 16, 16, 768)  0           conv5_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block9_1_conv (Conv2D)    (None, 16, 16, 128)  98304       conv5_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block9_1_bn (BatchNormali (None, 16, 16, 128)  512         conv5_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block9_1_relu (Activation (None, 16, 16, 128)  0           conv5_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block9_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv5_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block9_concat (Concatenat (None, 16, 16, 800)  0           conv5_block8_concat[0][0]
#                                                                  conv5_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block10_0_bn (BatchNormal (None, 16, 16, 800)  3200        conv5_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block10_0_relu (Activatio (None, 16, 16, 800)  0           conv5_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block10_1_conv (Conv2D)   (None, 16, 16, 128)  102400      conv5_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block10_1_bn (BatchNormal (None, 16, 16, 128)  512         conv5_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block10_1_relu (Activatio (None, 16, 16, 128)  0           conv5_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block10_2_conv (Conv2D)   (None, 16, 16, 32)   36864       conv5_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block10_concat (Concatena (None, 16, 16, 832)  0           conv5_block9_concat[0][0]
#                                                                  conv5_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block11_0_bn (BatchNormal (None, 16, 16, 832)  3328        conv5_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block11_0_relu (Activatio (None, 16, 16, 832)  0           conv5_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block11_1_conv (Conv2D)   (None, 16, 16, 128)  106496      conv5_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block11_1_bn (BatchNormal (None, 16, 16, 128)  512         conv5_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block11_1_relu (Activatio (None, 16, 16, 128)  0           conv5_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block11_2_conv (Conv2D)   (None, 16, 16, 32)   36864       conv5_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block11_concat (Concatena (None, 16, 16, 864)  0           conv5_block10_concat[0][0]
#                                                                  conv5_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block12_0_bn (BatchNormal (None, 16, 16, 864)  3456        conv5_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block12_0_relu (Activatio (None, 16, 16, 864)  0           conv5_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block12_1_conv (Conv2D)   (None, 16, 16, 128)  110592      conv5_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block12_1_bn (BatchNormal (None, 16, 16, 128)  512         conv5_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block12_1_relu (Activatio (None, 16, 16, 128)  0           conv5_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block12_2_conv (Conv2D)   (None, 16, 16, 32)   36864       conv5_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block12_concat (Concatena (None, 16, 16, 896)  0           conv5_block11_concat[0][0]
#                                                                  conv5_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block13_0_bn (BatchNormal (None, 16, 16, 896)  3584        conv5_block12_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block13_0_relu (Activatio (None, 16, 16, 896)  0           conv5_block13_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block13_1_conv (Conv2D)   (None, 16, 16, 128)  114688      conv5_block13_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block13_1_bn (BatchNormal (None, 16, 16, 128)  512         conv5_block13_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block13_1_relu (Activatio (None, 16, 16, 128)  0           conv5_block13_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block13_2_conv (Conv2D)   (None, 16, 16, 32)   36864       conv5_block13_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block13_concat (Concatena (None, 16, 16, 928)  0           conv5_block12_concat[0][0]
#                                                                  conv5_block13_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block14_0_bn (BatchNormal (None, 16, 16, 928)  3712        conv5_block13_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block14_0_relu (Activatio (None, 16, 16, 928)  0           conv5_block14_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block14_1_conv (Conv2D)   (None, 16, 16, 128)  118784      conv5_block14_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block14_1_bn (BatchNormal (None, 16, 16, 128)  512         conv5_block14_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block14_1_relu (Activatio (None, 16, 16, 128)  0           conv5_block14_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block14_2_conv (Conv2D)   (None, 16, 16, 32)   36864       conv5_block14_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block14_concat (Concatena (None, 16, 16, 960)  0           conv5_block13_concat[0][0]
#                                                                  conv5_block14_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block15_0_bn (BatchNormal (None, 16, 16, 960)  3840        conv5_block14_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block15_0_relu (Activatio (None, 16, 16, 960)  0           conv5_block15_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block15_1_conv (Conv2D)   (None, 16, 16, 128)  122880      conv5_block15_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block15_1_bn (BatchNormal (None, 16, 16, 128)  512         conv5_block15_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block15_1_relu (Activatio (None, 16, 16, 128)  0           conv5_block15_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block15_2_conv (Conv2D)   (None, 16, 16, 32)   36864       conv5_block15_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block15_concat (Concatena (None, 16, 16, 992)  0           conv5_block14_concat[0][0]
#                                                                  conv5_block15_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block16_0_bn (BatchNormal (None, 16, 16, 992)  3968        conv5_block15_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block16_0_relu (Activatio (None, 16, 16, 992)  0           conv5_block16_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block16_1_conv (Conv2D)   (None, 16, 16, 128)  126976      conv5_block16_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block16_1_bn (BatchNormal (None, 16, 16, 128)  512         conv5_block16_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block16_1_relu (Activatio (None, 16, 16, 128)  0           conv5_block16_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block16_2_conv (Conv2D)   (None, 16, 16, 32)   36864       conv5_block16_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block16_concat (Concatena (None, 16, 16, 1024) 0           conv5_block15_concat[0][0]
#                                                                  conv5_block16_2_conv[0][0]
# __________________________________________________________________________________________________
# bn (BatchNormalization)         (None, 16, 16, 1024) 4096        conv5_block16_concat[0][0]
# __________________________________________________________________________________________________
# relu (Activation)               (None, 16, 16, 1024) 0           bn[0][0]
# __________________________________________________________________________________________________
# max_pool (GlobalMaxPooling2D)   (None, 1024)         0           relu[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 3)            3075        max_pool[0][0]
# ==================================================================================================
# Total params: 7,040,579
# Trainable params: 3,075
# Non-trainable params: 7,037,504
# __________________________________________________________________________________________________

# %% [markdown]
# ##### Densenet without class balancing

# %%
dense_model.fit(train_ds,validation_data=val_ds,epochs = 40, verbose = 1, workers = 3,callbacks = callbacks_dense)
# Out:
# Epoch 1/40
# 25/25 [==============================] - 94s 2s/step - loss: 4.8745 - accuracy: 0.2375 - val_loss: 4.7399 - val_accuracy: 0.3150
#
# Epoch 00001: saving model to sloan_dense/model-00001-4.87-0.2375-4.74-0.3150.h5
# Epoch 2/40
# 25/25 [==============================] - 14s 515ms/step - loss: 3.8640 - accuracy: 0.2962 - val_loss: 3.6376 - val_accuracy: 0.2950
#
# Epoch 00002: saving model to sloan_dense/model-00002-3.86-0.2962-3.64-0.2950.h5
# Epoch 3/40
# 25/25 [==============================] - 14s 515ms/step - loss: 3.0170 - accuracy: 0.3200 - val_loss: 2.9390 - val_accuracy: 0.3450
#
# Epoch 00003: saving model to sloan_dense/model-00003-3.02-0.3200-2.94-0.3450.h5
# Epoch 4/40
# 25/25 [==============================] - 14s 513ms/step - loss: 2.3455 - accuracy: 0.3775 - val_loss: 2.3026 - val_accuracy: 0.3950
#
# Epoch 00004: saving model to sloan_dense/model-00004-2.35-0.3775-2.30-0.3950.h5
# Epoch 5/40
# 25/25 [==============================] - 14s 512ms/step - loss: 1.8780 - accuracy: 0.4712 - val_loss: 1.9022 - val_accuracy: 0.5000
#
# Epoch 00005: saving model to sloan_dense/model-00005-1.88-0.4712-1.90-0.5000.h5
# Epoch 6/40
# 25/25 [==============================] - 14s 513ms/step - loss: 1.5721 - accuracy: 0.5325 - val_loss: 1.6478 - val_accuracy: 0.5700
#
# Epoch 00006: saving model to sloan_dense/model-00006-1.57-0.5325-1.65-0.5700.h5
# Epoch 7/40
# 25/25 [==============================] - 14s 513ms/step - loss: 1.3724 - accuracy: 0.5987 - val_loss: 1.5606 - val_accuracy: 0.5950
#
# Epoch 00007: saving model to sloan_dense/model-00007-1.37-0.5987-1.56-0.5950.h5
# Epoch 8/40
# 25/25 [==============================] - 14s 509ms/step - loss: 1.2454 - accuracy: 0.6525 - val_loss: 1.4098 - val_accuracy: 0.6700
#
# Epoch 00008: saving model to sloan_dense/model-00008-1.25-0.6525-1.41-0.6700.h5
# Epoch 9/40
# 25/25 [==============================] - 14s 511ms/step - loss: 1.1527 - accuracy: 0.6800 - val_loss: 1.3420 - val_accuracy: 0.6700
#
# Epoch 00009: saving model to sloan_dense/model-00009-1.15-0.6800-1.34-0.6700.h5
# Epoch 10/40
# 25/25 [==============================] - 14s 513ms/step - loss: 1.0930 - accuracy: 0.7013 - val_loss: 1.2678 - val_accuracy: 0.7050
#
# Epoch 00010: saving model to sloan_dense/model-00010-1.09-0.7013-1.27-0.7050.h5
# Epoch 11/40
# 25/25 [==============================] - 14s 513ms/step - loss: 1.0386 - accuracy: 0.7200 - val_loss: 1.2438 - val_accuracy: 0.7150
#
# Epoch 00011: saving model to sloan_dense/model-00011-1.04-0.7200-1.24-0.7150.h5
# Epoch 12/40
# 25/25 [==============================] - 14s 507ms/step - loss: 0.9882 - accuracy: 0.7275 - val_loss: 1.2352 - val_accuracy: 0.7250
#
# Epoch 00012: saving model to sloan_dense/model-00012-0.99-0.7275-1.24-0.7250.h5
# Epoch 13/40
# 25/25 [==============================] - 14s 511ms/step - loss: 0.9473 - accuracy: 0.7337 - val_loss: 1.1820 - val_accuracy: 0.7550
#
# Epoch 00013: saving model to sloan_dense/model-00013-0.95-0.7337-1.18-0.7550.h5
# Epoch 14/40
# 25/25 [==============================] - 14s 510ms/step - loss: 0.9035 - accuracy: 0.7563 - val_loss: 1.1486 - val_accuracy: 0.7450
#
# Epoch 00014: saving model to sloan_dense/model-00014-0.90-0.7563-1.15-0.7450.h5
# Epoch 15/40
# 25/25 [==============================] - 14s 508ms/step - loss: 0.8718 - accuracy: 0.7575 - val_loss: 1.1352 - val_accuracy: 0.7650
#
# Epoch 00015: saving model to sloan_dense/model-00015-0.87-0.7575-1.14-0.7650.h5
# Epoch 16/40
# 25/25 [==============================] - 14s 509ms/step - loss: 0.8416 - accuracy: 0.7700 - val_loss: 1.0969 - val_accuracy: 0.7700
#
# Epoch 00016: saving model to sloan_dense/model-00016-0.84-0.7700-1.10-0.7700.h5
# Epoch 17/40
# 25/25 [==============================] - 14s 511ms/step - loss: 0.8165 - accuracy: 0.7663 - val_loss: 1.0860 - val_accuracy: 0.7800
#
# Epoch 00017: saving model to sloan_dense/model-00017-0.82-0.7663-1.09-0.7800.h5
# Epoch 18/40
# 25/25 [==============================] - 14s 509ms/step - loss: 0.7934 - accuracy: 0.7825 - val_loss: 1.0643 - val_accuracy: 0.7900
#
# Epoch 00018: saving model to sloan_dense/model-00018-0.79-0.7825-1.06-0.7900.h5
# Epoch 19/40
# 25/25 [==============================] - 14s 507ms/step - loss: 0.7767 - accuracy: 0.7812 - val_loss: 1.0827 - val_accuracy: 0.7750
#
# Epoch 00019: saving model to sloan_dense/model-00019-0.78-0.7812-1.08-0.7750.h5
# Epoch 20/40
# 25/25 [==============================] - 14s 508ms/step - loss: 0.7487 - accuracy: 0.7887 - val_loss: 1.0470 - val_accuracy: 0.7800
#
# Epoch 00020: saving model to sloan_dense/model-00020-0.75-0.7887-1.05-0.7800.h5
# Epoch 21/40
# 25/25 [==============================] - 14s 509ms/step - loss: 0.7203 - accuracy: 0.7962 - val_loss: 1.0138 - val_accuracy: 0.8000
#
# Epoch 00021: saving model to sloan_dense/model-00021-0.72-0.7962-1.01-0.8000.h5
# Epoch 22/40
# 25/25 [==============================] - 14s 510ms/step - loss: 0.7146 - accuracy: 0.7975 - val_loss: 0.9983 - val_accuracy: 0.8100
#
# Epoch 00022: saving model to sloan_dense/model-00022-0.71-0.7975-1.00-0.8100.h5
# Epoch 23/40
# 25/25 [==============================] - 14s 506ms/step - loss: 0.6843 - accuracy: 0.8150 - val_loss: 0.9851 - val_accuracy: 0.8150
#
# Epoch 00023: saving model to sloan_dense/model-00023-0.68-0.8150-0.99-0.8150.h5
# Epoch 24/40
# 25/25 [==============================] - 14s 504ms/step - loss: 0.6650 - accuracy: 0.8175 - val_loss: 0.9847 - val_accuracy: 0.8050
#
# Epoch 00024: saving model to sloan_dense/model-00024-0.67-0.8175-0.98-0.8050.h5
# Epoch 25/40
# 25/25 [==============================] - 14s 504ms/step - loss: 0.6486 - accuracy: 0.8138 - val_loss: 0.9910 - val_accuracy: 0.7900
#
# Epoch 00025: saving model to sloan_dense/model-00025-0.65-0.8138-0.99-0.7900.h5
# Epoch 26/40
# 25/25 [==============================] - 14s 501ms/step - loss: 0.6354 - accuracy: 0.8200 - val_loss: 0.9556 - val_accuracy: 0.8100
#
# Epoch 00026: saving model to sloan_dense/model-00026-0.64-0.8200-0.96-0.8100.h5
# Epoch 27/40
# 25/25 [==============================] - 14s 510ms/step - loss: 0.6152 - accuracy: 0.8313 - val_loss: 0.9563 - val_accuracy: 0.8050
#
# Epoch 00027: saving model to sloan_dense/model-00027-0.62-0.8313-0.96-0.8050.h5
# Epoch 28/40
# 25/25 [==============================] - 14s 503ms/step - loss: 0.6008 - accuracy: 0.8338 - val_loss: 0.9395 - val_accuracy: 0.8100
#
# Epoch 00028: saving model to sloan_dense/model-00028-0.60-0.8338-0.94-0.8100.h5
# Epoch 29/40
# 25/25 [==============================] - 14s 511ms/step - loss: 0.5849 - accuracy: 0.8363 - val_loss: 0.9547 - val_accuracy: 0.8150
#
# Epoch 00029: saving model to sloan_dense/model-00029-0.58-0.8363-0.95-0.8150.h5
# Epoch 30/40
# 25/25 [==============================] - 14s 510ms/step - loss: 0.5744 - accuracy: 0.8388 - val_loss: 0.9241 - val_accuracy: 0.8100
#
# Epoch 00030: saving model to sloan_dense/model-00030-0.57-0.8388-0.92-0.8100.h5
# Epoch 31/40
# 25/25 [==============================] - 14s 512ms/step - loss: 0.5591 - accuracy: 0.8363 - val_loss: 0.9337 - val_accuracy: 0.7900
#
# Epoch 00031: saving model to sloan_dense/model-00031-0.56-0.8363-0.93-0.7900.h5
# Epoch 32/40
# 25/25 [==============================] - 14s 508ms/step - loss: 0.5529 - accuracy: 0.8400 - val_loss: 0.9252 - val_accuracy: 0.8100
#
# Epoch 00032: saving model to sloan_dense/model-00032-0.55-0.8400-0.93-0.8100.h5
# Epoch 33/40
# 25/25 [==============================] - 14s 505ms/step - loss: 0.5353 - accuracy: 0.8525 - val_loss: 0.8907 - val_accuracy: 0.8200
#
# Epoch 00033: saving model to sloan_dense/model-00033-0.54-0.8525-0.89-0.8200.h5
# Epoch 34/40
# 25/25 [==============================] - 14s 501ms/step - loss: 0.5215 - accuracy: 0.8500 - val_loss: 0.8957 - val_accuracy: 0.8300
#
# Epoch 00034: saving model to sloan_dense/model-00034-0.52-0.8500-0.90-0.8300.h5
# Epoch 35/40
# 25/25 [==============================] - 14s 502ms/step - loss: 0.5200 - accuracy: 0.8600 - val_loss: 0.8801 - val_accuracy: 0.8350
#
# Epoch 00035: saving model to sloan_dense/model-00035-0.52-0.8600-0.88-0.8350.h5
# Epoch 36/40
# 25/25 [==============================] - 14s 502ms/step - loss: 0.4973 - accuracy: 0.8662 - val_loss: 0.8660 - val_accuracy: 0.8350
#
# Epoch 00036: saving model to sloan_dense/model-00036-0.50-0.8662-0.87-0.8350.h5
# Epoch 37/40
# 25/25 [==============================] - 14s 503ms/step - loss: 0.4910 - accuracy: 0.8600 - val_loss: 0.8738 - val_accuracy: 0.8350
#
# Epoch 00037: saving model to sloan_dense/model-00037-0.49-0.8600-0.87-0.8350.h5
# Epoch 38/40
# 25/25 [==============================] - 14s 501ms/step - loss: 0.4808 - accuracy: 0.8662 - val_loss: 0.8538 - val_accuracy: 0.8350
#
# Epoch 00038: saving model to sloan_dense/model-00038-0.48-0.8662-0.85-0.8350.h5
# Epoch 39/40
# 25/25 [==============================] - 14s 502ms/step - loss: 0.4719 - accuracy: 0.8712 - val_loss: 0.8618 - val_accuracy: 0.8400
#
# Epoch 00039: saving model to sloan_dense/model-00039-0.47-0.8712-0.86-0.8400.h5
# Epoch 40/40
# 25/25 [==============================] - 14s 507ms/step - loss: 0.4683 - accuracy: 0.8675 - val_loss: 0.8540 - val_accuracy: 0.8400
#
# Epoch 00040: saving model to sloan_dense/model-00040-0.47-0.8675-0.85-0.8400.h5

# %%
metrics = Metrics(densenet_model,val_ds)
print(metrics.calculate_scores())
print('---------------------------------------------------------------------------------------------------------------------')
# Out:
# calculating score.....
# [[85  2  9]
#  [ 4  5  8]
#  [ 4  5 78]]
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.89      0.90        96
#          1.0       0.42      0.29      0.34        17
#          2.0       0.82      0.90      0.86        87
#
#     accuracy                           0.84       200
#    macro avg       0.72      0.69      0.70       200
# weighted avg       0.83      0.84      0.83       200
#
# None
# ---------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ##### densenet without scaling

# %%
densenet_model.fit(train_ds,validation_data=val_ds,epochs = 40, verbose = 1, workers = 3, class_weight = {0:1.13, 1:8.03, 2:1}, callbacks = callbacks_dense)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/40
# 25/25 [==============================] - 20s 460ms/step - loss: 6.8324 - accuracy: 0.2100 - val_loss: 4.3144 - val_accuracy: 0.2250
#
# Epoch 00001: saving model to sloan_dense/model-00001-6.83-0.2100-4.31-0.2250.h5
# Epoch 2/40
# 25/25 [==============================] - 11s 377ms/step - loss: 5.6543 - accuracy: 0.2612 - val_loss: 3.5993 - val_accuracy: 0.2400
#
# Epoch 00002: saving model to sloan_dense/model-00002-5.65-0.2612-3.60-0.2400.h5
# Epoch 3/40
# 25/25 [==============================] - 11s 383ms/step - loss: 4.7375 - accuracy: 0.2937 - val_loss: 3.2093 - val_accuracy: 0.2950
#
# Epoch 00003: saving model to sloan_dense/model-00003-4.74-0.2937-3.21-0.2950.h5
# Epoch 4/40
# 25/25 [==============================] - 11s 380ms/step - loss: 4.0245 - accuracy: 0.3650 - val_loss: 2.7328 - val_accuracy: 0.3500
#
# Epoch 00004: saving model to sloan_dense/model-00004-4.02-0.3650-2.73-0.3500.h5
# Epoch 5/40
# 25/25 [==============================] - 11s 377ms/step - loss: 3.4404 - accuracy: 0.3963 - val_loss: 2.5113 - val_accuracy: 0.3900
#
# Epoch 00005: saving model to sloan_dense/model-00005-3.44-0.3963-2.51-0.3900.h5
# Epoch 6/40
# 25/25 [==============================] - 11s 377ms/step - loss: 3.0325 - accuracy: 0.4425 - val_loss: 2.1657 - val_accuracy: 0.4450
#
# Epoch 00006: saving model to sloan_dense/model-00006-3.03-0.4425-2.17-0.4450.h5
# Epoch 7/40
# 25/25 [==============================] - 11s 380ms/step - loss: 2.7578 - accuracy: 0.4787 - val_loss: 2.0220 - val_accuracy: 0.4900
#
# Epoch 00007: saving model to sloan_dense/model-00007-2.76-0.4787-2.02-0.4900.h5
# Epoch 8/40
# 25/25 [==============================] - 11s 381ms/step - loss: 2.5051 - accuracy: 0.5350 - val_loss: 1.8600 - val_accuracy: 0.5400
#
# Epoch 00008: saving model to sloan_dense/model-00008-2.51-0.5350-1.86-0.5400.h5
# Epoch 9/40
# 25/25 [==============================] - 11s 377ms/step - loss: 2.3072 - accuracy: 0.5512 - val_loss: 1.6567 - val_accuracy: 0.5500
#
# Epoch 00009: saving model to sloan_dense/model-00009-2.31-0.5512-1.66-0.5500.h5
# Epoch 10/40
# 25/25 [==============================] - 11s 379ms/step - loss: 2.1883 - accuracy: 0.5800 - val_loss: 1.6140 - val_accuracy: 0.5700
#
# Epoch 00010: saving model to sloan_dense/model-00010-2.19-0.5800-1.61-0.5700.h5
# Epoch 11/40
# 25/25 [==============================] - 11s 378ms/step - loss: 1.9926 - accuracy: 0.6037 - val_loss: 1.4675 - val_accuracy: 0.5900
#
# Epoch 00011: saving model to sloan_dense/model-00011-1.99-0.6037-1.47-0.5900.h5
# Epoch 12/40
# 25/25 [==============================] - 11s 372ms/step - loss: 1.9043 - accuracy: 0.6200 - val_loss: 1.5184 - val_accuracy: 0.6000
#
# Epoch 00012: saving model to sloan_dense/model-00012-1.90-0.6200-1.52-0.6000.h5
# Epoch 13/40
# 25/25 [==============================] - 11s 374ms/step - loss: 1.7556 - accuracy: 0.6225 - val_loss: 1.2998 - val_accuracy: 0.6300
#
# Epoch 00013: saving model to sloan_dense/model-00013-1.76-0.6225-1.30-0.6300.h5
# Epoch 14/40
# 25/25 [==============================] - 11s 377ms/step - loss: 1.6906 - accuracy: 0.6300 - val_loss: 1.2417 - val_accuracy: 0.6300
#
# Epoch 00014: saving model to sloan_dense/model-00014-1.69-0.6300-1.24-0.6300.h5
# Epoch 15/40
# 25/25 [==============================] - 11s 375ms/step - loss: 1.5901 - accuracy: 0.6612 - val_loss: 1.2091 - val_accuracy: 0.6400
#
# Epoch 00015: saving model to sloan_dense/model-00015-1.59-0.6612-1.21-0.6400.h5
# Epoch 16/40
# 25/25 [==============================] - 11s 371ms/step - loss: 1.5090 - accuracy: 0.6812 - val_loss: 1.1727 - val_accuracy: 0.6650
#
# Epoch 00016: saving model to sloan_dense/model-00016-1.51-0.6812-1.17-0.6650.h5
# Epoch 17/40
# 25/25 [==============================] - 11s 374ms/step - loss: 1.4711 - accuracy: 0.6850 - val_loss: 1.1010 - val_accuracy: 0.6750
#
# Epoch 00017: saving model to sloan_dense/model-00017-1.47-0.6850-1.10-0.6750.h5
# Epoch 18/40
# 25/25 [==============================] - 11s 373ms/step - loss: 1.4047 - accuracy: 0.6963 - val_loss: 1.0241 - val_accuracy: 0.6800
#
# Epoch 00018: saving model to sloan_dense/model-00018-1.40-0.6963-1.02-0.6800.h5
# Epoch 19/40
# 25/25 [==============================] - 11s 372ms/step - loss: 1.3510 - accuracy: 0.7237 - val_loss: 1.0533 - val_accuracy: 0.7000
#
# Epoch 00019: saving model to sloan_dense/model-00019-1.35-0.7237-1.05-0.7000.h5
# Epoch 20/40
# 25/25 [==============================] - 11s 371ms/step - loss: 1.2850 - accuracy: 0.7237 - val_loss: 0.9643 - val_accuracy: 0.7100
#
# Epoch 00020: saving model to sloan_dense/model-00020-1.29-0.7237-0.96-0.7100.h5
# Epoch 21/40
# 25/25 [==============================] - 11s 374ms/step - loss: 1.2480 - accuracy: 0.7500 - val_loss: 0.9715 - val_accuracy: 0.7200
#
# Epoch 00021: saving model to sloan_dense/model-00021-1.25-0.7500-0.97-0.7200.h5
# Epoch 22/40
# 25/25 [==============================] - 11s 374ms/step - loss: 1.2113 - accuracy: 0.7312 - val_loss: 0.9070 - val_accuracy: 0.7250
#
# Epoch 00022: saving model to sloan_dense/model-00022-1.21-0.7312-0.91-0.7250.h5
# Epoch 23/40
# 25/25 [==============================] - 11s 374ms/step - loss: 1.1688 - accuracy: 0.7538 - val_loss: 0.9103 - val_accuracy: 0.7400
#
# Epoch 00023: saving model to sloan_dense/model-00023-1.17-0.7538-0.91-0.7400.h5
# Epoch 24/40
# 25/25 [==============================] - 11s 378ms/step - loss: 1.1349 - accuracy: 0.7575 - val_loss: 0.8576 - val_accuracy: 0.7300
#
# Epoch 00024: saving model to sloan_dense/model-00024-1.13-0.7575-0.86-0.7300.h5
# Epoch 25/40
# 25/25 [==============================] - 11s 376ms/step - loss: 1.1089 - accuracy: 0.7563 - val_loss: 0.8584 - val_accuracy: 0.7450
#
# Epoch 00025: saving model to sloan_dense/model-00025-1.11-0.7563-0.86-0.7450.h5
# Epoch 26/40
# 25/25 [==============================] - 12s 386ms/step - loss: 1.0704 - accuracy: 0.7688 - val_loss: 0.8218 - val_accuracy: 0.7550
#
# Epoch 00026: saving model to sloan_dense/model-00026-1.07-0.7688-0.82-0.7550.h5
# Epoch 27/40
# 25/25 [==============================] - 11s 381ms/step - loss: 1.0338 - accuracy: 0.7850 - val_loss: 0.8455 - val_accuracy: 0.7550
#
# Epoch 00027: saving model to sloan_dense/model-00027-1.03-0.7850-0.85-0.7550.h5
# Epoch 28/40
# 25/25 [==============================] - 11s 383ms/step - loss: 1.0105 - accuracy: 0.7925 - val_loss: 0.7963 - val_accuracy: 0.7700
#
# Epoch 00028: saving model to sloan_dense/model-00028-1.01-0.7925-0.80-0.7700.h5
# Epoch 29/40
# 25/25 [==============================] - 11s 386ms/step - loss: 0.9954 - accuracy: 0.7825 - val_loss: 0.7796 - val_accuracy: 0.7700
#
# Epoch 00029: saving model to sloan_dense/model-00029-1.00-0.7825-0.78-0.7700.h5
# Epoch 30/40
# 25/25 [==============================] - 11s 374ms/step - loss: 0.9521 - accuracy: 0.8037 - val_loss: 0.8135 - val_accuracy: 0.7750
#
# Epoch 00030: saving model to sloan_dense/model-00030-0.95-0.8037-0.81-0.7750.h5
# Epoch 31/40
# 25/25 [==============================] - 11s 373ms/step - loss: 0.9312 - accuracy: 0.8062 - val_loss: 0.7705 - val_accuracy: 0.7900
#
# Epoch 00031: saving model to sloan_dense/model-00031-0.93-0.8062-0.77-0.7900.h5
# Epoch 32/40
# 25/25 [==============================] - 11s 374ms/step - loss: 0.9171 - accuracy: 0.8037 - val_loss: 0.7481 - val_accuracy: 0.7750
#
# Epoch 00032: saving model to sloan_dense/model-00032-0.92-0.8037-0.75-0.7750.h5
# Epoch 33/40
# 25/25 [==============================] - 11s 373ms/step - loss: 0.9077 - accuracy: 0.8087 - val_loss: 0.7464 - val_accuracy: 0.7850
#
# Epoch 00033: saving model to sloan_dense/model-00033-0.91-0.8087-0.75-0.7850.h5
# Epoch 34/40
# 25/25 [==============================] - 11s 376ms/step - loss: 0.8685 - accuracy: 0.8188 - val_loss: 0.7226 - val_accuracy: 0.7900
#
# Epoch 00034: saving model to sloan_dense/model-00034-0.87-0.8188-0.72-0.7900.h5
# Epoch 35/40
# 25/25 [==============================] - 11s 376ms/step - loss: 0.8462 - accuracy: 0.8200 - val_loss: 0.7377 - val_accuracy: 0.8000
#
# Epoch 00035: saving model to sloan_dense/model-00035-0.85-0.8200-0.74-0.8000.h5
# Epoch 36/40
# 25/25 [==============================] - 11s 371ms/step - loss: 0.8380 - accuracy: 0.8100 - val_loss: 0.7159 - val_accuracy: 0.7950
#
# Epoch 00036: saving model to sloan_dense/model-00036-0.84-0.8100-0.72-0.7950.h5
# Epoch 37/40
# 25/25 [==============================] - 11s 372ms/step - loss: 0.8376 - accuracy: 0.8275 - val_loss: 0.7054 - val_accuracy: 0.8000
#
# Epoch 00037: saving model to sloan_dense/model-00037-0.84-0.8275-0.71-0.8000.h5
# Epoch 38/40
# 25/25 [==============================] - 11s 374ms/step - loss: 0.7978 - accuracy: 0.8363 - val_loss: 0.6904 - val_accuracy: 0.7950
#
# Epoch 00038: saving model to sloan_dense/model-00038-0.80-0.8363-0.69-0.7950.h5
# Epoch 39/40
# 25/25 [==============================] - 11s 374ms/step - loss: 0.7689 - accuracy: 0.8300 - val_loss: 0.7082 - val_accuracy: 0.8050
#
# Epoch 00039: saving model to sloan_dense/model-00039-0.77-0.8300-0.71-0.8050.h5
# Epoch 40/40
# 25/25 [==============================] - 11s 372ms/step - loss: 0.7548 - accuracy: 0.8363 - val_loss: 0.6877 - val_accuracy: 0.8000
#
# Epoch 00040: saving model to sloan_dense/model-00040-0.75-0.8363-0.69-0.8000.h5

# %%
metrics = Metrics(densenet_model,val_ds)
print(metrics.calculate_scores())
print('---------------------------------------------------------------------------------------------------------------------')
# Out:
# calculating score.....
# [[84  3  9]
#  [ 1  9  7]
#  [ 7 13 67]]
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.88      0.89        96
#          1.0       0.36      0.53      0.43        17
#          2.0       0.81      0.77      0.79        87
#
#     accuracy                           0.80       200
#    macro avg       0.69      0.72      0.70       200
# weighted avg       0.82      0.80      0.81       200
#
# None
# ---------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ##### Densenet with scale

# %%
densenet_model.fit(train_ds_scaled,validation_data=val_ds_scaled,epochs = 40, verbose = 1, workers = 3, class_weight = {0:1.13, 1:8.03, 2:1}, callbacks = callbacks_dense)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/40
# 25/25 [==============================] - 86s 2s/step - loss: 5.1717 - accuracy: 0.4475 - val_loss: 1.8372 - val_accuracy: 0.3900
#
# Epoch 00001: saving model to sloan_dense/model-00001-5.17-0.4475-1.84-0.3900.h5
# Epoch 2/40
# 25/25 [==============================] - 10s 351ms/step - loss: 3.1863 - accuracy: 0.3750 - val_loss: 1.6543 - val_accuracy: 0.3800
#
# Epoch 00002: saving model to sloan_dense/model-00002-3.19-0.3750-1.65-0.3800.h5
# Epoch 3/40
# 25/25 [==============================] - 10s 350ms/step - loss: 2.7202 - accuracy: 0.3913 - val_loss: 1.4601 - val_accuracy: 0.4250
#
# Epoch 00003: saving model to sloan_dense/model-00003-2.72-0.3913-1.46-0.4250.h5
# Epoch 4/40
# 25/25 [==============================] - 10s 350ms/step - loss: 2.4120 - accuracy: 0.4450 - val_loss: 1.3066 - val_accuracy: 0.5000
#
# Epoch 00004: saving model to sloan_dense/model-00004-2.41-0.4450-1.31-0.5000.h5
# Epoch 5/40
# 25/25 [==============================] - 10s 349ms/step - loss: 2.1391 - accuracy: 0.5275 - val_loss: 1.1841 - val_accuracy: 0.5850
#
# Epoch 00005: saving model to sloan_dense/model-00005-2.14-0.5275-1.18-0.5850.h5
# Epoch 6/40
# 25/25 [==============================] - 10s 349ms/step - loss: 1.9123 - accuracy: 0.5525 - val_loss: 1.1339 - val_accuracy: 0.5900
#
# Epoch 00006: saving model to sloan_dense/model-00006-1.91-0.5525-1.13-0.5900.h5
# Epoch 7/40
# 25/25 [==============================] - 10s 350ms/step - loss: 1.7363 - accuracy: 0.6125 - val_loss: 1.0509 - val_accuracy: 0.6150
#
# Epoch 00007: saving model to sloan_dense/model-00007-1.74-0.6125-1.05-0.6150.h5
# Epoch 8/40
# 25/25 [==============================] - 10s 349ms/step - loss: 1.5706 - accuracy: 0.6212 - val_loss: 0.9058 - val_accuracy: 0.6600
#
# Epoch 00008: saving model to sloan_dense/model-00008-1.57-0.6212-0.91-0.6600.h5
# Epoch 9/40
# 25/25 [==============================] - 10s 348ms/step - loss: 1.4406 - accuracy: 0.6750 - val_loss: 0.8870 - val_accuracy: 0.6800
#
# Epoch 00009: saving model to sloan_dense/model-00009-1.44-0.6750-0.89-0.6800.h5
# Epoch 10/40
# 25/25 [==============================] - 10s 349ms/step - loss: 1.3360 - accuracy: 0.6925 - val_loss: 0.8340 - val_accuracy: 0.6950
#
# Epoch 00010: saving model to sloan_dense/model-00010-1.34-0.6925-0.83-0.6950.h5
# Epoch 11/40
# 25/25 [==============================] - 10s 349ms/step - loss: 1.2509 - accuracy: 0.7125 - val_loss: 0.7606 - val_accuracy: 0.7100
#
# Epoch 00011: saving model to sloan_dense/model-00011-1.25-0.7125-0.76-0.7100.h5
# Epoch 12/40
# 25/25 [==============================] - 10s 348ms/step - loss: 1.1778 - accuracy: 0.7412 - val_loss: 0.7625 - val_accuracy: 0.7300
#
# Epoch 00012: saving model to sloan_dense/model-00012-1.18-0.7412-0.76-0.7300.h5
# Epoch 13/40
# 25/25 [==============================] - 10s 348ms/step - loss: 1.1260 - accuracy: 0.7375 - val_loss: 0.7131 - val_accuracy: 0.7400
#
# Epoch 00013: saving model to sloan_dense/model-00013-1.13-0.7375-0.71-0.7400.h5
# Epoch 14/40
# 25/25 [==============================] - 10s 350ms/step - loss: 1.0681 - accuracy: 0.7487 - val_loss: 0.7128 - val_accuracy: 0.7300
#
# Epoch 00014: saving model to sloan_dense/model-00014-1.07-0.7487-0.71-0.7300.h5
# Epoch 15/40
# 25/25 [==============================] - 10s 349ms/step - loss: 1.0320 - accuracy: 0.7487 - val_loss: 0.6532 - val_accuracy: 0.7600
#
# Epoch 00015: saving model to sloan_dense/model-00015-1.03-0.7487-0.65-0.7600.h5
# Epoch 16/40
# 25/25 [==============================] - 10s 352ms/step - loss: 0.9869 - accuracy: 0.7525 - val_loss: 0.6834 - val_accuracy: 0.7350
#
# Epoch 00016: saving model to sloan_dense/model-00016-0.99-0.7525-0.68-0.7350.h5
# Epoch 17/40
# 25/25 [==============================] - 10s 350ms/step - loss: 0.9555 - accuracy: 0.7625 - val_loss: 0.6421 - val_accuracy: 0.7650
#
# Epoch 00017: saving model to sloan_dense/model-00017-0.96-0.7625-0.64-0.7650.h5
# Epoch 18/40
# 25/25 [==============================] - 10s 353ms/step - loss: 0.9290 - accuracy: 0.7812 - val_loss: 0.6579 - val_accuracy: 0.7650
#
# Epoch 00018: saving model to sloan_dense/model-00018-0.93-0.7812-0.66-0.7650.h5
# Epoch 19/40
# 25/25 [==============================] - 10s 351ms/step - loss: 0.9011 - accuracy: 0.7663 - val_loss: 0.6407 - val_accuracy: 0.7700
#
# Epoch 00019: saving model to sloan_dense/model-00019-0.90-0.7663-0.64-0.7700.h5
# Epoch 20/40
# 25/25 [==============================] - 10s 349ms/step - loss: 0.8825 - accuracy: 0.7937 - val_loss: 0.6423 - val_accuracy: 0.7650
#
# Epoch 00020: saving model to sloan_dense/model-00020-0.88-0.7937-0.64-0.7650.h5
# Epoch 21/40
# 25/25 [==============================] - 10s 351ms/step - loss: 0.8572 - accuracy: 0.7812 - val_loss: 0.6235 - val_accuracy: 0.7700
#
# Epoch 00021: saving model to sloan_dense/model-00021-0.86-0.7812-0.62-0.7700.h5
# Epoch 22/40
# 25/25 [==============================] - 10s 351ms/step - loss: 0.8455 - accuracy: 0.8000 - val_loss: 0.6231 - val_accuracy: 0.7650
#
# Epoch 00022: saving model to sloan_dense/model-00022-0.85-0.8000-0.62-0.7650.h5
# Epoch 23/40
# 25/25 [==============================] - 10s 349ms/step - loss: 0.8213 - accuracy: 0.7862 - val_loss: 0.6087 - val_accuracy: 0.7650
#
# Epoch 00023: saving model to sloan_dense/model-00023-0.82-0.7862-0.61-0.7650.h5
# Epoch 24/40
# 25/25 [==============================] - 10s 352ms/step - loss: 0.8135 - accuracy: 0.8225 - val_loss: 0.5809 - val_accuracy: 0.7800
#
# Epoch 00024: saving model to sloan_dense/model-00024-0.81-0.8225-0.58-0.7800.h5
# Epoch 25/40
# 25/25 [==============================] - 10s 351ms/step - loss: 0.7928 - accuracy: 0.7950 - val_loss: 0.6044 - val_accuracy: 0.7600
#
# Epoch 00025: saving model to sloan_dense/model-00025-0.79-0.7950-0.60-0.7600.h5
# Epoch 26/40
# 25/25 [==============================] - 10s 350ms/step - loss: 0.7774 - accuracy: 0.8062 - val_loss: 0.5753 - val_accuracy: 0.7800
#
# Epoch 00026: saving model to sloan_dense/model-00026-0.78-0.8062-0.58-0.7800.h5
# Epoch 27/40
# 25/25 [==============================] - 10s 352ms/step - loss: 0.7622 - accuracy: 0.8238 - val_loss: 0.5695 - val_accuracy: 0.7800
#
# Epoch 00027: saving model to sloan_dense/model-00027-0.76-0.8238-0.57-0.7800.h5
# Epoch 28/40
# 25/25 [==============================] - 10s 348ms/step - loss: 0.7502 - accuracy: 0.8062 - val_loss: 0.5767 - val_accuracy: 0.7650
#
# Epoch 00028: saving model to sloan_dense/model-00028-0.75-0.8062-0.58-0.7650.h5
# Epoch 29/40
# 25/25 [==============================] - 10s 350ms/step - loss: 0.7379 - accuracy: 0.8200 - val_loss: 0.5423 - val_accuracy: 0.7950
#
# Epoch 00029: saving model to sloan_dense/model-00029-0.74-0.8200-0.54-0.7950.h5
# Epoch 30/40
# 25/25 [==============================] - 10s 350ms/step - loss: 0.7270 - accuracy: 0.8300 - val_loss: 0.5480 - val_accuracy: 0.7950
#
# Epoch 00030: saving model to sloan_dense/model-00030-0.73-0.8300-0.55-0.7950.h5
# Epoch 31/40
# 25/25 [==============================] - 10s 351ms/step - loss: 0.7157 - accuracy: 0.8175 - val_loss: 0.5562 - val_accuracy: 0.7750
#
# Epoch 00031: saving model to sloan_dense/model-00031-0.72-0.8175-0.56-0.7750.h5
# Epoch 32/40
# 25/25 [==============================] - 10s 348ms/step - loss: 0.7082 - accuracy: 0.8275 - val_loss: 0.5272 - val_accuracy: 0.8050
#
# Epoch 00032: saving model to sloan_dense/model-00032-0.71-0.8275-0.53-0.8050.h5
# Epoch 33/40
# 25/25 [==============================] - 10s 350ms/step - loss: 0.6988 - accuracy: 0.8350 - val_loss: 0.5371 - val_accuracy: 0.7950
#
# Epoch 00033: saving model to sloan_dense/model-00033-0.70-0.8350-0.54-0.7950.h5
# Epoch 34/40
# 25/25 [==============================] - 10s 351ms/step - loss: 0.6903 - accuracy: 0.8250 - val_loss: 0.5194 - val_accuracy: 0.8100
#
# Epoch 00034: saving model to sloan_dense/model-00034-0.69-0.8250-0.52-0.8100.h5
# Epoch 35/40
# 25/25 [==============================] - 10s 347ms/step - loss: 0.6851 - accuracy: 0.8413 - val_loss: 0.4909 - val_accuracy: 0.8100
#
# Epoch 00035: saving model to sloan_dense/model-00035-0.69-0.8413-0.49-0.8100.h5
# Epoch 36/40
# 25/25 [==============================] - 10s 351ms/step - loss: 0.6644 - accuracy: 0.8438 - val_loss: 0.5382 - val_accuracy: 0.7750
#
# Epoch 00036: saving model to sloan_dense/model-00036-0.66-0.8438-0.54-0.7750.h5
# Epoch 37/40
# 25/25 [==============================] - 10s 350ms/step - loss: 0.6627 - accuracy: 0.8400 - val_loss: 0.5099 - val_accuracy: 0.8100
#
# Epoch 00037: saving model to sloan_dense/model-00037-0.66-0.8400-0.51-0.8100.h5
# Epoch 38/40
# 25/25 [==============================] - 10s 350ms/step - loss: 0.6601 - accuracy: 0.8512 - val_loss: 0.5192 - val_accuracy: 0.7900
#
# Epoch 00038: saving model to sloan_dense/model-00038-0.66-0.8512-0.52-0.7900.h5
# Epoch 39/40
# 25/25 [==============================] - 10s 353ms/step - loss: 0.6457 - accuracy: 0.8487 - val_loss: 0.5037 - val_accuracy: 0.8100
#
# Epoch 00039: saving model to sloan_dense/model-00039-0.65-0.8487-0.50-0.8100.h5
# Epoch 40/40
# 25/25 [==============================] - 10s 349ms/step - loss: 0.6367 - accuracy: 0.8500 - val_loss: 0.4970 - val_accuracy: 0.8100
#
# Epoch 00040: saving model to sloan_dense/model-00040-0.64-0.8500-0.50-0.8100.h5

# %%
dense_scaled = load_model('./sloan_dense/Dense_scale-0.69-0.8250-0.52-0.8100.h5') 
metrics = Metrics(dense_scaled,val_ds_scaled)
print(metrics.calculate_scores())
print('---------------------------------------------------------------------------------------------------------------------')
# Out:
# calculating score.....
# [[89  2  5]
#  [ 1 11  5]
#  [ 7 18 62]]
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.93      0.92        96
#          1.0       0.35      0.65      0.46        17
#          2.0       0.86      0.71      0.78        87
#
#     accuracy                           0.81       200
#    macro avg       0.71      0.76      0.72       200
# weighted avg       0.85      0.81      0.82       200
#
# None
# ---------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ##### Augmentation techniques

# %%
train_ds_scaled_flip = prepare_dataset(train_ds_scaled, flip= True)
train_ds_scaled_flip_rotate = prepare_dataset(train_ds_scaled, flip_rotate = True)
train_ds_scaled_crop_flip = prepare_dataset_crop(train_ds_scaled_cropped, crop_flip = True)
train_ds_scaled_crop_flip_rotate = prepare_dataset_crop(train_ds_scaled_cropped, crop_flip_rotate = True)

train_ds_normal_crop = prepare_dataset_normal_crop(train_ds_scaled_cropped, training = True) 
val_ds_normal_crop = prepare_dataset_normal_crop(val_ds_scaled_cropped, training = False)

dense_scaled_flip = load_model('./sloan_dense/Dense_scale-0.69-0.8250-0.52-0.8100.h5')
dense_scaled_flip_rotate = load_model('./sloan_dense/Dense_scale-0.69-0.8250-0.52-0.8100.h5') 
dense_scaled_crop_flip = load_model('./sloan_dense/Dense_scale-0.69-0.8250-0.52-0.8100.h5') 
dense_scaled_crop_flip_rotate = load_model('./sloan_dense/Dense_scale-0.69-0.8250-0.52-0.8100.h5')

# %% [markdown]
# ##### Dense scaled flip

# %%
dense_scaled_flip.fit(train_ds_scaled_flip,validation_data=val_ds_scaled,epochs = 40, verbose = 1, workers = 3, class_weight = {0:1.13, 1:8.03, 2:1}, callbacks = callbacks_dense)
# Out:
# Epoch 1/40
# 25/25 [==============================] - 14s 390ms/step - loss: 0.7504 - accuracy: 0.8338 - val_loss: 0.5467 - val_accuracy: 0.7750
#
# Epoch 00001: saving model to sloan_dense/model-00001-0.75-0.8338-0.55-0.7750.h5
# Epoch 2/40
# 25/25 [==============================] - 10s 325ms/step - loss: 0.6854 - accuracy: 0.8375 - val_loss: 0.5118 - val_accuracy: 0.8050
#
# Epoch 00002: saving model to sloan_dense/model-00002-0.69-0.8375-0.51-0.8050.h5
# Epoch 3/40
# 25/25 [==============================] - 10s 326ms/step - loss: 0.6996 - accuracy: 0.8250 - val_loss: 0.5497 - val_accuracy: 0.7800
#
# Epoch 00003: saving model to sloan_dense/model-00003-0.70-0.8250-0.55-0.7800.h5
# Epoch 4/40
# 25/25 [==============================] - 10s 333ms/step - loss: 0.6715 - accuracy: 0.8413 - val_loss: 0.5307 - val_accuracy: 0.7850
#
# Epoch 00004: saving model to sloan_dense/model-00004-0.67-0.8413-0.53-0.7850.h5
# Epoch 5/40
# 25/25 [==============================] - 10s 326ms/step - loss: 0.7026 - accuracy: 0.8238 - val_loss: 0.5690 - val_accuracy: 0.7850
#
# Epoch 00005: saving model to sloan_dense/model-00005-0.70-0.8238-0.57-0.7850.h5
# Epoch 6/40
# 25/25 [==============================] - 10s 330ms/step - loss: 0.6666 - accuracy: 0.8200 - val_loss: 0.4944 - val_accuracy: 0.8100
#
# Epoch 00006: saving model to sloan_dense/model-00006-0.67-0.8200-0.49-0.8100.h5
# Epoch 7/40
# 25/25 [==============================] - 10s 326ms/step - loss: 0.6765 - accuracy: 0.8550 - val_loss: 0.5468 - val_accuracy: 0.7950
#
# Epoch 00007: saving model to sloan_dense/model-00007-0.68-0.8550-0.55-0.7950.h5
# Epoch 8/40
# 25/25 [==============================] - 10s 331ms/step - loss: 0.6573 - accuracy: 0.8288 - val_loss: 0.5093 - val_accuracy: 0.7950
#
# Epoch 00008: saving model to sloan_dense/model-00008-0.66-0.8288-0.51-0.7950.h5
# Epoch 9/40
# 25/25 [==============================] - 10s 329ms/step - loss: 0.6374 - accuracy: 0.8413 - val_loss: 0.4800 - val_accuracy: 0.8150
#
# Epoch 00009: saving model to sloan_dense/model-00009-0.64-0.8413-0.48-0.8150.h5
# Epoch 10/40
# 25/25 [==============================] - 10s 325ms/step - loss: 0.6092 - accuracy: 0.8612 - val_loss: 0.5047 - val_accuracy: 0.8000
#
# Epoch 00010: saving model to sloan_dense/model-00010-0.61-0.8612-0.50-0.8000.h5
# Epoch 11/40
# 25/25 [==============================] - 10s 325ms/step - loss: 0.6299 - accuracy: 0.8612 - val_loss: 0.4901 - val_accuracy: 0.8050
#
# Epoch 00011: saving model to sloan_dense/model-00011-0.63-0.8612-0.49-0.8050.h5
# Epoch 12/40
# 25/25 [==============================] - 10s 330ms/step - loss: 0.6159 - accuracy: 0.8625 - val_loss: 0.5315 - val_accuracy: 0.7950
#
# Epoch 00012: saving model to sloan_dense/model-00012-0.62-0.8625-0.53-0.7950.h5
# Epoch 13/40
# 25/25 [==============================] - 10s 327ms/step - loss: 0.6251 - accuracy: 0.8413 - val_loss: 0.4686 - val_accuracy: 0.8150
#
# Epoch 00013: saving model to sloan_dense/model-00013-0.63-0.8413-0.47-0.8150.h5
# Epoch 14/40
# 25/25 [==============================] - 10s 331ms/step - loss: 0.6247 - accuracy: 0.8575 - val_loss: 0.4817 - val_accuracy: 0.8000
#
# Epoch 00014: saving model to sloan_dense/model-00014-0.62-0.8575-0.48-0.8000.h5
# Epoch 15/40
# 25/25 [==============================] - 10s 332ms/step - loss: 0.5777 - accuracy: 0.8650 - val_loss: 0.4760 - val_accuracy: 0.8000
#
# Epoch 00015: saving model to sloan_dense/model-00015-0.58-0.8650-0.48-0.8000.h5
# Epoch 16/40
# 25/25 [==============================] - 10s 333ms/step - loss: 0.6133 - accuracy: 0.8625 - val_loss: 0.4790 - val_accuracy: 0.8050
#
# Epoch 00016: saving model to sloan_dense/model-00016-0.61-0.8625-0.48-0.8050.h5
# Epoch 17/40
# 25/25 [==============================] - 10s 331ms/step - loss: 0.5932 - accuracy: 0.8637 - val_loss: 0.4722 - val_accuracy: 0.8100
#
# Epoch 00017: saving model to sloan_dense/model-00017-0.59-0.8637-0.47-0.8100.h5
# Epoch 18/40
# 25/25 [==============================] - 10s 337ms/step - loss: 0.6124 - accuracy: 0.8475 - val_loss: 0.4670 - val_accuracy: 0.8150
#
# Epoch 00018: saving model to sloan_dense/model-00018-0.61-0.8475-0.47-0.8150.h5
# Epoch 19/40
# 25/25 [==============================] - 10s 333ms/step - loss: 0.6564 - accuracy: 0.8600 - val_loss: 0.4871 - val_accuracy: 0.8150
#
# Epoch 00019: saving model to sloan_dense/model-00019-0.66-0.8600-0.49-0.8150.h5
# Epoch 20/40
# 25/25 [==============================] - 10s 330ms/step - loss: 0.5725 - accuracy: 0.8500 - val_loss: 0.4406 - val_accuracy: 0.8200
#
# Epoch 00020: saving model to sloan_dense/model-00020-0.57-0.8500-0.44-0.8200.h5
# Epoch 21/40
# 25/25 [==============================] - 10s 329ms/step - loss: 0.6069 - accuracy: 0.8763 - val_loss: 0.4718 - val_accuracy: 0.8100
#
# Epoch 00021: saving model to sloan_dense/model-00021-0.61-0.8763-0.47-0.8100.h5
# Epoch 22/40
# 25/25 [==============================] - 10s 329ms/step - loss: 0.5915 - accuracy: 0.8487 - val_loss: 0.4923 - val_accuracy: 0.8150
#
# Epoch 00022: saving model to sloan_dense/model-00022-0.59-0.8487-0.49-0.8150.h5
# Epoch 23/40
# 25/25 [==============================] - 10s 327ms/step - loss: 0.5760 - accuracy: 0.8788 - val_loss: 0.4626 - val_accuracy: 0.8100
#
# Epoch 00023: saving model to sloan_dense/model-00023-0.58-0.8788-0.46-0.8100.h5
# Epoch 24/40
# 25/25 [==============================] - 10s 329ms/step - loss: 0.5804 - accuracy: 0.8662 - val_loss: 0.4205 - val_accuracy: 0.8300
#
# Epoch 00024: saving model to sloan_dense/model-00024-0.58-0.8662-0.42-0.8300.h5
# Epoch 25/40
# 25/25 [==============================] - 10s 331ms/step - loss: 0.5548 - accuracy: 0.8800 - val_loss: 0.4639 - val_accuracy: 0.8150
#
# Epoch 00025: saving model to sloan_dense/model-00025-0.55-0.8800-0.46-0.8150.h5
# Epoch 26/40
# 25/25 [==============================] - 10s 326ms/step - loss: 0.5789 - accuracy: 0.8687 - val_loss: 0.4173 - val_accuracy: 0.8300
#
# Epoch 00026: saving model to sloan_dense/model-00026-0.58-0.8687-0.42-0.8300.h5
# Epoch 27/40
# 25/25 [==============================] - 10s 328ms/step - loss: 0.5509 - accuracy: 0.8737 - val_loss: 0.4283 - val_accuracy: 0.8250
#
# Epoch 00027: saving model to sloan_dense/model-00027-0.55-0.8737-0.43-0.8250.h5
# Epoch 28/40
# 25/25 [==============================] - 10s 329ms/step - loss: 0.5921 - accuracy: 0.8650 - val_loss: 0.4425 - val_accuracy: 0.8150
#
# Epoch 00028: saving model to sloan_dense/model-00028-0.59-0.8650-0.44-0.8150.h5
# Epoch 29/40
# 25/25 [==============================] - 10s 335ms/step - loss: 0.5373 - accuracy: 0.8838 - val_loss: 0.4404 - val_accuracy: 0.8200
#
# Epoch 00029: saving model to sloan_dense/model-00029-0.54-0.8838-0.44-0.8200.h5
# Epoch 30/40
# 25/25 [==============================] - 10s 334ms/step - loss: 0.5421 - accuracy: 0.8850 - val_loss: 0.4360 - val_accuracy: 0.8150
#
# Epoch 00030: saving model to sloan_dense/model-00030-0.54-0.8850-0.44-0.8150.h5
# Epoch 31/40
# 25/25 [==============================] - 10s 329ms/step - loss: 0.5806 - accuracy: 0.8612 - val_loss: 0.4201 - val_accuracy: 0.8300
#
# Epoch 00031: saving model to sloan_dense/model-00031-0.58-0.8612-0.42-0.8300.h5
# Epoch 32/40
# 25/25 [==============================] - 10s 327ms/step - loss: 0.5217 - accuracy: 0.8763 - val_loss: 0.4132 - val_accuracy: 0.8350
#
# Epoch 00032: saving model to sloan_dense/model-00032-0.52-0.8763-0.41-0.8350.h5
# Epoch 33/40
# 25/25 [==============================] - 10s 331ms/step - loss: 0.5240 - accuracy: 0.8900 - val_loss: 0.4178 - val_accuracy: 0.8350
#
# Epoch 00033: saving model to sloan_dense/model-00033-0.52-0.8900-0.42-0.8350.h5
# Epoch 34/40
# 25/25 [==============================] - 10s 335ms/step - loss: 0.5169 - accuracy: 0.8863 - val_loss: 0.4111 - val_accuracy: 0.8350
#
# Epoch 00034: saving model to sloan_dense/model-00034-0.52-0.8863-0.41-0.8350.h5
# Epoch 35/40
# 25/25 [==============================] - 10s 332ms/step - loss: 0.5520 - accuracy: 0.8712 - val_loss: 0.4436 - val_accuracy: 0.8150
#
# Epoch 00035: saving model to sloan_dense/model-00035-0.55-0.8712-0.44-0.8150.h5
# Epoch 36/40
# 25/25 [==============================] - 10s 334ms/step - loss: 0.4843 - accuracy: 0.8875 - val_loss: 0.4089 - val_accuracy: 0.8400
#
# Epoch 00036: saving model to sloan_dense/model-00036-0.48-0.8875-0.41-0.8400.h5
# Epoch 37/40
# 25/25 [==============================] - 10s 332ms/step - loss: 0.5059 - accuracy: 0.9025 - val_loss: 0.3976 - val_accuracy: 0.8350
#
# Epoch 00037: saving model to sloan_dense/model-00037-0.51-0.9025-0.40-0.8350.h5
# Epoch 38/40
# 25/25 [==============================] - 10s 337ms/step - loss: 0.5336 - accuracy: 0.8900 - val_loss: 0.4141 - val_accuracy: 0.8400
#
# Epoch 00038: saving model to sloan_dense/model-00038-0.53-0.8900-0.41-0.8400.h5
# Epoch 39/40
# 25/25 [==============================] - 10s 334ms/step - loss: 0.5260 - accuracy: 0.8875 - val_loss: 0.4323 - val_accuracy: 0.8250
#
# Epoch 00039: saving model to sloan_dense/model-00039-0.53-0.8875-0.43-0.8250.h5
# Epoch 40/40
# 25/25 [==============================] - 10s 335ms/step - loss: 0.5128 - accuracy: 0.8863 - val_loss: 0.3850 - val_accuracy: 0.8500
#
# Epoch 00040: saving model to sloan_dense/model-00040-0.51-0.8863-0.38-0.8500.h5

# %%
dense_scaled_flipped_model = load_model('./sloan_dense/dense_scaled_flip-0.51-0.8863-0.38-0.8500.h5') 
metrics = Metrics(dense_scaled_flipped_model,val_ds_scaled)
print(metrics.calculate_scores())
print('---------------------------------------------------------------------------------------------------------------------')
# Out:
# calculating score.....
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f0d15908b90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [[89  3  4]
#  [ 1  9  7]
#  [ 1 14 72]]
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.93      0.95        96
#          1.0       0.35      0.53      0.42        17
#          2.0       0.87      0.83      0.85        87
#
#     accuracy                           0.85       200
#    macro avg       0.73      0.76      0.74       200
# weighted avg       0.88      0.85      0.86       200
#
# None
# ---------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ##### Dense Scaled flip rotate

# %%
dense_scaled_flip_rotate.fit(train_ds_scaled_flip_rotate,validation_data=val_ds_scaled,epochs = 40, verbose = 1, workers = 3, class_weight = {0:1.13, 1:8.03, 2:1}, callbacks = callbacks_dense)
# Out:
# Epoch 1/40
# 25/25 [==============================] - 21s 626ms/step - loss: 0.7086 - accuracy: 0.8200 - val_loss: 0.5007 - val_accuracy: 0.8050
#
# Epoch 00001: saving model to sloan_dense/model-00001-0.71-0.8200-0.50-0.8050.h5
# Epoch 2/40
# 25/25 [==============================] - 17s 569ms/step - loss: 0.7479 - accuracy: 0.8150 - val_loss: 0.5632 - val_accuracy: 0.7700
#
# Epoch 00002: saving model to sloan_dense/model-00002-0.75-0.8150-0.56-0.7700.h5
# Epoch 3/40
# 25/25 [==============================] - 16s 563ms/step - loss: 0.7515 - accuracy: 0.8000 - val_loss: 0.5506 - val_accuracy: 0.7750
#
# Epoch 00003: saving model to sloan_dense/model-00003-0.75-0.8000-0.55-0.7750.h5
# Epoch 4/40
# 25/25 [==============================] - 17s 566ms/step - loss: 0.7665 - accuracy: 0.8300 - val_loss: 0.5460 - val_accuracy: 0.7800
#
# Epoch 00004: saving model to sloan_dense/model-00004-0.77-0.8300-0.55-0.7800.h5
# Epoch 5/40
# 25/25 [==============================] - 17s 563ms/step - loss: 0.7204 - accuracy: 0.8213 - val_loss: 0.5643 - val_accuracy: 0.7850
#
# Epoch 00005: saving model to sloan_dense/model-00005-0.72-0.8213-0.56-0.7850.h5
# Epoch 6/40
# 25/25 [==============================] - 17s 559ms/step - loss: 0.7099 - accuracy: 0.8175 - val_loss: 0.5270 - val_accuracy: 0.7850
#
# Epoch 00006: saving model to sloan_dense/model-00006-0.71-0.8175-0.53-0.7850.h5
# Epoch 7/40
# 25/25 [==============================] - 17s 572ms/step - loss: 0.7261 - accuracy: 0.8188 - val_loss: 0.5577 - val_accuracy: 0.7850
#
# Epoch 00007: saving model to sloan_dense/model-00007-0.73-0.8188-0.56-0.7850.h5
# Epoch 8/40
# 25/25 [==============================] - 17s 568ms/step - loss: 0.6803 - accuracy: 0.8250 - val_loss: 0.5374 - val_accuracy: 0.7900
#
# Epoch 00008: saving model to sloan_dense/model-00008-0.68-0.8250-0.54-0.7900.h5
# Epoch 9/40
# 25/25 [==============================] - 17s 563ms/step - loss: 0.6928 - accuracy: 0.8213 - val_loss: 0.5459 - val_accuracy: 0.7900
#
# Epoch 00009: saving model to sloan_dense/model-00009-0.69-0.8213-0.55-0.7900.h5
# Epoch 10/40
# 25/25 [==============================] - 16s 553ms/step - loss: 0.6434 - accuracy: 0.8413 - val_loss: 0.4890 - val_accuracy: 0.8050
#
# Epoch 00010: saving model to sloan_dense/model-00010-0.64-0.8413-0.49-0.8050.h5
# Epoch 11/40
# 25/25 [==============================] - 17s 562ms/step - loss: 0.6527 - accuracy: 0.8525 - val_loss: 0.5319 - val_accuracy: 0.7850
#
# Epoch 00011: saving model to sloan_dense/model-00011-0.65-0.8525-0.53-0.7850.h5
# Epoch 12/40
# 25/25 [==============================] - 17s 565ms/step - loss: 0.6298 - accuracy: 0.8400 - val_loss: 0.4918 - val_accuracy: 0.7950
#
# Epoch 00012: saving model to sloan_dense/model-00012-0.63-0.8400-0.49-0.7950.h5
# Epoch 13/40
# 25/25 [==============================] - 17s 574ms/step - loss: 0.6544 - accuracy: 0.8300 - val_loss: 0.4994 - val_accuracy: 0.8000
#
# Epoch 00013: saving model to sloan_dense/model-00013-0.65-0.8300-0.50-0.8000.h5
# Epoch 14/40
# 25/25 [==============================] - 17s 565ms/step - loss: 0.6292 - accuracy: 0.8375 - val_loss: 0.4923 - val_accuracy: 0.8000
#
# Epoch 00014: saving model to sloan_dense/model-00014-0.63-0.8375-0.49-0.8000.h5
# Epoch 15/40
# 25/25 [==============================] - 17s 572ms/step - loss: 0.6831 - accuracy: 0.8250 - val_loss: 0.5264 - val_accuracy: 0.7950
#
# Epoch 00015: saving model to sloan_dense/model-00015-0.68-0.8250-0.53-0.7950.h5
# Epoch 16/40
# 25/25 [==============================] - 17s 560ms/step - loss: 0.6302 - accuracy: 0.8537 - val_loss: 0.4821 - val_accuracy: 0.8000
#
# Epoch 00016: saving model to sloan_dense/model-00016-0.63-0.8537-0.48-0.8000.h5
# Epoch 17/40
# 25/25 [==============================] - 16s 556ms/step - loss: 0.6463 - accuracy: 0.8438 - val_loss: 0.5043 - val_accuracy: 0.7900
#
# Epoch 00017: saving model to sloan_dense/model-00017-0.65-0.8438-0.50-0.7900.h5
# Epoch 18/40
# 25/25 [==============================] - 17s 574ms/step - loss: 0.6589 - accuracy: 0.8300 - val_loss: 0.4643 - val_accuracy: 0.8050
#
# Epoch 00018: saving model to sloan_dense/model-00018-0.66-0.8300-0.46-0.8050.h5
# Epoch 19/40
# 25/25 [==============================] - 16s 549ms/step - loss: 0.6580 - accuracy: 0.8475 - val_loss: 0.4895 - val_accuracy: 0.8050
#
# Epoch 00019: saving model to sloan_dense/model-00019-0.66-0.8475-0.49-0.8050.h5
# Epoch 20/40
# 25/25 [==============================] - 17s 563ms/step - loss: 0.6282 - accuracy: 0.8425 - val_loss: 0.5177 - val_accuracy: 0.8000
#
# Epoch 00020: saving model to sloan_dense/model-00020-0.63-0.8425-0.52-0.8000.h5
# Epoch 21/40
# 25/25 [==============================] - 17s 567ms/step - loss: 0.5359 - accuracy: 0.8512 - val_loss: 0.4426 - val_accuracy: 0.8200
#
# Epoch 00021: saving model to sloan_dense/model-00021-0.54-0.8512-0.44-0.8200.h5
# Epoch 22/40
# 25/25 [==============================] - 16s 548ms/step - loss: 0.6145 - accuracy: 0.8625 - val_loss: 0.4381 - val_accuracy: 0.8250
#
# Epoch 00022: saving model to sloan_dense/model-00022-0.61-0.8625-0.44-0.8250.h5
# Epoch 23/40
# 25/25 [==============================] - 17s 567ms/step - loss: 0.6322 - accuracy: 0.8438 - val_loss: 0.5135 - val_accuracy: 0.8000
#
# Epoch 00023: saving model to sloan_dense/model-00023-0.63-0.8438-0.51-0.8000.h5
# Epoch 24/40
# 25/25 [==============================] - 17s 563ms/step - loss: 0.6275 - accuracy: 0.8475 - val_loss: 0.4490 - val_accuracy: 0.8150
#
# Epoch 00024: saving model to sloan_dense/model-00024-0.63-0.8475-0.45-0.8150.h5
# Epoch 25/40
# 25/25 [==============================] - 17s 567ms/step - loss: 0.6712 - accuracy: 0.8388 - val_loss: 0.4793 - val_accuracy: 0.8100
#
# Epoch 00025: saving model to sloan_dense/model-00025-0.67-0.8388-0.48-0.8100.h5
# Epoch 26/40
# 25/25 [==============================] - 16s 559ms/step - loss: 0.6204 - accuracy: 0.8525 - val_loss: 0.4343 - val_accuracy: 0.8150
#
# Epoch 00026: saving model to sloan_dense/model-00026-0.62-0.8525-0.43-0.8150.h5
# Epoch 27/40
# 25/25 [==============================] - 17s 560ms/step - loss: 0.5724 - accuracy: 0.8712 - val_loss: 0.4982 - val_accuracy: 0.8000
#
# Epoch 00027: saving model to sloan_dense/model-00027-0.57-0.8712-0.50-0.8000.h5
# Epoch 28/40
# 25/25 [==============================] - 17s 556ms/step - loss: 0.6671 - accuracy: 0.8250 - val_loss: 0.4907 - val_accuracy: 0.8000
#
# Epoch 00028: saving model to sloan_dense/model-00028-0.67-0.8250-0.49-0.8000.h5
# Epoch 29/40
# 25/25 [==============================] - 16s 560ms/step - loss: 0.6164 - accuracy: 0.8650 - val_loss: 0.4727 - val_accuracy: 0.7950
#
# Epoch 00029: saving model to sloan_dense/model-00029-0.62-0.8650-0.47-0.7950.h5
# Epoch 30/40
# 25/25 [==============================] - 17s 584ms/step - loss: 0.6068 - accuracy: 0.8338 - val_loss: 0.4589 - val_accuracy: 0.8150
#
# Epoch 00030: saving model to sloan_dense/model-00030-0.61-0.8338-0.46-0.8150.h5
# Epoch 31/40
# 25/25 [==============================] - 17s 567ms/step - loss: 0.5668 - accuracy: 0.8763 - val_loss: 0.4510 - val_accuracy: 0.8200
#
# Epoch 00031: saving model to sloan_dense/model-00031-0.57-0.8763-0.45-0.8200.h5
# Epoch 32/40
# 25/25 [==============================] - 17s 565ms/step - loss: 0.6102 - accuracy: 0.8575 - val_loss: 0.4838 - val_accuracy: 0.8050
#
# Epoch 00032: saving model to sloan_dense/model-00032-0.61-0.8575-0.48-0.8050.h5
# Epoch 33/40
# 25/25 [==============================] - 17s 570ms/step - loss: 0.6465 - accuracy: 0.8388 - val_loss: 0.4446 - val_accuracy: 0.8200
#
# Epoch 00033: saving model to sloan_dense/model-00033-0.65-0.8388-0.44-0.8200.h5
# Epoch 34/40
# 25/25 [==============================] - 17s 569ms/step - loss: 0.5969 - accuracy: 0.8650 - val_loss: 0.4529 - val_accuracy: 0.8150
#
# Epoch 00034: saving model to sloan_dense/model-00034-0.60-0.8650-0.45-0.8150.h5
# Epoch 35/40
# 25/25 [==============================] - 17s 574ms/step - loss: 0.5707 - accuracy: 0.8500 - val_loss: 0.4342 - val_accuracy: 0.8150
#
# Epoch 00035: saving model to sloan_dense/model-00035-0.57-0.8500-0.43-0.8150.h5
# Epoch 36/40
# 25/25 [==============================] - 17s 563ms/step - loss: 0.5718 - accuracy: 0.8612 - val_loss: 0.4158 - val_accuracy: 0.8150
#
# Epoch 00036: saving model to sloan_dense/model-00036-0.57-0.8612-0.42-0.8150.h5
# Epoch 37/40
# 25/25 [==============================] - 17s 568ms/step - loss: 0.5456 - accuracy: 0.8800 - val_loss: 0.4624 - val_accuracy: 0.8150
#
# Epoch 00037: saving model to sloan_dense/model-00037-0.55-0.8800-0.46-0.8150.h5
# Epoch 38/40
# 25/25 [==============================] - 17s 573ms/step - loss: 0.5519 - accuracy: 0.8662 - val_loss: 0.4323 - val_accuracy: 0.8200
#
# Epoch 00038: saving model to sloan_dense/model-00038-0.55-0.8662-0.43-0.8200.h5
# Epoch 39/40
# 25/25 [==============================] - 16s 543ms/step - loss: 0.5599 - accuracy: 0.8575 - val_loss: 0.4564 - val_accuracy: 0.8100
#
# Epoch 00039: saving model to sloan_dense/model-00039-0.56-0.8575-0.46-0.8100.h5
# Epoch 40/40
# 25/25 [==============================] - 17s 560ms/step - loss: 0.5601 - accuracy: 0.8662 - val_loss: 0.4147 - val_accuracy: 0.8200
#
# Epoch 00040: saving model to sloan_dense/model-00040-0.56-0.8662-0.41-0.8200.h5

# %%
dense_scaled_flipped_rotate_model = load_model('./sloan_dense/dense_scaled_flip_rotate-0.61-0.8625-0.44-0.8250.h5') 
metrics = Metrics(dense_scaled_flipped_rotate_model,val_ds_scaled)
print(metrics.calculate_scores())
print('---------------------------------------------------------------------------------------------------------------------')
# Out:
# calculating score.....
# [[90  2  4]
#  [ 1 11  5]
#  [ 4 19 64]]
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.94      0.94        96
#          1.0       0.34      0.65      0.45        17
#          2.0       0.88      0.74      0.80        87
#
#     accuracy                           0.82       200
#    macro avg       0.72      0.77      0.73       200
# weighted avg       0.87      0.82      0.84       200
#
# None
# ---------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ##### Densent crop flip scaled

# %%
dense_scaled_crop_flip.fit(train_ds_scaled_crop_flip,validation_data=val_ds_scaled,epochs = 40, verbose = 1, workers = 3, class_weight = {0:1.13, 1:8.03, 2:1}, callbacks = callbacks_dense)
# Out:
# Epoch 1/40
# 25/25 [==============================] - 16s 457ms/step - loss: 2.0104 - accuracy: 0.4250 - val_loss: 1.0156 - val_accuracy: 0.6450
#
# Epoch 00001: saving model to sloan_dense/model-00001-2.01-0.4250-1.02-0.6450.h5
# Epoch 2/40
# 25/25 [==============================] - 12s 406ms/step - loss: 1.6210 - accuracy: 0.3187 - val_loss: 1.0815 - val_accuracy: 0.6100
#
# Epoch 00002: saving model to sloan_dense/model-00002-1.62-0.3187-1.08-0.6100.h5
# Epoch 3/40
# 25/25 [==============================] - 12s 407ms/step - loss: 1.6005 - accuracy: 0.4437 - val_loss: 0.9644 - val_accuracy: 0.6600
#
# Epoch 00003: saving model to sloan_dense/model-00003-1.60-0.4437-0.96-0.6600.h5
# Epoch 4/40
# 25/25 [==============================] - 12s 403ms/step - loss: 1.5966 - accuracy: 0.5113 - val_loss: 0.9822 - val_accuracy: 0.6550
#
# Epoch 00004: saving model to sloan_dense/model-00004-1.60-0.5113-0.98-0.6550.h5
# Epoch 5/40
# 25/25 [==============================] - 12s 395ms/step - loss: 1.5938 - accuracy: 0.5138 - val_loss: 1.0079 - val_accuracy: 0.6350
#
# Epoch 00005: saving model to sloan_dense/model-00005-1.59-0.5138-1.01-0.6350.h5
# Epoch 6/40
# 25/25 [==============================] - 12s 398ms/step - loss: 1.5949 - accuracy: 0.5138 - val_loss: 0.9907 - val_accuracy: 0.6450
#
# Epoch 00006: saving model to sloan_dense/model-00006-1.59-0.5138-0.99-0.6450.h5
# Epoch 7/40
# 25/25 [==============================] - 12s 398ms/step - loss: 1.5954 - accuracy: 0.5113 - val_loss: 0.9883 - val_accuracy: 0.6500
#
# Epoch 00007: saving model to sloan_dense/model-00007-1.60-0.5113-0.99-0.6500.h5
# Epoch 8/40
# 25/25 [==============================] - 11s 392ms/step - loss: 1.5992 - accuracy: 0.5125 - val_loss: 0.9816 - val_accuracy: 0.6550
#
# Epoch 00008: saving model to sloan_dense/model-00008-1.60-0.5125-0.98-0.6550.h5
# Epoch 9/40
# 25/25 [==============================] - 11s 392ms/step - loss: 1.5958 - accuracy: 0.5138 - val_loss: 0.9888 - val_accuracy: 0.6550
#
# Epoch 00009: saving model to sloan_dense/model-00009-1.60-0.5138-0.99-0.6550.h5
# Epoch 10/40
# 25/25 [==============================] - 12s 397ms/step - loss: 1.5965 - accuracy: 0.4725 - val_loss: 1.0189 - val_accuracy: 0.6300
#
# Epoch 00010: saving model to sloan_dense/model-00010-1.60-0.4725-1.02-0.6300.h5
# Epoch 11/40
# 25/25 [==============================] - 11s 394ms/step - loss: 1.5949 - accuracy: 0.5138 - val_loss: 0.9697 - val_accuracy: 0.6550
#
# Epoch 00011: saving model to sloan_dense/model-00011-1.59-0.5138-0.97-0.6550.h5
# Epoch 12/40
# 25/25 [==============================] - 12s 396ms/step - loss: 1.5971 - accuracy: 0.4812 - val_loss: 0.9910 - val_accuracy: 0.6450
#
# Epoch 00012: saving model to sloan_dense/model-00012-1.60-0.4812-0.99-0.6450.h5
# Epoch 13/40
# 25/25 [==============================] - 12s 399ms/step - loss: 1.5982 - accuracy: 0.4650 - val_loss: 0.9944 - val_accuracy: 0.6500
#
# Epoch 00013: saving model to sloan_dense/model-00013-1.60-0.4650-0.99-0.6500.h5
# Epoch 14/40
# 25/25 [==============================] - 11s 392ms/step - loss: 1.5943 - accuracy: 0.5138 - val_loss: 1.0073 - val_accuracy: 0.6450
#
# Epoch 00014: saving model to sloan_dense/model-00014-1.59-0.5138-1.01-0.6450.h5
# Epoch 15/40
# 25/25 [==============================] - 11s 397ms/step - loss: 1.5957 - accuracy: 0.5138 - val_loss: 0.9940 - val_accuracy: 0.6450
#
# Epoch 00015: saving model to sloan_dense/model-00015-1.60-0.5138-0.99-0.6450.h5
# Epoch 16/40
# 25/25 [==============================] - 12s 395ms/step - loss: 1.5966 - accuracy: 0.5038 - val_loss: 0.9940 - val_accuracy: 0.6450
#
# Epoch 00016: saving model to sloan_dense/model-00016-1.60-0.5038-0.99-0.6450.h5
# Epoch 17/40
# 25/25 [==============================] - 12s 390ms/step - loss: 1.5940 - accuracy: 0.4688 - val_loss: 1.0098 - val_accuracy: 0.6350
#
# Epoch 00017: saving model to sloan_dense/model-00017-1.59-0.4688-1.01-0.6350.h5
# Epoch 18/40
# 25/25 [==============================] - 12s 396ms/step - loss: 1.5948 - accuracy: 0.5138 - val_loss: 0.9907 - val_accuracy: 0.6550
#
# Epoch 00018: saving model to sloan_dense/model-00018-1.59-0.5138-0.99-0.6550.h5
# Epoch 19/40
# 25/25 [==============================] - 11s 394ms/step - loss: 1.5960 - accuracy: 0.5063 - val_loss: 0.9873 - val_accuracy: 0.6550
#
# Epoch 00019: saving model to sloan_dense/model-00019-1.60-0.5063-0.99-0.6550.h5
# Epoch 20/40
# 25/25 [==============================] - 12s 398ms/step - loss: 1.5945 - accuracy: 0.4913 - val_loss: 1.0037 - val_accuracy: 0.6450
#
# Epoch 00020: saving model to sloan_dense/model-00020-1.59-0.4913-1.00-0.6450.h5
# Epoch 21/40
# 25/25 [==============================] - 12s 393ms/step - loss: 1.5970 - accuracy: 0.5138 - val_loss: 0.9913 - val_accuracy: 0.6450
#
# Epoch 00021: saving model to sloan_dense/model-00021-1.60-0.5138-0.99-0.6450.h5
# Epoch 22/40
# 25/25 [==============================] - 11s 396ms/step - loss: 1.5978 - accuracy: 0.5088 - val_loss: 1.0098 - val_accuracy: 0.6350
#
# Epoch 00022: saving model to sloan_dense/model-00022-1.60-0.5088-1.01-0.6350.h5
# Epoch 23/40
# 25/25 [==============================] - 11s 393ms/step - loss: 1.5963 - accuracy: 0.5138 - val_loss: 0.9910 - val_accuracy: 0.6450
#
# Epoch 00023: saving model to sloan_dense/model-00023-1.60-0.5138-0.99-0.6450.h5
# Epoch 24/40
# 25/25 [==============================] - 11s 395ms/step - loss: 1.5975 - accuracy: 0.5138 - val_loss: 0.9907 - val_accuracy: 0.6550
#
# Epoch 00024: saving model to sloan_dense/model-00024-1.60-0.5138-0.99-0.6550.h5
# Epoch 25/40
# 25/25 [==============================] - 11s 395ms/step - loss: 1.5977 - accuracy: 0.4575 - val_loss: 0.9942 - val_accuracy: 0.6450
#
# Epoch 00025: saving model to sloan_dense/model-00025-1.60-0.4575-0.99-0.6450.h5
# Epoch 26/40
# 25/25 [==============================] - 11s 394ms/step - loss: 1.5972 - accuracy: 0.5075 - val_loss: 1.0073 - val_accuracy: 0.6450
#
# Epoch 00026: saving model to sloan_dense/model-00026-1.60-0.5075-1.01-0.6450.h5
# Epoch 27/40
# 25/25 [==============================] - 11s 393ms/step - loss: 1.5955 - accuracy: 0.5138 - val_loss: 0.9964 - val_accuracy: 0.6450
#
# Epoch 00027: saving model to sloan_dense/model-00027-1.60-0.5138-1.00-0.6450.h5
# Epoch 28/40
# 25/25 [==============================] - 12s 396ms/step - loss: 1.5983 - accuracy: 0.5125 - val_loss: 1.0080 - val_accuracy: 0.6400
#
# Epoch 00028: saving model to sloan_dense/model-00028-1.60-0.5125-1.01-0.6400.h5
# Epoch 29/40
# 25/25 [==============================] - 11s 395ms/step - loss: 1.6002 - accuracy: 0.5138 - val_loss: 0.9958 - val_accuracy: 0.6450
#
# Epoch 00029: saving model to sloan_dense/model-00029-1.60-0.5138-1.00-0.6450.h5
# Epoch 30/40
# 25/25 [==============================] - 11s 395ms/step - loss: 1.5976 - accuracy: 0.5125 - val_loss: 0.9885 - val_accuracy: 0.6550
#
# Epoch 00030: saving model to sloan_dense/model-00030-1.60-0.5125-0.99-0.6550.h5
# Epoch 31/40
# 25/25 [==============================] - 11s 393ms/step - loss: 1.5958 - accuracy: 0.4675 - val_loss: 1.0191 - val_accuracy: 0.6350
#
# Epoch 00031: saving model to sloan_dense/model-00031-1.60-0.4675-1.02-0.6350.h5
# Epoch 32/40
# 25/25 [==============================] - 12s 398ms/step - loss: 1.5958 - accuracy: 0.5138 - val_loss: 1.0038 - val_accuracy: 0.6450
#
# Epoch 00032: saving model to sloan_dense/model-00032-1.60-0.5138-1.00-0.6450.h5
# Epoch 33/40
# 25/25 [==============================] - 11s 394ms/step - loss: 1.5973 - accuracy: 0.4575 - val_loss: 0.9574 - val_accuracy: 0.6550
#
# Epoch 00033: saving model to sloan_dense/model-00033-1.60-0.4575-0.96-0.6550.h5
# Epoch 34/40
# 25/25 [==============================] - 12s 399ms/step - loss: 1.5957 - accuracy: 0.5088 - val_loss: 1.0046 - val_accuracy: 0.6450
#
# Epoch 00034: saving model to sloan_dense/model-00034-1.60-0.5088-1.00-0.6450.h5
# Epoch 35/40
# 25/25 [==============================] - 11s 396ms/step - loss: 1.5947 - accuracy: 0.5038 - val_loss: 0.9939 - val_accuracy: 0.6500
#
# Epoch 00035: saving model to sloan_dense/model-00035-1.59-0.5038-0.99-0.6500.h5
# Epoch 36/40
# 25/25 [==============================] - 12s 396ms/step - loss: 1.5940 - accuracy: 0.4825 - val_loss: 0.9964 - val_accuracy: 0.6500
#
# Epoch 00036: saving model to sloan_dense/model-00036-1.59-0.4825-1.00-0.6500.h5
# Epoch 37/40
# 25/25 [==============================] - 11s 395ms/step - loss: 1.5987 - accuracy: 0.5125 - val_loss: 1.0249 - val_accuracy: 0.6350
#
# Epoch 00037: saving model to sloan_dense/model-00037-1.60-0.5125-1.02-0.6350.h5
# Epoch 38/40
# 25/25 [==============================] - 11s 394ms/step - loss: 1.5990 - accuracy: 0.4588 - val_loss: 1.0011 - val_accuracy: 0.6450
#
# Epoch 00038: saving model to sloan_dense/model-00038-1.60-0.4588-1.00-0.6450.h5
# Epoch 39/40
# 25/25 [==============================] - 11s 395ms/step - loss: 1.5952 - accuracy: 0.4475 - val_loss: 0.9955 - val_accuracy: 0.6500
#
# Epoch 00039: saving model to sloan_dense/model-00039-1.60-0.4475-1.00-0.6500.h5
# Epoch 40/40
# 25/25 [==============================] - 11s 393ms/step - loss: 1.5965 - accuracy: 0.5138 - val_loss: 0.9774 - val_accuracy: 0.6550
#
# Epoch 00040: saving model to sloan_dense/model-00040-1.60-0.5138-0.98-0.6550.h5

# %%
dense_scaled_crop_flipped_model = load_model('./sloan_dense/densenet_scaled_flip_crop-1.60-0.5138-0.98-0.6550.h5') 
metrics = Metrics(dense_scaled_crop_flipped_model,val_ds_scaled)
print(metrics.calculate_scores())
print('---------------------------------------------------------------------------------------------------------------------')
# Out:
# calculating score.....
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fc55deacb90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [[51 17 28]
#  [ 0 11  6]
#  [ 0 18 69]]
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.53      0.69        96
#          1.0       0.24      0.65      0.35        17
#          2.0       0.67      0.79      0.73        87
#
#     accuracy                           0.66       200
#    macro avg       0.64      0.66      0.59       200
# weighted avg       0.79      0.66      0.68       200
#
# None
# ---------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ##### dense_scaled_crop_flip_rotate

# %%
dense_scaled_crop_flip_rotate.fit(train_ds_scaled_crop_flip_rotate,validation_data=val_ds_scaled,epochs = 40, verbose = 1, workers = 3, class_weight = {0:1.13, 1:8.03, 2:1}, callbacks = callbacks_dense)
# Out:
# Epoch 1/40
# 25/25 [==============================] - 21s 638ms/step - loss: 1.9936 - accuracy: 0.4425 - val_loss: 0.9835 - val_accuracy: 0.6550
#
# Epoch 00001: saving model to sloan_dense/model-00001-1.99-0.4425-0.98-0.6550.h5
# Epoch 2/40
# 25/25 [==============================] - 17s 570ms/step - loss: 1.6162 - accuracy: 0.4837 - val_loss: 1.0806 - val_accuracy: 0.6200
#
# Epoch 00002: saving model to sloan_dense/model-00002-1.62-0.4837-1.08-0.6200.h5
# Epoch 3/40
# 25/25 [==============================] - 17s 576ms/step - loss: 1.6037 - accuracy: 0.5125 - val_loss: 0.9867 - val_accuracy: 0.6500
#
# Epoch 00003: saving model to sloan_dense/model-00003-1.60-0.5125-0.99-0.6500.h5
# Epoch 4/40
# 25/25 [==============================] - 17s 575ms/step - loss: 1.5959 - accuracy: 0.5138 - val_loss: 0.9908 - val_accuracy: 0.6500
#
# Epoch 00004: saving model to sloan_dense/model-00004-1.60-0.5138-0.99-0.6500.h5
# Epoch 5/40
# 25/25 [==============================] - 17s 581ms/step - loss: 1.5947 - accuracy: 0.5138 - val_loss: 1.0133 - val_accuracy: 0.6350
#
# Epoch 00005: saving model to sloan_dense/model-00005-1.59-0.5138-1.01-0.6350.h5
# Epoch 6/40
# 25/25 [==============================] - 17s 578ms/step - loss: 1.5970 - accuracy: 0.4500 - val_loss: 0.9910 - val_accuracy: 0.6450
#
# Epoch 00006: saving model to sloan_dense/model-00006-1.60-0.4500-0.99-0.6450.h5
# Epoch 7/40
# 25/25 [==============================] - 17s 579ms/step - loss: 1.5942 - accuracy: 0.5138 - val_loss: 1.0032 - val_accuracy: 0.6450
#
# Epoch 00007: saving model to sloan_dense/model-00007-1.59-0.5138-1.00-0.6450.h5
# Epoch 8/40
# 25/25 [==============================] - 17s 581ms/step - loss: 1.5961 - accuracy: 0.5138 - val_loss: 0.9787 - val_accuracy: 0.6550
#
# Epoch 00008: saving model to sloan_dense/model-00008-1.60-0.5138-0.98-0.6550.h5
# Epoch 9/40
# 25/25 [==============================] - 17s 570ms/step - loss: 1.5975 - accuracy: 0.4487 - val_loss: 1.0008 - val_accuracy: 0.6450
#
# Epoch 00009: saving model to sloan_dense/model-00009-1.60-0.4487-1.00-0.6450.h5
# Epoch 10/40
# 25/25 [==============================] - 17s 579ms/step - loss: 1.5957 - accuracy: 0.5138 - val_loss: 0.9941 - val_accuracy: 0.6500
#
# Epoch 00010: saving model to sloan_dense/model-00010-1.60-0.5138-0.99-0.6500.h5
# Epoch 11/40
# 25/25 [==============================] - 17s 582ms/step - loss: 1.5972 - accuracy: 0.4487 - val_loss: 0.9867 - val_accuracy: 0.6550
#
# Epoch 00011: saving model to sloan_dense/model-00011-1.60-0.4487-0.99-0.6550.h5
# Epoch 12/40
# 25/25 [==============================] - 17s 573ms/step - loss: 1.5941 - accuracy: 0.5238 - val_loss: 0.9950 - val_accuracy: 0.6450
#
# Epoch 00012: saving model to sloan_dense/model-00012-1.59-0.5238-1.00-0.6450.h5
# Epoch 13/40
# 25/25 [==============================] - 17s 565ms/step - loss: 1.5956 - accuracy: 0.5138 - val_loss: 1.0215 - val_accuracy: 0.6350
#
# Epoch 00013: saving model to sloan_dense/model-00013-1.60-0.5138-1.02-0.6350.h5
# Epoch 14/40
# 25/25 [==============================] - 17s 572ms/step - loss: 1.5981 - accuracy: 0.5100 - val_loss: 0.9822 - val_accuracy: 0.6500
#
# Epoch 00014: saving model to sloan_dense/model-00014-1.60-0.5100-0.98-0.6500.h5
# Epoch 15/40
# 25/25 [==============================] - 17s 564ms/step - loss: 1.5933 - accuracy: 0.5113 - val_loss: 1.0151 - val_accuracy: 0.6300
#
# Epoch 00015: saving model to sloan_dense/model-00015-1.59-0.5113-1.02-0.6300.h5
# Epoch 16/40
# 25/25 [==============================] - 17s 564ms/step - loss: 1.5961 - accuracy: 0.5138 - val_loss: 0.9929 - val_accuracy: 0.6450
#
# Epoch 00016: saving model to sloan_dense/model-00016-1.60-0.5138-0.99-0.6450.h5
# Epoch 17/40
# 25/25 [==============================] - 16s 561ms/step - loss: 1.5955 - accuracy: 0.4725 - val_loss: 1.0038 - val_accuracy: 0.6450
#
# Epoch 00017: saving model to sloan_dense/model-00017-1.60-0.4725-1.00-0.6450.h5
# Epoch 18/40
# 25/25 [==============================] - 17s 591ms/step - loss: 1.6018 - accuracy: 0.5138 - val_loss: 0.9832 - val_accuracy: 0.6550
#
# Epoch 00018: saving model to sloan_dense/model-00018-1.60-0.5138-0.98-0.6550.h5
# Epoch 19/40
# 25/25 [==============================] - 17s 573ms/step - loss: 1.5984 - accuracy: 0.5138 - val_loss: 1.0322 - val_accuracy: 0.6250
#
# Epoch 00019: saving model to sloan_dense/model-00019-1.60-0.5138-1.03-0.6250.h5
# Epoch 20/40
# 25/25 [==============================] - 17s 589ms/step - loss: 1.5979 - accuracy: 0.4525 - val_loss: 0.9952 - val_accuracy: 0.6500
#
# Epoch 00020: saving model to sloan_dense/model-00020-1.60-0.4525-1.00-0.6500.h5
# Epoch 21/40
# 25/25 [==============================] - 17s 570ms/step - loss: 1.5950 - accuracy: 0.5138 - val_loss: 1.0105 - val_accuracy: 0.6350
#
# Epoch 00021: saving model to sloan_dense/model-00021-1.60-0.5138-1.01-0.6350.h5
# Epoch 22/40
# 25/25 [==============================] - 17s 567ms/step - loss: 1.5974 - accuracy: 0.5025 - val_loss: 1.0003 - val_accuracy: 0.6450
#
# Epoch 00022: saving model to sloan_dense/model-00022-1.60-0.5025-1.00-0.6450.h5
# Epoch 23/40
# 25/25 [==============================] - 17s 587ms/step - loss: 1.5960 - accuracy: 0.5138 - val_loss: 1.0095 - val_accuracy: 0.6450
#
# Epoch 00023: saving model to sloan_dense/model-00023-1.60-0.5138-1.01-0.6450.h5
# Epoch 24/40
# 25/25 [==============================] - 17s 568ms/step - loss: 1.5951 - accuracy: 0.4600 - val_loss: 0.9941 - val_accuracy: 0.6500
#
# Epoch 00024: saving model to sloan_dense/model-00024-1.60-0.4600-0.99-0.6500.h5
# Epoch 25/40
# 25/25 [==============================] - 17s 571ms/step - loss: 1.5943 - accuracy: 0.5138 - val_loss: 0.9923 - val_accuracy: 0.6450
#
# Epoch 00025: saving model to sloan_dense/model-00025-1.59-0.5138-0.99-0.6450.h5
# Epoch 26/40
# 25/25 [==============================] - 17s 577ms/step - loss: 1.5969 - accuracy: 0.5113 - val_loss: 1.0007 - val_accuracy: 0.6450
#
# Epoch 00026: saving model to sloan_dense/model-00026-1.60-0.5113-1.00-0.6450.h5
# Epoch 27/40
# 25/25 [==============================] - 17s 576ms/step - loss: 1.5949 - accuracy: 0.5138 - val_loss: 1.0109 - val_accuracy: 0.6350
#
# Epoch 00027: saving model to sloan_dense/model-00027-1.59-0.5138-1.01-0.6350.h5
# Epoch 28/40
# 25/25 [==============================] - 17s 579ms/step - loss: 1.5966 - accuracy: 0.4588 - val_loss: 1.0103 - val_accuracy: 0.6350
#
# Epoch 00028: saving model to sloan_dense/model-00028-1.60-0.4588-1.01-0.6350.h5
# Epoch 29/40
# 25/25 [==============================] - 17s 570ms/step - loss: 1.5941 - accuracy: 0.5138 - val_loss: 1.0119 - val_accuracy: 0.6350
#
# Epoch 00029: saving model to sloan_dense/model-00029-1.59-0.5138-1.01-0.6350.h5
# Epoch 30/40
# 25/25 [==============================] - 17s 567ms/step - loss: 1.5949 - accuracy: 0.5088 - val_loss: 0.9897 - val_accuracy: 0.6500
#
# Epoch 00030: saving model to sloan_dense/model-00030-1.59-0.5088-0.99-0.6500.h5
# Epoch 31/40
# 25/25 [==============================] - 17s 575ms/step - loss: 1.5974 - accuracy: 0.3900 - val_loss: 1.0084 - val_accuracy: 0.6450
#
# Epoch 00031: saving model to sloan_dense/model-00031-1.60-0.3900-1.01-0.6450.h5
# Epoch 32/40
# 25/25 [==============================] - 17s 581ms/step - loss: 1.5957 - accuracy: 0.5138 - val_loss: 0.9969 - val_accuracy: 0.6450
#
# Epoch 00032: saving model to sloan_dense/model-00032-1.60-0.5138-1.00-0.6450.h5
# Epoch 33/40
# 25/25 [==============================] - 17s 587ms/step - loss: 1.5942 - accuracy: 0.5138 - val_loss: 1.0095 - val_accuracy: 0.6350
#
# Epoch 00033: saving model to sloan_dense/model-00033-1.59-0.5138-1.01-0.6350.h5
# Epoch 34/40
# 25/25 [==============================] - 17s 582ms/step - loss: 1.5949 - accuracy: 0.5113 - val_loss: 0.9938 - val_accuracy: 0.6450
#
# Epoch 00034: saving model to sloan_dense/model-00034-1.59-0.5113-0.99-0.6450.h5
# Epoch 35/40
# 25/25 [==============================] - 17s 576ms/step - loss: 1.5987 - accuracy: 0.4512 - val_loss: 0.9724 - val_accuracy: 0.6550
#
# Epoch 00035: saving model to sloan_dense/model-00035-1.60-0.4512-0.97-0.6550.h5
# Epoch 36/40
# 25/25 [==============================] - 17s 583ms/step - loss: 1.5965 - accuracy: 0.4137 - val_loss: 1.0297 - val_accuracy: 0.6200
#
# Epoch 00036: saving model to sloan_dense/model-00036-1.60-0.4137-1.03-0.6200.h5
# Epoch 37/40
# 25/25 [==============================] - 17s 569ms/step - loss: 1.5960 - accuracy: 0.5138 - val_loss: 0.9853 - val_accuracy: 0.6550
#
# Epoch 00037: saving model to sloan_dense/model-00037-1.60-0.5138-0.99-0.6550.h5
# Epoch 38/40
# 25/25 [==============================] - 17s 559ms/step - loss: 1.6051 - accuracy: 0.2912 - val_loss: 0.9865 - val_accuracy: 0.6500
#
# Epoch 00038: saving model to sloan_dense/model-00038-1.61-0.2912-0.99-0.6500.h5
# Epoch 39/40
# 25/25 [==============================] - 17s 578ms/step - loss: 1.5945 - accuracy: 0.5125 - val_loss: 0.9885 - val_accuracy: 0.6550
#
# Epoch 00039: saving model to sloan_dense/model-00039-1.59-0.5125-0.99-0.6550.h5
# Epoch 40/40
# 25/25 [==============================] - 17s 574ms/step - loss: 1.5950 - accuracy: 0.5138 - val_loss: 0.9888 - val_accuracy: 0.6550
#
# Epoch 00040: saving model to sloan_dense/model-00040-1.60-0.5138-0.99-0.6550.h5

# %%
dense_scaled_crop_flipped_rotate_model = load_model('./sloan_dense/densenet_scaled_flip_crop_rotate-1.60-0.5138-0.98-0.6550.h5') 
metrics = Metrics(dense_scaled_crop_flipped_rotate_model,val_ds_scaled)
print(metrics.calculate_scores())
print('---------------------------------------------------------------------------------------------------------------------')
# Out:
# calculating score.....
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fc7be370320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [[51 17 28]
#  [ 0 11  6]
#  [ 0 18 69]]
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.53      0.69        96
#          1.0       0.24      0.65      0.35        17
#          2.0       0.67      0.79      0.73        87
#
#     accuracy                           0.66       200
#    macro avg       0.64      0.66      0.59       200
# weighted avg       0.79      0.66      0.68       200
#
# None
# ---------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ##### Densenetpreprocess crop

# %%
densenet_model.fit(train_ds_normal_crop,validation_data=val_ds_normal_crop, epochs=40, verbose = 1, workers = 3, class_weight = {0:1.13, 1:8.03, 2:1}, callbacks = callbacks_dense)
# Out:
# Epoch 1/40
# 25/25 [==============================] - 16s 411ms/step - loss: 1.6607 - accuracy: 0.2000 - val_loss: 1.0416 - val_accuracy: 0.4350
#
# Epoch 00001: saving model to sloan_dense/model-00001-1.66-0.2000-1.04-0.4350.h5
# Epoch 2/40
# 25/25 [==============================] - 10s 355ms/step - loss: 1.5980 - accuracy: 0.4412 - val_loss: 1.0728 - val_accuracy: 0.4250
#
# Epoch 00002: saving model to sloan_dense/model-00002-1.60-0.4412-1.07-0.4250.h5
# Epoch 3/40
# 25/25 [==============================] - 10s 357ms/step - loss: 1.5948 - accuracy: 0.5150 - val_loss: 1.0854 - val_accuracy: 0.4350
#
# Epoch 00003: saving model to sloan_dense/model-00003-1.59-0.5150-1.09-0.4350.h5
# Epoch 4/40
# 25/25 [==============================] - 10s 354ms/step - loss: 1.5964 - accuracy: 0.4338 - val_loss: 1.0856 - val_accuracy: 0.4300
#
# Epoch 00004: saving model to sloan_dense/model-00004-1.60-0.4338-1.09-0.4300.h5
# Epoch 5/40
# 25/25 [==============================] - 10s 356ms/step - loss: 1.5991 - accuracy: 0.5138 - val_loss: 1.0826 - val_accuracy: 0.4350
#
# Epoch 00005: saving model to sloan_dense/model-00005-1.60-0.5138-1.08-0.4350.h5
# Epoch 6/40
# 25/25 [==============================] - 10s 353ms/step - loss: 1.5994 - accuracy: 0.4750 - val_loss: 1.0772 - val_accuracy: 0.4350
#
# Epoch 00006: saving model to sloan_dense/model-00006-1.60-0.4750-1.08-0.4350.h5
# Epoch 7/40
# 25/25 [==============================] - 10s 356ms/step - loss: 1.5973 - accuracy: 0.4500 - val_loss: 1.0673 - val_accuracy: 0.4350
#
# Epoch 00007: saving model to sloan_dense/model-00007-1.60-0.4500-1.07-0.4350.h5
# Epoch 8/40
# 25/25 [==============================] - 10s 356ms/step - loss: 1.6009 - accuracy: 0.5025 - val_loss: 1.0741 - val_accuracy: 0.4350
#
# Epoch 00008: saving model to sloan_dense/model-00008-1.60-0.5025-1.07-0.4350.h5
# Epoch 9/40
# 25/25 [==============================] - 10s 356ms/step - loss: 1.5954 - accuracy: 0.5125 - val_loss: 1.1030 - val_accuracy: 0.4350
#
# Epoch 00009: saving model to sloan_dense/model-00009-1.60-0.5125-1.10-0.4350.h5
# Epoch 10/40
# 25/25 [==============================] - 10s 359ms/step - loss: 1.5998 - accuracy: 0.5075 - val_loss: 1.0857 - val_accuracy: 0.4350
#
# Epoch 00010: saving model to sloan_dense/model-00010-1.60-0.5075-1.09-0.4350.h5
# Epoch 11/40
# 25/25 [==============================] - 10s 358ms/step - loss: 1.5952 - accuracy: 0.5088 - val_loss: 1.0788 - val_accuracy: 0.4350
#
# Epoch 00011: saving model to sloan_dense/model-00011-1.60-0.5088-1.08-0.4350.h5
# Epoch 12/40
# 25/25 [==============================] - 10s 358ms/step - loss: 1.5960 - accuracy: 0.5138 - val_loss: 1.0834 - val_accuracy: 0.4250
#
# Epoch 00012: saving model to sloan_dense/model-00012-1.60-0.5138-1.08-0.4250.h5
# Epoch 13/40
# 25/25 [==============================] - 10s 352ms/step - loss: 1.5963 - accuracy: 0.4900 - val_loss: 1.0734 - val_accuracy: 0.4350
#
# Epoch 00013: saving model to sloan_dense/model-00013-1.60-0.4900-1.07-0.4350.h5
# Epoch 14/40
# 25/25 [==============================] - 10s 352ms/step - loss: 1.5987 - accuracy: 0.4475 - val_loss: 1.0610 - val_accuracy: 0.4350
#
# Epoch 00014: saving model to sloan_dense/model-00014-1.60-0.4475-1.06-0.4350.h5
# Epoch 15/40
# 25/25 [==============================] - 10s 354ms/step - loss: 1.5958 - accuracy: 0.4762 - val_loss: 1.0958 - val_accuracy: 0.4300
#
# Epoch 00015: saving model to sloan_dense/model-00015-1.60-0.4762-1.10-0.4300.h5
# Epoch 16/40
# 25/25 [==============================] - 10s 355ms/step - loss: 1.5987 - accuracy: 0.5138 - val_loss: 1.0656 - val_accuracy: 0.4350
#
# Epoch 00016: saving model to sloan_dense/model-00016-1.60-0.5138-1.07-0.4350.h5
# Epoch 17/40
# 25/25 [==============================] - 10s 357ms/step - loss: 1.5969 - accuracy: 0.4550 - val_loss: 1.1008 - val_accuracy: 0.4350
#
# Epoch 00017: saving model to sloan_dense/model-00017-1.60-0.4550-1.10-0.4350.h5
# Epoch 18/40
# 25/25 [==============================] - 10s 357ms/step - loss: 1.5993 - accuracy: 0.4150 - val_loss: 1.0943 - val_accuracy: 0.4350
#
# Epoch 00018: saving model to sloan_dense/model-00018-1.60-0.4150-1.09-0.4350.h5
# Epoch 19/40
# 25/25 [==============================] - 10s 358ms/step - loss: 1.5971 - accuracy: 0.5138 - val_loss: 1.0669 - val_accuracy: 0.4350
#
# Epoch 00019: saving model to sloan_dense/model-00019-1.60-0.5138-1.07-0.4350.h5
# Epoch 20/40
# 25/25 [==============================] - 10s 357ms/step - loss: 1.5945 - accuracy: 0.5125 - val_loss: 1.0815 - val_accuracy: 0.4350
#
# Epoch 00020: saving model to sloan_dense/model-00020-1.59-0.5125-1.08-0.4350.h5
# Epoch 21/40
# 25/25 [==============================] - 10s 356ms/step - loss: 1.5950 - accuracy: 0.5138 - val_loss: 1.0834 - val_accuracy: 0.4350
#
# Epoch 00021: saving model to sloan_dense/model-00021-1.59-0.5138-1.08-0.4350.h5
# Epoch 22/40
# 25/25 [==============================] - 10s 358ms/step - loss: 1.5962 - accuracy: 0.4525 - val_loss: 1.0606 - val_accuracy: 0.4350
#
# Epoch 00022: saving model to sloan_dense/model-00022-1.60-0.4525-1.06-0.4350.h5
# Epoch 23/40
# 25/25 [==============================] - 10s 358ms/step - loss: 1.5949 - accuracy: 0.5138 - val_loss: 1.0863 - val_accuracy: 0.4350
#
# Epoch 00023: saving model to sloan_dense/model-00023-1.59-0.5138-1.09-0.4350.h5
# Epoch 24/40
# 25/25 [==============================] - 10s 354ms/step - loss: 1.5991 - accuracy: 0.5050 - val_loss: 1.0678 - val_accuracy: 0.4350
#
# Epoch 00024: saving model to sloan_dense/model-00024-1.60-0.5050-1.07-0.4350.h5
# Epoch 25/40
# 25/25 [==============================] - 10s 353ms/step - loss: 1.5979 - accuracy: 0.4925 - val_loss: 1.0752 - val_accuracy: 0.4350
#
# Epoch 00025: saving model to sloan_dense/model-00025-1.60-0.4925-1.08-0.4350.h5
# Epoch 26/40
# 25/25 [==============================] - 10s 354ms/step - loss: 1.6028 - accuracy: 0.4750 - val_loss: 1.0634 - val_accuracy: 0.4350
#
# Epoch 00026: saving model to sloan_dense/model-00026-1.60-0.4750-1.06-0.4350.h5
# Epoch 27/40
# 25/25 [==============================] - 10s 356ms/step - loss: 1.5953 - accuracy: 0.5088 - val_loss: 1.0814 - val_accuracy: 0.4350
#
# Epoch 00027: saving model to sloan_dense/model-00027-1.60-0.5088-1.08-0.4350.h5
# Epoch 28/40
# 25/25 [==============================] - 10s 357ms/step - loss: 1.5976 - accuracy: 0.4363 - val_loss: 1.0898 - val_accuracy: 0.4350
#
# Epoch 00028: saving model to sloan_dense/model-00028-1.60-0.4363-1.09-0.4350.h5
# Epoch 29/40
# 25/25 [==============================] - 10s 350ms/step - loss: 1.5979 - accuracy: 0.5138 - val_loss: 1.0855 - val_accuracy: 0.4350
#
# Epoch 00029: saving model to sloan_dense/model-00029-1.60-0.5138-1.09-0.4350.h5
# Epoch 30/40
# 25/25 [==============================] - 10s 356ms/step - loss: 1.6015 - accuracy: 0.4650 - val_loss: 1.0583 - val_accuracy: 0.4250
#
# Epoch 00030: saving model to sloan_dense/model-00030-1.60-0.4650-1.06-0.4250.h5
# Epoch 31/40
# 25/25 [==============================] - 10s 353ms/step - loss: 1.5958 - accuracy: 0.5138 - val_loss: 1.1001 - val_accuracy: 0.4350
#
# Epoch 00031: saving model to sloan_dense/model-00031-1.60-0.5138-1.10-0.4350.h5
# Epoch 32/40
# 25/25 [==============================] - 10s 359ms/step - loss: 1.5988 - accuracy: 0.4137 - val_loss: 1.0692 - val_accuracy: 0.4350
#
# Epoch 00032: saving model to sloan_dense/model-00032-1.60-0.4137-1.07-0.4350.h5
# Epoch 33/40
# 25/25 [==============================] - 10s 356ms/step - loss: 1.5955 - accuracy: 0.5138 - val_loss: 1.0708 - val_accuracy: 0.4350
#
# Epoch 00033: saving model to sloan_dense/model-00033-1.60-0.5138-1.07-0.4350.h5
# Epoch 34/40
# 25/25 [==============================] - 10s 356ms/step - loss: 1.5947 - accuracy: 0.4925 - val_loss: 1.0889 - val_accuracy: 0.4350
#
# Epoch 00034: saving model to sloan_dense/model-00034-1.59-0.4925-1.09-0.4350.h5
# Epoch 35/40
# 25/25 [==============================] - 10s 355ms/step - loss: 1.5989 - accuracy: 0.5138 - val_loss: 1.0803 - val_accuracy: 0.4350
#
# Epoch 00035: saving model to sloan_dense/model-00035-1.60-0.5138-1.08-0.4350.h5
# Epoch 36/40
# 25/25 [==============================] - 10s 355ms/step - loss: 1.5974 - accuracy: 0.3487 - val_loss: 1.0883 - val_accuracy: 0.4350
#
# Epoch 00036: saving model to sloan_dense/model-00036-1.60-0.3487-1.09-0.4350.h5
# Epoch 37/40
# 25/25 [==============================] - 10s 357ms/step - loss: 1.5961 - accuracy: 0.4500 - val_loss: 1.0736 - val_accuracy: 0.4350
#
# Epoch 00037: saving model to sloan_dense/model-00037-1.60-0.4500-1.07-0.4350.h5
# Epoch 38/40
# 25/25 [==============================] - 10s 357ms/step - loss: 1.5980 - accuracy: 0.5138 - val_loss: 1.0734 - val_accuracy: 0.4350
#
# Epoch 00038: saving model to sloan_dense/model-00038-1.60-0.5138-1.07-0.4350.h5
# Epoch 39/40
# 25/25 [==============================] - 10s 360ms/step - loss: 1.5965 - accuracy: 0.5138 - val_loss: 1.0891 - val_accuracy: 0.4350
#
# Epoch 00039: saving model to sloan_dense/model-00039-1.60-0.5138-1.09-0.4350.h5
# Epoch 40/40
# 25/25 [==============================] - 10s 353ms/step - loss: 1.5970 - accuracy: 0.5113 - val_loss: 1.0627 - val_accuracy: 0.4350
#
# Epoch 00040: saving model to sloan_dense/model-00040-1.60-0.5113-1.06-0.4350.h5

# %%
dense_scaled_crop_flipped_rotate_model = load_model('./sloan_dense/dense_preprocess_scale_crop-1.60-0.5113-1.06-0.4350.h5') 
metrics = Metrics(dense_scaled_crop_flipped_rotate_model,val_ds_scaled)
print(metrics.calculate_scores())
print('---------------------------------------------------------------------------------------------------------------------')
# Out:
# calculating score.....
# [[95  0  1]
#  [15  1  1]
#  [77  2  8]]
# ------------------------------------
#               precision    recall  f1-score   support
#
#          0.0       0.51      0.99      0.67        96
#          1.0       0.33      0.06      0.10        17
#          2.0       0.80      0.09      0.16        87
#
#     accuracy                           0.52       200
#    macro avg       0.55      0.38      0.31       200
# weighted avg       0.62      0.52      0.40       200
#
# None
# ---------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ##### Best CNN network custom

# %%
def baseline_model(aug = False):
    model = Sequential()
    model.add(layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)))
    if aug == True:
        model.add(layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"))
    model.add(Conv2D(32, kernel_size = (3,3), padding = 'same', activation  = 'relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size = (2,2)))
    
    model.add(Conv2D(64, kernel_size = (3,3), padding = 'same', activation  = 'relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size = (2,2)))
    
    model.add(Conv2D(128, kernel_size = (3,3), padding = 'same', activation  = 'relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size = (2,2)))
    
    model.add(Conv2D(256, kernel_size = (3,3), padding = 'same', activation  = 'relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size = (2,2)))
    
    model.add(Flatten())

    model.add(Dense(512, activation = 'relu'))
    model.add(Dropout(0.75))
    # Final layer
    model.add(Dense(num_classes, activation = 'softmax'))
    return model
    
model5 = baseline_model()
model5_aug = baseline_model(aug=True)
optimizer = optimizers.SGD(lr = 1e-4)
model5.compile(loss = 'categorical_crossentropy', optimizer = optimizer, metrics = ['accuracy'])
model5_aug.compile(loss = 'categorical_crossentropy', optimizer = optimizer, metrics = ['accuracy'])
model5.summary()
model5_aug.summary()
